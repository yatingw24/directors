# %% [markdown]
# # Set up data

# %% [markdown]
# ## Import libraries: Beautiful soup, requests, and re (For regular expressions)

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Getting Data From BBC Lists

# %% [markdown]
# ## THE FIRST LIST - scraping the list of 100 greatest films directed by women

# %%
bbc_url = "https://www.bbc.com/culture/article/20191125-the-100-greatest-films-directed-by-women-poll"

# %%
response = requests.get(bbc_url, headers={'User-Agent': 'Mozilla/5.0'})
bbc_html = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ### 1. find all movie titles and directors and put them into a list of dictionaries - title, director, and year

# %%
movie_paragraphs = bbc_html.find_all('p', class_='sc-9a00e533-0 hxuGS')

movie_data = []

for movie in movie_paragraphs:
    text = movie.get_text(strip=True)
    match = re.match(r'(\d+)\.\s*(.*?)\s*\((.*?),\s*(\d{4})\)', text)
    
    if match:
        title = match.group(2).strip()
        director = match.group(3).strip()
        year = match.group(4)
        title = ' '.join(title.split())
        
        movie_data.append({
            'title': title,
            'director': director,
            'year': year
        })

# %% [markdown]
# ### 2. merge each film's webpage from boxmojo

# %% [markdown]
# #### write the function of getting imdb link

# %%
def get_mojo_link(title, year):
    base_url = "https://www.boxofficemojo.com"
    search_query = title.replace(' ', '+')
    search_url = f"{base_url}/search/?q={search_query}"
    
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(search_url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        result = soup.find('a', class_='a-size-medium a-link-normal a-text-bold')
        
        if result:
            return base_url + result['href'].split('?')[0] 
        return None
    except Exception as e:
        print(f"Error searching for {title}: {e}")
        return None

# %% [markdown]
# #### create a loop to print each movie's link

# %%
for movie in movie_data:
    movie['mojolink'] = get_mojo_link(movie['title'], movie['year'])

# %%
# checkpoint - if everything is loaded correctly
movie_data
# Out:
# [{'title': 'The Kids are All Right',
#   'director': 'Lisa Cholodenko',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0842926/'},
#  {'title': 'The Souvenir',
#   'director': 'Joanna Hogg',
#   'year': '2019',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt6920356/'},
#  {'title': 'Somewhere',
#   'director': 'Sofia Coppola',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1421051/'},
#  {'title': 'Adoption',
#   'director': 'Márta Mészáros',
#   'year': '1975',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt8555446/'},
#  {'title': 'The Meetings of Anna',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0078152/'},
#  {'title': 'Ritual in Transfigured Time',
#   'director': 'Maya Deren',
#   'year': '1946',
#   'mojolink': None},
#  {'title': 'News From Home',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0097332/'},
#  {'title': 'Red Road',
#   'director': 'Andrea Arnold',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0471030/'},
#  {'title': 'Raw',
#   'director': 'Julia Ducournau',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt4954522/'},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1135952/'},
#  {'title': 'Fast Times at Ridgemont High',
#   'director': 'Amy Heckerling',
#   'year': '1982',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0083929/'},
#  {'title': 'The Beaches of Agnes',
#   'director': 'Agnès Varda',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1129435/'},
#  {'title': 'The Silences of the Palace',
#   'director': 'Moufida Tlatli',
#   'year': '1994',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt14549270/'},
#  {'title': '35 Shots of Rum',
#   'director': 'Claire Denis',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1100048/'},
#  {'title': 'Wadjda',
#   'director': 'Haifaa Al-Mansour',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2258858/'},
#  {'title': 'One Sings, The Other Doesn’t',
#   'director': 'Agnès Varda',
#   'year': '1977',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0076855/'},
#  {'title': 'Portrait of Jason',
#   'director': 'Shirley Clarke',
#   'year': '1967',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt8613070/'},
#  {'title': 'Sleepless in Seattle',
#   'director': 'Nora Ephron',
#   'year': '1993',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0108160/'},
#  {'title': 'At Land',
#   'director': 'Maya Deren',
#   'year': '1944',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1918921/'},
#  {'title': 'A Girl Walks Home Alone at Night',
#   'director': 'Ana Lily Amirpour',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2326554/'},
#  {'title': 'Big',
#   'director': 'Penny Marshall',
#   'year': '1988',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0094737/'},
#  {'title': 'Shoes',
#   'director': 'Lois Weber',
#   'year': '1916',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0419677/'},
#  {'title': 'The Apple',
#   'director': 'Samira Makhmalbaf',
#   'year': '1998',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0080380/'},
#  {'title': 'Tomboy',
#   'director': 'Céline Sciamma',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1847731/'},
#  {'title': 'Girlhood',
#   'director': 'Céline Sciamma',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3655522/'},
#  {'title': 'Meek’s Cutoff',
#   'director': 'Kelly Reichardt',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1518812/'},
#  {'title': 'Chocolat',
#   'director': 'Claire Denis',
#   'year': '1988',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0241303/'},
#  {'title': 'On Body and Soul',
#   'director': 'Ildikó Enyedi',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt5607714/'},
#  {'title': 'Europa Europa',
#   'director': 'Agnieszka Holland',
#   'year': '1980',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0099776/'},
#  {'title': 'The Seashell and the Clergyman',
#   'director': 'Germaine Dulac',
#   'year': '1928',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0060196/'},
#  {'title': 'Whale Rider',
#   'director': 'Niki Caro',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0298228/'},
#  {'title': 'The Connection',
#   'director': 'Shirley Clarke',
#   'year': '1961',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2935564/'},
#  {'title': 'Eve’s Bayou',
#   'director': 'Kasi Lemmons',
#   'year': '1997',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0119080/'},
#  {'title': 'The German Sisters',
#   'director': 'Margarethe von Trotta',
#   'year': '1981',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0452624/'},
#  {'title': 'Ratcatcher',
#   'director': 'Lynne Ramsay',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0171685/'},
#  {'title': 'Leave no Trace',
#   'director': 'Debra Granik',
#   'year': '2018',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3892172/'},
#  {'title': 'The Rider',
#   'director': 'Chloe Zhao',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt6217608/'},
#  {'title': 'Marie Antoinette',
#   'director': 'Sofia Coppola',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt15384074/'},
#  {'title': 'Strange Days',
#   'director': 'Kathryn Bigelow',
#   'year': '1995',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0114558/'},
#  {'title': 'India Song',
#   'director': 'Marguerite Duras',
#   'year': '1975',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0073166/'},
#  {'title': 'A League of their Own',
#   'director': 'Penny Marshall',
#   'year': '1992',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0104694/'},
#  {'title': 'The Long Farewell',
#   'director': 'Kira Muratova',
#   'year': '1971',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0092905/'},
#  {'title': 'Desperately Seeking Susan',
#   'director': 'Susan Seidelman',
#   'year': '1985',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0089017/'},
#  {'title': 'The Babadook',
#   'director': 'Jennifer Kent',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2321549/'},
#  {'title': '13th',
#   'director': 'Ava DuVernay',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt5895028/'},
#  {'title': 'Monster',
#   'director': 'Patty Jenkins',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt23736044/'},
#  {'title': 'Bright Star',
#   'director': 'Jane Campion',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0810784/'},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1221141/'},
#  {'title': 'Happy as Lazzaro',
#   'director': 'Alice Rohrwacher',
#   'year': '2018',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt6752992/'},
#  {'title': 'Harlan County, USA',
#   'director': 'Barbara Kopple',
#   'year': '1976',
#   'mojolink': None},
#  {'title': 'Outrage',
#   'director': 'Ida Lupino',
#   'year': '1950',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1462667/'},
#  {'title': 'Salaam Bombay!',
#   'director': 'Mira Nair',
#   'year': '1988',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0096028/'},
#  {'title': 'The Asthenic Syndrome',
#   'director': 'Kira Muratova',
#   'year': '1989',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0078966/'},
#  {'title': 'An Angel at my Table',
#   'director': 'Jane Campion',
#   'year': '1990',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0099040/'},
#  {'title': 'Near Dark',
#   'director': 'Kathryn Bigelow',
#   'year': '1987',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0093605/'},
#  {'title': 'Triumph of the Will',
#   'director': 'Leni Riefenstahl',
#   'year': '1935',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0098513/'},
#  {'title': 'American Honey',
#   'director': 'Andrea Arnold',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3721936/'},
#  {'title': 'The Virgin Suicides',
#   'director': 'Sofia Coppola',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0159097/'},
#  {'title': 'The Adventures of Prince Achmed',
#   'director': 'Lotte Reiniger',
#   'year': '1926',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0015532/'},
#  {'title': 'Capernaum',
#   'director': 'Nadine Labaki',
#   'year': '2018',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt8267604/'},
#  {'title': 'Boys Don’t Cry',
#   'director': 'Kimberly Peirce',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0171804/'},
#  {'title': 'Portrait of a Lady on Fire',
#   'director': 'Céline Sciamma',
#   'year': '2019',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt8613070/'},
#  {'title': 'Paris is Burning',
#   'director': 'Jennie Livingston',
#   'year': '1990',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0100332/'},
#  {'title': 'Olympia',
#   'director': 'Leni Riefenstahl',
#   'year': '1938',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0457302/'},
#  {'title': 'Wendy and Lucy',
#   'director': 'Kelly Reichardt',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1152850/'},
#  {'title': 'The Matrix',
#   'director': 'Lana and Lilly Wachowski',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0133093/'},
#  {'title': 'Morvern Callar',
#   'director': 'Lynne Ramsay',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0300214/'},
#  {'title': 'You Were Never Really Here',
#   'director': 'Lynne Ramsay',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt5742374/'},
#  {'title': 'The Night Porter',
#   'director': 'Liliana Cavani',
#   'year': '1974',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0054130/'},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0247380/'},
#  {'title': 'Zama',
#   'director': 'Lucrecia Martel',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2386377/'},
#  {'title': 'Monsoon Wedding',
#   'director': 'Mira Nair',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0265343/'},
#  {'title': 'Le Bonheur',
#   'director': 'Agnès Varda',
#   'year': '1965',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1327194/'},
#  {'title': 'Selma',
#   'director': 'Ava DuVernay',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1020072/'},
#  {'title': 'Stories we Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2366450/'},
#  {'title': 'The House is Black',
#   'director': 'Forugh Farrokhzad',
#   'year': '1963',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0093342/'},
#  {'title': 'Lady Bird',
#   'director': 'Greta Gerwig',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt4925292/'},
#  {'title': 'The Hitch-Hiker',
#   'director': 'Ida Lupino',
#   'year': '1953',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0092796/'},
#  {'title': 'We Need to Talk About Kevin',
#   'director': 'Lynne Ramsay',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1242460/'},
#  {'title': 'Winter’s Bone',
#   'director': 'Debra Granik',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1399683/'},
#  {'title': 'Clueless',
#   'director': 'Amy Heckerling',
#   'year': '1995',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0112697/'},
#  {'title': 'Orlando',
#   'director': 'Sally Potter',
#   'year': '1992',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0107756/'},
#  {'title': 'American Psycho',
#   'director': 'Mary Harron',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0144084/'},
#  {'title': 'Seven Beauties',
#   'director': 'Lina Wertmüller',
#   'year': '1975',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0075040/'},
#  {'title': 'Wanda',
#   'director': 'Barbara Loden',
#   'year': '1970',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0067961/'},
#  {'title': 'The Swamp',
#   'director': 'Lucrecia Martel',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0240419/'},
#  {'title': 'Point Break',
#   'director': 'Kathryn Bigelow',
#   'year': '1991',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0102685/'},
#  {'title': 'Vagabond',
#   'director': 'Agnès Varda',
#   'year': '1985',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0050798/'},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1790885/'},
#  {'title': 'The Ascent',
#   'director': 'Larisa Shepitko',
#   'year': '1977',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt7893394/'},
#  {'title': 'Daughters of the Dust',
#   'director': 'Julie Dash',
#   'year': '1991',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0104057/'},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1232776/'},
#  {'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt4048272/'},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0887912/'},
#  {'title': 'Daisies',
#   'director': 'Věra Chytilová',
#   'year': '1966',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0060959/'},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0335266/'},
#  {'title': 'Beau Travail',
#   'director': 'Claire Denis',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0209933/'},
#  {'title': 'Jeanne Dielman, 23 Quai du Commerce, 1080 Bruxelles',
#   'director': 'Chantal Akerman',
#   'year': '1975',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0073198/'},
#  {'title': 'Cléo from 5 to 7',
#   'director': 'Agnès Varda',
#   'year': '1962',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0055852/'},
#  {'title': 'The Piano',
#   'director': 'Jane Campion',
#   'year': '1993',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0107822/'}]

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %% [markdown]
# #### correct wrong links

# %%
corrected = {
    'The Long Farewell': 'https://www.boxofficemojo.com/title/tt0092905/',
    'The Headless Woman': 'https://www.boxofficemojo.com/title/tt1221141/',
}

for movie in movie_data:
    title = movie['title']
    if title in corrected:
        movie['link'] = corrected[title]

# %% [markdown]
# #### extract each film's box office

# %%
for movie in movie_data:
    try:
        response = requests.get(movie['mojolink'], headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Method 1: Look for Worldwide section
        worldwide_header = soup.find('span', string='Worldwide')
        if worldwide_header:
            money_value = worldwide_header.find_next('span', class_='money')
            movie['worldwide_gross'] = money_value.get_text(strip=True) if money_value else "N/A"
        else:
            # Method 2: Check performance summary table
            performance_table = soup.find('div', class_='mojo-performance-summary-table')
            if performance_table:
                # Look for "Worldwide" in table rows
                for row in performance_table.find_all('div', class_='a-section'):
                    if 'Worldwide' in row.get_text():
                        money_value = row.find('span', class_='money')
                        if money_value:
                            movie['worldwide_gross'] = money_value.get_text(strip=True)
                            break
                else:
                    movie['worldwide_gross'] = "N/A"
            else:
                # Method 3: Fallback to first money value after "All Releases"
                all_releases = soup.find('h2', string='All Releases')
                if all_releases:
                    money_value = all_releases.find_next('span', class_='money')
                    movie['worldwide_gross'] = money_value.get_text(strip=True) if money_value else "N/A"
                else:
                    movie['worldwide_gross'] = "N/A"
                    
    except Exception as e:
        print(f"Error getting worldwide gross for {movie['title']}: {str(e)}")
        movie['worldwide_gross'] = "N/A"
# Out:
# Error getting worldwide gross for Ritual in Transfigured Time: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error getting worldwide gross for Harlan County, USA: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?

# %%
# second checkpoint
movie_data
# Out:
# [{'title': 'The Kids are All Right',
#   'director': 'Lisa Cholodenko',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0842926/',
#   'worldwide_gross': '$34,758,951'},
#  {'title': 'The Souvenir',
#   'director': 'Joanna Hogg',
#   'year': '2019',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt6920356/',
#   'worldwide_gross': '$1,777,486'},
#  {'title': 'Somewhere',
#   'director': 'Sofia Coppola',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1421051/',
#   'worldwide_gross': '$15,249,195'},
#  {'title': 'Adoption',
#   'director': 'Márta Mészáros',
#   'year': '1975',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt8555446/',
#   'worldwide_gross': '$7,120'},
#  {'title': 'The Meetings of Anna',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0078152/',
#   'worldwide_gross': '$330'},
#  {'title': 'Ritual in Transfigured Time',
#   'director': 'Maya Deren',
#   'year': '1946',
#   'mojolink': None,
#   'worldwide_gross': 'N/A'},
#  {'title': 'News From Home',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0097332/',
#   'worldwide_gross': '$11,859'},
#  {'title': 'Red Road',
#   'director': 'Andrea Arnold',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0471030/',
#   'worldwide_gross': '$1,128,345'},
#  {'title': 'Raw',
#   'director': 'Julia Ducournau',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt4954522/',
#   'worldwide_gross': '$3,098,251'},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1135952/',
#   'worldwide_gross': '$1,392,434'},
#  {'title': 'Fast Times at Ridgemont High',
#   'director': 'Amy Heckerling',
#   'year': '1982',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0083929/',
#   'worldwide_gross': '$27,093,151'},
#  {'title': 'The Beaches of Agnes',
#   'director': 'Agnès Varda',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1129435/',
#   'worldwide_gross': '$2,235,006'},
#  {'title': 'The Silences of the Palace',
#   'director': 'Moufida Tlatli',
#   'year': '1994',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt14549270/',
#   'worldwide_gross': '$972,161'},
#  {'title': '35 Shots of Rum',
#   'director': 'Claire Denis',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1100048/',
#   'worldwide_gross': '$973,539'},
#  {'title': 'Wadjda',
#   'director': 'Haifaa Al-Mansour',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2258858/',
#   'worldwide_gross': '$6,499,169'},
#  {'title': 'One Sings, The Other Doesn’t',
#   'director': 'Agnès Varda',
#   'year': '1977',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0076855/',
#   'worldwide_gross': '$19,919'},
#  {'title': 'Portrait of Jason',
#   'director': 'Shirley Clarke',
#   'year': '1967',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt8613070/',
#   'worldwide_gross': '$9,869,497'},
#  {'title': 'Sleepless in Seattle',
#   'director': 'Nora Ephron',
#   'year': '1993',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0108160/',
#   'worldwide_gross': '$227,927,165'},
#  {'title': 'At Land',
#   'director': 'Maya Deren',
#   'year': '1944',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1918921/',
#   'worldwide_gross': '$1,573,762'},
#  {'title': 'A Girl Walks Home Alone at Night',
#   'director': 'Ana Lily Amirpour',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2326554/',
#   'worldwide_gross': '$587,247'},
#  {'title': 'Big',
#   'director': 'Penny Marshall',
#   'year': '1988',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0094737/',
#   'worldwide_gross': '$151,927,281'},
#  {'title': 'Shoes',
#   'director': 'Lois Weber',
#   'year': '1916',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0419677/',
#   'worldwide_gross': '$241,688'},
#  {'title': 'The Apple',
#   'director': 'Samira Makhmalbaf',
#   'year': '1998',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0080380/',
#   'worldwide_gross': '$569'},
#  {'title': 'Tomboy',
#   'director': 'Céline Sciamma',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1847731/',
#   'worldwide_gross': '$1,424,716'},
#  {'title': 'Girlhood',
#   'director': 'Céline Sciamma',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3655522/',
#   'worldwide_gross': '$1,862,990'},
#  {'title': 'Meek’s Cutoff',
#   'director': 'Kelly Reichardt',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1518812/',
#   'worldwide_gross': '$1,205,257'},
#  {'title': 'Chocolat',
#   'director': 'Claire Denis',
#   'year': '1988',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0241303/',
#   'worldwide_gross': '$152,700,626'},
#  {'title': 'On Body and Soul',
#   'director': 'Ildikó Enyedi',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt5607714/',
#   'worldwide_gross': '$2,132,634'},
#  {'title': 'Europa Europa',
#   'director': 'Agnieszka Holland',
#   'year': '1980',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0099776/',
#   'worldwide_gross': '$5,575,738'},
#  {'title': 'The Seashell and the Clergyman',
#   'director': 'Germaine Dulac',
#   'year': '1928',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0060196/',
#   'worldwide_gross': '$25,265,416'},
#  {'title': 'Whale Rider',
#   'director': 'Niki Caro',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0298228/',
#   'worldwide_gross': '$41,062,976'},
#  {'title': 'The Connection',
#   'director': 'Shirley Clarke',
#   'year': '1961',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2935564/',
#   'worldwide_gross': '$12,062,441'},
#  {'title': 'Eve’s Bayou',
#   'director': 'Kasi Lemmons',
#   'year': '1997',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0119080/',
#   'worldwide_gross': '$14,842,388'},
#  {'title': 'The German Sisters',
#   'director': 'Margarethe von Trotta',
#   'year': '1981',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0452624/',
#   'worldwide_gross': '$5,914,908'},
#  {'title': 'Ratcatcher',
#   'director': 'Lynne Ramsay',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0171685/',
#   'worldwide_gross': '$232,280'},
#  {'title': 'Leave no Trace',
#   'director': 'Debra Granik',
#   'year': '2018',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3892172/',
#   'worldwide_gross': '$7,682,928'},
#  {'title': 'The Rider',
#   'director': 'Chloe Zhao',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt6217608/',
#   'worldwide_gross': '$3,436,124'},
#  {'title': 'Marie Antoinette',
#   'director': 'Sofia Coppola',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt15384074/',
#   'worldwide_gross': '$78,241'},
#  {'title': 'Strange Days',
#   'director': 'Kathryn Bigelow',
#   'year': '1995',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0114558/',
#   'worldwide_gross': '$7,959,751'},
#  {'title': 'India Song',
#   'director': 'Marguerite Duras',
#   'year': '1975',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0073166/',
#   'worldwide_gross': '$9,308'},
#  {'title': 'A League of their Own',
#   'director': 'Penny Marshall',
#   'year': '1992',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0104694/',
#   'worldwide_gross': '$132,440,069'},
#  {'title': 'The Long Farewell',
#   'director': 'Kira Muratova',
#   'year': '1971',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0092905/',
#   'link': 'https://www.boxofficemojo.com/title/tt0092905/',
#   'worldwide_gross': '$4,168'},
#  {'title': 'Desperately Seeking Susan',
#   'director': 'Susan Seidelman',
#   'year': '1985',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0089017/',
#   'worldwide_gross': '$27,399,597'},
#  {'title': 'The Babadook',
#   'director': 'Jennifer Kent',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2321549/',
#   'worldwide_gross': '$10,685,444'},
#  {'title': '13th',
#   'director': 'Ava DuVernay',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt5895028/',
#   'worldwide_gross': '$566'},
#  {'title': 'Monster',
#   'director': 'Patty Jenkins',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt23736044/',
#   'worldwide_gross': '$20,453,866'},
#  {'title': 'Bright Star',
#   'director': 'Jane Campion',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0810784/',
#   'worldwide_gross': '$14,374,652'},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1221141/',
#   'link': 'https://www.boxofficemojo.com/title/tt1221141/',
#   'worldwide_gross': '$305,766'},
#  {'title': 'Happy as Lazzaro',
#   'director': 'Alice Rohrwacher',
#   'year': '2018',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt6752992/',
#   'worldwide_gross': '$1,824,399'},
#  {'title': 'Harlan County, USA',
#   'director': 'Barbara Kopple',
#   'year': '1976',
#   'mojolink': None,
#   'worldwide_gross': 'N/A'},
#  {'title': 'Outrage',
#   'director': 'Ida Lupino',
#   'year': '1950',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1462667/',
#   'worldwide_gross': '$8,457,741'},
#  {'title': 'Salaam Bombay!',
#   'director': 'Mira Nair',
#   'year': '1988',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0096028/',
#   'worldwide_gross': '$2,080,758'},
#  {'title': 'The Asthenic Syndrome',
#   'director': 'Kira Muratova',
#   'year': '1989',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0078966/',
#   'worldwide_gross': '$51,718,485'},
#  {'title': 'An Angel at my Table',
#   'director': 'Jane Campion',
#   'year': '1990',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0099040/',
#   'worldwide_gross': '$1,055,995'},
#  {'title': 'Near Dark',
#   'director': 'Kathryn Bigelow',
#   'year': '1987',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0093605/',
#   'worldwide_gross': '$3,369,628'},
#  {'title': 'Triumph of the Will',
#   'director': 'Leni Riefenstahl',
#   'year': '1935',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0098513/',
#   'worldwide_gross': '$408,839'},
#  {'title': 'American Honey',
#   'director': 'Andrea Arnold',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3721936/',
#   'worldwide_gross': '$2,888,927'},
#  {'title': 'The Virgin Suicides',
#   'director': 'Sofia Coppola',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0159097/',
#   'worldwide_gross': '$10,414,053'},
#  {'title': 'The Adventures of Prince Achmed',
#   'director': 'Lotte Reiniger',
#   'year': '1926',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0015532/',
#   'worldwide_gross': '$100,156'},
#  {'title': 'Capernaum',
#   'director': 'Nadine Labaki',
#   'year': '2018',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt8267604/',
#   'worldwide_gross': '$64,417,003'},
#  {'title': 'Boys Don’t Cry',
#   'director': 'Kimberly Peirce',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0171804/',
#   'worldwide_gross': '$11,540,607'},
#  {'title': 'Portrait of a Lady on Fire',
#   'director': 'Céline Sciamma',
#   'year': '2019',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt8613070/',
#   'worldwide_gross': '$9,869,497'},
#  {'title': 'Paris is Burning',
#   'director': 'Jennie Livingston',
#   'year': '1990',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0100332/',
#   'worldwide_gross': '$3,906,006'},
#  {'title': 'Olympia',
#   'director': 'Leni Riefenstahl',
#   'year': '1938',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0457302/',
#   'worldwide_gross': '$14,632'},
#  {'title': 'Wendy and Lucy',
#   'director': 'Kelly Reichardt',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1152850/',
#   'worldwide_gross': '$1,192,995'},
#  {'title': 'The Matrix',
#   'director': 'Lana and Lilly Wachowski',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0133093/',
#   'worldwide_gross': '$467,841,735'},
#  {'title': 'Morvern Callar',
#   'director': 'Lynne Ramsay',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0300214/',
#   'worldwide_gross': '$869,820'},
#  {'title': 'You Were Never Really Here',
#   'director': 'Lynne Ramsay',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt5742374/',
#   'worldwide_gross': '$9,360,514'},
#  {'title': 'The Night Porter',
#   'director': 'Liliana Cavani',
#   'year': '1974',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0054130/',
#   'worldwide_gross': '$40,703'},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0247380/',
#   'worldwide_gross': '$159,165'},
#  {'title': 'Zama',
#   'director': 'Lucrecia Martel',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2386377/',
#   'worldwide_gross': '$4,912'},
#  {'title': 'Monsoon Wedding',
#   'director': 'Mira Nair',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0265343/',
#   'worldwide_gross': '$30,787,356'},
#  {'title': 'Le Bonheur',
#   'director': 'Agnès Varda',
#   'year': '1965',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1327194/',
#   'worldwide_gross': '$99,357,138'},
#  {'title': 'Selma',
#   'director': 'Ava DuVernay',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1020072/',
#   'worldwide_gross': '$67,782,762'},
#  {'title': 'Stories we Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2366450/',
#   'worldwide_gross': '$2,641,053'},
#  {'title': 'The House is Black',
#   'director': 'Forugh Farrokhzad',
#   'year': '1963',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0093342/',
#   'worldwide_gross': '$14,413'},
#  {'title': 'Lady Bird',
#   'director': 'Greta Gerwig',
#   'year': '2017',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt4925292/',
#   'worldwide_gross': '$78,987,280'},
#  {'title': 'The Hitch-Hiker',
#   'director': 'Ida Lupino',
#   'year': '1953',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0092796/',
#   'worldwide_gross': '$14,000,000'},
#  {'title': 'We Need to Talk About Kevin',
#   'director': 'Lynne Ramsay',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1242460/',
#   'worldwide_gross': '$9,212,174'},
#  {'title': 'Winter’s Bone',
#   'director': 'Debra Granik',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1399683/',
#   'worldwide_gross': '$13,796,834'},
#  {'title': 'Clueless',
#   'director': 'Amy Heckerling',
#   'year': '1995',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0112697/',
#   'worldwide_gross': '$56,687,093'},
#  {'title': 'Orlando',
#   'director': 'Sally Potter',
#   'year': '1992',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0107756/',
#   'worldwide_gross': '$5,409,423'},
#  {'title': 'American Psycho',
#   'director': 'Mary Harron',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0144084/',
#   'worldwide_gross': '$34,266,679'},
#  {'title': 'Seven Beauties',
#   'director': 'Lina Wertmüller',
#   'year': '1975',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0075040/',
#   'worldwide_gross': '$12,619'},
#  {'title': 'Wanda',
#   'director': 'Barbara Loden',
#   'year': '1970',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0067961/',
#   'worldwide_gross': '$108,692'},
#  {'title': 'The Swamp',
#   'director': 'Lucrecia Martel',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0240419/',
#   'worldwide_gross': '$270,811'},
#  {'title': 'Point Break',
#   'director': 'Kathryn Bigelow',
#   'year': '1991',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0102685/',
#   'worldwide_gross': '$83,531,958'},
#  {'title': 'Vagabond',
#   'director': 'Agnès Varda',
#   'year': '1985',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0050798/',
#   'worldwide_gross': '$91'},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1790885/',
#   'worldwide_gross': '$132,820,716'},
#  {'title': 'The Ascent',
#   'director': 'Larisa Shepitko',
#   'year': '1977',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt7893394/',
#   'worldwide_gross': '$24,666'},
#  {'title': 'Daughters of the Dust',
#   'director': 'Julie Dash',
#   'year': '1991',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0104057/',
#   'worldwide_gross': '$1,689,776'},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1232776/',
#   'worldwide_gross': '$2,404,300'},
#  {'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt4048272/',
#   'worldwide_gross': '$12,002,864'},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0887912/',
#   'worldwide_gross': '$49,259,766'},
#  {'title': 'Daisies',
#   'director': 'Věra Chytilová',
#   'year': '1966',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0060959/',
#   'worldwide_gross': '$14,191'},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0335266/',
#   'worldwide_gross': '$118,688,756'},
#  {'title': 'Beau Travail',
#   'director': 'Claire Denis',
#   'year': '1999',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0209933/',
#   'worldwide_gross': '$4,104'},
#  {'title': 'Jeanne Dielman, 23 Quai du Commerce, 1080 Bruxelles',
#   'director': 'Chantal Akerman',
#   'year': '1975',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0073198/',
#   'worldwide_gross': '$40,514'},
#  {'title': 'Cléo from 5 to 7',
#   'director': 'Agnès Varda',
#   'year': '1962',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0055852/',
#   'worldwide_gross': '$7,893'},
#  {'title': 'The Piano',
#   'director': 'Jane Campion',
#   'year': '1993',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0107822/',
#   'worldwide_gross': '$40,185,766'}]

# %%
df_mojowomen = pd.DataFrame(movie_data)

# %%
df_mojowomen['gender'] = 'female'

# %%
df_mojowomen['worldwide_gross'] = (
    df_mojowomen['worldwide_gross']
    .str.replace('$', '', regex=False)  
    .str.replace(',', '', regex=False) 
    .pipe(pd.to_numeric, errors='coerce') 
)

# %%
df_mojowomen
# Out:
#                                                 title  \
# 0                              The Kids are All Right
# 1                                        The Souvenir
# 2                                           Somewhere
# 3                                            Adoption
# 4                                The Meetings of Anna
# 5                         Ritual in Transfigured Time
# 6                                      News From Home
# 7                                            Red Road
# 8                                                 Raw
# 9                                      White Material
# 10                       Fast Times at Ridgemont High
# 11                               The Beaches of Agnes
# 12                         The Silences of the Palace
# 13                                    35 Shots of Rum
# 14                                             Wadjda
# 15                       One Sings, The Other Doesn’t
# 16                                  Portrait of Jason
# 17                               Sleepless in Seattle
# 18                                            At Land
# 19                   A Girl Walks Home Alone at Night
# 20                                                Big
# 21                                              Shoes
# 22                                          The Apple
# 23                                             Tomboy
# 24                                           Girlhood
# 25                                      Meek’s Cutoff
# 26                                           Chocolat
# 27                                   On Body and Soul
# 28                                      Europa Europa
# 29                     The Seashell and the Clergyman
# 30                                        Whale Rider
# 31                                     The Connection
# 32                                        Eve’s Bayou
# 33                                 The German Sisters
# 34                                         Ratcatcher
# 35                                     Leave no Trace
# 36                                          The Rider
# 37                                   Marie Antoinette
# 38                                       Strange Days
# 39                                         India Song
# 40                              A League of their Own
# 41                                  The Long Farewell
# 42                          Desperately Seeking Susan
# 43                                       The Babadook
# 44                                               13th
# 45                                            Monster
# 46                                        Bright Star
# 47                                 The Headless Woman
# 48                                   Happy as Lazzaro
# 49                                 Harlan County, USA
# 50                                            Outrage
# 51                                     Salaam Bombay!
# 52                              The Asthenic Syndrome
# 53                               An Angel at my Table
# 54                                          Near Dark
# 55                                Triumph of the Will
# 56                                     American Honey
# 57                                The Virgin Suicides
# 58                    The Adventures of Prince Achmed
# 59                                          Capernaum
# 60                                     Boys Don’t Cry
# 61                         Portrait of a Lady on Fire
# 62                                   Paris is Burning
# 63                                            Olympia
# 64                                     Wendy and Lucy
# 65                                         The Matrix
# 66                                     Morvern Callar
# 67                         You Were Never Really Here
# 68                                   The Night Porter
# 69                                 The Gleaners and I
# 70                                               Zama
# 71                                    Monsoon Wedding
# 72                                         Le Bonheur
# 73                                              Selma
# 74                                    Stories we Tell
# 75                                 The House is Black
# 76                                          Lady Bird
# 77                                    The Hitch-Hiker
# 78                        We Need to Talk About Kevin
# 79                                      Winter’s Bone
# 80                                           Clueless
# 81                                            Orlando
# 82                                    American Psycho
# 83                                     Seven Beauties
# 84                                              Wanda
# 85                                          The Swamp
# 86                                        Point Break
# 87                                           Vagabond
# 88                                   Zero Dark Thirty
# 89                                         The Ascent
# 90                              Daughters of the Dust
# 91                                          Fish Tank
# 92                                       Toni Erdmann
# 93                                    The Hurt Locker
# 94                                            Daisies
# 95                                Lost in Translation
# 96                                       Beau Travail
# 97  Jeanne Dielman, 23 Quai du Commerce, 1080 Brux...
# 98                                   Cléo from 5 to 7
# 99                                          The Piano
#
#                     director  year  \
# 0            Lisa Cholodenko  2010
# 1                Joanna Hogg  2019
# 93   https://www.boxofficemojo.com/title/tt0887912/       49259766.0
# 94   https://www.boxofficemojo.com/title/tt0060959/          14191.0
# 95   https://www.boxofficemojo.com/title/tt0335266/      118688756.0
# 96   https://www.boxofficemojo.com/title/tt0209933/           4104.0
# 97   https://www.boxofficemojo.com/title/tt0073198/          40514.0
# 98   https://www.boxofficemojo.com/title/tt0055852/           7893.0
# 99   https://www.boxofficemojo.com/title/tt0107822/       40185766.0
#
#                                               link  gender
# 0                                              NaN  female
# 1                                              NaN  female
# 2                                              NaN  female
# 3                                              NaN  female
# 4                                              NaN  female
# 5                                              NaN  female
# 6                                              NaN  female
# 7                                              NaN  female
# 8                                              NaN  female
# 9                                              NaN  female
# 10                                             NaN  female
# 11                                             NaN  female
# 12                                             NaN  female
# 13                                             NaN  female
# 14                                             NaN  female
# 15                                             NaN  female
# 16                                             NaN  female
# 17                                             NaN  female
# 18                                             NaN  female
# 19                                             NaN  female
# 20                                             NaN  female
# 21                                             NaN  female
# 22                                             NaN  female
# 23                                             NaN  female
# 24                                             NaN  female
# 25                                             NaN  female
# 26                                             NaN  female
# 27                                             NaN  female
# 28                                             NaN  female
# 29                                             NaN  female
# 30                                             NaN  female
# 31                                             NaN  female
# 32                                             NaN  female
# 33                                             NaN  female
# 34                                             NaN  female
# 35                                             NaN  female
# 36                                             NaN  female
# 37                                             NaN  female
# 38                                             NaN  female
# 39                                             NaN  female
# 40                                             NaN  female
# 41  https://www.boxofficemojo.com/title/tt0092905/  female
# 42                                             NaN  female
# 43                                             NaN  female
# 44                                             NaN  female
# 45                                             NaN  female
# 46                                             NaN  female
# 47  https://www.boxofficemojo.com/title/tt1221141/  female
# 48                                             NaN  female
# 49                                             NaN  female
# 50                                             NaN  female
# 51                                             NaN  female
# 52                                             NaN  female
# 53                                             NaN  female
# 54                                             NaN  female
# 55                                             NaN  female
# 56                                             NaN  female
# 57                                             NaN  female
# 58                                             NaN  female
# 59                                             NaN  female
# 60                                             NaN  female
# 61                                             NaN  female
# 62                                             NaN  female
# 63                                             NaN  female
# 64                                             NaN  female
# 65                                             NaN  female
# 66                                             NaN  female
# 67                                             NaN  female
# 68                                             NaN  female
# 69                                             NaN  female
# 70                                             NaN  female
# 71                                             NaN  female
# 72                                             NaN  female
# 73                                             NaN  female
# 74                                             NaN  female
# 75                                             NaN  female
# 76                                             NaN  female
# 77                                             NaN  female
# 78                                             NaN  female
# 79                                             NaN  female
# 80                                             NaN  female
# 81                                             NaN  female
# 82                                             NaN  female
# 83                                             NaN  female
# 84                                             NaN  female
# 85                                             NaN  female
# 86                                             NaN  female
# 87                                             NaN  female
# 88                                             NaN  female
# 89                                             NaN  female
# 90                                             NaN  female
# 91                                             NaN  female
# 92                                             NaN  female
# 93                                             NaN  female
# 94                                             NaN  female
# 95                                             NaN  female
# 96                                             NaN  female
# 97                                             NaN  female
# 98                                             NaN  female
# 99                                             NaN  female

# %% [markdown]
# ## THE SECOND LIST - 100 Greatest Film
# ### Given most films in this list are directed by male, scraping below aims to compare the statistics with the list of best films made by women.

# %%
main_url = "https://www.bbc.com/culture/article/20160819-the-21st-centurys-100-greatest-films"

# %%
response_main = requests.get(main_url, headers={'User-Agent': 'Mozilla/5.0'})
main_html = BeautifulSoup(response_main.content, 'html.parser')

# %% [markdown]
# ### 1. find all movie titles and directors and put them into a list of dictionaries - title, director, and year

# %%
main_paragraphs = main_html.find_all('p', class_='sc-9a00e533-0 hxuGS')

# Initialize list to store movie data
main_data = []

for each in main_paragraphs:
    text = each.get_text(strip=True)
    
    # Use regex to extract the components
    match = re.match(r'(\d+)\.\s*(.*?)\s*\((.*?),\s*(\d{4})\)', text)
    
    if match:
        title = match.group(2).strip()
        director = match.group(3).strip()
        year = match.group(4)
        
        # Clean up any extra whitespace or non-breaking spaces in the title
        title = ' '.join(title.split())
        
        main_data.append({
            'title': title,
            'director': director,
            'year': year
        })

# %% [markdown]
# ### 2. merge each film's webpage from BoxMojo

# %% [markdown]
# #### use the function, get_mojo_link, which I set up earlier to get links for films in this list

# %%
for movie in main_data:
    movie['mojolink'] = get_mojo_link(movie['title'], movie['year'])

# %%
# checkpoint
main_data
# Out:
# [{'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt4048272/'},
#  {'title': 'Requiem for a Dream',
#   'director': 'Darren Aronofsky',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0180093/'},
#  {'title': 'Carlos',
#   'director': 'Olivier Assayas',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt20417104/'},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0247380/'},
#  {'title': 'Ten',
#   'director': 'Abbas Kiarostami',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0049833/'},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1135952/'},
#  {'title': 'Finding Nemo',
#   'director': 'Andrew Stanton',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0266543/'},
#  {'title': 'Moonrise Kingdom',
#   'director': 'Wes Anderson',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1748122/'},
#  {'title': 'Let the Right One In',
#   'director': 'Tomas Alfredson',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1139797/'},
#  {'title': 'Ratatouille',
#   'director': 'Brad Bird',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0382932/'},
#  {'title': 'The Assassination of Jesse James by the Coward Robert Ford',
#   'director': 'Andrew Dominik',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0443680/'},
#  {'title': 'The Secret in Their Eyes',
#   'director': 'Juan José Campanella',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1305806/'},
#  {'title': 'The Pianist',
#   'director': 'Roman Polanski',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0253474/'},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1221141/'},
#  {'title': 'Spotlight',
#   'director': 'Tom McCarthy',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1895587/'},
#  {'title': 'Amélie',
#   'director': 'Jean-Pierre Jeunet',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0211915/'},
#  {'title': 'Far From Heaven',
#   'director': 'Todd Haynes',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0297884/'},
#  {'title': 'A Prophet',
#   'director': 'Jacques Audiard',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1235166/'},
#  {'title': 'Her',
#   'director': 'Spike Jonze',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1798709/'},
#  {'title': 'A.I. Artificial Intelligence',
#   'director': 'Steven Spielberg',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0212720/'},
#  {'title': 'A Serious Man',
#   'director': 'Joel and Ethan Coen',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1019452/'},
#  {'title': 'Shame',
#   'director': 'Steve McQueen',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1723811/'},
#  {'title': 'The Return',
#   'director': 'Andrey Zvyagintsev',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt19861162/'},
#  {'title': 'Almost Famous',
#   'director': 'Cameron Crowe',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0181875/'},
#  {'title': 'The Wolf of Wall Street',
#   'director': 'Martin Scorsese',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0993846/'},
#  {'title': 'The Diving Bell and the Butterfly',
#   'director': 'Julian Schnabel',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0401383/'},
#  {'title': 'Dogville',
#   'director': 'Lars von Trier',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0276919/'},
#  {'title': 'Inherent Vice',
#   'director': 'Paul Thomas Anderson',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1791528/'},
#  {'title': 'Spring Breakers',
#   'director': 'Harmony Korine',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2101441/'},
#  {'title': 'Before Sunset',
#   'director': 'Richard Linklater',
#   'year': '2004',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0381681/'},
#  {'title': 'Only Lovers Left Alive',
#   'director': 'Jim Jarmusch',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1714915/'},
#  {'title': 'Tabu',
#   'director': 'Miguel Gomes',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0100114/'},
#  {'title': 'Stories We Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2366450/'},
#  {'title': 'Carol',
#   'director': 'Todd Haynes',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2402927/'},
#  {'title': 'The Royal Tenenbaums',
#   'director': 'Wes Anderson',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0265666/'},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0887912/'},
#  {'title': 'Spring, Summer, Fall, Winter…and Spring',
#   'director': 'Kim Ki-duk',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0374546/'},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1232776/'},
#  {'title': 'The Great Beauty',
#   'director': 'Paolo Sorrentino',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2358891/'},
#  {'title': 'The Turin Horse',
#   'director': 'Béla Tarr and Ágnes Hranitzky',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1316540/'},
#  {'title': 'Inglourious Basterds',
#   'director': 'Quentin Tarantino',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0361748/'},
#  {'title': 'Under the Skin',
#   'director': 'Jonathan Glazer',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1441395/'},
#  {'title': 'Syndromes and a Century',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0477731/'},
#  {'title': 'A History of Violence',
#   'director': 'David Cronenberg',
#   'year': '2005',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0399146/'},
#  {'title': 'Moolaadé',
#   'director': 'Ousmane Sembène',
#   'year': '2004',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0416991/'},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1790885/'},
#  {'title': 'Werckmeister Harmonies',
#   'director': 'Béla Tarr, director; Ágnes Hranitzky, co-director',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0249241/'},
#  {'title': 'Ida',
#   'director': 'Paweł Pawlikowski',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1869716/'},
#  {'title': 'Once Upon a Time in Anatolia',
#   'director': 'Nuri Bilge Ceylan',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1827487/'},
#  {'title': 'Moulin Rouge!',
#   'director': 'Baz Luhrmann',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0203009/'},
#  {'title': 'Tropical Malady',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2004',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0381668/'},
#  {'title': 'Inception',
#   'director': 'Christopher Nolan',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1375666/'},
#  {'title': 'The Assassin',
#   'director': 'Hou Hsiao-hsien',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0107843/'},
#  {'title': 'Goodbye to Language',
#   'director': 'Jean-Luc Godard',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2400275/'},
#  {'title': 'Brooklyn',
#   'director': 'John Crowley',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2381111/'},
#  {'title': 'Leviathan',
#   'director': 'Andrey Zvyagintsev',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0097737/'},
#  {'title': 'Certified Copy',
#   'director': 'Abbas Kiarostami',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1020773/'},
#  {'title': 'Blue Is the Warmest Color',
#   'director': 'Abdellatif Kechiche',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2278871/'},
#  {'title': '12 Years a Slave',
#   'director': 'Steve McQueen',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2024544/'},
#  {'title': 'Melancholia',
#   'director': 'Lars von Trier',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1527186/'},
#  {'title': 'Amour',
#   'director': 'Michael Haneke',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1602620/'},
#  {'title': 'Inside Out',
#   'director': 'Pete Docter',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2096673/'},
#  {'title': 'Brokeback Mountain',
#   'director': 'Ang Lee',
#   'year': '2005',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0388795/'},
#  {'title': 'The New World',
#   'director': 'Terrence Malick',
#   'year': '2005',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0402399/'},
#  {'title': 'City of God',
#   'director': 'Fernando Meirelles and Kátia Lund',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0317248/'},
#  {'title': 'Uncle Boonmee Who Can Recall His Past Lives',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1588895/'},
#  {'title': 'Timbuktu',
#   'director': 'Abderrahmane Sissako',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3409392/'},
#  {'title': 'Crouching Tiger, Hidden Dragon',
#   'director': 'Ang Lee',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0190332/'},
#  {'title': 'Son of Saul',
#   'director': 'László Nemes',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3808342/'},
#  {'title': 'The Dark Knight',
#   'director': 'Christopher Nolan',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0468569/'},
#  {'title': 'The Lives of Others',
#   'director': 'Florian Henckel von Donnersmarck',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0405094/'},
#  {'title': 'Margaret',
#   'director': 'Kenneth Lonergan',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3777860/'},
#  {'title': 'Oldboy',
#   'director': 'Park Chan-wook',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0364569/'},
#  {'title': 'WALL-E',
#   'director': 'Andrew Stanton',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0910970/'},
#  {'title': 'Talk to Her',
#   'director': 'Pedro Almodóvar',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0287467/'},
#  {'title': 'The Social Network',
#   'director': 'David Fincher',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1285016/'},
#  {'title': '25th Hour',
#   'director': 'Spike Lee',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0307901/'},
#  {'title': '\u200bMemento',
#   'director': 'Christopher Nolan',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0209144/'},
#  {'title': 'The Master',
#   'director': 'Paul Thomas Anderson',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1560747/'},
#  {'title': 'Caché',
#   'director': 'Michael Haneke',
#   'year': '2005',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0387898/'},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0335266/'},
#  {'title': 'The Grand Budapest Hotel',
#   'director': 'Wes Anderson',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2278388/'},
#  {'title': 'Synecdoche, New York',
#   'director': 'Charlie Kaufman',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0383028/'},
#  {'title': 'Mad Max: Fury Road',
#   'director': 'George Miller',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1392190/'},
#  {'title': 'The White Ribbon',
#   'director': 'Michael Haneke',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1149362/'},
#  {'title': "Pan's Labyrinth",
#   'director': 'Guillermo Del Toro',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0457430/'},
#  {'title': 'Holy Motors',
#   'director': 'Leos Carax',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2076220/'},
#  {'title': '4 Months, 3 Weeks and 2 Days',
#   'director': 'Cristian Mungiu',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1032846/'},
#  {'title': 'The Act of Killing',
#   'director': 'Joshua Oppenheimer',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2375605/'},
#  {'title': 'Children of Men',
#   'director': 'Alfonso Cuarón',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0206634/'},
#  {'title': 'Zodiac',
#   'director': 'David Fincher',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0443706/'},
#  {'title': 'Inside Llewyn Davis',
#   'director': 'Joel and Ethan Coen',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2042568/'},
#  {'title': 'No Country for Old Men',
#   'director': 'Joel and Ethan Coen',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0477348/'},
#  {'title': 'A Separation',
#   'director': 'Asghar Farhadi',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1832382/'},
#  {'title': 'Yi Yi: A One and a Two',
#   'director': 'Edward Yang',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0244316/'},
#  {'title': 'The Tree of Life',
#   'director': 'Terrence Malick',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0478304/'},
#  {'title': 'Eternal Sunshine of the Spotless Mind',
#   'director': 'Michel Gondry',
#   'year': '2004',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0338013/'},
#  {'title': 'Boyhood',
#   'director': 'Richard Linklater',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1065073/'},
#  {'title': 'Spirited Away',
#   'director': 'Hayao Miyazaki',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0245429/'},
#  {'title': 'There Will Be Blood',
#   'director': 'Paul Thomas Anderson',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0469494/'},
#  {'title': 'In the Mood for Love',
#   'director': 'Wong Kar-wai',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0118694/'},
#  {'title': 'Mulholland Drive',
#   'director': 'David Lynch',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0166924/'}]

# %% [markdown]
# #### get each film's worldwide box office

# %%
for movie in main_data:
    try:
        response = requests.get(movie['mojolink'], headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Method 1: Look for Worldwide section
        worldwide_header = soup.find('span', string='Worldwide')
        if worldwide_header:
            money_value = worldwide_header.find_next('span', class_='money')
            movie['worldwide_gross'] = money_value.get_text(strip=True) if money_value else "N/A"
        else:
            # Method 2: Check performance summary table
            performance_table = soup.find('div', class_='mojo-performance-summary-table')
            if performance_table:
                # Look for "Worldwide" in table rows
                for row in performance_table.find_all('div', class_='a-section'):
                    if 'Worldwide' in row.get_text():
                        money_value = row.find('span', class_='money')
                        if money_value:
                            movie['worldwide_gross'] = money_value.get_text(strip=True)
                            break
                else:
                    movie['worldwide_gross'] = "N/A"
            else:
                # Method 3: Fallback to first money value after "All Releases"
                all_releases = soup.find('h2', string='All Releases')
                if all_releases:
                    money_value = all_releases.find_next('span', class_='money')
                    movie['worldwide_gross'] = money_value.get_text(strip=True) if money_value else "N/A"
                else:
                    movie['worldwide_gross'] = "N/A"
                    
    except Exception as e:
        print(f"Error getting worldwide gross for {movie['title']}: {str(e)}")
        movie['worldwide_gross'] = "N/A"

# %%
# checkpoint
main_data
# Out:
# [{'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt4048272/',
#   'worldwide_gross': '$12,002,864'},
#  {'title': 'Requiem for a Dream',
#   'director': 'Darren Aronofsky',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0180093/',
#   'worldwide_gross': '$7,391,471'},
#  {'title': 'Carlos',
#   'director': 'Olivier Assayas',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt20417104/',
#   'worldwide_gross': '$446,190'},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0247380/',
#   'worldwide_gross': '$159,165'},
#  {'title': 'Ten',
#   'director': 'Abbas Kiarostami',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0049833/',
#   'worldwide_gross': '$65,500,755'},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1135952/',
#   'worldwide_gross': '$1,392,434'},
#  {'title': 'Finding Nemo',
#   'director': 'Andrew Stanton',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0266543/',
#   'worldwide_gross': '$941,637,960'},
#  {'title': 'Moonrise Kingdom',
#   'director': 'Wes Anderson',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1748122/',
#   'worldwide_gross': '$68,299,602'},
#  {'title': 'Let the Right One In',
#   'director': 'Tomas Alfredson',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1139797/',
#   'worldwide_gross': '$11,227,336'},
#  {'title': 'Ratatouille',
#   'director': 'Brad Bird',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0382932/',
#   'worldwide_gross': '$623,729,380'},
#  {'title': 'The Assassination of Jesse James by the Coward Robert Ford',
#   'director': 'Andrew Dominik',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0443680/',
#   'worldwide_gross': '$15,004,260'},
#  {'title': 'The Secret in Their Eyes',
#   'director': 'Juan José Campanella',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1305806/',
#   'worldwide_gross': '$35,079,650'},
#  {'title': 'The Pianist',
#   'director': 'Roman Polanski',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0253474/',
#   'worldwide_gross': '$120,098,945'},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1221141/',
#   'worldwide_gross': '$305,766'},
#  {'title': 'Spotlight',
#   'director': 'Tom McCarthy',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1895587/',
#   'worldwide_gross': '$98,690,254'},
#  {'title': 'Amélie',
#   'director': 'Jean-Pierre Jeunet',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0211915/',
#   'worldwide_gross': '$175,183,052'},
#  {'title': 'Far From Heaven',
#   'director': 'Todd Haynes',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0297884/',
#   'worldwide_gross': '$29,027,914'},
#  {'title': 'A Prophet',
#   'director': 'Jacques Audiard',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1235166/',
#   'worldwide_gross': '$17,873,691'},
#  {'title': 'Her',
#   'director': 'Spike Jonze',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1798709/',
#   'worldwide_gross': '$48,269,269'},
#  {'title': 'A.I. Artificial Intelligence',
#   'director': 'Steven Spielberg',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0212720/',
#   'worldwide_gross': '$235,926,635'},
#  {'title': 'A Serious Man',
#   'director': 'Joel and Ethan Coen',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1019452/',
#   'worldwide_gross': '$31,431,652'},
#  {'title': 'Shame',
#   'director': 'Steve McQueen',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1723811/',
#   'worldwide_gross': '$19,126,823'},
#  {'title': 'The Return',
#   'director': 'Andrey Zvyagintsev',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt19861162/',
#   'worldwide_gross': '$2,799,877'},
#  {'title': 'Almost Famous',
#   'director': 'Cameron Crowe',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0181875/',
#   'worldwide_gross': '$47,387,566'},
#  {'title': 'The Wolf of Wall Street',
#   'director': 'Martin Scorsese',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0993846/',
#   'worldwide_gross': '$407,039,432'},
#  {'title': 'The Diving Bell and the Butterfly',
#   'director': 'Julian Schnabel',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0401383/',
#   'worldwide_gross': '$19,780,116'},
#  {'title': 'Dogville',
#   'director': 'Lars von Trier',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0276919/',
#   'worldwide_gross': '$16,690,617'},
#  {'title': 'Inherent Vice',
#   'director': 'Paul Thomas Anderson',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1791528/',
#   'worldwide_gross': '$14,810,975'},
#  {'title': 'Spring Breakers',
#   'director': 'Harmony Korine',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2101441/',
#   'worldwide_gross': '$32,016,127'},
#  {'title': 'Before Sunset',
#   'director': 'Richard Linklater',
#   'year': '2004',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0381681/',
#   'worldwide_gross': '$16,506,532'},
#  {'title': 'Only Lovers Left Alive',
#   'director': 'Jim Jarmusch',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1714915/',
#   'worldwide_gross': '$8,161,154'},
#  {'title': 'Tabu',
#   'director': 'Miguel Gomes',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0100114/',
#   'worldwide_gross': '$57,968,936'},
#  {'title': 'Stories We Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2366450/',
#   'worldwide_gross': '$2,641,053'},
#  {'title': 'Carol',
#   'director': 'Todd Haynes',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2402927/',
#   'worldwide_gross': '$44,375,432'},
#  {'title': 'The Royal Tenenbaums',
#   'director': 'Wes Anderson',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0265666/',
#   'worldwide_gross': '$71,444,769'},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0887912/',
#   'worldwide_gross': '$49,259,766'},
#  {'title': 'Spring, Summer, Fall, Winter…and Spring',
#   'director': 'Kim Ki-duk',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0374546/',
#   'worldwide_gross': '$8,842,902'},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1232776/',
#   'worldwide_gross': '$2,404,300'},
#  {'title': 'The Great Beauty',
#   'director': 'Paolo Sorrentino',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2358891/',
#   'worldwide_gross': '$25,458,131'},
#  {'title': 'The Turin Horse',
#   'director': 'Béla Tarr and Ágnes Hranitzky',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1316540/',
#   'worldwide_gross': '$162,088'},
#  {'title': 'Inglourious Basterds',
#   'director': 'Quentin Tarantino',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0361748/',
#   'worldwide_gross': '$321,460,744'},
#  {'title': 'Under the Skin',
#   'director': 'Jonathan Glazer',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1441395/',
#   'worldwide_gross': '$7,494,387'},
#  {'title': 'Syndromes and a Century',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0477731/',
#   'worldwide_gross': '$70,649'},
#  {'title': 'A History of Violence',
#   'director': 'David Cronenberg',
#   'year': '2005',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0399146/',
#   'worldwide_gross': '$61,385,065'},
#  {'title': 'Moolaadé',
#   'director': 'Ousmane Sembène',
#   'year': '2004',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0416991/',
#   'worldwide_gross': '$495,270'},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1790885/',
#   'worldwide_gross': '$132,820,716'},
#  {'title': 'Werckmeister Harmonies',
#   'director': 'Béla Tarr, director; Ágnes Hranitzky, co-director',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0249241/',
#   'worldwide_gross': '$69,923'},
#  {'title': 'Ida',
#   'director': 'Paweł Pawlikowski',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1869716/',
#   'worldwide_gross': '$2,891,812'},
#  {'title': 'Once Upon a Time in Anatolia',
#   'director': 'Nuri Bilge Ceylan',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1827487/',
#   'worldwide_gross': '$2,099,472'},
#  {'title': 'Moulin Rouge!',
#   'director': 'Baz Luhrmann',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0203009/',
#   'worldwide_gross': '$184,935,252'},
#  {'title': 'Tropical Malady',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2004',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0381668/',
#   'worldwide_gross': '$46,750'},
#  {'title': 'Inception',
#   'director': 'Christopher Nolan',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1375666/',
#   'worldwide_gross': '$839,381,898'},
#  {'title': 'The Assassin',
#   'director': 'Hou Hsiao-hsien',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0107843/',
#   'worldwide_gross': '$30,038,362'},
#  {'title': 'Goodbye to Language',
#   'director': 'Jean-Luc Godard',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2400275/',
#   'worldwide_gross': '$567,868'},
#  {'title': 'Brooklyn',
#   'director': 'John Crowley',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2381111/',
#   'worldwide_gross': '$62,402,155'},
#  {'title': 'Leviathan',
#   'director': 'Andrey Zvyagintsev',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0097737/',
#   'worldwide_gross': '$15,704,614'},
#  {'title': 'Certified Copy',
#   'director': 'Abbas Kiarostami',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1020773/',
#   'worldwide_gross': '$7,736,632'},
#  {'title': 'Blue Is the Warmest Color',
#   'director': 'Abdellatif Kechiche',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2278871/',
#   'worldwide_gross': '$19,796,489'},
#  {'title': '12 Years a Slave',
#   'director': 'Steve McQueen',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2024544/',
#   'worldwide_gross': '$187,734,091'},
#  {'title': 'Melancholia',
#   'director': 'Lars von Trier',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1527186/',
#   'worldwide_gross': '$17,683,518'},
#  {'title': 'Amour',
#   'director': 'Michael Haneke',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1602620/',
#   'worldwide_gross': '$29,664,140'},
#  {'title': 'Inside Out',
#   'director': 'Pete Docter',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2096673/',
#   'worldwide_gross': '$859,076,254'},
#  {'title': 'Brokeback Mountain',
#   'director': 'Ang Lee',
#   'year': '2005',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0388795/',
#   'worldwide_gross': '$178,064,141'},
#  {'title': 'The New World',
#   'director': 'Terrence Malick',
#   'year': '2005',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0402399/',
#   'worldwide_gross': '$49,334,775'},
#  {'title': 'City of God',
#   'director': 'Fernando Meirelles and Kátia Lund',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0317248/',
#   'worldwide_gross': '$30,681,033'},
#  {'title': 'Uncle Boonmee Who Can Recall His Past Lives',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1588895/',
#   'worldwide_gross': '$1,214,424'},
#  {'title': 'Timbuktu',
#   'director': 'Abderrahmane Sissako',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3409392/',
#   'worldwide_gross': '$7,179,391'},
#  {'title': 'Crouching Tiger, Hidden Dragon',
#   'director': 'Ang Lee',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0190332/',
#   'worldwide_gross': '$213,978,518'},
#  {'title': 'Son of Saul',
#   'director': 'László Nemes',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3808342/',
#   'worldwide_gross': '$6,659,121'},
#  {'title': 'The Dark Knight',
#   'director': 'Christopher Nolan',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0468569/',
#   'worldwide_gross': '$1,012,558,979'},
#  {'title': 'The Lives of Others',
#   'director': 'Florian Henckel von Donnersmarck',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0405094/',
#   'worldwide_gross': '$77,672,685'},
#  {'title': 'Margaret',
#   'director': 'Kenneth Lonergan',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt3777860/',
#   'worldwide_gross': '$10,107'},
#  {'title': 'Oldboy',
#   'director': 'Park Chan-wook',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0364569/',
#   'worldwide_gross': '$17,617,021'},
#  {'title': 'WALL-E',
#   'director': 'Andrew Stanton',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0910970/',
#   'worldwide_gross': '$527,403,656'},
#  {'title': 'Talk to Her',
#   'director': 'Pedro Almodóvar',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0287467/',
#   'worldwide_gross': '$64,826,117'},
#  {'title': 'The Social Network',
#   'director': 'David Fincher',
#   'year': '2010',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1285016/',
#   'worldwide_gross': '$224,927,749'},
#  {'title': '25th Hour',
#   'director': 'Spike Lee',
#   'year': '2002',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0307901/',
#   'worldwide_gross': '$23,936,003'},
#  {'title': '\u200bMemento',
#   'director': 'Christopher Nolan',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0209144/',
#   'worldwide_gross': '$40,047,236'},
#  {'title': 'The Master',
#   'director': 'Paul Thomas Anderson',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1560747/',
#   'worldwide_gross': '$28,288,071'},
#  {'title': 'Caché',
#   'director': 'Michael Haneke',
#   'year': '2005',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0387898/',
#   'worldwide_gross': '$16,197,824'},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0335266/',
#   'worldwide_gross': '$118,688,756'},
#  {'title': 'The Grand Budapest Hotel',
#   'director': 'Wes Anderson',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2278388/',
#   'worldwide_gross': '$174,567,384'},
#  {'title': 'Synecdoche, New York',
#   'director': 'Charlie Kaufman',
#   'year': '2008',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0383028/',
#   'worldwide_gross': '$4,659,875'},
#  {'title': 'Mad Max: Fury Road',
#   'director': 'George Miller',
#   'year': '2015',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1392190/',
#   'worldwide_gross': '$380,437,267'},
#  {'title': 'The White Ribbon',
#   'director': 'Michael Haneke',
#   'year': '2009',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1149362/',
#   'worldwide_gross': '$19,353,588'},
#  {'title': "Pan's Labyrinth",
#   'director': 'Guillermo Del Toro',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0457430/',
#   'worldwide_gross': '$83,863,565'},
#  {'title': 'Holy Motors',
#   'director': 'Leos Carax',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2076220/',
#   'worldwide_gross': '$1,953,562'},
#  {'title': '4 Months, 3 Weeks and 2 Days',
#   'director': 'Cristian Mungiu',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1032846/',
#   'worldwide_gross': '$10,174,839'},
#  {'title': 'The Act of Killing',
#   'director': 'Joshua Oppenheimer',
#   'year': '2012',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2375605/',
#   'worldwide_gross': '$726,324'},
#  {'title': 'Children of Men',
#   'director': 'Alfonso Cuarón',
#   'year': '2006',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0206634/',
#   'worldwide_gross': '$70,596,471'},
#  {'title': 'Zodiac',
#   'director': 'David Fincher',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0443706/',
#   'worldwide_gross': '$84,786,496'},
#  {'title': 'Inside Llewyn Davis',
#   'director': 'Joel and Ethan Coen',
#   'year': '2013',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt2042568/',
#   'worldwide_gross': '$33,014,317'},
#  {'title': 'No Country for Old Men',
#   'director': 'Joel and Ethan Coen',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0477348/',
#   'worldwide_gross': '$171,632,777'},
#  {'title': 'A Separation',
#   'director': 'Asghar Farhadi',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1832382/',
#   'worldwide_gross': '$22,926,076'},
#  {'title': 'Yi Yi: A One and a Two',
#   'director': 'Edward Yang',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0244316/',
#   'worldwide_gross': '$1,206,638'},
#  {'title': 'The Tree of Life',
#   'director': 'Terrence Malick',
#   'year': '2011',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0478304/',
#   'worldwide_gross': '$58,386,787'},
#  {'title': 'Eternal Sunshine of the Spotless Mind',
#   'director': 'Michel Gondry',
#   'year': '2004',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0338013/',
#   'worldwide_gross': '$73,384,095'},
#  {'title': 'Boyhood',
#   'director': 'Richard Linklater',
#   'year': '2014',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt1065073/',
#   'worldwide_gross': '$48,137,666'},
#  {'title': 'Spirited Away',
#   'director': 'Hayao Miyazaki',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0245429/',
#   'worldwide_gross': '$358,897,687'},
#  {'title': 'There Will Be Blood',
#   'director': 'Paul Thomas Anderson',
#   'year': '2007',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0469494/',
#   'worldwide_gross': '$76,430,381'},
#  {'title': 'In the Mood for Love',
#   'director': 'Wong Kar-wai',
#   'year': '2000',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0118694/',
#   'worldwide_gross': '$15,815,968'},
#  {'title': 'Mulholland Drive',
#   'director': 'David Lynch',
#   'year': '2001',
#   'mojolink': 'https://www.boxofficemojo.com/title/tt0166924/',
#   'worldwide_gross': '$20,391,793'}]

# %%
df_mojomen = pd.DataFrame(main_data)

# %%
df_mojomen['gender'] = 'male'

# %%
df_mojomen['worldwide_gross'] = df_mojomen['worldwide_gross'].str.replace('$', '', regex=False)
df_mojomen['worldwide_gross'] = df_mojomen['worldwide_gross'].str.replace(',', '', regex=False)

# %%
df_mojomen['worldwide_gross'] = pd.to_numeric(df_mojomen['worldwide_gross'])

# %%
df_mojomen
# Out:
#                                                  title  \
# 0                                         Toni Erdmann
# 1                                  Requiem for a Dream
# 2                                               Carlos
# 3                                   The Gleaners and I
# 4                                                  Ten
# 5                                       White Material
# 6                                         Finding Nemo
# 7                                     Moonrise Kingdom
# 8                                 Let the Right One In
# 9                                          Ratatouille
# 10   The Assassination of Jesse James by the Coward...
# 11                            The Secret in Their Eyes
# 12                                         The Pianist
# 13                                  The Headless Woman
# 14                                           Spotlight
# 15                                              Amélie
# 16                                     Far From Heaven
# 17                                           A Prophet
# 18                                                 Her
# 19                        A.I. Artificial Intelligence
# 20                                       A Serious Man
# 21                                               Shame
# 22                                          The Return
# 23                                       Almost Famous
# 24                             The Wolf of Wall Street
# 25                   The Diving Bell and the Butterfly
# 26                                            Dogville
# 27                                       Inherent Vice
# 28                                     Spring Breakers
# 29                                       Before Sunset
# 30                              Only Lovers Left Alive
# 31                                                Tabu
# 32                                     Stories We Tell
# 33                                               Carol
# 34                                The Royal Tenenbaums
# 35                                     The Hurt Locker
# 36             Spring, Summer, Fall, Winter…and Spring
# 37                                           Fish Tank
# 38                                    The Great Beauty
# 39                                     The Turin Horse
# 40                                Inglourious Basterds
# 101   https://www.boxofficemojo.com/title/tt0166924/         20391793   male

# %%
df_mojomen['worldwide_gross'].mean()
# Out:
# 103134706.51960784

# %%
bins = [2000, 2005, 2010, 2015, 2020]
labels = ['2000-2005', '2006-2010', '2011-2015', '2016-2020']

# Create Era column
df_mojomen['Era'] = pd.cut(df_mojomen['year'], 
                          bins=bins, 
                          labels=labels, 
                          right=False)

# %%
median_by_era = df_mojomen.groupby('Era')['worldwide_gross'].median().reset_index()
print(median_by_era)
# Out:
#          Era  worldwide_gross
# 0  2000-2005       29854473.5
# 1  2006-2010       42169708.0
# 2  2011-2015       19461656.0
# 3  2016-2020       53388793.5
# /var/folders/zz/2b8md6f924779tdhfsf8zvqm0000gn/T/ipykernel_86057/692954825.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   median_by_era = df_mojomen.groupby('Era')['worldwide_gross'].median().reset_index()

# %%
df_mojowomen['worldwide_gross'].mean()
# Out:
# 25326563.602040816

# %%
bins = [2000, 2005, 2010, 2015, 2020]
labels = ['2000-2005', '2006-2010', '2011-2015', '2016-2020']

# Create Era column
df_mojowomen['Era'] = pd.cut(df_mojowomen['year'], 
                          bins=bins, 
                          labels=labels, 
                          right=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 5
#       2 labels = ['2000-2005', '2006-2010', '2011-2015', '2016-2020']
#       4 # Create Era column
# ----> 5 df_mojowomen['Era'] = pd.cut(df_mojowomen['year'],
#       6                           bins=bins,
#       7                           labels=labels,
#       8                           right=False)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/pandas/core/reshape/tile.py:257, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     254     if not bins.is_monotonic_increasing:
#     255         raise ValueError("bins must increase monotonically.")
# --> 257 fac, bins = _bins_to_cuts(
#     258     x_idx,
#     259     bins,
#     260     right=right,
#     261     labels=labels,
#     262     precision=precision,
#     263     include_lowest=include_lowest,
#     264     duplicates=duplicates,
#     265     ordered=ordered,
#     266 )
#     268 return _postprocess_for_cut(fac, bins, retbins, original)
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/pandas/core/reshape/tile.py:452, in _bins_to_cuts(x_idx, bins, right, labels, precision, include_lowest, duplicates, ordered)
#     449 side: Literal["left", "right"] = "left" if right else "right"
#     451 try:
# --> 452     ids = bins.searchsorted(x_idx, side=side)
#     453 except TypeError as err:
#     454     # e.g. test_datetime_nan_error if bins are DatetimeArray and x_idx
#     455     #  is integers
#     456     if x_idx.dtype.kind == "m":
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/pandas/core/base.py:1352, in IndexOpsMixin.searchsorted(self, value, side, sorter)
#    1348 if not isinstance(values, np.ndarray):
#    1349     # Going through EA.searchsorted directly improves performance GH#38083
#    1350     return values.searchsorted(value, side=side, sorter=sorter)
# -> 1352 return algorithms.searchsorted(
#    1353     values,
#    1354     value,
#    1355     side=side,
#    1356     sorter=sorter,
#    1357 )
#
# File ~/.pyenv/versions/3.12.7/lib/python3.12/site-packages/pandas/core/algorithms.py:1329, in searchsorted(arr, value, side, sorter)
#    1325     arr = ensure_wrapped_if_datetimelike(arr)
#    1327 # Argument 1 to "searchsorted" of "ndarray" has incompatible type
#    1328 # "Union[NumpyValueArrayLike, ExtensionArray]"; expected "NumpyValueArrayLike"
# -> 1329 return arr.searchsorted(value, side=side, sorter=sorter)
#
# TypeError: '<' not supported between instances of 'int' and 'str'
