# %% [markdown]
# # Set up data

# %% [markdown]
# ## Import libraries: Beautiful soup, requests, and re (For regular expressions)

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Getting Data From BBC Lists

# %% [markdown]
# ## THE FIRST LIST - scraping the list of 100 greatest films directed by women

# %%
bbc_url = "https://www.bbc.com/culture/article/20191125-the-100-greatest-films-directed-by-women-poll"

# %%
response = requests.get(bbc_url, headers={'User-Agent': 'Mozilla/5.0'})
bbc_html = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ### 1. find all movie titles and directors and put them into a list of dictionaries - title, director, and year

# %%
movie_paragraphs = bbc_html.find_all('p', class_='sc-9a00e533-0 hxuGS')

movie_data = []

for movie in movie_paragraphs:
    text = movie.get_text(strip=True)
    match = re.match(r'(\d+)\.\s*(.*?)\s*\((.*?),\s*(\d{4})\)', text)
    
    if match:
        title = match.group(2).strip()
        director = match.group(3).strip()
        year = match.group(4)
        title = ' '.join(title.split())
        
        movie_data.append({
            'title': title,
            'director': director,
            'year': year
        })

# %% [markdown]
# ### 2. merge each film's webpage from IMDb

# %% [markdown]
# #### write the function of getting imdb link

# %%
def get_imdb_link(title, year):
    base_url = "https://www.imdb.com"
    search_url = f"{base_url}/find/?q={title.replace(' ', '+')}+{year}"
    
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(search_url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        result = soup.find('a', class_='ipc-metadata-list-summary-item__t')
        
        if result:
            return base_url + result['href'].split('?')[0] 
        return None
    except Exception as e:
        print(f"Error searching for {title}: {e}")
        return None

# %% [markdown]
# #### create a loop to print each movie's link

# %%
for movie in movie_data:
    link = get_imdb_link(movie['title'], movie['year'])
    movie['link'] = link

# %%
# checkpoint - if everything is loaded correctly
movie_data
# Out:
# [{'title': 'The Kids are All Right',
#   'director': 'Lisa Cholodenko',
#   'year': '2010',
#   'link': 'https://www.boxofficemojo.com/title/tt0842926/',
#   'boxofficemojo_link': None},
#  {'title': 'The Souvenir',
#   'director': 'Joanna Hogg',
#   'year': '2019',
#   'link': 'https://www.boxofficemojo.com/title/tt6920356/',
#   'boxofficemojo_link': None},
#  {'title': 'Somewhere',
#   'director': 'Sofia Coppola',
#   'year': '2010',
#   'link': 'https://www.boxofficemojo.com/title/tt1421051/',
#   'boxofficemojo_link': None},
#  {'title': 'Adoption',
#   'director': 'Márta Mészáros',
#   'year': '1975',
#   'link': 'https://www.boxofficemojo.com/title/tt8555446/',
#   'boxofficemojo_link': None},
#  {'title': 'The Meetings of Anna',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'link': 'https://www.boxofficemojo.com/title/tt0078152/',
#   'boxofficemojo_link': None},
#  {'title': 'Ritual in Transfigured Time',
#   'director': 'Maya Deren',
#   'year': '1946',
#   'link': None,
#   'boxofficemojo_link': None},
#  {'title': 'News From Home',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'link': 'https://www.boxofficemojo.com/title/tt0097332/',
#   'boxofficemojo_link': None},
#  {'title': 'Red Road',
#   'director': 'Andrea Arnold',
#   'year': '2006',
#   'link': 'https://www.boxofficemojo.com/title/tt0471030/',
#   'boxofficemojo_link': None},
#  {'title': 'Raw',
#   'director': 'Julia Ducournau',
#   'year': '2016',
#   'link': 'https://www.boxofficemojo.com/title/tt4954522/',
#   'boxofficemojo_link': None},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'link': 'https://www.boxofficemojo.com/title/tt1135952/',
#   'boxofficemojo_link': None},
#  {'title': 'Fast Times at Ridgemont High',
#   'director': 'Amy Heckerling',
#   'year': '1982',
#   'link': 'https://www.boxofficemojo.com/title/tt0083929/',
#   'boxofficemojo_link': None},
#  {'title': 'The Beaches of Agnes',
#   'director': 'Agnès Varda',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt1129435/',
#   'boxofficemojo_link': None},
#  {'title': 'The Silences of the Palace',
#   'director': 'Moufida Tlatli',
#   'year': '1994',
#   'link': 'https://www.boxofficemojo.com/title/tt14549270/',
#   'boxofficemojo_link': None},
#  {'title': '35 Shots of Rum',
#   'director': 'Claire Denis',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt1100048/',
#   'boxofficemojo_link': None},
#  {'title': 'Wadjda',
#   'director': 'Haifaa Al-Mansour',
#   'year': '2012',
#   'link': 'https://www.boxofficemojo.com/title/tt2258858/',
#   'boxofficemojo_link': None},
#  {'title': 'One Sings, The Other Doesn’t',
#   'director': 'Agnès Varda',
#   'year': '1977',
#   'link': 'https://www.boxofficemojo.com/title/tt0076855/',
#   'boxofficemojo_link': None},
#  {'title': 'Portrait of Jason',
#   'director': 'Shirley Clarke',
#   'year': '1967',
#   'link': 'https://www.boxofficemojo.com/title/tt8613070/',
#   'boxofficemojo_link': None},
#  {'title': 'Sleepless in Seattle',
#   'director': 'Nora Ephron',
#   'year': '1993',
#   'link': 'https://www.boxofficemojo.com/title/tt0108160/',
#   'boxofficemojo_link': None},
#  {'title': 'At Land',
#   'director': 'Maya Deren',
#   'year': '1944',
#   'link': 'https://www.boxofficemojo.com/title/tt1918921/',
#   'boxofficemojo_link': None},
#  {'title': 'A Girl Walks Home Alone at Night',
#   'director': 'Ana Lily Amirpour',
#   'year': '2014',
#   'link': 'https://www.boxofficemojo.com/title/tt2326554/',
#   'boxofficemojo_link': None},
#  {'title': 'Big',
#   'director': 'Penny Marshall',
#   'year': '1988',
#   'link': 'https://www.boxofficemojo.com/title/tt0094737/',
#   'boxofficemojo_link': None},
#  {'title': 'Shoes',
#   'director': 'Lois Weber',
#   'year': '1916',
#   'link': 'https://www.boxofficemojo.com/title/tt0419677/',
#   'boxofficemojo_link': None},
#  {'title': 'The Apple',
#   'director': 'Samira Makhmalbaf',
#   'year': '1998',
#   'link': 'https://www.boxofficemojo.com/title/tt0080380/',
#   'boxofficemojo_link': None},
#  {'title': 'Tomboy',
#   'director': 'Céline Sciamma',
#   'year': '2011',
#   'link': 'https://www.boxofficemojo.com/title/tt1847731/',
#   'boxofficemojo_link': None},
#  {'title': 'Girlhood',
#   'director': 'Céline Sciamma',
#   'year': '2014',
#   'link': 'https://www.boxofficemojo.com/title/tt3655522/',
#   'boxofficemojo_link': None},
#  {'title': 'Meek’s Cutoff',
#   'director': 'Kelly Reichardt',
#   'year': '2010',
#   'link': 'https://www.boxofficemojo.com/title/tt1518812/',
#   'boxofficemojo_link': None},
#  {'title': 'Chocolat',
#   'director': 'Claire Denis',
#   'year': '1988',
#   'link': 'https://www.boxofficemojo.com/title/tt0241303/',
#   'boxofficemojo_link': None},
#  {'title': 'On Body and Soul',
#   'director': 'Ildikó Enyedi',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt5607714/',
#   'boxofficemojo_link': None},
#  {'title': 'Europa Europa',
#   'director': 'Agnieszka Holland',
#   'year': '1980',
#   'link': 'https://www.boxofficemojo.com/title/tt0099776/',
#   'boxofficemojo_link': None},
#  {'title': 'The Seashell and the Clergyman',
#   'director': 'Germaine Dulac',
#   'year': '1928',
#   'link': 'https://www.boxofficemojo.com/title/tt0060196/',
#   'boxofficemojo_link': None},
#  {'title': 'Whale Rider',
#   'director': 'Niki Caro',
#   'year': '2002',
#   'link': 'https://www.boxofficemojo.com/title/tt0298228/',
#   'boxofficemojo_link': None},
#  {'title': 'The Connection',
#   'director': 'Shirley Clarke',
#   'year': '1961',
#   'link': 'https://www.boxofficemojo.com/title/tt2935564/',
#   'boxofficemojo_link': None},
#  {'title': 'Eve’s Bayou',
#   'director': 'Kasi Lemmons',
#   'year': '1997',
#   'link': 'https://www.boxofficemojo.com/title/tt0119080/',
#   'boxofficemojo_link': None},
#  {'title': 'The German Sisters',
#   'director': 'Margarethe von Trotta',
#   'year': '1981',
#   'link': 'https://www.boxofficemojo.com/title/tt0452624/',
#   'boxofficemojo_link': None},
#  {'title': 'Ratcatcher',
#   'director': 'Lynne Ramsay',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0171685/',
#   'boxofficemojo_link': None},
#  {'title': 'Leave no Trace',
#   'director': 'Debra Granik',
#   'year': '2018',
#   'link': 'https://www.boxofficemojo.com/title/tt3892172/',
#   'boxofficemojo_link': None},
#  {'title': 'The Rider',
#   'director': 'Chloe Zhao',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt6217608/',
#   'boxofficemojo_link': None},
#  {'title': 'Marie Antoinette',
#   'director': 'Sofia Coppola',
#   'year': '2006',
#   'link': 'https://www.boxofficemojo.com/title/tt15384074/',
#   'boxofficemojo_link': None},
#  {'title': 'Strange Days',
#   'director': 'Kathryn Bigelow',
#   'year': '1995',
#   'link': 'https://www.boxofficemojo.com/title/tt0114558/',
#   'boxofficemojo_link': None},
#  {'title': 'India Song',
#   'director': 'Marguerite Duras',
#   'year': '1975',
#   'link': 'https://www.boxofficemojo.com/title/tt0073166/',
#   'boxofficemojo_link': None},
#  {'title': 'A League of their Own',
#   'director': 'Penny Marshall',
#   'year': '1992',
#   'link': 'https://www.boxofficemojo.com/title/tt0104694/',
#   'boxofficemojo_link': None},
#  {'title': 'The Long Farewell',
#   'director': 'Kira Muratova',
#   'year': '1971',
#   'link': 'https://www.boxofficemojo.com/title/tt0092905/',
#   'boxofficemojo_link': None},
#  {'title': 'Desperately Seeking Susan',
#   'director': 'Susan Seidelman',
#   'year': '1985',
#   'link': 'https://www.boxofficemojo.com/title/tt0089017/',
#   'boxofficemojo_link': None},
#  {'title': 'The Babadook',
#   'director': 'Jennifer Kent',
#   'year': '2014',
#   'link': 'https://www.boxofficemojo.com/title/tt2321549/',
#   'boxofficemojo_link': None},
#  {'title': '13th',
#   'director': 'Ava DuVernay',
#   'year': '2016',
#   'link': 'https://www.boxofficemojo.com/title/tt5895028/',
#   'boxofficemojo_link': None},
#  {'title': 'Monster',
#   'director': 'Patty Jenkins',
#   'year': '2003',
#   'link': 'https://www.boxofficemojo.com/title/tt23736044/',
#   'boxofficemojo_link': None},
#  {'title': 'Bright Star',
#   'director': 'Jane Campion',
#   'year': '2009',
#   'link': 'https://www.boxofficemojo.com/title/tt0810784/',
#   'boxofficemojo_link': None},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt1221141/',
#   'boxofficemojo_link': None},
#  {'title': 'Happy as Lazzaro',
#   'director': 'Alice Rohrwacher',
#   'year': '2018',
#   'link': 'https://www.boxofficemojo.com/title/tt6752992/',
#   'boxofficemojo_link': None},
#  {'title': 'Harlan County, USA',
#   'director': 'Barbara Kopple',
#   'year': '1976',
#   'link': None,
#   'boxofficemojo_link': None},
#  {'title': 'Outrage',
#   'director': 'Ida Lupino',
#   'year': '1950',
#   'link': 'https://www.boxofficemojo.com/title/tt1462667/',
#   'boxofficemojo_link': None},
#  {'title': 'Salaam Bombay!',
#   'director': 'Mira Nair',
#   'year': '1988',
#   'link': 'https://www.boxofficemojo.com/title/tt0096028/',
#   'boxofficemojo_link': None},
#  {'title': 'The Asthenic Syndrome',
#   'director': 'Kira Muratova',
#   'year': '1989',
#   'link': 'https://www.boxofficemojo.com/title/tt0078966/',
#   'boxofficemojo_link': None},
#  {'title': 'An Angel at my Table',
#   'director': 'Jane Campion',
#   'year': '1990',
#   'link': 'https://www.boxofficemojo.com/title/tt0099040/',
#   'boxofficemojo_link': None},
#  {'title': 'Near Dark',
#   'director': 'Kathryn Bigelow',
#   'year': '1987',
#   'link': 'https://www.boxofficemojo.com/title/tt0093605/',
#   'boxofficemojo_link': None},
#  {'title': 'Triumph of the Will',
#   'director': 'Leni Riefenstahl',
#   'year': '1935',
#   'link': 'https://www.boxofficemojo.com/title/tt0098513/',
#   'boxofficemojo_link': None},
#  {'title': 'American Honey',
#   'director': 'Andrea Arnold',
#   'year': '2016',
#   'link': 'https://www.boxofficemojo.com/title/tt3721936/',
#   'boxofficemojo_link': None},
#  {'title': 'The Virgin Suicides',
#   'director': 'Sofia Coppola',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0159097/',
#   'boxofficemojo_link': None},
#  {'title': 'The Adventures of Prince Achmed',
#   'director': 'Lotte Reiniger',
#   'year': '1926',
#   'link': 'https://www.boxofficemojo.com/title/tt0015532/',
#   'boxofficemojo_link': None},
#  {'title': 'Capernaum',
#   'director': 'Nadine Labaki',
#   'year': '2018',
#   'link': 'https://www.boxofficemojo.com/title/tt8267604/',
#   'boxofficemojo_link': None},
#  {'title': 'Boys Don’t Cry',
#   'director': 'Kimberly Peirce',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0171804/',
#   'boxofficemojo_link': None},
#  {'title': 'Portrait of a Lady on Fire',
#   'director': 'Céline Sciamma',
#   'year': '2019',
#   'link': 'https://www.boxofficemojo.com/title/tt8613070/',
#   'boxofficemojo_link': None},
#  {'title': 'Paris is Burning',
#   'director': 'Jennie Livingston',
#   'year': '1990',
#   'link': 'https://www.boxofficemojo.com/title/tt0100332/',
#   'boxofficemojo_link': None},
#  {'title': 'Olympia',
#   'director': 'Leni Riefenstahl',
#   'year': '1938',
#   'link': 'https://www.boxofficemojo.com/title/tt0457302/',
#   'boxofficemojo_link': None},
#  {'title': 'Wendy and Lucy',
#   'director': 'Kelly Reichardt',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt1152850/',
#   'boxofficemojo_link': None},
#  {'title': 'The Matrix',
#   'director': 'Lana and Lilly Wachowski',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0133093/',
#   'boxofficemojo_link': None},
#  {'title': 'Morvern Callar',
#   'director': 'Lynne Ramsay',
#   'year': '2002',
#   'link': 'https://www.boxofficemojo.com/title/tt0300214/',
#   'boxofficemojo_link': None},
#  {'title': 'You Were Never Really Here',
#   'director': 'Lynne Ramsay',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt5742374/',
#   'boxofficemojo_link': None},
#  {'title': 'The Night Porter',
#   'director': 'Liliana Cavani',
#   'year': '1974',
#   'link': 'https://www.boxofficemojo.com/title/tt0054130/',
#   'boxofficemojo_link': None},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'link': 'https://www.boxofficemojo.com/title/tt0247380/',
#   'boxofficemojo_link': None},
#  {'title': 'Zama',
#   'director': 'Lucrecia Martel',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt2386377/',
#   'boxofficemojo_link': None},
#  {'title': 'Monsoon Wedding',
#   'director': 'Mira Nair',
#   'year': '2001',
#   'link': 'https://www.boxofficemojo.com/title/tt0265343/',
#   'boxofficemojo_link': None},
#  {'title': 'Le Bonheur',
#   'director': 'Agnès Varda',
#   'year': '1965',
#   'link': 'https://www.boxofficemojo.com/title/tt1327194/',
#   'boxofficemojo_link': None},
#  {'title': 'Selma',
#   'director': 'Ava DuVernay',
#   'year': '2014',
#   'link': 'https://www.boxofficemojo.com/title/tt1020072/',
#   'boxofficemojo_link': None},
#  {'title': 'Stories we Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'link': 'https://www.boxofficemojo.com/title/tt2366450/',
#   'boxofficemojo_link': None},
#  {'title': 'The House is Black',
#   'director': 'Forugh Farrokhzad',
#   'year': '1963',
#   'link': 'https://www.boxofficemojo.com/title/tt0093342/',
#   'boxofficemojo_link': None},
#  {'title': 'Lady Bird',
#   'director': 'Greta Gerwig',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt4925292/',
#   'boxofficemojo_link': None},
#  {'title': 'The Hitch-Hiker',
#   'director': 'Ida Lupino',
#   'year': '1953',
#   'link': 'https://www.boxofficemojo.com/title/tt0092796/',
#   'boxofficemojo_link': None},
#  {'title': 'We Need to Talk About Kevin',
#   'director': 'Lynne Ramsay',
#   'year': '2011',
#   'link': 'https://www.boxofficemojo.com/title/tt1242460/',
#   'boxofficemojo_link': None},
#  {'title': 'Winter’s Bone',
#   'director': 'Debra Granik',
#   'year': '2010',
#   'link': 'https://www.boxofficemojo.com/title/tt1399683/',
#   'boxofficemojo_link': None},
#  {'title': 'Clueless',
#   'director': 'Amy Heckerling',
#   'year': '1995',
#   'link': 'https://www.boxofficemojo.com/title/tt0112697/',
#   'boxofficemojo_link': None},
#  {'title': 'Orlando',
#   'director': 'Sally Potter',
#   'year': '1992',
#   'link': 'https://www.boxofficemojo.com/title/tt0107756/',
#   'boxofficemojo_link': None},
#  {'title': 'American Psycho',
#   'director': 'Mary Harron',
#   'year': '2000',
#   'link': 'https://www.boxofficemojo.com/title/tt0144084/',
#   'boxofficemojo_link': None},
#  {'title': 'Seven Beauties',
#   'director': 'Lina Wertmüller',
#   'year': '1975',
#   'link': 'https://www.boxofficemojo.com/title/tt0075040/',
#   'boxofficemojo_link': None},
#  {'title': 'Wanda',
#   'director': 'Barbara Loden',
#   'year': '1970',
#   'link': 'https://www.boxofficemojo.com/title/tt0067961/',
#   'boxofficemojo_link': None},
#  {'title': 'The Swamp',
#   'director': 'Lucrecia Martel',
#   'year': '2001',
#   'link': 'https://www.boxofficemojo.com/title/tt0240419/',
#   'boxofficemojo_link': None},
#  {'title': 'Point Break',
#   'director': 'Kathryn Bigelow',
#   'year': '1991',
#   'link': 'https://www.boxofficemojo.com/title/tt0102685/',
#   'boxofficemojo_link': None},
#  {'title': 'Vagabond',
#   'director': 'Agnès Varda',
#   'year': '1985',
#   'link': 'https://www.boxofficemojo.com/title/tt0050798/',
#   'boxofficemojo_link': None},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'link': 'https://www.boxofficemojo.com/title/tt1790885/',
#   'boxofficemojo_link': None},
#  {'title': 'The Ascent',
#   'director': 'Larisa Shepitko',
#   'year': '1977',
#   'link': 'https://www.boxofficemojo.com/title/tt7893394/',
#   'boxofficemojo_link': None},
#  {'title': 'Daughters of the Dust',
#   'director': 'Julie Dash',
#   'year': '1991',
#   'link': 'https://www.boxofficemojo.com/title/tt0104057/',
#   'boxofficemojo_link': None},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'link': 'https://www.boxofficemojo.com/title/tt1232776/',
#   'boxofficemojo_link': None},
#  {'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'link': 'https://www.boxofficemojo.com/title/tt4048272/',
#   'boxofficemojo_link': None},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt0887912/',
#   'boxofficemojo_link': None},
#  {'title': 'Daisies',
#   'director': 'Věra Chytilová',
#   'year': '1966',
#   'link': 'https://www.boxofficemojo.com/title/tt0060959/',
#   'boxofficemojo_link': None},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'link': 'https://www.boxofficemojo.com/title/tt0335266/',
#   'boxofficemojo_link': None},
#  {'title': 'Beau Travail',
#   'director': 'Claire Denis',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0209933/',
#   'boxofficemojo_link': None},
#  {'title': 'Jeanne Dielman, 23 Quai du Commerce, 1080 Bruxelles',
#   'director': 'Chantal Akerman',
#   'year': '1975',
#   'link': 'https://www.boxofficemojo.com/title/tt0073198/',
#   'boxofficemojo_link': None},
#  {'title': 'Cléo from 5 to 7',
#   'director': 'Agnès Varda',
#   'year': '1962',
#   'link': 'https://www.boxofficemojo.com/title/tt0055852/',
#   'boxofficemojo_link': None},
#  {'title': 'The Piano',
#   'director': 'Jane Campion',
#   'year': '1993',
#   'link': 'https://www.boxofficemojo.com/title/tt0107822/',
#   'boxofficemojo_link': None}]

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %% [markdown]
# #### extract each film's rating

# %%
for movie in movie_data:
    try:
        response = requests.get(movie['link'], headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Try both possible rating locations
        rating = soup.find(class_='sc-d541859f-1 imUuxf').get_text(strip=True)
        
        movie['rating'] = rating if rating else "N/A"
        
    except Exception as e:
        print(f"Error getting rating for {movie['title']}: {str(e)}")
        movie['rating'] = "N/A"
# Out:
# Error getting rating for The Long Farewell: 'NoneType' object has no attribute 'get_text'
# Error getting rating for The Headless Woman: 'NoneType' object has no attribute 'get_text'

# %% [markdown]
# #### correct wrong links

# %%
corrected = {
    'The Long Farewell': 'https://www.imdb.com/title/tt0092905/',
    'The Headless Woman': 'https://www.imdb.com/title/tt1221141/',
}

for movie in movie_data:
    title = movie['title']
    if title in corrected:
        movie['link'] = corrected[title]

# %%
# second checkpoint
movie_data
# Out:
# [{'title': 'The Kids are All Right',
#   'director': 'Lisa Cholodenko',
#   'year': '2010',
#   'link': 'https://www.boxofficemojo.com/title/tt0842926/',
#   'boxofficemojo_link': None},
#  {'title': 'The Souvenir',
#   'director': 'Joanna Hogg',
#   'year': '2019',
#   'link': 'https://www.boxofficemojo.com/title/tt6920356/',
#   'boxofficemojo_link': None},
#  {'title': 'Somewhere',
#   'director': 'Sofia Coppola',
#   'year': '2010',
#   'link': 'https://www.boxofficemojo.com/title/tt1421051/',
#   'boxofficemojo_link': None},
#  {'title': 'Adoption',
#   'director': 'Márta Mészáros',
#   'year': '1975',
#   'link': 'https://www.boxofficemojo.com/title/tt8555446/',
#   'boxofficemojo_link': None},
#  {'title': 'The Meetings of Anna',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'link': 'https://www.boxofficemojo.com/title/tt0078152/',
#   'boxofficemojo_link': None},
#  {'title': 'Ritual in Transfigured Time',
#   'director': 'Maya Deren',
#   'year': '1946',
#   'link': None,
#   'boxofficemojo_link': None},
#  {'title': 'News From Home',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'link': 'https://www.boxofficemojo.com/title/tt0097332/',
#   'boxofficemojo_link': None},
#  {'title': 'Red Road',
#   'director': 'Andrea Arnold',
#   'year': '2006',
#   'link': 'https://www.boxofficemojo.com/title/tt0471030/',
#   'boxofficemojo_link': None},
#  {'title': 'Raw',
#   'director': 'Julia Ducournau',
#   'year': '2016',
#   'link': 'https://www.boxofficemojo.com/title/tt4954522/',
#   'boxofficemojo_link': None},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'link': 'https://www.boxofficemojo.com/title/tt1135952/',
#   'boxofficemojo_link': None},
#  {'title': 'Fast Times at Ridgemont High',
#   'director': 'Amy Heckerling',
#   'year': '1982',
#   'link': 'https://www.boxofficemojo.com/title/tt0083929/',
#   'boxofficemojo_link': None},
#  {'title': 'The Beaches of Agnes',
#   'director': 'Agnès Varda',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt1129435/',
#   'boxofficemojo_link': None},
#  {'title': 'The Silences of the Palace',
#   'director': 'Moufida Tlatli',
#   'year': '1994',
#   'link': 'https://www.boxofficemojo.com/title/tt14549270/',
#   'boxofficemojo_link': None},
#  {'title': '35 Shots of Rum',
#   'director': 'Claire Denis',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt1100048/',
#   'boxofficemojo_link': None},
#  {'title': 'Wadjda',
#   'director': 'Haifaa Al-Mansour',
#   'year': '2012',
#   'link': 'https://www.boxofficemojo.com/title/tt2258858/',
#   'boxofficemojo_link': None},
#  {'title': 'One Sings, The Other Doesn’t',
#   'director': 'Agnès Varda',
#   'year': '1977',
#   'link': 'https://www.boxofficemojo.com/title/tt0076855/',
#   'boxofficemojo_link': None},
#  {'title': 'Portrait of Jason',
#   'director': 'Shirley Clarke',
#   'year': '1967',
#   'link': 'https://www.boxofficemojo.com/title/tt8613070/',
#   'boxofficemojo_link': None},
#  {'title': 'Sleepless in Seattle',
#   'director': 'Nora Ephron',
#   'year': '1993',
#   'link': 'https://www.boxofficemojo.com/title/tt0108160/',
#   'boxofficemojo_link': None},
#  {'title': 'At Land',
#   'director': 'Maya Deren',
#   'year': '1944',
#   'link': 'https://www.boxofficemojo.com/title/tt1918921/',
#   'boxofficemojo_link': None},
#  {'title': 'A Girl Walks Home Alone at Night',
#   'director': 'Ana Lily Amirpour',
#   'year': '2014',
#   'link': 'https://www.boxofficemojo.com/title/tt2326554/',
#   'boxofficemojo_link': None},
#  {'title': 'Big',
#   'director': 'Penny Marshall',
#   'year': '1988',
#   'link': 'https://www.boxofficemojo.com/title/tt0094737/',
#   'boxofficemojo_link': None},
#  {'title': 'Shoes',
#   'director': 'Lois Weber',
#   'year': '1916',
#   'link': 'https://www.boxofficemojo.com/title/tt0419677/',
#   'boxofficemojo_link': None},
#  {'title': 'The Apple',
#   'director': 'Samira Makhmalbaf',
#   'year': '1998',
#   'link': 'https://www.boxofficemojo.com/title/tt0080380/',
#   'boxofficemojo_link': None},
#  {'title': 'Tomboy',
#   'director': 'Céline Sciamma',
#   'year': '2011',
#   'link': 'https://www.boxofficemojo.com/title/tt1847731/',
#   'boxofficemojo_link': None},
#  {'title': 'Girlhood',
#   'director': 'Céline Sciamma',
#   'year': '2014',
#   'link': 'https://www.boxofficemojo.com/title/tt3655522/',
#   'boxofficemojo_link': None},
#  {'title': 'Meek’s Cutoff',
#   'director': 'Kelly Reichardt',
#   'year': '2010',
#   'link': 'https://www.boxofficemojo.com/title/tt1518812/',
#   'boxofficemojo_link': None},
#  {'title': 'Chocolat',
#   'director': 'Claire Denis',
#   'year': '1988',
#   'link': 'https://www.boxofficemojo.com/title/tt0241303/',
#   'boxofficemojo_link': None},
#  {'title': 'On Body and Soul',
#   'director': 'Ildikó Enyedi',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt5607714/',
#   'boxofficemojo_link': None},
#  {'title': 'Europa Europa',
#   'director': 'Agnieszka Holland',
#   'year': '1980',
#   'link': 'https://www.boxofficemojo.com/title/tt0099776/',
#   'boxofficemojo_link': None},
#  {'title': 'The Seashell and the Clergyman',
#   'director': 'Germaine Dulac',
#   'year': '1928',
#   'link': 'https://www.boxofficemojo.com/title/tt0060196/',
#   'boxofficemojo_link': None},
#  {'title': 'Whale Rider',
#   'director': 'Niki Caro',
#   'year': '2002',
#   'link': 'https://www.boxofficemojo.com/title/tt0298228/',
#   'boxofficemojo_link': None},
#  {'title': 'The Connection',
#   'director': 'Shirley Clarke',
#   'year': '1961',
#   'link': 'https://www.boxofficemojo.com/title/tt2935564/',
#   'boxofficemojo_link': None},
#  {'title': 'Eve’s Bayou',
#   'director': 'Kasi Lemmons',
#   'year': '1997',
#   'link': 'https://www.boxofficemojo.com/title/tt0119080/',
#   'boxofficemojo_link': None},
#  {'title': 'The German Sisters',
#   'director': 'Margarethe von Trotta',
#   'year': '1981',
#   'link': 'https://www.boxofficemojo.com/title/tt0452624/',
#   'boxofficemojo_link': None},
#  {'title': 'Ratcatcher',
#   'director': 'Lynne Ramsay',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0171685/',
#   'boxofficemojo_link': None},
#  {'title': 'Leave no Trace',
#   'director': 'Debra Granik',
#   'year': '2018',
#   'link': 'https://www.boxofficemojo.com/title/tt3892172/',
#   'boxofficemojo_link': None},
#  {'title': 'The Rider',
#   'director': 'Chloe Zhao',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt6217608/',
#   'boxofficemojo_link': None},
#  {'title': 'Marie Antoinette',
#   'director': 'Sofia Coppola',
#   'year': '2006',
#   'link': 'https://www.boxofficemojo.com/title/tt15384074/',
#   'boxofficemojo_link': None},
#  {'title': 'Strange Days',
#   'director': 'Kathryn Bigelow',
#   'year': '1995',
#   'link': 'https://www.boxofficemojo.com/title/tt0114558/',
#   'boxofficemojo_link': None},
#  {'title': 'India Song',
#   'director': 'Marguerite Duras',
#   'year': '1975',
#   'link': 'https://www.boxofficemojo.com/title/tt0073166/',
#   'boxofficemojo_link': None},
#  {'title': 'A League of their Own',
#   'director': 'Penny Marshall',
#   'year': '1992',
#   'link': 'https://www.boxofficemojo.com/title/tt0104694/',
#   'boxofficemojo_link': None},
#  {'title': 'The Long Farewell',
#   'director': 'Kira Muratova',
#   'year': '1971',
#   'link': 'https://www.boxofficemojo.com/title/tt0092905/',
#   'boxofficemojo_link': None},
#  {'title': 'Desperately Seeking Susan',
#   'director': 'Susan Seidelman',
#   'year': '1985',
#   'link': 'https://www.boxofficemojo.com/title/tt0089017/',
#   'boxofficemojo_link': None},
#  {'title': 'The Babadook',
#   'director': 'Jennifer Kent',
#   'year': '2014',
#   'link': 'https://www.boxofficemojo.com/title/tt2321549/',
#   'boxofficemojo_link': None},
#  {'title': '13th',
#   'director': 'Ava DuVernay',
#   'year': '2016',
#   'link': 'https://www.boxofficemojo.com/title/tt5895028/',
#   'boxofficemojo_link': None},
#  {'title': 'Monster',
#   'director': 'Patty Jenkins',
#   'year': '2003',
#   'link': 'https://www.boxofficemojo.com/title/tt23736044/',
#   'boxofficemojo_link': None},
#  {'title': 'Bright Star',
#   'director': 'Jane Campion',
#   'year': '2009',
#   'link': 'https://www.boxofficemojo.com/title/tt0810784/',
#   'boxofficemojo_link': None},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt1221141/',
#   'boxofficemojo_link': None},
#  {'title': 'Happy as Lazzaro',
#   'director': 'Alice Rohrwacher',
#   'year': '2018',
#   'link': 'https://www.boxofficemojo.com/title/tt6752992/',
#   'boxofficemojo_link': None},
#  {'title': 'Harlan County, USA',
#   'director': 'Barbara Kopple',
#   'year': '1976',
#   'link': None,
#   'boxofficemojo_link': None},
#  {'title': 'Outrage',
#   'director': 'Ida Lupino',
#   'year': '1950',
#   'link': 'https://www.boxofficemojo.com/title/tt1462667/',
#   'boxofficemojo_link': None},
#  {'title': 'Salaam Bombay!',
#   'director': 'Mira Nair',
#   'year': '1988',
#   'link': 'https://www.boxofficemojo.com/title/tt0096028/',
#   'boxofficemojo_link': None},
#  {'title': 'The Asthenic Syndrome',
#   'director': 'Kira Muratova',
#   'year': '1989',
#   'link': 'https://www.boxofficemojo.com/title/tt0078966/',
#   'boxofficemojo_link': None},
#  {'title': 'An Angel at my Table',
#   'director': 'Jane Campion',
#   'year': '1990',
#   'link': 'https://www.boxofficemojo.com/title/tt0099040/',
#   'boxofficemojo_link': None},
#  {'title': 'Near Dark',
#   'director': 'Kathryn Bigelow',
#   'year': '1987',
#   'link': 'https://www.boxofficemojo.com/title/tt0093605/',
#   'boxofficemojo_link': None},
#  {'title': 'Triumph of the Will',
#   'director': 'Leni Riefenstahl',
#   'year': '1935',
#   'link': 'https://www.boxofficemojo.com/title/tt0098513/',
#   'boxofficemojo_link': None},
#  {'title': 'American Honey',
#   'director': 'Andrea Arnold',
#   'year': '2016',
#   'link': 'https://www.boxofficemojo.com/title/tt3721936/',
#   'boxofficemojo_link': None},
#  {'title': 'The Virgin Suicides',
#   'director': 'Sofia Coppola',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0159097/',
#   'boxofficemojo_link': None},
#  {'title': 'The Adventures of Prince Achmed',
#   'director': 'Lotte Reiniger',
#   'year': '1926',
#   'link': 'https://www.boxofficemojo.com/title/tt0015532/',
#   'boxofficemojo_link': None},
#  {'title': 'Capernaum',
#   'director': 'Nadine Labaki',
#   'year': '2018',
#   'link': 'https://www.boxofficemojo.com/title/tt8267604/',
#   'boxofficemojo_link': None},
#  {'title': 'Boys Don’t Cry',
#   'director': 'Kimberly Peirce',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0171804/',
#   'boxofficemojo_link': None},
#  {'title': 'Portrait of a Lady on Fire',
#   'director': 'Céline Sciamma',
#   'year': '2019',
#   'link': 'https://www.boxofficemojo.com/title/tt8613070/',
#   'boxofficemojo_link': None},
#  {'title': 'Paris is Burning',
#   'director': 'Jennie Livingston',
#   'year': '1990',
#   'link': 'https://www.boxofficemojo.com/title/tt0100332/',
#   'boxofficemojo_link': None},
#  {'title': 'Olympia',
#   'director': 'Leni Riefenstahl',
#   'year': '1938',
#   'link': 'https://www.boxofficemojo.com/title/tt0457302/',
#   'boxofficemojo_link': None},
#  {'title': 'Wendy and Lucy',
#   'director': 'Kelly Reichardt',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt1152850/',
#   'boxofficemojo_link': None},
#  {'title': 'The Matrix',
#   'director': 'Lana and Lilly Wachowski',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0133093/',
#   'boxofficemojo_link': None},
#  {'title': 'Morvern Callar',
#   'director': 'Lynne Ramsay',
#   'year': '2002',
#   'link': 'https://www.boxofficemojo.com/title/tt0300214/',
#   'boxofficemojo_link': None},
#  {'title': 'You Were Never Really Here',
#   'director': 'Lynne Ramsay',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt5742374/',
#   'boxofficemojo_link': None},
#  {'title': 'The Night Porter',
#   'director': 'Liliana Cavani',
#   'year': '1974',
#   'link': 'https://www.boxofficemojo.com/title/tt0054130/',
#   'boxofficemojo_link': None},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'link': 'https://www.boxofficemojo.com/title/tt0247380/',
#   'boxofficemojo_link': None},
#  {'title': 'Zama',
#   'director': 'Lucrecia Martel',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt2386377/',
#   'boxofficemojo_link': None},
#  {'title': 'Monsoon Wedding',
#   'director': 'Mira Nair',
#   'year': '2001',
#   'link': 'https://www.boxofficemojo.com/title/tt0265343/',
#   'boxofficemojo_link': None},
#  {'title': 'Le Bonheur',
#   'director': 'Agnès Varda',
#   'year': '1965',
#   'link': 'https://www.boxofficemojo.com/title/tt1327194/',
#   'boxofficemojo_link': None},
#  {'title': 'Selma',
#   'director': 'Ava DuVernay',
#   'year': '2014',
#   'link': 'https://www.boxofficemojo.com/title/tt1020072/',
#   'boxofficemojo_link': None},
#  {'title': 'Stories we Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'link': 'https://www.boxofficemojo.com/title/tt2366450/',
#   'boxofficemojo_link': None},
#  {'title': 'The House is Black',
#   'director': 'Forugh Farrokhzad',
#   'year': '1963',
#   'link': 'https://www.boxofficemojo.com/title/tt0093342/',
#   'boxofficemojo_link': None},
#  {'title': 'Lady Bird',
#   'director': 'Greta Gerwig',
#   'year': '2017',
#   'link': 'https://www.boxofficemojo.com/title/tt4925292/',
#   'boxofficemojo_link': None},
#  {'title': 'The Hitch-Hiker',
#   'director': 'Ida Lupino',
#   'year': '1953',
#   'link': 'https://www.boxofficemojo.com/title/tt0092796/',
#   'boxofficemojo_link': None},
#  {'title': 'We Need to Talk About Kevin',
#   'director': 'Lynne Ramsay',
#   'year': '2011',
#   'link': 'https://www.boxofficemojo.com/title/tt1242460/',
#   'boxofficemojo_link': None},
#  {'title': 'Winter’s Bone',
#   'director': 'Debra Granik',
#   'year': '2010',
#   'link': 'https://www.boxofficemojo.com/title/tt1399683/',
#   'boxofficemojo_link': None},
#  {'title': 'Clueless',
#   'director': 'Amy Heckerling',
#   'year': '1995',
#   'link': 'https://www.boxofficemojo.com/title/tt0112697/',
#   'boxofficemojo_link': None},
#  {'title': 'Orlando',
#   'director': 'Sally Potter',
#   'year': '1992',
#   'link': 'https://www.boxofficemojo.com/title/tt0107756/',
#   'boxofficemojo_link': None},
#  {'title': 'American Psycho',
#   'director': 'Mary Harron',
#   'year': '2000',
#   'link': 'https://www.boxofficemojo.com/title/tt0144084/',
#   'boxofficemojo_link': None},
#  {'title': 'Seven Beauties',
#   'director': 'Lina Wertmüller',
#   'year': '1975',
#   'link': 'https://www.boxofficemojo.com/title/tt0075040/',
#   'boxofficemojo_link': None},
#  {'title': 'Wanda',
#   'director': 'Barbara Loden',
#   'year': '1970',
#   'link': 'https://www.boxofficemojo.com/title/tt0067961/',
#   'boxofficemojo_link': None},
#  {'title': 'The Swamp',
#   'director': 'Lucrecia Martel',
#   'year': '2001',
#   'link': 'https://www.boxofficemojo.com/title/tt0240419/',
#   'boxofficemojo_link': None},
#  {'title': 'Point Break',
#   'director': 'Kathryn Bigelow',
#   'year': '1991',
#   'link': 'https://www.boxofficemojo.com/title/tt0102685/',
#   'boxofficemojo_link': None},
#  {'title': 'Vagabond',
#   'director': 'Agnès Varda',
#   'year': '1985',
#   'link': 'https://www.boxofficemojo.com/title/tt0050798/',
#   'boxofficemojo_link': None},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'link': 'https://www.boxofficemojo.com/title/tt1790885/',
#   'boxofficemojo_link': None},
#  {'title': 'The Ascent',
#   'director': 'Larisa Shepitko',
#   'year': '1977',
#   'link': 'https://www.boxofficemojo.com/title/tt7893394/',
#   'boxofficemojo_link': None},
#  {'title': 'Daughters of the Dust',
#   'director': 'Julie Dash',
#   'year': '1991',
#   'link': 'https://www.boxofficemojo.com/title/tt0104057/',
#   'boxofficemojo_link': None},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'link': 'https://www.boxofficemojo.com/title/tt1232776/',
#   'boxofficemojo_link': None},
#  {'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'link': 'https://www.boxofficemojo.com/title/tt4048272/',
#   'boxofficemojo_link': None},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'link': 'https://www.boxofficemojo.com/title/tt0887912/',
#   'boxofficemojo_link': None},
#  {'title': 'Daisies',
#   'director': 'Věra Chytilová',
#   'year': '1966',
#   'link': 'https://www.boxofficemojo.com/title/tt0060959/',
#   'boxofficemojo_link': None},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'link': 'https://www.boxofficemojo.com/title/tt0335266/',
#   'boxofficemojo_link': None},
#  {'title': 'Beau Travail',
#   'director': 'Claire Denis',
#   'year': '1999',
#   'link': 'https://www.boxofficemojo.com/title/tt0209933/',
#   'boxofficemojo_link': None},
#  {'title': 'Jeanne Dielman, 23 Quai du Commerce, 1080 Bruxelles',
#   'director': 'Chantal Akerman',
#   'year': '1975',
#   'link': 'https://www.boxofficemojo.com/title/tt0073198/',
#   'boxofficemojo_link': None},
#  {'title': 'Cléo from 5 to 7',
#   'director': 'Agnès Varda',
#   'year': '1962',
#   'link': 'https://www.boxofficemojo.com/title/tt0055852/',
#   'boxofficemojo_link': None},
#  {'title': 'The Piano',
#   'director': 'Jane Campion',
#   'year': '1993',
#   'link': 'https://www.boxofficemojo.com/title/tt0107822/',
#   'boxofficemojo_link': None}]

# %% [markdown]
# ### 3. write a function that extracts the number of wins and nominations

# %%
def extract_wins_nominations(awards_text):
    match = re.search(r'(\d+)\s*wins?\s*&\s*(\d+)\s*nominations?', awards_text)
    if match:
        return int(match.group(1)), int(match.group(2))
    return None, None

for movie in movie_data:
    if not movie.get('link'):
        movie['wins'] = None
        movie['nominations'] = None
        continue
    
    try:       
        response = requests.get(movie['link'], headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        awards_span = soup.find('span', class_='ipc-metadata-list-item__list-content-item')
        
        if awards_span:
            awards_text = awards_span.get_text(strip=True)
            wins, nominations = extract_wins_nominations(awards_text)
            
            movie['wins'] = wins
            movie['nominations'] = nominations

        else:
            movie['wins'] = None
            movie['nominations'] = None
            
    except Exception as e:
        print(f"Error processing {movie.get('title', 'Unknown')}: {str(e)}")
        movie['wins'] = None
        movie['nominations'] = None

# %%
# third checkpoint
movie_data
# Out:
# [{'title': 'The Kids are All Right',
#   'director': 'Lisa Cholodenko',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt0842926/',
#   'rating': '7.0',
#   'wins': 29,
#   'nominations': 133},
#  {'title': 'The Souvenir',
#   'director': 'Joanna Hogg',
#   'year': '2019',
#   'link': 'https://www.imdb.com/title/tt6920356/',
#   'rating': '6.4',
#   'wins': 7,
#   'nominations': 37},
#  {'title': 'Somewhere',
#   'director': 'Sofia Coppola',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1421051/',
#   'rating': '6.3',
#   'wins': 4,
#   'nominations': 8},
#  {'title': 'Adoption',
#   'director': 'Márta Mészáros',
#   'year': '1975',
#   'link': 'https://www.imdb.com/title/tt0073948/',
#   'rating': '7.2',
#   'wins': 4,
#   'nominations': 1},
#  {'title': 'The Meetings of Anna',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'link': 'https://www.imdb.com/title/tt4441280/',
#   'rating': '5.9',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Ritual in Transfigured Time',
#   'director': 'Maya Deren',
#   'year': '1946',
#   'link': 'https://www.imdb.com/title/tt0038885/',
#   'rating': '6.9',
#   'wins': None,
#   'nominations': None},
#  {'title': 'News From Home',
#   'director': 'Chantal Akerman',
#   'year': '1977',
#   'link': 'https://www.imdb.com/title/tt0076452/',
#   'rating': '7.3',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Red Road',
#   'director': 'Andrea Arnold',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0471030/',
#   'rating': '6.8',
#   'wins': 22,
#   'nominations': 12},
#  {'title': 'Raw',
#   'director': 'Julia Ducournau',
#   'year': '2016',
#   'link': 'https://www.imdb.com/title/tt4954522/',
#   'rating': '6.9',
#   'wins': 25,
#   'nominations': 45},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1135952/',
#   'rating': '6.9',
#   'wins': 1,
#   'nominations': 10},
#  {'title': 'Fast Times at Ridgemont High',
#   'director': 'Amy Heckerling',
#   'year': '1982',
#   'link': 'https://www.imdb.com/title/tt0083929/',
#   'rating': '7.1',
#   'wins': 1,
#   'nominations': 1},
#  {'title': 'The Beaches of Agnes',
#   'director': 'Agnès Varda',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt1129435/',
#   'rating': '8.0',
#   'wins': 12,
#   'nominations': 13},
#  {'title': 'The Silences of the Palace',
#   'director': 'Moufida Tlatli',
#   'year': '1994',
#   'link': 'https://www.imdb.com/title/tt0111055/',
#   'rating': '7.3',
#   'wins': None,
#   'nominations': None},
#  {'title': '35 Shots of Rum',
#   'director': 'Claire Denis',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt1100048/',
#   'rating': '7.1',
#   'wins': 2,
#   'nominations': 17},
#  {'title': 'Wadjda',
#   'director': 'Haifaa Al-Mansour',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2258858/',
#   'rating': '7.5',
#   'wins': 22,
#   'nominations': 36},
#  {'title': 'One Sings, The Other Doesn’t',
#   'director': 'Agnès Varda',
#   'year': '1977',
#   'link': 'https://www.imdb.com/title/tt0076855/',
#   'rating': '7.4',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Portrait of Jason',
#   'director': 'Shirley Clarke',
#   'year': '1967',
#   'link': 'https://www.imdb.com/title/tt0062144/',
#   'rating': '7.0',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Sleepless in Seattle',
#   'director': 'Nora Ephron',
#   'year': '1993',
#   'link': 'https://www.imdb.com/title/tt0108160/',
#   'rating': '6.8',
#   'wins': 4,
#   'nominations': 19},
#  {'title': 'At Land',
#   'director': 'Maya Deren',
#   'year': '1944',
#   'link': 'https://www.imdb.com/title/tt0036618/',
#   'rating': '7.5',
#   'wins': None,
#   'nominations': None},
#  {'title': 'A Girl Walks Home Alone at Night',
#   'director': 'Ana Lily Amirpour',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt2326554/',
#   'rating': '6.9',
#   'wins': 9,
#   'nominations': 23},
#  {'title': 'Big',
#   'director': 'Penny Marshall',
#   'year': '1988',
#   'link': 'https://www.imdb.com/title/tt0094737/',
#   'rating': '7.3',
#   'wins': 11,
#   'nominations': 14},
#  {'title': 'Shoes',
#   'director': 'Lois Weber',
#   'year': '1916',
#   'link': 'https://www.imdb.com/title/tt0007340/',
#   'rating': '6.9',
#   'wins': None,
#   'nominations': None},
#  {'title': 'The Apple',
#   'director': 'Samira Makhmalbaf',
#   'year': '1998',
#   'link': 'https://www.imdb.com/title/tt0156901/',
#   'rating': '7.2',
#   'wins': 7,
#   'nominations': 7},
#  {'title': 'Tomboy',
#   'director': 'Céline Sciamma',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1847731/',
#   'rating': '7.4',
#   'wins': 10,
#   'nominations': 6},
#  {'title': 'Girlhood',
#   'director': 'Céline Sciamma',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt3655522/',
#   'rating': '6.9',
#   'wins': 12,
#   'nominations': 22},
#  {'title': 'Meek’s Cutoff',
#   'director': 'Kelly Reichardt',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1518812/',
#   'rating': '6.5',
#   'wins': 7,
#   'nominations': 14},
#  {'title': 'Chocolat',
#   'director': 'Claire Denis',
#   'year': '1988',
#   'link': 'https://www.imdb.com/title/tt0094868/',
#   'rating': '7.3',
#   'wins': 1,
#   'nominations': 3},
#  {'title': 'On Body and Soul',
#   'director': 'Ildikó Enyedi',
#   'year': '2017',
#   'link': 'https://www.imdb.com/title/tt5607714/',
#   'rating': '7.5',
#   'wins': 19,
#   'nominations': 23},
#  {'title': 'Europa Europa',
#   'director': 'Agnieszka Holland',
#   'year': '1980',
#   'link': 'https://www.imdb.com/title/tt0099776/',
#   'rating': '7.5',
#   'wins': 8,
#   'nominations': 8},
#  {'title': 'The Seashell and the Clergyman',
#   'director': 'Germaine Dulac',
#   'year': '1928',
#   'link': 'https://www.imdb.com/title/tt0017775/',
#   'rating': '7.0',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Whale Rider',
#   'director': 'Niki Caro',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0298228/',
#   'rating': '7.5',
#   'wins': 33,
#   'nominations': 35},
#  {'title': 'The Connection',
#   'director': 'Shirley Clarke',
#   'year': '1961',
#   'link': 'https://www.imdb.com/title/tt0054763/',
#   'rating': '7.0',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Eve’s Bayou',
#   'director': 'Kasi Lemmons',
#   'year': '1997',
#   'link': 'https://www.imdb.com/title/tt0119080/',
#   'rating': '7.2',
#   'wins': 12,
#   'nominations': 17},
#  {'title': 'The German Sisters',
#   'director': 'Margarethe von Trotta',
#   'year': '1981',
#   'link': 'https://www.imdb.com/title/tt0082081/',
#   'rating': '7.3',
#   'wins': 13,
#   'nominations': 7},
#  {'title': 'Ratcatcher',
#   'director': 'Lynne Ramsay',
#   'year': '1999',
#   'link': 'https://www.imdb.com/title/tt0171685/',
#   'rating': '7.5',
#   'wins': 12,
#   'nominations': 6},
#  {'title': 'Leave no Trace',
#   'director': 'Debra Granik',
#   'year': '2018',
#   'link': 'https://www.imdb.com/title/tt3892172/',
#   'rating': '7.1',
#   'wins': 18,
#   'nominations': 92},
#  {'title': 'The Rider',
#   'director': 'Chloe Zhao',
#   'year': '2017',
#   'link': 'https://www.imdb.com/title/tt6217608/',
#   'rating': '7.4',
#   'wins': 25,
#   'nominations': 59},
#  {'title': 'Marie Antoinette',
#   'director': 'Sofia Coppola',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0422720/',
#   'rating': '6.5',
#   'wins': 19,
#   'nominations': 24},
#  {'title': 'Strange Days',
#   'director': 'Kathryn Bigelow',
#   'year': '1995',
#   'link': 'https://www.imdb.com/title/tt0114558/',
#   'rating': '7.2',
#   'wins': 2,
#   'nominations': 4},
#  {'title': 'India Song',
#   'director': 'Marguerite Duras',
#   'year': '1975',
#   'link': 'https://www.imdb.com/title/tt0073166/',
#   'rating': '6.1',
#   'wins': None,
#   'nominations': None},
#  {'title': 'A League of their Own',
#   'director': 'Penny Marshall',
#   'year': '1992',
#   'link': 'https://www.imdb.com/title/tt0104694/',
#   'rating': '7.4',
#   'wins': 6,
#   'nominations': 13},
#  {'title': 'The Long Farewell',
#   'director': 'Kira Muratova',
#   'year': '1971',
#   'link': 'https://www.imdb.com/title/tt0092905/',
#   'rating': 'N/A',
#   'wins': 1,
#   'nominations': 4},
#  {'title': 'Desperately Seeking Susan',
#   'director': 'Susan Seidelman',
#   'year': '1985',
#   'link': 'https://www.imdb.com/title/tt0089017/',
#   'rating': '6.1',
#   'wins': 2,
#   'nominations': 6},
#  {'title': 'The Babadook',
#   'director': 'Jennifer Kent',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt2321549/',
#   'rating': '6.8',
#   'wins': 56,
#   'nominations': 64},
#  {'title': '13th',
#   'director': 'Ava DuVernay',
#   'year': '2016',
#   'link': 'https://www.imdb.com/title/tt5895028/',
#   'rating': '8.2',
#   'wins': 32,
#   'nominations': 47},
#  {'title': 'Monster',
#   'director': 'Patty Jenkins',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0340855/',
#   'rating': '7.3',
#   'wins': 31,
#   'nominations': 26},
#  {'title': 'Bright Star',
#   'director': 'Jane Campion',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt0810784/',
#   'rating': '6.9',
#   'wins': 16,
#   'nominations': 54},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt1221141/',
#   'rating': 'N/A',
#   'wins': 9,
#   'nominations': 19},
#  {'title': 'Happy as Lazzaro',
#   'director': 'Alice Rohrwacher',
#   'year': '2018',
#   'link': 'https://www.imdb.com/title/tt6752992/',
#   'rating': '7.5',
#   'wins': 18,
#   'nominations': 52},
#  {'title': 'Harlan County, USA',
#   'director': 'Barbara Kopple',
#   'year': '1976',
#   'link': 'https://www.imdb.com/title/tt0074605/',
#   'rating': '8.2',
#   'wins': 9,
#   'nominations': 1},
#  {'title': 'Outrage',
#   'director': 'Ida Lupino',
#   'year': '1950',
#   'link': 'https://www.imdb.com/title/tt0042824/',
#   'rating': '6.7',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Salaam Bombay!',
#   'director': 'Mira Nair',
#   'year': '1988',
#   'link': 'https://www.imdb.com/title/tt0096028/',
#   'rating': '7.9',
#   'wins': 13,
#   'nominations': 8},
#  {'title': 'The Asthenic Syndrome',
#   'director': 'Kira Muratova',
#   'year': '1989',
#   'link': 'https://www.imdb.com/title/tt0096841/',
#   'rating': '6.6',
#   'wins': 3,
#   'nominations': 4},
#  {'title': 'An Angel at my Table',
#   'director': 'Jane Campion',
#   'year': '1990',
#   'link': 'https://www.imdb.com/title/tt0099040/',
#   'rating': '7.4',
#   'wins': 19,
#   'nominations': 5},
#  {'title': 'Near Dark',
#   'director': 'Kathryn Bigelow',
#   'year': '1987',
#   'link': 'https://www.imdb.com/title/tt0093605/',
#   'rating': '6.9',
#   'wins': 1,
#   'nominations': 9},
#  {'title': 'Triumph of the Will',
#   'director': 'Leni Riefenstahl',
#   'year': '1935',
#   'link': 'https://www.imdb.com/title/tt0025913/',
#   'rating': '7.1',
#   'wins': 1,
#   'nominations': 1},
#  {'title': 'American Honey',
#   'director': 'Andrea Arnold',
#   'year': '2016',
#   'link': 'https://www.imdb.com/title/tt3721936/',
#   'rating': '7.0',
#   'wins': 13,
#   'nominations': 43},
#  {'title': 'The Virgin Suicides',
#   'director': 'Sofia Coppola',
#   'year': '1999',
#   'link': 'https://www.imdb.com/title/tt0159097/',
#   'rating': '7.2',
#   'wins': 3,
#   'nominations': 14},
#  {'title': 'The Adventures of Prince Achmed',
#   'director': 'Lotte Reiniger',
#   'year': '1926',
#   'link': 'https://www.imdb.com/title/tt0015532/',
#   'rating': '7.8',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Capernaum',
#   'director': 'Nadine Labaki',
#   'year': '2018',
#   'link': 'https://www.imdb.com/title/tt8267604/',
#   'rating': '8.4',
#   'wins': 37,
#   'nominations': 55},
#  {'title': 'Boys Don’t Cry',
#   'director': 'Kimberly Peirce',
#   'year': '1999',
#   'link': 'https://www.imdb.com/title/tt0171804/',
#   'rating': '7.5',
#   'wins': 50,
#   'nominations': 39},
#  {'title': 'Portrait of a Lady on Fire',
#   'director': 'Céline Sciamma',
#   'year': '2019',
#   'link': 'https://www.imdb.com/title/tt8613070/',
#   'rating': '8.1',
#   'wins': 60,
#   'nominations': 164},
#  {'title': 'Paris is Burning',
#   'director': 'Jennie Livingston',
#   'year': '1990',
#   'link': 'https://www.imdb.com/title/tt0100332/',
#   'rating': '8.2',
#   'wins': 17,
#   'nominations': 1},
#  {'title': 'Olympia',
#   'director': 'Leni Riefenstahl',
#   'year': '1938',
#   'link': 'https://www.imdb.com/title/tt0030522/',
#   'rating': '7.7',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Wendy and Lucy',
#   'director': 'Kelly Reichardt',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt1152850/',
#   'rating': '7.1',
#   'wins': 9,
#   'nominations': 16},
#  {'title': 'The Matrix',
#   'director': 'Lana and Lilly Wachowski',
#   'year': '1999',
#   'link': 'https://www.imdb.com/title/tt0133093/',
#   'rating': '8.7',
#   'wins': 42,
#   'nominations': 52},
#  {'title': 'Morvern Callar',
#   'director': 'Lynne Ramsay',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0300214/',
#   'rating': '6.8',
#   'wins': 10,
#   'nominations': 16},
#  {'title': 'You Were Never Really Here',
#   'director': 'Lynne Ramsay',
#   'year': '2017',
#   'link': 'https://www.imdb.com/title/tt5742374/',
#   'rating': '6.7',
#   'wins': 24,
#   'nominations': 78},
#  {'title': 'The Night Porter',
#   'director': 'Liliana Cavani',
#   'year': '1974',
#   'link': 'https://www.imdb.com/title/tt0071910/',
#   'rating': '6.6',
#   'wins': None,
#   'nominations': None},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0247380/',
#   'rating': '7.7',
#   'wins': 16,
#   'nominations': 3},
#  {'title': 'Zama',
#   'director': 'Lucrecia Martel',
#   'year': '2017',
#   'link': 'https://www.imdb.com/title/tt3409848/',
#   'rating': '6.7',
#   'wins': 42,
#   'nominations': 48},
#  {'title': 'Monsoon Wedding',
#   'director': 'Mira Nair',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0265343/',
#   'rating': '7.3',
#   'wins': 7,
#   'nominations': 12},
#  {'title': 'Le Bonheur',
#   'director': 'Agnès Varda',
#   'year': '1965',
#   'link': 'https://www.imdb.com/title/tt0058985/',
#   'rating': '7.6',
#   'wins': 3,
#   'nominations': 3},
#  {'title': 'Selma',
#   'director': 'Ava DuVernay',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt1020072/',
#   'rating': '7.5',
#   'wins': 58,
#   'nominations': 91},
#  {'title': 'Stories we Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2366450/',
#   'rating': '7.5',
#   'wins': 25,
#   'nominations': 44},
#  {'title': 'The House is Black',
#   'director': 'Forugh Farrokhzad',
#   'year': '1963',
#   'link': 'https://www.imdb.com/title/tt0336693/',
#   'rating': '7.8',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Lady Bird',
#   'director': 'Greta Gerwig',
#   'year': '2017',
#   'link': 'https://www.imdb.com/title/tt4925292/',
#   'rating': '7.4',
#   'wins': 124,
#   'nominations': 228},
#  {'title': 'The Hitch-Hiker',
#   'director': 'Ida Lupino',
#   'year': '1953',
#   'link': 'https://www.imdb.com/title/tt0045877/',
#   'rating': '6.9',
#   'wins': None,
#   'nominations': None},
#  {'title': 'We Need to Talk About Kevin',
#   'director': 'Lynne Ramsay',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1242460/',
#   'rating': '7.4',
#   'wins': 26,
#   'nominations': 66},
#  {'title': 'Winter’s Bone',
#   'director': 'Debra Granik',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1399683/',
#   'rating': '7.1',
#   'wins': 63,
#   'nominations': 131},
#  {'title': 'Clueless',
#   'director': 'Amy Heckerling',
#   'year': '1995',
#   'link': 'https://www.imdb.com/title/tt0112697/',
#   'rating': '6.9',
#   'wins': 6,
#   'nominations': 12},
#  {'title': 'Orlando',
#   'director': 'Sally Potter',
#   'year': '1992',
#   'link': 'https://www.imdb.com/title/tt0107756/',
#   'rating': '7.1',
#   'wins': 15,
#   'nominations': 11},
#  {'title': 'American Psycho',
#   'director': 'Mary Harron',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0144084/',
#   'rating': '7.6',
#   'wins': 7,
#   'nominations': 11},
#  {'title': 'Seven Beauties',
#   'director': 'Lina Wertmüller',
#   'year': '1975',
#   'link': 'https://www.imdb.com/title/tt0075040/',
#   'rating': '7.7',
#   'wins': 2,
#   'nominations': 9},
#  {'title': 'Wanda',
#   'director': 'Barbara Loden',
#   'year': '1970',
#   'link': 'https://www.imdb.com/title/tt0067961/',
#   'rating': '7.1',
#   'wins': None,
#   'nominations': None},
#  {'title': 'The Swamp',
#   'director': 'Lucrecia Martel',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0240419/',
#   'rating': '7.0',
#   'wins': 16,
#   'nominations': 8},
#  {'title': 'Point Break',
#   'director': 'Kathryn Bigelow',
#   'year': '1991',
#   'link': 'https://www.imdb.com/title/tt0102685/',
#   'rating': '7.3',
#   'wins': 1,
#   'nominations': 2},
#  {'title': 'Vagabond',
#   'director': 'Agnès Varda',
#   'year': '1985',
#   'link': 'https://www.imdb.com/title/tt0089960/',
#   'rating': '7.6',
#   'wins': 8,
#   'nominations': 5},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1790885/',
#   'rating': '7.4',
#   'wins': 85,
#   'nominations': 174},
#  {'title': 'The Ascent',
#   'director': 'Larisa Shepitko',
#   'year': '1977',
#   'link': 'https://www.imdb.com/title/tt0075404/',
#   'rating': '8.2',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Daughters of the Dust',
#   'director': 'Julie Dash',
#   'year': '1991',
#   'link': 'https://www.imdb.com/title/tt0104057/',
#   'rating': '6.6',
#   'wins': 4,
#   'nominations': 2},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1232776/',
#   'rating': '7.3',
#   'wins': 21,
#   'nominations': 30},
#  {'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'link': 'https://www.imdb.com/title/tt4048272/',
#   'rating': '7.3',
#   'wins': 59,
#   'nominations': 85},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0887912/',
#   'rating': '7.5',
#   'wins': 125,
#   'nominations': 130},
#  {'title': 'Daisies',
#   'director': 'Věra Chytilová',
#   'year': '1966',
#   'link': 'https://www.imdb.com/title/tt0060959/',
#   'rating': '7.2',
#   'wins': 1,
#   'nominations': 1},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0335266/',
#   'rating': '7.7',
#   'wins': 97,
#   'nominations': 133},
#  {'title': 'Beau Travail',
#   'director': 'Claire Denis',
#   'year': '1999',
#   'link': 'https://www.imdb.com/title/tt0209933/',
#   'rating': '7.3',
#   'wins': 6,
#   'nominations': 12},
#  {'title': 'Jeanne Dielman, 23 Quai du Commerce, 1080 Bruxelles',
#   'director': 'Chantal Akerman',
#   'year': '1975',
#   'link': 'https://www.imdb.com/title/tt0073198/',
#   'rating': '7.5',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Cléo from 5 to 7',
#   'director': 'Agnès Varda',
#   'year': '1962',
#   'link': 'https://www.imdb.com/title/tt0055852/',
#   'rating': '7.8',
#   'wins': 2,
#   'nominations': 1},
#  {'title': 'The Piano',
#   'director': 'Jane Campion',
#   'year': '1993',
#   'link': 'https://www.imdb.com/title/tt0107822/',
#   'rating': '7.5',
#   'wins': 65,
#   'nominations': 57}]

# %%
df_females = pd.DataFrame(movie_data)

# %%
df_females.to_csv('females_list.csv', index=False)

# %%
df_females = pd.read_csv('females_list.csv')

# %%
list_of_females = df_females.to_dict('records')

# %%
for movie in list_of_females:
    try:
        response = requests.get(movie['link'], headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        genre_tags = soup.find_all('a', class_='ipc-chip ipc-chip--on-baseAlt')
        movie['genres'] = [tag.span.get_text(strip=True) for tag in genre_tags if tag.span]
    except Exception as e:
        print(f"🚨 Error processing {movie['title']}: {str(e)}")
        movie.setdefault('genres', [])

# %%
list_of_females
# Out:
# [{'title': 'The Kids are All Right',
#   'director': 'Lisa Cholodenko',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt0842926/',
#   'rating': 7.0,
#   'wins': 29.0,
#   'nominations': 133.0,
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'The Souvenir',
#   'director': 'Joanna Hogg',
#   'year': 2019,
#   'link': 'https://www.imdb.com/title/tt6920356/',
#   'rating': 6.4,
#   'wins': 7.0,
#   'nominations': 37.0,
#   'genres': ['Coming-of-Age', 'Period Drama', 'Drama', 'Romance']},
#  {'title': 'Somewhere',
#   'director': 'Sofia Coppola',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt1421051/',
#   'rating': 6.3,
#   'wins': 4.0,
#   'nominations': 8.0,
#   'genres': ['Dark Comedy', 'Quirky Comedy', 'Comedy', 'Drama', 'Romance']},
#  {'title': 'Adoption',
#   'director': 'Márta Mészáros',
#   'year': 1975,
#   'link': 'https://www.imdb.com/title/tt0073948/',
#   'rating': 7.2,
#   'wins': 4.0,
#   'nominations': 1.0,
#   'genres': ['Drama']},
#  {'title': 'The Meetings of Anna',
#   'director': 'Chantal Akerman',
#   'year': 1977,
#   'link': 'https://www.imdb.com/title/tt4441280/',
#   'rating': 5.9,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Drama', 'Thriller']},
#  {'title': 'Ritual in Transfigured Time',
#   'director': 'Maya Deren',
#   'year': 1946,
#   'link': 'https://www.imdb.com/title/tt0038885/',
#   'rating': 6.9,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Fantasy', 'Short']},
#  {'title': 'News From Home',
#   'director': 'Chantal Akerman',
#   'year': 1977,
#   'link': 'https://www.imdb.com/title/tt0076452/',
#   'rating': 7.3,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Documentary']},
#  {'title': 'Red Road',
#   'director': 'Andrea Arnold',
#   'year': 2006,
#   'link': 'https://www.imdb.com/title/tt0471030/',
#   'rating': 6.8,
#   'wins': 22.0,
#   'nominations': 12.0,
#   'genres': ['Drama', 'Mystery', 'Thriller']},
#  {'title': 'Raw',
#   'director': 'Julia Ducournau',
#   'year': 2016,
#   'link': 'https://www.imdb.com/title/tt4954522/',
#   'rating': 6.9,
#   'wins': 25.0,
#   'nominations': 45.0,
#   'genres': ['Body Horror', 'Coming-of-Age', 'Drama', 'Horror']},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt1135952/',
#   'rating': 6.9,
#   'wins': 1.0,
#   'nominations': 10.0,
#   'genres': ['Drama', 'War']},
#  {'title': 'Fast Times at Ridgemont High',
#   'director': 'Amy Heckerling',
#   'year': 1982,
#   'link': 'https://www.imdb.com/title/tt0083929/',
#   'rating': 7.1,
#   'wins': 1.0,
#   'nominations': 1.0,
#   'genres': ['Teen Comedy', 'Comedy', 'Drama']},
#  {'title': 'The Beaches of Agnes',
#   'director': 'Agnès Varda',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt1129435/',
#   'rating': 8.0,
#   'wins': 12.0,
#   'nominations': 13.0,
#   'genres': ['Biography', 'Documentary']},
#  {'title': 'The Silences of the Palace',
#   'director': 'Moufida Tlatli',
#   'year': 1994,
#   'link': 'https://www.imdb.com/title/tt0111055/',
#   'rating': 7.3,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Drama']},
#  {'title': '35 Shots of Rum',
#   'director': 'Claire Denis',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt1100048/',
#   'rating': 7.1,
#   'wins': 2.0,
#   'nominations': 17.0,
#   'genres': ['Coming-of-Age', 'Drama']},
#  {'title': 'Wadjda',
#   'director': 'Haifaa Al-Mansour',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt2258858/',
#   'rating': 7.5,
#   'wins': 22.0,
#   'nominations': 36.0,
#   'genres': ['Coming-of-Age', 'Comedy', 'Drama']},
#  {'title': 'One Sings, The Other Doesn’t',
#   'director': 'Agnès Varda',
#   'year': 1977,
#   'link': 'https://www.imdb.com/title/tt0076855/',
#   'rating': 7.4,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Drama', 'History']},
#  {'title': 'Portrait of Jason',
#   'director': 'Shirley Clarke',
#   'year': 1967,
#   'link': 'https://www.imdb.com/title/tt0062144/',
#   'rating': 7.0,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Biography', 'Documentary']},
#  {'title': 'Sleepless in Seattle',
#   'director': 'Nora Ephron',
#   'year': 1993,
#   'link': 'https://www.imdb.com/title/tt0108160/',
#   'rating': 6.8,
#   'wins': 4.0,
#   'nominations': 19.0,
#   'genres': ['Feel-Good Romance',
#    'Romantic Comedy',
#    'Romantic Epic',
#    'Comedy',
#    'Drama',
#    'Romance']},
#  {'title': 'At Land',
#   'director': 'Maya Deren',
#   'year': 1944,
#   'link': 'https://www.imdb.com/title/tt0036618/',
#   'rating': 7.5,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Drama', 'Fantasy', 'Short']},
#  {'title': 'A Girl Walks Home Alone at Night',
#   'director': 'Ana Lily Amirpour',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt2326554/',
#   'rating': 6.9,
#   'wins': 9.0,
#   'nominations': 23.0,
#   'genres': ['Dark Romance',
#    'Vampire Horror',
#    'Drama',
#    'Horror',
#    'Romance',
#    'Thriller']},
#  {'title': 'Big',
#   'director': 'Penny Marshall',
#   'year': 1988,
#   'link': 'https://www.imdb.com/title/tt0094737/',
#   'rating': 7.3,
#   'wins': 11.0,
#   'nominations': 14.0,
#   'genres': ['Body Swap Comedy',
#    'Coming-of-Age',
#    'High-Concept Comedy',
#    'Comedy',
#    'Drama',
#    'Fantasy',
#    'Romance']},
#  {'title': 'Shoes',
#   'director': 'Lois Weber',
#   'year': 1916,
#   'link': 'https://www.imdb.com/title/tt0007340/',
#   'rating': 6.9,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Drama']},
#  {'title': 'The Apple',
#   'director': 'Samira Makhmalbaf',
#   'year': 1998,
#   'link': 'https://www.imdb.com/title/tt0156901/',
#   'rating': 7.2,
#   'wins': 7.0,
#   'nominations': 7.0,
#   'genres': ['Docudrama', 'Drama']},
#  {'title': 'Tomboy',
#   'director': 'Céline Sciamma',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt1847731/',
#   'rating': 7.4,
#   'wins': 10.0,
#   'nominations': 6.0,
#   'genres': ['Coming-of-Age', 'Drama']},
#  {'title': 'Girlhood',
#   'director': 'Céline Sciamma',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt3655522/',
#   'rating': 6.9,
#   'wins': 12.0,
#   'nominations': 22.0,
#   'genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'title': 'Meek’s Cutoff',
#   'director': 'Kelly Reichardt',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt1518812/',
#   'rating': 6.5,
#   'wins': 7.0,
#   'nominations': 14.0,
#   'genres': ['Psychological Drama',
#    'Survival',
#    'Adventure',
#    'Drama',
#    'Thriller',
#    'Western']},
#  {'title': 'Chocolat',
#   'director': 'Claire Denis',
#   'year': 1988,
#   'link': 'https://www.imdb.com/title/tt0094868/',
#   'rating': 7.3,
#   'wins': 1.0,
#   'nominations': 3.0,
#   'genres': ['Drama']},
#  {'title': 'On Body and Soul',
#   'director': 'Ildikó Enyedi',
#   'year': 2017,
#   'link': 'https://www.imdb.com/title/tt5607714/',
#   'rating': 7.5,
#   'wins': 19.0,
#   'nominations': 23.0,
#   'genres': ['Drama', 'Fantasy', 'Mystery', 'Romance']},
#  {'title': 'Europa Europa',
#   'director': 'Agnieszka Holland',
#   'year': 1980,
#   'link': 'https://www.imdb.com/title/tt0099776/',
#   'rating': 7.5,
#   'wins': 8.0,
#   'nominations': 8.0,
#   'genres': ['Drama', 'History', 'War']},
#  {'title': 'The Seashell and the Clergyman',
#   'director': 'Germaine Dulac',
#   'year': 1928,
#   'link': 'https://www.imdb.com/title/tt0017775/',
#   'rating': 7.0,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Drama', 'Fantasy', 'Short']},
#  {'title': 'Whale Rider',
#   'director': 'Niki Caro',
#   'year': 2002,
#   'link': 'https://www.imdb.com/title/tt0298228/',
#   'rating': 7.5,
#   'wins': 33.0,
#   'nominations': 35.0,
#   'genres': ['Drama', 'Family']},
#  {'title': 'The Connection',
#   'director': 'Shirley Clarke',
#   'year': 1961,
#   'link': 'https://www.imdb.com/title/tt0054763/',
#   'rating': 7.0,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Drama']},
#  {'title': 'Eve’s Bayou',
#   'director': 'Kasi Lemmons',
#   'year': 1997,
#   'link': 'https://www.imdb.com/title/tt0119080/',
#   'rating': 7.2,
#   'wins': 12.0,
#   'nominations': 17.0,
#   'genres': ['Coming-of-Age', 'Psychological Drama', 'Drama']},
#  {'title': 'The German Sisters',
#   'director': 'Margarethe von Trotta',
#   'year': 1981,
#   'link': 'https://www.imdb.com/title/tt0082081/',
#   'rating': 7.3,
#   'wins': 13.0,
#   'nominations': 7.0,
#   'genres': ['Drama']},
#  {'title': 'Ratcatcher',
#   'director': 'Lynne Ramsay',
#   'year': 1999,
#   'link': 'https://www.imdb.com/title/tt0171685/',
#   'rating': 7.5,
#   'wins': 12.0,
#   'nominations': 6.0,
#   'genres': ['Coming-of-Age', 'Drama']},
#  {'title': 'Leave no Trace',
#   'director': 'Debra Granik',
#   'year': 2018,
#   'link': 'https://www.imdb.com/title/tt3892172/',
#   'rating': 7.1,
#   'wins': 18.0,
#   'nominations': 92.0,
#   'genres': ['Adventure', 'Drama']},
#  {'title': 'The Rider',
#   'director': 'Chloe Zhao',
#   'year': 2017,
#   'link': 'https://www.imdb.com/title/tt6217608/',
#   'rating': 7.4,
#   'wins': 25.0,
#   'nominations': 59.0,
#   'genres': ['Drama', 'Western']},
#  {'title': 'Marie Antoinette',
#   'director': 'Sofia Coppola',
#   'year': 2006,
#   'link': 'https://www.imdb.com/title/tt0422720/',
#   'rating': 6.5,
#   'wins': 19.0,
#   'nominations': 24.0,
#   'genres': ['Coming-of-Age',
#    'Costume Drama',
#    'Docudrama',
#    'Period Drama',
#    'Teen Drama',
#    'Biography',
#    'Drama',
#    'History',
#    'Romance']},
#  {'title': 'Strange Days',
#   'director': 'Kathryn Bigelow',
#   'year': 1995,
#   'link': 'https://www.imdb.com/title/tt0114558/',
#   'rating': 7.2,
#   'wins': 2.0,
#   'nominations': 4.0,
#   'genres': ['Cyber Thriller',
#    'Cyberpunk',
#    'Crime',
#    'Drama',
#    'Sci-Fi',
#    'Thriller']},
#  {'title': 'India Song',
#   'director': 'Marguerite Duras',
#   'year': 1975,
#   'link': 'https://www.imdb.com/title/tt0073166/',
#   'rating': 6.1,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Drama', 'Fantasy', 'Romance']},
#  {'title': 'A League of their Own',
#   'director': 'Penny Marshall',
#   'year': 1992,
#   'link': 'https://www.imdb.com/title/tt0104694/',
#   'rating': 7.4,
#   'wins': 6.0,
#   'nominations': 13.0,
#   'genres': ['Baseball', 'Comedy', 'Drama', 'Sport']},
#  {'title': 'The Long Farewell',
#   'director': 'Kira Muratova',
#   'year': 1971,
#   'link': 'https://www.imdb.com/title/tt0092905/',
#   'rating': nan,
#   'wins': 1.0,
#   'nominations': 4.0,
#   'genres': ['Drama']},
#  {'title': 'Desperately Seeking Susan',
#   'director': 'Susan Seidelman',
#   'year': 1985,
#   'link': 'https://www.imdb.com/title/tt0089017/',
#   'rating': 6.1,
#   'wins': 2.0,
#   'nominations': 6.0,
#   'genres': ['Quirky Comedy', 'Screwball Comedy', 'Comedy', 'Drama']},
#  {'title': 'The Babadook',
#   'director': 'Jennifer Kent',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt2321549/',
#   'rating': 6.8,
#   'wins': 56.0,
#   'nominations': 64.0,
#   'genres': ['Monster Horror',
#    'Psychological Horror',
#    'Supernatural Horror',
#    'Drama',
#    'Horror',
#    'Mystery']},
#  {'title': '13th',
#   'director': 'Ava DuVernay',
#   'year': 2016,
#   'link': 'https://www.imdb.com/title/tt5895028/',
#   'rating': 8.2,
#   'wins': 32.0,
#   'nominations': 47.0,
#   'genres': ['History Documentary',
#    'Political Documentary',
#    'Crime',
#    'Documentary',
#    'History']},
#  {'title': 'Monster',
#   'director': 'Patty Jenkins',
#   'year': 2003,
#   'link': 'https://www.imdb.com/title/tt0340855/',
#   'rating': 7.3,
#   'wins': 31.0,
#   'nominations': 26.0,
#   'genres': ['Serial Killer',
#    'Tragedy',
#    'True Crime',
#    'Biography',
#    'Crime',
#    'Drama',
#    'Thriller']},
#  {'title': 'Bright Star',
#   'director': 'Jane Campion',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt0810784/',
#   'rating': 6.9,
#   'wins': 16.0,
#   'nominations': 54.0,
#   'genres': ['Costume Drama',
#    'Period Drama',
#    'Biography',
#    'Drama',
#    'Romance']},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt1221141/',
#   'rating': nan,
#   'wins': 9.0,
#   'nominations': 19.0,
#   'genres': ['Drama', 'Mystery', 'Thriller']},
#  {'title': 'Happy as Lazzaro',
#   'director': 'Alice Rohrwacher',
#   'year': 2018,
#   'link': 'https://www.imdb.com/title/tt6752992/',
#   'rating': 7.5,
#   'wins': 18.0,
#   'nominations': 52.0,
#   'genres': ['Coming-of-Age',
#    'Suspense Mystery',
#    'Drama',
#    'Fantasy',
#    'Mystery']},
#  {'title': 'Harlan County, USA',
#   'director': 'Barbara Kopple',
#   'year': 1976,
#   'link': 'https://www.imdb.com/title/tt0074605/',
#   'rating': 8.2,
#   'wins': 9.0,
#   'nominations': 1.0,
#   'genres': ['Documentary']},
#  {'title': 'Outrage',
#   'director': 'Ida Lupino',
#   'year': 1950,
#   'link': 'https://www.imdb.com/title/tt0042824/',
#   'rating': 6.7,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Film Noir', 'Crime', 'Drama']},
#  {'title': 'Salaam Bombay!',
#   'director': 'Mira Nair',
#   'year': 1988,
#   'link': 'https://www.imdb.com/title/tt0096028/',
#   'rating': 7.9,
#   'wins': 13.0,
#   'nominations': 8.0,
#   'genres': ['Docudrama', 'Crime', 'Drama']},
#  {'title': 'The Asthenic Syndrome',
#   'director': 'Kira Muratova',
#   'year': 1989,
#   'link': 'https://www.imdb.com/title/tt0096841/',
#   'rating': 6.6,
#   'wins': 3.0,
#   'nominations': 4.0,
#   'genres': ['Drama']},
#  {'title': 'An Angel at my Table',
#   'director': 'Jane Campion',
#   'year': 1990,
#   'link': 'https://www.imdb.com/title/tt0099040/',
#   'rating': 7.4,
#   'wins': 19.0,
#   'nominations': 5.0,
#   'genres': ['Coming-of-Age', 'Biography', 'Drama']},
#  {'title': 'Near Dark',
#   'director': 'Kathryn Bigelow',
#   'year': 1987,
#   'link': 'https://www.imdb.com/title/tt0093605/',
#   'rating': 6.9,
#   'wins': 1.0,
#   'nominations': 9.0,
#   'genres': ['Contemporary Western',
#    'Dark Comedy',
#    'Vampire Horror',
#    'Horror']},
#  {'title': 'Triumph of the Will',
#   'director': 'Leni Riefenstahl',
#   'year': 1935,
#   'link': 'https://www.imdb.com/title/tt0025913/',
#   'rating': 7.1,
#   'wins': 1.0,
#   'nominations': 1.0,
#   'genres': ['Epic',
#    'Historical Epic',
#    'History Documentary',
#    'Military Documentary',
#    'Political Documentary',
#    'Documentary',
#    'History']},
#  {'title': 'American Honey',
#   'director': 'Andrea Arnold',
#   'year': 2016,
#   'link': 'https://www.imdb.com/title/tt3721936/',
#   'rating': 7.0,
#   'wins': 13.0,
#   'nominations': 43.0,
#   'genres': ['Road Trip', 'Adventure', 'Drama', 'Romance']},
#  {'title': 'The Virgin Suicides',
#   'director': 'Sofia Coppola',
#   'year': 1999,
#   'link': 'https://www.imdb.com/title/tt0159097/',
#   'rating': 7.2,
#   'wins': 3.0,
#   'nominations': 14.0,
#   'genres': ['Coming-of-Age', 'Teen Drama', 'Tragedy', 'Drama', 'Romance']},
#  {'title': 'The Adventures of Prince Achmed',
#   'director': 'Lotte Reiniger',
#   'year': 1926,
#   'link': 'https://www.imdb.com/title/tt0015532/',
#   'rating': 7.8,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Adventure Epic',
#    'Desert Adventure',
#    'Epic',
#    'Fantasy Epic',
#    'Period Drama',
#    'Romantic Epic',
#    'Stop Motion Animation',
#    'Sword & Sorcery',
#    'Tragedy',
#    'Adventure']},
#  {'title': 'Capernaum',
#   'director': 'Nadine Labaki',
#   'year': 2018,
#   'link': 'https://www.imdb.com/title/tt8267604/',
#   'rating': 8.4,
#   'wins': 37.0,
#   'nominations': 55.0,
#   'genres': ['Coming-of-Age', 'Legal Drama', 'Drama']},
#  {'title': 'Boys Don’t Cry',
#   'director': 'Kimberly Peirce',
#   'year': 1999,
#   'link': 'https://www.imdb.com/title/tt0171804/',
#   'rating': 7.5,
#   'wins': 50.0,
#   'nominations': 39.0,
#   'genres': ['Coming-of-Age',
#    'Docudrama',
#    'Tragic Romance',
#    'True Crime',
#    'Biography',
#    'Crime',
#    'Drama',
#    'Romance']},
#  {'title': 'Portrait of a Lady on Fire',
#   'director': 'Céline Sciamma',
#   'year': 2019,
#   'link': 'https://www.imdb.com/title/tt8613070/',
#   'rating': 8.1,
#   'wins': 60.0,
#   'nominations': 164.0,
#   'genres': ['Steamy Romance', 'Drama', 'Romance']},
#  {'title': 'Paris is Burning',
#   'director': 'Jennie Livingston',
#   'year': 1990,
#   'link': 'https://www.imdb.com/title/tt0100332/',
#   'rating': 8.2,
#   'wins': 17.0,
#   'nominations': 1.0,
#   'genres': ['Documentary']},
#  {'title': 'Olympia',
#   'director': 'Leni Riefenstahl',
#   'year': 1938,
#   'link': 'https://www.imdb.com/title/tt0030522/',
#   'rating': 7.7,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Sports Documentary', 'Documentary', 'Sport']},
#  {'title': 'Wendy and Lucy',
#   'director': 'Kelly Reichardt',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt1152850/',
#   'rating': 7.1,
#   'wins': 9.0,
#   'nominations': 16.0,
#   'genres': ['Tragedy', 'Drama']},
#  {'title': 'The Matrix',
#   'director': 'Lana and Lilly Wachowski',
#   'year': 1999,
#   'link': 'https://www.imdb.com/title/tt0133093/',
#   'rating': 8.7,
#   'wins': 42.0,
#   'nominations': 52.0,
#   'genres': ['Action Epic',
#    'Artificial Intelligence',
#    'Cyberpunk',
#    'Dystopian Sci-Fi',
#    'Gun Fu',
#    'Martial Arts',
#    'Sci-Fi Epic',
#    'Action',
#    'Sci-Fi']},
#  {'title': 'Morvern Callar',
#   'director': 'Lynne Ramsay',
#   'year': 2002,
#   'link': 'https://www.imdb.com/title/tt0300214/',
#   'rating': 6.8,
#   'wins': 10.0,
#   'nominations': 16.0,
#   'genres': ['Drama']},
#  {'title': 'You Were Never Really Here',
#   'director': 'Lynne Ramsay',
#   'year': 2017,
#   'link': 'https://www.imdb.com/title/tt5742374/',
#   'rating': 6.7,
#   'wins': 24.0,
#   'nominations': 78.0,
#   'genres': ['Crime', 'Drama', 'Thriller']},
#  {'title': 'The Night Porter',
#   'director': 'Liliana Cavani',
#   'year': 1974,
#   'link': 'https://www.imdb.com/title/tt0071910/',
#   'rating': 6.6,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Psychological Drama', 'Drama']},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0247380/',
#   'rating': 7.7,
#   'wins': 16.0,
#   'nominations': 3.0,
#   'genres': ['Documentary']},
#  {'title': 'Zama',
#   'director': 'Lucrecia Martel',
#   'year': 2017,
#   'link': 'https://www.imdb.com/title/tt3409848/',
#   'rating': 6.7,
#   'wins': 42.0,
#   'nominations': 48.0,
#   'genres': ['Drama', 'History']},
#  {'title': 'Monsoon Wedding',
#   'director': 'Mira Nair',
#   'year': 2001,
#   'link': 'https://www.imdb.com/title/tt0265343/',
#   'rating': 7.3,
#   'wins': 7.0,
#   'nominations': 12.0,
#   'genres': ['Feel-Good Romance',
#    'Romantic Comedy',
#    'Comedy',
#    'Drama',
#    'Romance']},
#  {'title': 'Le Bonheur',
#   'director': 'Agnès Varda',
#   'year': 1965,
#   'link': 'https://www.imdb.com/title/tt0058985/',
#   'rating': 7.6,
#   'wins': 3.0,
#   'nominations': 3.0,
#   'genres': ['Tragedy', 'Tragic Romance', 'Drama', 'Romance']},
#  {'title': 'Selma',
#   'director': 'Ava DuVernay',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt1020072/',
#   'rating': 7.5,
#   'wins': 58.0,
#   'nominations': 91.0,
#   'genres': ['Docudrama', 'Period Drama', 'Biography', 'Drama', 'History']},
#  {'title': 'Stories we Tell',
#   'director': 'Sarah Polley',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt2366450/',
#   'rating': 7.5,
#   'wins': 25.0,
#   'nominations': 44.0,
#   'genres': ['Documentary']},
#  {'title': 'The House is Black',
#   'director': 'Forugh Farrokhzad',
#   'year': 1963,
#   'link': 'https://www.imdb.com/title/tt0336693/',
#   'rating': 7.8,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Documentary', 'Short']},
#  {'title': 'Lady Bird',
#   'director': 'Greta Gerwig',
#   'year': 2017,
#   'link': 'https://www.imdb.com/title/tt4925292/',
#   'rating': 7.4,
#   'wins': 124.0,
#   'nominations': 228.0,
#   'genres': ['Coming-of-Age',
#    'Quirky Comedy',
#    'Teen Comedy',
#    'Comedy',
#    'Drama']},
#  {'title': 'The Hitch-Hiker',
#   'director': 'Ida Lupino',
#   'year': 1953,
#   'link': 'https://www.imdb.com/title/tt0045877/',
#   'rating': 6.9,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Film Noir', 'Crime', 'Drama', 'Thriller']},
#  {'title': 'We Need to Talk About Kevin',
#   'director': 'Lynne Ramsay',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt1242460/',
#   'rating': 7.4,
#   'wins': 26.0,
#   'nominations': 66.0,
#   'genres': ['Tragedy', 'Drama', 'Mystery', 'Thriller']},
#  {'title': 'Winter’s Bone',
#   'director': 'Debra Granik',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt1399683/',
#   'rating': 7.1,
#   'wins': 63.0,
#   'nominations': 131.0,
#   'genres': ['Mountain Adventure',
#    'Quest',
#    'Survival',
#    'Suspense Mystery',
#    'Teen Drama',
#    'Crime',
#    'Drama',
#    'Mystery',
#    'Thriller']},
#  {'title': 'Clueless',
#   'director': 'Amy Heckerling',
#   'year': 1995,
#   'link': 'https://www.imdb.com/title/tt0112697/',
#   'rating': 6.9,
#   'wins': 6.0,
#   'nominations': 12.0,
#   'genres': ['Coming-of-Age',
#    'Feel-Good Romance',
#    'Romantic Comedy',
#    'Satire',
#    'Teen Comedy',
#    'Teen Romance',
#    'Comedy',
#    'Romance']},
#  {'title': 'Orlando',
#   'director': 'Sally Potter',
#   'year': 1992,
#   'link': 'https://www.imdb.com/title/tt0107756/',
#   'rating': 7.1,
#   'wins': 15.0,
#   'nominations': 11.0,
#   'genres': ['Period Drama', 'Biography', 'Drama', 'Fantasy', 'Romance']},
#  {'title': 'American Psycho',
#   'director': 'Mary Harron',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0144084/',
#   'rating': 7.6,
#   'wins': 7.0,
#   'nominations': 11.0,
#   'genres': ['Dark Comedy',
#    'Psychological Drama',
#    'Psychological Horror',
#    'Serial Killer',
#    'Slasher Horror',
#    'Workplace Drama',
#    'Crime',
#    'Drama',
#    'Horror']},
#  {'title': 'Seven Beauties',
#   'director': 'Lina Wertmüller',
#   'year': 1975,
#   'link': 'https://www.imdb.com/title/tt0075040/',
#   'rating': 7.7,
#   'wins': 2.0,
#   'nominations': 9.0,
#   'genres': ['Comedy', 'Drama', 'War']},
#  {'title': 'Wanda',
#   'director': 'Barbara Loden',
#   'year': 1970,
#   'link': 'https://www.imdb.com/title/tt0067961/',
#   'rating': 7.1,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Heist', 'Psychological Drama', 'Tragedy', 'Crime', 'Drama']},
#  {'title': 'The Swamp',
#   'director': 'Lucrecia Martel',
#   'year': 2001,
#   'link': 'https://www.imdb.com/title/tt0240419/',
#   'rating': 7.0,
#   'wins': 16.0,
#   'nominations': 8.0,
#   'genres': ['Comedy', 'Drama']},
#  {'title': 'Point Break',
#   'director': 'Kathryn Bigelow',
#   'year': 1991,
#   'link': 'https://www.imdb.com/title/tt0102685/',
#   'rating': 7.3,
#   'wins': 1.0,
#   'nominations': 2.0,
#   'genres': ['Heist', 'Action', 'Crime', 'Thriller']},
#  {'title': 'Vagabond',
#   'director': 'Agnès Varda',
#   'year': 1985,
#   'link': 'https://www.imdb.com/title/tt0089960/',
#   'rating': 7.6,
#   'wins': 8.0,
#   'nominations': 5.0,
#   'genres': ['Psychological Drama', 'Tragedy', 'Drama']},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt1790885/',
#   'rating': 7.4,
#   'wins': 85.0,
#   'nominations': 174.0,
#   'genres': ['Docudrama',
#    'Political Drama',
#    'Political Thriller',
#    'Drama',
#    'History',
#    'Thriller']},
#  {'title': 'The Ascent',
#   'director': 'Larisa Shepitko',
#   'year': 1977,
#   'link': 'https://www.imdb.com/title/tt0075404/',
#   'rating': 8.2,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Psychological Drama', 'Drama', 'War']},
#  {'title': 'Daughters of the Dust',
#   'director': 'Julie Dash',
#   'year': 1991,
#   'link': 'https://www.imdb.com/title/tt0104057/',
#   'rating': 6.6,
#   'wins': 4.0,
#   'nominations': 2.0,
#   'genres': ['Drama', 'History', 'Romance']},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt1232776/',
#   'rating': 7.3,
#   'wins': 21.0,
#   'nominations': 30.0,
#   'genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': 2016,
#   'link': 'https://www.imdb.com/title/tt4048272/',
#   'rating': 7.3,
#   'wins': 59.0,
#   'nominations': 85.0,
#   'genres': ['Psychological Drama', 'Quirky Comedy', 'Comedy', 'Drama']},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt0887912/',
#   'rating': 7.5,
#   'wins': 125.0,
#   'nominations': 130.0,
#   'genres': ['Psychological Drama', 'Drama', 'Thriller', 'War']},
#  {'title': 'Daisies',
#   'director': 'Věra Chytilová',
#   'year': 1966,
#   'link': 'https://www.imdb.com/title/tt0060959/',
#   'rating': 7.2,
#   'wins': 1.0,
#   'nominations': 1.0,
#   'genres': ['Coming-of-Age',
#    'Dark Comedy',
#    'Satire',
#    'Screwball Comedy',
#    'Slapstick',
#    'Teen Comedy',
#    'Comedy']},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': 2003,
#   'link': 'https://www.imdb.com/title/tt0335266/',
#   'rating': 7.7,
#   'wins': 97.0,
#   'nominations': 133.0,
#   'genres': ['Coming-of-Age', 'Comedy', 'Drama']},
#  {'title': 'Beau Travail',
#   'director': 'Claire Denis',
#   'year': 1999,
#   'link': 'https://www.imdb.com/title/tt0209933/',
#   'rating': 7.3,
#   'wins': 6.0,
#   'nominations': 12.0,
#   'genres': ['Drama', 'War']},
#  {'title': 'Jeanne Dielman, 23 Quai du Commerce, 1080 Bruxelles',
#   'director': 'Chantal Akerman',
#   'year': 1975,
#   'link': 'https://www.imdb.com/title/tt0073198/',
#   'rating': 7.5,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Psychological Drama', 'Drama']},
#  {'title': 'Cléo from 5 to 7',
#   'director': 'Agnès Varda',
#   'year': 1962,
#   'link': 'https://www.imdb.com/title/tt0055852/',
#   'rating': 7.8,
#   'wins': 2.0,
#   'nominations': 1.0,
#   'genres': ['Psychological Drama', 'Comedy', 'Drama', 'Music']},
#  {'title': 'The Piano',
#   'director': 'Jane Campion',
#   'year': 1993,
#   'link': 'https://www.imdb.com/title/tt0107822/',
#   'rating': 7.5,
#   'wins': 65.0,
#   'nominations': 57.0,
#   'genres': ['Costume Drama',
#    'Period Drama',
#    'Steamy Romance',
#    'Drama',
#    'Music',
#    'Romance']}]

# %%
df_list_of_females = pd.DataFrame(list_of_females)

# %%
df_list_of_females.to_csv('females_list_bbc.csv', index=False)

# %% [markdown]
# ## THE SECOND LIST - 100 Greatest Film
# ### Given most films in this list are directed by male, scraping below aims to compare the statistics with the list of best films made by women.

# %%
main_url = "https://www.bbc.com/culture/article/20160819-the-21st-centurys-100-greatest-films"

# %%
response_main = requests.get(main_url, headers={'User-Agent': 'Mozilla/5.0'})
main_html = BeautifulSoup(response_main.content, 'html.parser')

# %% [markdown]
# ### 1. find all movie titles and directors and put them into a list of dictionaries - title, director, and year

# %%
main_paragraphs = main_html.find_all('p', class_='sc-9a00e533-0 hxuGS')

# Initialize list to store movie data
main_data = []

for each in main_paragraphs:
    text = each.get_text(strip=True)
    
    # Use regex to extract the components
    match = re.match(r'(\d+)\.\s*(.*?)\s*\((.*?),\s*(\d{4})\)', text)
    
    if match:
        title = match.group(2).strip()
        director = match.group(3).strip()
        year = match.group(4)
        
        # Clean up any extra whitespace or non-breaking spaces in the title
        title = ' '.join(title.split())
        
        main_data.append({
            'title': title,
            'director': director,
            'year': year
        })

# %% [markdown]
# ### 2. merge each film's webpage from IMDb

# %% [markdown]
# #### use the function, get_imdb_link, which I set up earlier to get links for films in this list

# %%
for movie in main_data:
    link = get_imdb_link(movie['title'], movie['year'])
    movie['link'] = link

# %%
# checkpoint
main_data
# Out:
# [{'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'link': 'https://www.imdb.com/title/tt4048272/'},
#  {'title': 'Requiem for a Dream',
#   'director': 'Darren Aronofsky',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0180093/'},
#  {'title': 'Carlos',
#   'director': 'Olivier Assayas',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1321865/'},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0247380/'},
#  {'title': 'Ten',
#   'director': 'Abbas Kiarostami',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0301978/'},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1135952/'},
#  {'title': 'Finding Nemo',
#   'director': 'Andrew Stanton',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0266543/'},
#  {'title': 'Moonrise Kingdom',
#   'director': 'Wes Anderson',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1748122/'},
#  {'title': 'Let the Right One In',
#   'director': 'Tomas Alfredson',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt1139797/'},
#  {'title': 'Ratatouille',
#   'director': 'Brad Bird',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0382932/'},
#  {'title': 'The Assassination of Jesse James by the Coward Robert Ford',
#   'director': 'Andrew Dominik',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0443680/'},
#  {'title': 'The Secret in Their Eyes',
#   'director': 'Juan José Campanella',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1305806/'},
#  {'title': 'The Pianist',
#   'director': 'Roman Polanski',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0253474/'},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt32605199/'},
#  {'title': 'Spotlight',
#   'director': 'Tom McCarthy',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt1895587/'},
#  {'title': 'Amélie',
#   'director': 'Jean-Pierre Jeunet',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0211915/'},
#  {'title': 'Far From Heaven',
#   'director': 'Todd Haynes',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0297884/'},
#  {'title': 'A Prophet',
#   'director': 'Jacques Audiard',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1235166/'},
#  {'title': 'Her',
#   'director': 'Spike Jonze',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt1798709/'},
#  {'title': 'A.I. Artificial Intelligence',
#   'director': 'Steven Spielberg',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0212720/'},
#  {'title': 'A Serious Man',
#   'director': 'Joel and Ethan Coen',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1019452/'},
#  {'title': 'Shame',
#   'director': 'Steve McQueen',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1723811/'},
#  {'title': 'The Return',
#   'director': 'Andrey Zvyagintsev',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0167260/'},
#  {'title': 'Almost Famous',
#   'director': 'Cameron Crowe',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0181875/'},
#  {'title': 'The Wolf of Wall Street',
#   'director': 'Martin Scorsese',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt0993846/'},
#  {'title': 'The Diving Bell and the Butterfly',
#   'director': 'Julian Schnabel',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt2998630/'},
#  {'title': 'Dogville',
#   'director': 'Lars von Trier',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0276919/'},
#  {'title': 'Inherent Vice',
#   'director': 'Paul Thomas Anderson',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt1791528/'},
#  {'title': 'Spring Breakers',
#   'director': 'Harmony Korine',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2101441/'},
#  {'title': 'Before Sunset',
#   'director': 'Richard Linklater',
#   'year': '2004',
#   'link': 'https://www.imdb.com/title/tt0381681/'},
#  {'title': 'Only Lovers Left Alive',
#   'director': 'Jim Jarmusch',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt1714915/'},
#  {'title': 'Tabu',
#   'director': 'Miguel Gomes',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2153963/'},
#  {'title': 'Stories We Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2366450/'},
#  {'title': 'Carol',
#   'director': 'Todd Haynes',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt2402927/'},
#  {'title': 'The Royal Tenenbaums',
#   'director': 'Wes Anderson',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0265666/'},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0887912/'},
#  {'title': 'Spring, Summer, Fall, Winter…and Spring',
#   'director': 'Kim Ki-duk',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0374546/'},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1232776/'},
#  {'title': 'The Great Beauty',
#   'director': 'Paolo Sorrentino',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2358891/'},
#  {'title': 'The Turin Horse',
#   'director': 'Béla Tarr and Ágnes Hranitzky',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1316540/'},
#  {'title': 'Inglourious Basterds',
#   'director': 'Quentin Tarantino',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt0361748/'},
#  {'title': 'Under the Skin',
#   'director': 'Jonathan Glazer',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt1441395/'},
#  {'title': 'Syndromes and a Century',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0477731/'},
#  {'title': 'A History of Violence',
#   'director': 'David Cronenberg',
#   'year': '2005',
#   'link': 'https://www.imdb.com/title/tt0399146/'},
#  {'title': 'Moolaadé',
#   'director': 'Ousmane Sembène',
#   'year': '2004',
#   'link': 'https://www.imdb.com/title/tt33057548/'},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1790885/'},
#  {'title': 'Werckmeister Harmonies',
#   'director': 'Béla Tarr, director; Ágnes Hranitzky, co-director',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0249241/'},
#  {'title': 'Ida',
#   'director': 'Paweł Pawlikowski',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2718492/'},
#  {'title': 'Once Upon a Time in Anatolia',
#   'director': 'Nuri Bilge Ceylan',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1843230/'},
#  {'title': 'Moulin Rouge!',
#   'director': 'Baz Luhrmann',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0203009/'},
#  {'title': 'Tropical Malady',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2004',
#   'link': 'https://www.imdb.com/title/tt0381668/'},
#  {'title': 'Inception',
#   'director': 'Christopher Nolan',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1375666/'},
#  {'title': 'The Assassin',
#   'director': 'Hou Hsiao-hsien',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt3508840/'},
#  {'title': 'Goodbye to Language',
#   'director': 'Jean-Luc Godard',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt2400275/'},
#  {'title': 'Brooklyn',
#   'director': 'John Crowley',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt2381111/'},
#  {'title': 'Leviathan',
#   'director': 'Andrey Zvyagintsev',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt2802154/'},
#  {'title': 'Certified Copy',
#   'director': 'Abbas Kiarostami',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1020773/'},
#  {'title': 'Blue Is the Warmest Color',
#   'director': 'Abdellatif Kechiche',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2278871/'},
#  {'title': '12 Years a Slave',
#   'director': 'Steve McQueen',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2024544/'},
#  {'title': 'Melancholia',
#   'director': 'Lars von Trier',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1527186/'},
#  {'title': 'Amour',
#   'director': 'Michael Haneke',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1602620/'},
#  {'title': 'Inside Out',
#   'director': 'Pete Docter',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt2096673/'},
#  {'title': 'Brokeback Mountain',
#   'director': 'Ang Lee',
#   'year': '2005',
#   'link': 'https://www.imdb.com/title/tt0388795/'},
#  {'title': 'The New World',
#   'director': 'Terrence Malick',
#   'year': '2005',
#   'link': 'https://www.imdb.com/title/tt0402399/'},
#  {'title': 'City of God',
#   'director': 'Fernando Meirelles and Kátia Lund',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0317248/'},
#  {'title': 'Uncle Boonmee Who Can Recall His Past Lives',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1588895/'},
#  {'title': 'Timbuktu',
#   'director': 'Abderrahmane Sissako',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt3409392/'},
#  {'title': 'Crouching Tiger, Hidden Dragon',
#   'director': 'Ang Lee',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0190332/'},
#  {'title': 'Son of Saul',
#   'director': 'László Nemes',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt3808342/'},
#  {'title': 'The Dark Knight',
#   'director': 'Christopher Nolan',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0468569/'},
#  {'title': 'The Lives of Others',
#   'director': 'Florian Henckel von Donnersmarck',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0405094/'},
#  {'title': 'Margaret',
#   'director': 'Kenneth Lonergan',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt0466893/'},
#  {'title': 'Oldboy',
#   'director': 'Park Chan-wook',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0364569/'},
#  {'title': 'WALL-E',
#   'director': 'Andrew Stanton',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0910970/'},
#  {'title': 'Talk to Her',
#   'director': 'Pedro Almodóvar',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0287467/'},
#  {'title': 'The Social Network',
#   'director': 'David Fincher',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1285016/'},
#  {'title': '25th Hour',
#   'director': 'Spike Lee',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0307901/'},
#  {'title': '\u200bMemento',
#   'director': 'Christopher Nolan',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0209144/'},
#  {'title': 'The Master',
#   'director': 'Paul Thomas Anderson',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1560747/'},
#  {'title': 'Caché',
#   'director': 'Michael Haneke',
#   'year': '2005',
#   'link': 'https://www.imdb.com/title/tt0387898/'},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0335266/'},
#  {'title': 'The Grand Budapest Hotel',
#   'director': 'Wes Anderson',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt2278388/'},
#  {'title': 'Synecdoche, New York',
#   'director': 'Charlie Kaufman',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0383028/'},
#  {'title': 'Mad Max: Fury Road',
#   'director': 'George Miller',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt1392190/'},
#  {'title': 'The White Ribbon',
#   'director': 'Michael Haneke',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1149362/'},
#  {'title': "Pan's Labyrinth",
#   'director': 'Guillermo Del Toro',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0457430/'},
#  {'title': 'Holy Motors',
#   'director': 'Leos Carax',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2076220/'},
#  {'title': '4 Months, 3 Weeks and 2 Days',
#   'director': 'Cristian Mungiu',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt1032846/'},
#  {'title': 'The Act of Killing',
#   'director': 'Joshua Oppenheimer',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2375605/'},
#  {'title': 'Children of Men',
#   'director': 'Alfonso Cuarón',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0206634/'},
#  {'title': 'Zodiac',
#   'director': 'David Fincher',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0443706/'},
#  {'title': 'Inside Llewyn Davis',
#   'director': 'Joel and Ethan Coen',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2042568/'},
#  {'title': 'No Country for Old Men',
#   'director': 'Joel and Ethan Coen',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0477348/'},
#  {'title': 'A Separation',
#   'director': 'Asghar Farhadi',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1832382/'},
#  {'title': 'Yi Yi: A One and a Two',
#   'director': 'Edward Yang',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0244316/'},
#  {'title': 'The Tree of Life',
#   'director': 'Terrence Malick',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt0478304/'},
#  {'title': 'Eternal Sunshine of the Spotless Mind',
#   'director': 'Michel Gondry',
#   'year': '2004',
#   'link': 'https://www.imdb.com/title/tt0338013/'},
#  {'title': 'Boyhood',
#   'director': 'Richard Linklater',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt1065073/'},
#  {'title': 'Spirited Away',
#   'director': 'Hayao Miyazaki',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0245429/'},
#  {'title': 'There Will Be Blood',
#   'director': 'Paul Thomas Anderson',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0469494/'},
#  {'title': 'In the Mood for Love',
#   'director': 'Wong Kar-wai',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0118694/'},
#  {'title': 'Mulholland Drive',
#   'director': 'David Lynch',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0166924/'}]

# %% [markdown]
# #### extract each film's rating

# %%
for movie in main_data:
    try:
        response = requests.get(movie['link'], headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Try both possible rating locations
        rating = soup.find(class_='sc-d541859f-1 imUuxf').get_text(strip=True)
        
        movie['rating'] = rating if rating else "N/A"
        
    except Exception as e:
        print(f"Error getting rating for {movie['title']}: {str(e)}")
        movie['rating'] = "N/A"
# Out:
# Error getting rating for The Headless Woman: 'NoneType' object has no attribute 'get_text'
# Error getting rating for The Diving Bell and the Butterfly: 'NoneType' object has no attribute 'get_text'
# Error getting rating for Moolaadé: 'NoneType' object has no attribute 'get_text'

# %% [markdown]
# #### correct those films that incorrectly merged with wrong links

# %%
corrected_main = {
    'The Diving Bell and the Butterfly': 'https://www.imdb.com/title/tt0401383/',
    'The Headless Woman': 'https://www.imdb.com/title/tt1221141/',
    'Moolaadé': 'https://www.imdb.com/title/tt0416991/'
}

for movie in main_data:
    title = movie['title']
    if title in corrected:
        movie['link'] = corrected_main[title]

# %% [markdown]
# ### 3. use the function earlier, extract the number of nominations and wins for each film

# %%
for movie in main_data:
    if not movie.get('link'):
        movie['wins'] = None
        movie['nominations'] = None
        continue
    
    try:       
        response = requests.get(movie['link'], headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        awards_span = soup.find('span', class_='ipc-metadata-list-item__list-content-item')
        
        if awards_span:
            awards_text = awards_span.get_text(strip=True)
            wins, nominations = extract_wins_nominations(awards_text)
            
            movie['wins'] = wins
            movie['nominations'] = nominations

        else:
            movie['wins'] = None
            movie['nominations'] = None
            
    except Exception as e:
        print(f"Error processing {movie.get('title', 'Unknown')}: {str(e)}")
        movie['wins'] = None
        movie['nominations'] = None

# %%
# checkpoint
main_data
# Out:
# [{'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': '2016',
#   'link': 'https://www.imdb.com/title/tt4048272/',
#   'rating': '7.3',
#   'wins': 59,
#   'nominations': 85},
#  {'title': 'Requiem for a Dream',
#   'director': 'Darren Aronofsky',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0180093/',
#   'rating': '8.3',
#   'wins': 37,
#   'nominations': 69},
#  {'title': 'Carlos',
#   'director': 'Olivier Assayas',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1321865/',
#   'rating': '7.6',
#   'wins': 18,
#   'nominations': 49},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0247380/',
#   'rating': '7.7',
#   'wins': 16,
#   'nominations': 3},
#  {'title': 'Ten',
#   'director': 'Abbas Kiarostami',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0301978/',
#   'rating': '7.4',
#   'wins': 1,
#   'nominations': 4},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1135952/',
#   'rating': '6.9',
#   'wins': 1,
#   'nominations': 10},
#  {'title': 'Finding Nemo',
#   'director': 'Andrew Stanton',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0266543/',
#   'rating': '8.2',
#   'wins': 49,
#   'nominations': 63},
#  {'title': 'Moonrise Kingdom',
#   'director': 'Wes Anderson',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1748122/',
#   'rating': '7.8',
#   'wins': 36,
#   'nominations': 121},
#  {'title': 'Let the Right One In',
#   'director': 'Tomas Alfredson',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt1139797/',
#   'rating': '7.8',
#   'wins': 76,
#   'nominations': 58},
#  {'title': 'Ratatouille',
#   'director': 'Brad Bird',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0382932/',
#   'rating': '8.1',
#   'wins': 68,
#   'nominations': 42},
#  {'title': 'The Assassination of Jesse James by the Coward Robert Ford',
#   'director': 'Andrew Dominik',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0443680/',
#   'rating': '7.5',
#   'wins': 25,
#   'nominations': 69},
#  {'title': 'The Secret in Their Eyes',
#   'director': 'Juan José Campanella',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1305806/',
#   'rating': '8.2',
#   'wins': 53,
#   'nominations': 43},
#  {'title': 'The Pianist',
#   'director': 'Roman Polanski',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0253474/',
#   'rating': '8.5',
#   'wins': 57,
#   'nominations': 74},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt1221141/',
#   'rating': 'N/A',
#   'wins': 9,
#   'nominations': 19},
#  {'title': 'Spotlight',
#   'director': 'Tom McCarthy',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt1895587/',
#   'rating': '8.1',
#   'wins': 124,
#   'nominations': 145},
#  {'title': 'Amélie',
#   'director': 'Jean-Pierre Jeunet',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0211915/',
#   'rating': '8.3',
#   'wins': 59,
#   'nominations': 74},
#  {'title': 'Far From Heaven',
#   'director': 'Todd Haynes',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0297884/',
#   'rating': '7.3',
#   'wins': 102,
#   'nominations': 96},
#  {'title': 'A Prophet',
#   'director': 'Jacques Audiard',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1235166/',
#   'rating': '7.8',
#   'wins': 52,
#   'nominations': 57},
#  {'title': 'Her',
#   'director': 'Spike Jonze',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt1798709/',
#   'rating': '8.0',
#   'wins': 83,
#   'nominations': 187},
#  {'title': 'A.I. Artificial Intelligence',
#   'director': 'Steven Spielberg',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0212720/',
#   'rating': '7.2',
#   'wins': 18,
#   'nominations': 71},
#  {'title': 'A Serious Man',
#   'director': 'Joel and Ethan Coen',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1019452/',
#   'rating': '7.0',
#   'wins': 17,
#   'nominations': 80},
#  {'title': 'Shame',
#   'director': 'Steve McQueen',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1723811/',
#   'rating': '7.2',
#   'wins': 51,
#   'nominations': 94},
#  {'title': 'The Return',
#   'director': 'Andrey Zvyagintsev',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0167260/',
#   'rating': '9.0',
#   'wins': 215,
#   'nominations': 124},
#  {'title': 'Almost Famous',
#   'director': 'Cameron Crowe',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0181875/',
#   'rating': '7.9',
#   'wins': 54,
#   'nominations': 103},
#  {'title': 'The Wolf of Wall Street',
#   'director': 'Martin Scorsese',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt0993846/',
#   'rating': '8.2',
#   'wins': 38,
#   'nominations': 180},
#  {'title': 'The Diving Bell and the Butterfly',
#   'director': 'Julian Schnabel',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt2998630/',
#   'rating': 'N/A',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Dogville',
#   'director': 'Lars von Trier',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0276919/',
#   'rating': '8.0',
#   'wins': 21,
#   'nominations': 33},
#  {'title': 'Inherent Vice',
#   'director': 'Paul Thomas Anderson',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt1791528/',
#   'rating': '6.6',
#   'wins': 15,
#   'nominations': 99},
#  {'title': 'Spring Breakers',
#   'director': 'Harmony Korine',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2101441/',
#   'rating': '5.3',
#   'wins': 14,
#   'nominations': 35},
#  {'title': 'Before Sunset',
#   'director': 'Richard Linklater',
#   'year': '2004',
#   'link': 'https://www.imdb.com/title/tt0381681/',
#   'rating': '8.1',
#   'wins': 10,
#   'nominations': 32},
#  {'title': 'Only Lovers Left Alive',
#   'director': 'Jim Jarmusch',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt1714915/',
#   'rating': '7.2',
#   'wins': 8,
#   'nominations': 44},
#  {'title': 'Tabu',
#   'director': 'Miguel Gomes',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2153963/',
#   'rating': '7.3',
#   'wins': 21,
#   'nominations': 46},
#  {'title': 'Stories We Tell',
#   'director': 'Sarah Polley',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2366450/',
#   'rating': '7.5',
#   'wins': 25,
#   'nominations': 44},
#  {'title': 'Carol',
#   'director': 'Todd Haynes',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt2402927/',
#   'rating': '7.3',
#   'wins': 76,
#   'nominations': 255},
#  {'title': 'The Royal Tenenbaums',
#   'director': 'Wes Anderson',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0265666/',
#   'rating': '7.6',
#   'wins': 11,
#   'nominations': 46},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0887912/',
#   'rating': '7.5',
#   'wins': 125,
#   'nominations': 130},
#  {'title': 'Spring, Summer, Fall, Winter…and Spring',
#   'director': 'Kim Ki-duk',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0374546/',
#   'rating': '8.0',
#   'wins': 15,
#   'nominations': 9},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1232776/',
#   'rating': '7.3',
#   'wins': 21,
#   'nominations': 30},
#  {'title': 'The Great Beauty',
#   'director': 'Paolo Sorrentino',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2358891/',
#   'rating': '7.7',
#   'wins': 60,
#   'nominations': 78},
#  {'title': 'The Turin Horse',
#   'director': 'Béla Tarr and Ágnes Hranitzky',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1316540/',
#   'rating': '7.7',
#   'wins': 7,
#   'nominations': 15},
#  {'title': 'Inglourious Basterds',
#   'director': 'Quentin Tarantino',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt0361748/',
#   'rating': '8.4',
#   'wins': 134,
#   'nominations': 173},
#  {'title': 'Under the Skin',
#   'director': 'Jonathan Glazer',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt1441395/',
#   'rating': '6.3',
#   'wins': 23,
#   'nominations': 113},
#  {'title': 'Syndromes and a Century',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0477731/',
#   'rating': '7.3',
#   'wins': 3,
#   'nominations': 13},
#  {'title': 'A History of Violence',
#   'director': 'David Cronenberg',
#   'year': '2005',
#   'link': 'https://www.imdb.com/title/tt0399146/',
#   'rating': '7.4',
#   'wins': 37,
#   'nominations': 84},
#  {'title': 'Moolaadé',
#   'director': 'Ousmane Sembène',
#   'year': '2004',
#   'link': 'https://www.imdb.com/title/tt33057548/',
#   'rating': 'N/A',
#   'wins': None,
#   'nominations': None},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1790885/',
#   'rating': '7.4',
#   'wins': 85,
#   'nominations': 174},
#  {'title': 'Werckmeister Harmonies',
#   'director': 'Béla Tarr, director; Ágnes Hranitzky, co-director',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0249241/',
#   'rating': '8.0',
#   'wins': 5,
#   'nominations': 2},
#  {'title': 'Ida',
#   'director': 'Paweł Pawlikowski',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2718492/',
#   'rating': '7.4',
#   'wins': 69,
#   'nominations': 92},
#  {'title': 'Once Upon a Time in Anatolia',
#   'director': 'Nuri Bilge Ceylan',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1843230/',
#   'rating': '7.7',
#   'wins': 13,
#   'nominations': 95},
#  {'title': 'Moulin Rouge!',
#   'director': 'Baz Luhrmann',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0203009/',
#   'rating': '7.6',
#   'wins': 87,
#   'nominations': 133},
#  {'title': 'Tropical Malady',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2004',
#   'link': 'https://www.imdb.com/title/tt0381668/',
#   'rating': '7.1',
#   'wins': 7,
#   'nominations': 8},
#  {'title': 'Inception',
#   'director': 'Christopher Nolan',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1375666/',
#   'rating': '8.8',
#   'wins': 159,
#   'nominations': 220},
#  {'title': 'The Assassin',
#   'director': 'Hou Hsiao-hsien',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt3508840/',
#   'rating': '6.3',
#   'wins': 36,
#   'nominations': 75},
#  {'title': 'Goodbye to Language',
#   'director': 'Jean-Luc Godard',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt2400275/',
#   'rating': '5.8',
#   'wins': 4,
#   'nominations': 20},
#  {'title': 'Brooklyn',
#   'director': 'John Crowley',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt2381111/',
#   'rating': '7.5',
#   'wins': 38,
#   'nominations': 161},
#  {'title': 'Leviathan',
#   'director': 'Andrey Zvyagintsev',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt2802154/',
#   'rating': '7.6',
#   'wins': 38,
#   'nominations': 52},
#  {'title': 'Certified Copy',
#   'director': 'Abbas Kiarostami',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1020773/',
#   'rating': '7.2',
#   'wins': 11,
#   'nominations': 29},
#  {'title': 'Blue Is the Warmest Color',
#   'director': 'Abdellatif Kechiche',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2278871/',
#   'rating': '7.7',
#   'wins': 87,
#   'nominations': 106},
#  {'title': '12 Years a Slave',
#   'director': 'Steve McQueen',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2024544/',
#   'rating': '8.1',
#   'wins': 244,
#   'nominations': 338},
#  {'title': 'Melancholia',
#   'director': 'Lars von Trier',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1527186/',
#   'rating': '7.1',
#   'wins': 36,
#   'nominations': 95},
#  {'title': 'Amour',
#   'director': 'Michael Haneke',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1602620/',
#   'rating': '7.9',
#   'wins': 84,
#   'nominations': 111},
#  {'title': 'Inside Out',
#   'director': 'Pete Docter',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt2096673/',
#   'rating': '8.1',
#   'wins': 99,
#   'nominations': 118},
#  {'title': 'Brokeback Mountain',
#   'director': 'Ang Lee',
#   'year': '2005',
#   'link': 'https://www.imdb.com/title/tt0388795/',
#   'rating': '7.7',
#   'wins': 141,
#   'nominations': 133},
#  {'title': 'The New World',
#   'director': 'Terrence Malick',
#   'year': '2005',
#   'link': 'https://www.imdb.com/title/tt0402399/',
#   'rating': '6.7',
#   'wins': 6,
#   'nominations': 34},
#  {'title': 'City of God',
#   'director': 'Fernando Meirelles and Kátia Lund',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0317248/',
#   'rating': '8.6',
#   'wins': 75,
#   'nominations': 50},
#  {'title': 'Uncle Boonmee Who Can Recall His Past Lives',
#   'director': 'Apichatpong Weerasethakul',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1588895/',
#   'rating': '6.7',
#   'wins': 11,
#   'nominations': 25},
#  {'title': 'Timbuktu',
#   'director': 'Abderrahmane Sissako',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt3409392/',
#   'rating': '7.1',
#   'wins': 33,
#   'nominations': 28},
#  {'title': 'Crouching Tiger, Hidden Dragon',
#   'director': 'Ang Lee',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0190332/',
#   'rating': '7.9',
#   'wins': 101,
#   'nominations': 132},
#  {'title': 'Son of Saul',
#   'director': 'László Nemes',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt3808342/',
#   'rating': '7.4',
#   'wins': 65,
#   'nominations': 62},
#  {'title': 'The Dark Knight',
#   'director': 'Christopher Nolan',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0468569/',
#   'rating': '9.0',
#   'wins': 164,
#   'nominations': 165},
#  {'title': 'The Lives of Others',
#   'director': 'Florian Henckel von Donnersmarck',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0405094/',
#   'rating': '8.4',
#   'wins': 80,
#   'nominations': 38},
#  {'title': 'Margaret',
#   'director': 'Kenneth Lonergan',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt0466893/',
#   'rating': '6.5',
#   'wins': 10,
#   'nominations': 18},
#  {'title': 'Oldboy',
#   'director': 'Park Chan-wook',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0364569/',
#   'rating': '8.3',
#   'wins': 43,
#   'nominations': 28},
#  {'title': 'WALL-E',
#   'director': 'Andrew Stanton',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0910970/',
#   'rating': '8.4',
#   'wins': 96,
#   'nominations': 95},
#  {'title': 'Talk to Her',
#   'director': 'Pedro Almodóvar',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0287467/',
#   'rating': '7.9',
#   'wins': 47,
#   'nominations': 47},
#  {'title': 'The Social Network',
#   'director': 'David Fincher',
#   'year': '2010',
#   'link': 'https://www.imdb.com/title/tt1285016/',
#   'rating': '7.8',
#   'wins': 174,
#   'nominations': 188},
#  {'title': '25th Hour',
#   'director': 'Spike Lee',
#   'year': '2002',
#   'link': 'https://www.imdb.com/title/tt0307901/',
#   'rating': '7.6',
#   'wins': 4,
#   'nominations': 17},
#  {'title': '\u200bMemento',
#   'director': 'Christopher Nolan',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0209144/',
#   'rating': '8.4',
#   'wins': 57,
#   'nominations': 59},
#  {'title': 'The Master',
#   'director': 'Paul Thomas Anderson',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt1560747/',
#   'rating': '7.1',
#   'wins': 75,
#   'nominations': 187},
#  {'title': 'Caché',
#   'director': 'Michael Haneke',
#   'year': '2005',
#   'link': 'https://www.imdb.com/title/tt0387898/',
#   'rating': '7.3',
#   'wins': 29,
#   'nominations': 37},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': '2003',
#   'link': 'https://www.imdb.com/title/tt0335266/',
#   'rating': '7.7',
#   'wins': 97,
#   'nominations': 133},
#  {'title': 'The Grand Budapest Hotel',
#   'director': 'Wes Anderson',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt2278388/',
#   'rating': '8.1',
#   'wins': 135,
#   'nominations': 227},
#  {'title': 'Synecdoche, New York',
#   'director': 'Charlie Kaufman',
#   'year': '2008',
#   'link': 'https://www.imdb.com/title/tt0383028/',
#   'rating': '7.5',
#   'wins': 8,
#   'nominations': 29},
#  {'title': 'Mad Max: Fury Road',
#   'director': 'George Miller',
#   'year': '2015',
#   'link': 'https://www.imdb.com/title/tt1392190/',
#   'rating': '8.1',
#   'wins': 245,
#   'nominations': 234},
#  {'title': 'The White Ribbon',
#   'director': 'Michael Haneke',
#   'year': '2009',
#   'link': 'https://www.imdb.com/title/tt1149362/',
#   'rating': '7.8',
#   'wins': 62,
#   'nominations': 49},
#  {'title': "Pan's Labyrinth",
#   'director': 'Guillermo Del Toro',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0457430/',
#   'rating': '8.2',
#   'wins': 109,
#   'nominations': 115},
#  {'title': 'Holy Motors',
#   'director': 'Leos Carax',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2076220/',
#   'rating': '7.0',
#   'wins': 29,
#   'nominations': 74},
#  {'title': '4 Months, 3 Weeks and 2 Days',
#   'director': 'Cristian Mungiu',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt1032846/',
#   'rating': '7.9',
#   'wins': 41,
#   'nominations': 59},
#  {'title': 'The Act of Killing',
#   'director': 'Joshua Oppenheimer',
#   'year': '2012',
#   'link': 'https://www.imdb.com/title/tt2375605/',
#   'rating': '8.2',
#   'wins': 55,
#   'nominations': 46},
#  {'title': 'Children of Men',
#   'director': 'Alfonso Cuarón',
#   'year': '2006',
#   'link': 'https://www.imdb.com/title/tt0206634/',
#   'rating': '7.9',
#   'wins': 49,
#   'nominations': 89},
#  {'title': 'Zodiac',
#   'director': 'David Fincher',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0443706/',
#   'rating': '7.7',
#   'wins': 3,
#   'nominations': 71},
#  {'title': 'Inside Llewyn Davis',
#   'director': 'Joel and Ethan Coen',
#   'year': '2013',
#   'link': 'https://www.imdb.com/title/tt2042568/',
#   'rating': '7.4',
#   'wins': 47,
#   'nominations': 174},
#  {'title': 'No Country for Old Men',
#   'director': 'Joel and Ethan Coen',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0477348/',
#   'rating': '8.2',
#   'wins': 165,
#   'nominations': 139},
#  {'title': 'A Separation',
#   'director': 'Asghar Farhadi',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt1832382/',
#   'rating': '8.3',
#   'wins': 89,
#   'nominations': 52},
#  {'title': 'Yi Yi: A One and a Two',
#   'director': 'Edward Yang',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0244316/',
#   'rating': '8.1',
#   'wins': 14,
#   'nominations': 23},
#  {'title': 'The Tree of Life',
#   'director': 'Terrence Malick',
#   'year': '2011',
#   'link': 'https://www.imdb.com/title/tt0478304/',
#   'rating': '6.8',
#   'wins': 117,
#   'nominations': 130},
#  {'title': 'Eternal Sunshine of the Spotless Mind',
#   'director': 'Michel Gondry',
#   'year': '2004',
#   'link': 'https://www.imdb.com/title/tt0338013/',
#   'rating': '8.3',
#   'wins': 73,
#   'nominations': 111},
#  {'title': 'Boyhood',
#   'director': 'Richard Linklater',
#   'year': '2014',
#   'link': 'https://www.imdb.com/title/tt1065073/',
#   'rating': '7.9',
#   'wins': 178,
#   'nominations': 220},
#  {'title': 'Spirited Away',
#   'director': 'Hayao Miyazaki',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0245429/',
#   'rating': '8.6',
#   'wins': 58,
#   'nominations': 31},
#  {'title': 'There Will Be Blood',
#   'director': 'Paul Thomas Anderson',
#   'year': '2007',
#   'link': 'https://www.imdb.com/title/tt0469494/',
#   'rating': '8.2',
#   'wins': 114,
#   'nominations': 138},
#  {'title': 'In the Mood for Love',
#   'director': 'Wong Kar-wai',
#   'year': '2000',
#   'link': 'https://www.imdb.com/title/tt0118694/',
#   'rating': '8.1',
#   'wins': 45,
#   'nominations': 50},
#  {'title': 'Mulholland Drive',
#   'director': 'David Lynch',
#   'year': '2001',
#   'link': 'https://www.imdb.com/title/tt0166924/',
#   'rating': '7.9',
#   'wins': 50,
#   'nominations': 61}]

# %% [markdown]
# #### scraping the genre tags

# %%
df_all = pd.DataFrame(main_data)

# %%
df_all.to_csv('list_all.csv', index=False)

# %%
df_all = pd.read_csv('list_all.csv')

# %%
list_of_dicts = df_all.to_dict('records')

# %%
for movie in list_of_dicts:
    try:
        response = requests.get(movie['link'], headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        genre_tags = soup.find_all('a', class_='ipc-chip ipc-chip--on-baseAlt')
        movie['genres'] = [tag.span.get_text(strip=True) for tag in genre_tags if tag.span]
    except Exception as e:
        print(f"🚨 Error processing {movie['title']}: {str(e)}")
        movie.setdefault('genres', [])

# %%
list_of_dicts
# Out:
# [{'title': 'Toni Erdmann',
#   'director': 'Maren Ade',
#   'year': 2016,
#   'link': 'https://www.imdb.com/title/tt4048272/',
#   'rating': 7.3,
#   'wins': 59.0,
#   'nominations': 85.0,
#   'genres': ['Psychological Drama', 'Quirky Comedy', 'Comedy', 'Drama']},
#  {'title': 'Requiem for a Dream',
#   'director': 'Darren Aronofsky',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0180093/',
#   'rating': 8.3,
#   'wins': 37.0,
#   'nominations': 69.0,
#   'genres': ['Psychological Drama', 'Tragedy', 'Drama']},
#  {'title': 'Carlos',
#   'director': 'Olivier Assayas',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt1321865/',
#   'rating': 7.6,
#   'wins': 18.0,
#   'nominations': 49.0,
#   'genres': ['True Crime', 'Biography', 'Crime', 'Drama', 'Thriller']},
#  {'title': 'The Gleaners and I',
#   'director': 'Agnès Varda',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0247380/',
#   'rating': 7.7,
#   'wins': 16.0,
#   'nominations': 3.0,
#   'genres': ['Documentary']},
#  {'title': 'Ten',
#   'director': 'Abbas Kiarostami',
#   'year': 2002,
#   'link': 'https://www.imdb.com/title/tt0301978/',
#   'rating': 7.4,
#   'wins': 1.0,
#   'nominations': 4.0,
#   'genres': ['Drama']},
#  {'title': 'White Material',
#   'director': 'Claire Denis',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt1135952/',
#   'rating': 6.9,
#   'wins': 1.0,
#   'nominations': 10.0,
#   'genres': ['Drama', 'War']},
#  {'title': 'Finding Nemo',
#   'director': 'Andrew Stanton',
#   'year': 2003,
#   'link': 'https://www.imdb.com/title/tt0266543/',
#   'rating': 8.2,
#   'wins': 49.0,
#   'nominations': 63.0,
#   'genres': ['Animal Adventure',
#    'Buddy Comedy',
#    'Computer Animation',
#    'Quest',
#    'Sea Adventure',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family']},
#  {'title': 'Moonrise Kingdom',
#   'director': 'Wes Anderson',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt1748122/',
#   'rating': 7.8,
#   'wins': 36.0,
#   'nominations': 121.0,
#   'genres': ['Coming-of-Age',
#    'Feel-Good Romance',
#    'Quirky Comedy',
#    'Romantic Comedy',
#    'Teen Romance',
#    'Adventure',
#    'Comedy',
#    'Drama',
#    'Fantasy',
#    'Romance']},
#  {'title': 'Let the Right One In',
#   'director': 'Tomas Alfredson',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt1139797/',
#   'rating': 7.8,
#   'wins': 76.0,
#   'nominations': 58.0,
#   'genres': ['Coming-of-Age',
#    'Dark Fantasy',
#    'Dark Romance',
#    'Psychological Drama',
#    'Psychological Horror',
#    'Splatter Horror',
#    'Supernatural Fantasy',
#    'Supernatural Horror',
#    'Teen Romance',
#    'Vampire Horror']},
#  {'title': 'Ratatouille',
#   'director': 'Brad Bird',
#   'year': 2007,
#   'link': 'https://www.imdb.com/title/tt0382932/',
#   'rating': 8.1,
#   'wins': 68.0,
#   'nominations': 42.0,
#   'genres': ['Animal Adventure',
#    'Computer Animation',
#    'Satire',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy']},
#  {'title': 'The Assassination of Jesse James by the Coward Robert Ford',
#   'director': 'Andrew Dominik',
#   'year': 2007,
#   'link': 'https://www.imdb.com/title/tt0443680/',
#   'rating': 7.5,
#   'wins': 25.0,
#   'nominations': 69.0,
#   'genres': ['Costume Drama',
#    'Epic',
#    'Period Drama',
#    'True Crime',
#    'Western Epic',
#    'Biography',
#    'Crime',
#    'Drama',
#    'History',
#    'Western']},
#  {'title': 'The Secret in Their Eyes',
#   'director': 'Juan José Campanella',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt1305806/',
#   'rating': 8.2,
#   'wins': 53.0,
#   'nominations': 43.0,
#   'genres': ['Dark Romance',
#    'Erotic Thriller',
#    'Legal Thriller',
#    'Period Drama',
#    'Psychological Drama',
#    'Psychological Thriller',
#    'Suspense Mystery',
#    'Tragedy',
#    'Whodunnit',
#    'Drama']},
#  {'title': 'The Pianist',
#   'director': 'Roman Polanski',
#   'year': 2002,
#   'link': 'https://www.imdb.com/title/tt0253474/',
#   'rating': 8.5,
#   'wins': 57.0,
#   'nominations': 74.0,
#   'genres': ['Docudrama',
#    'Epic',
#    'Period Drama',
#    'Tragedy',
#    'War Epic',
#    'Biography',
#    'Drama',
#    'Music',
#    'War']},
#  {'title': 'The Headless Woman',
#   'director': 'Lucrecia Martel',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt1221141/',
#   'rating': nan,
#   'wins': 9.0,
#   'nominations': 19.0,
#   'genres': ['Drama', 'Mystery', 'Thriller']},
#  {'title': 'Spotlight',
#   'director': 'Tom McCarthy',
#   'year': 2015,
#   'link': 'https://www.imdb.com/title/tt1895587/',
#   'rating': 8.1,
#   'wins': 124.0,
#   'nominations': 145.0,
#   'genres': ['Docudrama',
#    'Legal Drama',
#    'Period Drama',
#    'True Crime',
#    'Workplace Drama',
#    'Biography',
#    'Crime',
#    'Drama']},
#  {'title': 'Amélie',
#   'director': 'Jean-Pierre Jeunet',
#   'year': 2001,
#   'link': 'https://www.imdb.com/title/tt0211915/',
#   'rating': 8.3,
#   'wins': 59.0,
#   'nominations': 74.0,
#   'genres': ['Feel-Good Romance',
#    'Quirky Comedy',
#    'Romantic Comedy',
#    'Comedy',
#    'Romance']},
#  {'title': 'Far From Heaven',
#   'director': 'Todd Haynes',
#   'year': 2002,
#   'link': 'https://www.imdb.com/title/tt0297884/',
#   'rating': 7.3,
#   'wins': 102.0,
#   'nominations': 96.0,
#   'genres': ['Period Drama', 'Drama', 'Romance']},
#  {'title': 'A Prophet',
#   'director': 'Jacques Audiard',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt1235166/',
#   'rating': 7.8,
#   'wins': 52.0,
#   'nominations': 57.0,
#   'genres': ['Prison Drama', 'Crime', 'Drama']},
#  {'title': 'Her',
#   'director': 'Spike Jonze',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt1798709/',
#   'rating': 8.0,
#   'wins': 83.0,
#   'nominations': 187.0,
#   'genres': ['Artificial Intelligence', 'Drama', 'Romance', 'Sci-Fi']},
#  {'title': 'A.I. Artificial Intelligence',
#   'director': 'Steven Spielberg',
#   'year': 2001,
#   'link': 'https://www.imdb.com/title/tt0212720/',
#   'rating': 7.2,
#   'wins': 18.0,
#   'nominations': 71.0,
#   'genres': ['Artificial Intelligence',
#    'Sci-Fi Epic',
#    'Adventure',
#    'Drama',
#    'Sci-Fi']},
#  {'title': 'A Serious Man',
#   'director': 'Joel and Ethan Coen',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt1019452/',
#   'rating': 7.0,
#   'wins': 17.0,
#   'nominations': 80.0,
#   'genres': ['Dark Comedy',
#    'Period Drama',
#    'Psychological Drama',
#    'Quirky Comedy',
#    'Tragedy',
#    'Comedy',
#    'Drama']},
#  {'title': 'Shame',
#   'director': 'Steve McQueen',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt1723811/',
#   'rating': 7.2,
#   'wins': 51.0,
#   'nominations': 94.0,
#   'genres': ['Psychological Drama', 'Drama']},
#  {'title': 'The Return',
#   'director': 'Andrey Zvyagintsev',
#   'year': 2003,
#   'link': 'https://www.imdb.com/title/tt0167260/',
#   'rating': 9.0,
#   'wins': 215.0,
#   'nominations': 124.0,
#   'genres': ['Action Epic',
#    'Adventure Epic',
#    'Epic',
#    'Fantasy Epic',
#    'Mountain Adventure',
#    'Quest',
#    'Sword & Sorcery',
#    'Tragedy',
#    'Adventure',
#    'Drama']},
#  {'title': 'Almost Famous',
#   'director': 'Cameron Crowe',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0181875/',
#   'rating': 7.9,
#   'wins': 54.0,
#   'nominations': 103.0,
#   'genres': ['Coming-of-Age',
#    'Period Drama',
#    'Road Trip',
#    'Showbiz Drama',
#    'Adventure',
#    'Comedy',
#    'Drama',
#    'Music']},
#  {'title': 'The Wolf of Wall Street',
#   'director': 'Martin Scorsese',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt0993846/',
#   'rating': 8.2,
#   'wins': 38.0,
#   'nominations': 180.0,
#   'genres': ['Dark Comedy',
#    'Docudrama',
#    'Epic',
#    'Raunchy Comedy',
#    'Satire',
#    'True Crime',
#    'Biography',
#    'Comedy',
#    'Crime',
#    'Drama']},
#  {'title': 'The Diving Bell and the Butterfly',
#   'director': 'Julian Schnabel',
#   'year': 2007,
#   'link': 'https://www.imdb.com/title/tt2998630/',
#   'rating': nan,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Short']},
#  {'title': 'Dogville',
#   'director': 'Lars von Trier',
#   'year': 2003,
#   'link': 'https://www.imdb.com/title/tt0276919/',
#   'rating': 8.0,
#   'wins': 21.0,
#   'nominations': 33.0,
#   'genres': ['Gangster', 'Psychological Drama', 'Crime', 'Drama']},
#  {'title': 'Inherent Vice',
#   'director': 'Paul Thomas Anderson',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt1791528/',
#   'rating': 6.6,
#   'wins': 15.0,
#   'nominations': 99.0,
#   'genres': ['Bumbling Detective',
#    'Dark Comedy',
#    'Period Drama',
#    'Satire',
#    'Whodunnit',
#    'Comedy',
#    'Crime',
#    'Drama',
#    'Mystery',
#    'Romance']},
#  {'title': 'Spring Breakers',
#   'director': 'Harmony Korine',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt2101441/',
#   'rating': 5.3,
#   'wins': 14.0,
#   'nominations': 35.0,
#   'genres': ['Caper',
#    'Coming-of-Age',
#    'Dark Comedy',
#    'Drug Crime',
#    'Erotic Thriller',
#    'Teen Drama',
#    'Crime',
#    'Drama',
#    'Thriller']},
#  {'title': 'Before Sunset',
#   'director': 'Richard Linklater',
#   'year': 2004,
#   'link': 'https://www.imdb.com/title/tt0381681/',
#   'rating': 8.1,
#   'wins': 10.0,
#   'nominations': 32.0,
#   'genres': ['Feel-Good Romance', 'Drama', 'Romance']},
#  {'title': 'Only Lovers Left Alive',
#   'director': 'Jim Jarmusch',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt1714915/',
#   'rating': 7.2,
#   'wins': 8.0,
#   'nominations': 44.0,
#   'genres': ['Dark Fantasy',
#    'Dark Romance',
#    'Comedy',
#    'Drama',
#    'Fantasy',
#    'Horror',
#    'Romance']},
#  {'title': 'Tabu',
#   'director': 'Miguel Gomes',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt2153963/',
#   'rating': 7.3,
#   'wins': 21.0,
#   'nominations': 46.0,
#   'genres': ['Drama', 'Romance']},
#  {'title': 'Stories We Tell',
#   'director': 'Sarah Polley',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt2366450/',
#   'rating': 7.5,
#   'wins': 25.0,
#   'nominations': 44.0,
#   'genres': ['Documentary']},
#  {'title': 'Carol',
#   'director': 'Todd Haynes',
#   'year': 2015,
#   'link': 'https://www.imdb.com/title/tt2402927/',
#   'rating': 7.3,
#   'wins': 76.0,
#   'nominations': 255.0,
#   'genres': ['Period Drama', 'Steamy Romance', 'Drama', 'Romance']},
#  {'title': 'The Royal Tenenbaums',
#   'director': 'Wes Anderson',
#   'year': 2001,
#   'link': 'https://www.imdb.com/title/tt0265666/',
#   'rating': 7.6,
#   'wins': 11.0,
#   'nominations': 46.0,
#   'genres': ['Quirky Comedy', 'Comedy', 'Drama']},
#  {'title': 'The Hurt Locker',
#   'director': 'Kathryn Bigelow',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt0887912/',
#   'rating': 7.5,
#   'wins': 125.0,
#   'nominations': 130.0,
#   'genres': ['Psychological Drama', 'Drama', 'Thriller', 'War']},
#  {'title': 'Spring, Summer, Fall, Winter…and Spring',
#   'director': 'Kim Ki-duk',
#   'year': 2003,
#   'link': 'https://www.imdb.com/title/tt0374546/',
#   'rating': 8.0,
#   'wins': 15.0,
#   'nominations': 9.0,
#   'genres': ['Coming-of-Age', 'Drama', 'Romance']},
#  {'title': 'Fish Tank',
#   'director': 'Andrea Arnold',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt1232776/',
#   'rating': 7.3,
#   'wins': 21.0,
#   'nominations': 30.0,
#   'genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'title': 'The Great Beauty',
#   'director': 'Paolo Sorrentino',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt2358891/',
#   'rating': 7.7,
#   'wins': 60.0,
#   'nominations': 78.0,
#   'genres': ['Drama']},
#  {'title': 'The Turin Horse',
#   'director': 'Béla Tarr and Ágnes Hranitzky',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt1316540/',
#   'rating': 7.7,
#   'wins': 7.0,
#   'nominations': 15.0,
#   'genres': ['Psychological Drama', 'Tragedy', 'Drama']},
#  {'title': 'Inglourious Basterds',
#   'director': 'Quentin Tarantino',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt0361748/',
#   'rating': 8.4,
#   'wins': 134.0,
#   'nominations': 173.0,
#   'genres': ['Dark Comedy', 'Period Drama', 'Adventure', 'Drama', 'War']},
#  {'title': 'Under the Skin',
#   'director': 'Jonathan Glazer',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt1441395/',
#   'rating': 6.3,
#   'wins': 23.0,
#   'nominations': 113.0,
#   'genres': ['Alien Invasion',
#    'Supernatural Horror',
#    'Drama',
#    'Horror',
#    'Mystery',
#    'Sci-Fi',
#    'Thriller']},
#  {'title': 'Syndromes and a Century',
#   'director': 'Apichatpong Weerasethakul',
#   'year': 2006,
#   'link': 'https://www.imdb.com/title/tt0477731/',
#   'rating': 7.3,
#   'wins': 3.0,
#   'nominations': 13.0,
#   'genres': ['Drama']},
#  {'title': 'A History of Violence',
#   'director': 'David Cronenberg',
#   'year': 2005,
#   'link': 'https://www.imdb.com/title/tt0399146/',
#   'rating': 7.4,
#   'wins': 37.0,
#   'nominations': 84.0,
#   'genres': ['Gangster',
#    'One-Person Army Action',
#    'Action',
#    'Crime',
#    'Drama',
#    'Thriller']},
#  {'title': 'Moolaadé',
#   'director': 'Ousmane Sembène',
#   'year': 2004,
#   'link': 'https://www.imdb.com/title/tt33057548/',
#   'rating': nan,
#   'wins': nan,
#   'nominations': nan,
#   'genres': ['Comedy']},
#  {'title': 'Zero Dark Thirty',
#   'director': 'Kathryn Bigelow',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt1790885/',
#   'rating': 7.4,
#   'wins': 85.0,
#   'nominations': 174.0,
#   'genres': ['Docudrama',
#    'Political Drama',
#    'Political Thriller',
#    'Drama',
#    'History',
#    'Thriller']},
#  {'title': 'Werckmeister Harmonies',
#   'director': 'Béla Tarr, director; Ágnes Hranitzky, co-director',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0249241/',
#   'rating': 8.0,
#   'wins': 5.0,
#   'nominations': 2.0,
#   'genres': ['Tragedy', 'Drama', 'Mystery']},
#  {'title': 'Ida',
#   'director': 'Paweł Pawlikowski',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt2718492/',
#   'rating': 7.4,
#   'wins': 69.0,
#   'nominations': 92.0,
#   'genres': ['Tragedy', 'Drama']},
#  {'title': 'Once Upon a Time in Anatolia',
#   'director': 'Nuri Bilge Ceylan',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt1843230/',
#   'rating': 7.7,
#   'wins': 13.0,
#   'nominations': 95.0,
#   'genres': ['Fairy Tale',
#    'Teen Fantasy',
#    'Teen Romance',
#    'Adventure',
#    'Fantasy',
#    'Romance']},
#  {'title': 'Moulin Rouge!',
#   'director': 'Baz Luhrmann',
#   'year': 2001,
#   'link': 'https://www.imdb.com/title/tt0203009/',
#   'rating': 7.6,
#   'wins': 87.0,
#   'nominations': 133.0,
#   'genres': ['Jukebox Musical',
#    'Period Drama',
#    'Pop Musical',
#    'Rock Musical',
#    'Tragic Romance',
#    'Drama',
#    'Musical',
#    'Romance']},
#  {'title': 'Tropical Malady',
#   'director': 'Apichatpong Weerasethakul',
#   'year': 2004,
#   'link': 'https://www.imdb.com/title/tt0381668/',
#   'rating': 7.1,
#   'wins': 7.0,
#   'nominations': 8.0,
#   'genres': ['Drama', 'Fantasy', 'Romance']},
#  {'title': 'Inception',
#   'director': 'Christopher Nolan',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt1375666/',
#   'rating': 8.8,
#   'wins': 159.0,
#   'nominations': 220.0,
#   'genres': ['Action Epic',
#    'Adventure Epic',
#    'Epic',
#    'Psychological Thriller',
#    'Sci-Fi Epic',
#    'Action',
#    'Adventure',
#    'Sci-Fi',
#    'Thriller']},
#  {'title': 'The Assassin',
#   'director': 'Hou Hsiao-hsien',
#   'year': 2015,
#   'link': 'https://www.imdb.com/title/tt3508840/',
#   'rating': 6.3,
#   'wins': 36.0,
#   'nominations': 75.0,
#   'genres': ['Wuxia', 'Action', 'Drama', 'History']},
#  {'title': 'Goodbye to Language',
#   'director': 'Jean-Luc Godard',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt2400275/',
#   'rating': 5.8,
#   'wins': 4.0,
#   'nominations': 20.0,
#   'genres': ['Drama', 'Fantasy']},
#  {'title': 'Brooklyn',
#   'director': 'John Crowley',
#   'year': 2015,
#   'link': 'https://www.imdb.com/title/tt2381111/',
#   'rating': 7.5,
#   'wins': 38.0,
#   'nominations': 161.0,
#   'genres': ['Period Drama', 'Drama', 'Romance']},
#  {'title': 'Leviathan',
#   'director': 'Andrey Zvyagintsev',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt2802154/',
#   'rating': 7.6,
#   'wins': 38.0,
#   'nominations': 52.0,
#   'genres': ['Dark Comedy',
#    'Gangster',
#    'Legal Drama',
#    'Tragedy',
#    'Crime',
#    'Drama']},
#  {'title': 'Certified Copy',
#   'director': 'Abbas Kiarostami',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt1020773/',
#   'rating': 7.2,
#   'wins': 11.0,
#   'nominations': 29.0,
#   'genres': ['Legal Drama', 'Psychological Drama', 'Drama', 'Romance']},
#  {'title': 'Blue Is the Warmest Color',
#   'director': 'Abdellatif Kechiche',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt2278871/',
#   'rating': 7.7,
#   'wins': 87.0,
#   'nominations': 106.0,
#   'genres': ['Coming-of-Age', 'Steamy Romance', 'Drama', 'Romance']},
#  {'title': '12 Years a Slave',
#   'director': 'Steve McQueen',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt2024544/',
#   'rating': 8.1,
#   'wins': 244.0,
#   'nominations': 338.0,
#   'genres': ['Costume Drama',
#    'Docudrama',
#    'Epic',
#    'Period Drama',
#    'Tragedy',
#    'Biography',
#    'Drama',
#    'History']},
#  {'title': 'Melancholia',
#   'director': 'Lars von Trier',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt1527186/',
#   'rating': 7.1,
#   'wins': 36.0,
#   'nominations': 95.0,
#   'genres': ['Psychological Drama', 'Tragedy', 'Drama', 'Sci-Fi']},
#  {'title': 'Amour',
#   'director': 'Michael Haneke',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt1602620/',
#   'rating': 7.9,
#   'wins': 84.0,
#   'nominations': 111.0,
#   'genres': ['Tragedy', 'Drama']},
#  {'title': 'Inside Out',
#   'director': 'Pete Docter',
#   'year': 2015,
#   'link': 'https://www.imdb.com/title/tt2096673/',
#   'rating': 8.1,
#   'wins': 99.0,
#   'nominations': 118.0,
#   'genres': ['Coming-of-Age',
#    'Computer Animation',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Drama',
#    'Family',
#    'Fantasy']},
#  {'title': 'Brokeback Mountain',
#   'director': 'Ang Lee',
#   'year': 2005,
#   'link': 'https://www.imdb.com/title/tt0388795/',
#   'rating': 7.7,
#   'wins': 141.0,
#   'nominations': 133.0,
#   'genres': ['Contemporary Western',
#    'Steamy Romance',
#    'Tragedy',
#    'Tragic Romance',
#    'Drama',
#    'Romance']},
#  {'title': 'The New World',
#   'director': 'Terrence Malick',
#   'year': 2005,
#   'link': 'https://www.imdb.com/title/tt0402399/',
#   'rating': 6.7,
#   'wins': 6.0,
#   'nominations': 34.0,
#   'genres': ['Period Drama', 'Biography', 'Drama', 'History', 'Romance']},
#  {'title': 'City of God',
#   'director': 'Fernando Meirelles and Kátia Lund',
#   'year': 2002,
#   'link': 'https://www.imdb.com/title/tt0317248/',
#   'rating': 8.6,
#   'wins': 75.0,
#   'nominations': 50.0,
#   'genres': ['Caper', 'Coming-of-Age', 'Gangster', 'Crime', 'Drama']},
#  {'title': 'Uncle Boonmee Who Can Recall His Past Lives',
#   'director': 'Apichatpong Weerasethakul',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt1588895/',
#   'rating': 6.7,
#   'wins': 11.0,
#   'nominations': 25.0,
#   'genres': ['Drama', 'Fantasy']},
#  {'title': 'Timbuktu',
#   'director': 'Abderrahmane Sissako',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt3409392/',
#   'rating': 7.1,
#   'wins': 33.0,
#   'nominations': 28.0,
#   'genres': ['Drama', 'War']},
#  {'title': 'Crouching Tiger, Hidden Dragon',
#   'director': 'Ang Lee',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0190332/',
#   'rating': 7.9,
#   'wins': 101.0,
#   'nominations': 132.0,
#   'genres': ['Action Epic',
#    'Adventure Epic',
#    'Epic',
#    'Fantasy Epic',
#    'Martial Arts',
#    'Period Drama',
#    'Quest',
#    'Romantic Epic',
#    'Sword & Sorcery',
#    'Wuxia']},
#  {'title': 'Son of Saul',
#   'director': 'László Nemes',
#   'year': 2015,
#   'link': 'https://www.imdb.com/title/tt3808342/',
#   'rating': 7.4,
#   'wins': 65.0,
#   'nominations': 62.0,
#   'genres': ['Prison Drama',
#    'Psychological Drama',
#    'Tragedy',
#    'Drama',
#    'War']},
#  {'title': 'The Dark Knight',
#   'director': 'Christopher Nolan',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt0468569/',
#   'rating': 9.0,
#   'wins': 164.0,
#   'nominations': 165.0,
#   'genres': ['Action Epic',
#    'Epic',
#    'Superhero',
#    'Tragedy',
#    'Action',
#    'Crime',
#    'Drama',
#    'Thriller']},
#  {'title': 'The Lives of Others',
#   'director': 'Florian Henckel von Donnersmarck',
#   'year': 2006,
#   'link': 'https://www.imdb.com/title/tt0405094/',
#   'rating': 8.4,
#   'wins': 80.0,
#   'nominations': 38.0,
#   'genres': ['Political Thriller',
#    'Psychological Drama',
#    'Spy',
#    'Drama',
#    'Mystery',
#    'Thriller']},
#  {'title': 'Margaret',
#   'director': 'Kenneth Lonergan',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt0466893/',
#   'rating': 6.5,
#   'wins': 10.0,
#   'nominations': 18.0,
#   'genres': ['Psychological Drama', 'Drama', 'Mystery']},
#  {'title': 'Oldboy',
#   'director': 'Park Chan-wook',
#   'year': 2003,
#   'link': 'https://www.imdb.com/title/tt0364569/',
#   'rating': 8.3,
#   'wins': 43.0,
#   'nominations': 28.0,
#   'genres': ['Dark Comedy',
#    'One-Person Army Action',
#    'Psychological Drama',
#    'Psychological Thriller',
#    'Action',
#    'Drama',
#    'Mystery',
#    'Thriller']},
#  {'title': 'WALL-E',
#   'director': 'Andrew Stanton',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt0910970/',
#   'rating': 8.4,
#   'wins': 96.0,
#   'nominations': 95.0,
#   'genres': ['Adventure Epic',
#    'Artificial Intelligence',
#    'Computer Animation',
#    'Dystopian Sci-Fi',
#    'Psychological Drama',
#    'Space Sci-Fi',
#    'Adventure',
#    'Animation',
#    'Family',
#    'Sci-Fi']},
#  {'title': 'Talk to Her',
#   'director': 'Pedro Almodóvar',
#   'year': 2002,
#   'link': 'https://www.imdb.com/title/tt0287467/',
#   'rating': 7.9,
#   'wins': 47.0,
#   'nominations': 47.0,
#   'genres': ['Steamy Romance', 'Drama', 'Mystery', 'Romance']},
#  {'title': 'The Social Network',
#   'director': 'David Fincher',
#   'year': 2010,
#   'link': 'https://www.imdb.com/title/tt1285016/',
#   'rating': 7.8,
#   'wins': 174.0,
#   'nominations': 188.0,
#   'genres': ['Docudrama', 'Epic', 'Legal Drama', 'Biography', 'Drama']},
#  {'title': '25th Hour',
#   'director': 'Spike Lee',
#   'year': 2002,
#   'link': 'https://www.imdb.com/title/tt0307901/',
#   'rating': 7.6,
#   'wins': 4.0,
#   'nominations': 17.0,
#   'genres': ['Prison Drama', 'Psychological Drama', 'Drama']},
#  {'title': '\u200bMemento',
#   'director': 'Christopher Nolan',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0209144/',
#   'rating': 8.4,
#   'wins': 57.0,
#   'nominations': 59.0,
#   'genres': ['Psychological Thriller',
#    'Suspense Mystery',
#    'Mystery',
#    'Thriller']},
#  {'title': 'The Master',
#   'director': 'Paul Thomas Anderson',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt1560747/',
#   'rating': 7.1,
#   'wins': 75.0,
#   'nominations': 187.0,
#   'genres': ['Psychological Drama', 'Drama', 'History']},
#  {'title': 'Caché',
#   'director': 'Michael Haneke',
#   'year': 2005,
#   'link': 'https://www.imdb.com/title/tt0387898/',
#   'rating': 7.3,
#   'wins': 29.0,
#   'nominations': 37.0,
#   'genres': ['Psychological Thriller', 'Drama', 'Mystery', 'Thriller']},
#  {'title': 'Lost in Translation',
#   'director': 'Sofia Coppola',
#   'year': 2003,
#   'link': 'https://www.imdb.com/title/tt0335266/',
#   'rating': 7.7,
#   'wins': 97.0,
#   'nominations': 133.0,
#   'genres': ['Coming-of-Age', 'Comedy', 'Drama']},
#  {'title': 'The Grand Budapest Hotel',
#   'director': 'Wes Anderson',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt2278388/',
#   'rating': 8.1,
#   'wins': 135.0,
#   'nominations': 227.0,
#   'genres': ['Quirky Comedy', 'Comedy', 'Drama']},
#  {'title': 'Synecdoche, New York',
#   'director': 'Charlie Kaufman',
#   'year': 2008,
#   'link': 'https://www.imdb.com/title/tt0383028/',
#   'rating': 7.5,
#   'wins': 8.0,
#   'nominations': 29.0,
#   'genres': ['Dark Comedy', 'Drama']},
#  {'title': 'Mad Max: Fury Road',
#   'director': 'George Miller',
#   'year': 2015,
#   'link': 'https://www.imdb.com/title/tt1392190/',
#   'rating': 8.1,
#   'wins': 245.0,
#   'nominations': 234.0,
#   'genres': ['Action Epic',
#    'Adventure Epic',
#    'Car Action',
#    'Desert Adventure',
#    'Dystopian Sci-Fi',
#    'Epic',
#    'Quest',
#    'Road Trip',
#    'Action',
#    'Adventure']},
#  {'title': 'The White Ribbon',
#   'director': 'Michael Haneke',
#   'year': 2009,
#   'link': 'https://www.imdb.com/title/tt1149362/',
#   'rating': 7.8,
#   'wins': 62.0,
#   'nominations': 49.0,
#   'genres': ['Costume Drama',
#    'Period Drama',
#    'Psychological Drama',
#    'Psychological Thriller',
#    'Drama',
#    'Mystery',
#    'Thriller']},
#  {'title': "Pan's Labyrinth",
#   'director': 'Guillermo Del Toro',
#   'year': 2006,
#   'link': 'https://www.imdb.com/title/tt0457430/',
#   'rating': 8.2,
#   'wins': 109.0,
#   'nominations': 115.0,
#   'genres': ['Coming-of-Age',
#    'Dark Fantasy',
#    'Fairy Tale',
#    'Period Drama',
#    'Supernatural Fantasy',
#    'Teen Fantasy',
#    'Tragedy',
#    'Drama',
#    'Fantasy',
#    'War']},
#  {'title': 'Holy Motors',
#   'director': 'Leos Carax',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt2076220/',
#   'rating': 7.0,
#   'wins': 29.0,
#   'nominations': 74.0,
#   'genres': ['Psychological Drama',
#    'Supernatural Fantasy',
#    'Drama',
#    'Fantasy']},
#  {'title': '4 Months, 3 Weeks and 2 Days',
#   'director': 'Cristian Mungiu',
#   'year': 2007,
#   'link': 'https://www.imdb.com/title/tt1032846/',
#   'rating': 7.9,
#   'wins': 41.0,
#   'nominations': 59.0,
#   'genres': ['Period Drama', 'Tragedy', 'Drama']},
#  {'title': 'The Act of Killing',
#   'director': 'Joshua Oppenheimer',
#   'year': 2012,
#   'link': 'https://www.imdb.com/title/tt2375605/',
#   'rating': 8.2,
#   'wins': 55.0,
#   'nominations': 46.0,
#   'genres': ['Crime Documentary',
#    'Biography',
#    'Crime',
#    'Documentary',
#    'History',
#    'War']},
#  {'title': 'Children of Men',
#   'director': 'Alfonso Cuarón',
#   'year': 2006,
#   'link': 'https://www.imdb.com/title/tt0206634/',
#   'rating': 7.9,
#   'wins': 49.0,
#   'nominations': 89.0,
#   'genres': ['Dystopian Sci-Fi',
#    'Epic',
#    'Sci-Fi Epic',
#    'Drama',
#    'Sci-Fi',
#    'Thriller']},
#  {'title': 'Zodiac',
#   'director': 'David Fincher',
#   'year': 2007,
#   'link': 'https://www.imdb.com/title/tt0443706/',
#   'rating': 7.7,
#   'wins': 3.0,
#   'nominations': 71.0,
#   'genres': ['Cop Drama',
#    'Epic',
#    'Police Procedural',
#    'Psychological Thriller',
#    'Serial Killer',
#    'True Crime',
#    'Whodunnit',
#    'Crime',
#    'Drama',
#    'Mystery']},
#  {'title': 'Inside Llewyn Davis',
#   'director': 'Joel and Ethan Coen',
#   'year': 2013,
#   'link': 'https://www.imdb.com/title/tt2042568/',
#   'rating': 7.4,
#   'wins': 47.0,
#   'nominations': 174.0,
#   'genres': ['Dark Comedy',
#    'Period Drama',
#    'Showbiz Drama',
#    'Tragedy',
#    'Drama',
#    'Music']},
#  {'title': 'No Country for Old Men',
#   'director': 'Joel and Ethan Coen',
#   'year': 2007,
#   'link': 'https://www.imdb.com/title/tt0477348/',
#   'rating': 8.2,
#   'wins': 165.0,
#   'nominations': 139.0,
#   'genres': ['Contemporary Western',
#    'Psychological Thriller',
#    'Serial Killer',
#    'Crime',
#    'Drama',
#    'Thriller']},
#  {'title': 'A Separation',
#   'director': 'Asghar Farhadi',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt1832382/',
#   'rating': 8.3,
#   'wins': 89.0,
#   'nominations': 52.0,
#   'genres': ['Legal Drama', 'Psychological Drama', 'Drama']},
#  {'title': 'Yi Yi: A One and a Two',
#   'director': 'Edward Yang',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0244316/',
#   'rating': 8.1,
#   'wins': 14.0,
#   'nominations': 23.0,
#   'genres': ['Drama', 'Romance']},
#  {'title': 'The Tree of Life',
#   'director': 'Terrence Malick',
#   'year': 2011,
#   'link': 'https://www.imdb.com/title/tt0478304/',
#   'rating': 6.8,
#   'wins': 117.0,
#   'nominations': 130.0,
#   'genres': ['Coming-of-Age', 'Drama', 'Fantasy']},
#  {'title': 'Eternal Sunshine of the Spotless Mind',
#   'director': 'Michel Gondry',
#   'year': 2004,
#   'link': 'https://www.imdb.com/title/tt0338013/',
#   'rating': 8.3,
#   'wins': 73.0,
#   'nominations': 111.0,
#   'genres': ['Dark Romance',
#    'Psychological Drama',
#    'Drama',
#    'Romance',
#    'Sci-Fi']},
#  {'title': 'Boyhood',
#   'director': 'Richard Linklater',
#   'year': 2014,
#   'link': 'https://www.imdb.com/title/tt1065073/',
#   'rating': 7.9,
#   'wins': 178.0,
#   'nominations': 220.0,
#   'genres': ['Coming-of-Age', 'Drama']},
#  {'title': 'Spirited Away',
#   'director': 'Hayao Miyazaki',
#   'year': 2001,
#   'link': 'https://www.imdb.com/title/tt0245429/',
#   'rating': 8.6,
#   'wins': 58.0,
#   'nominations': 31.0,
#   'genres': ['Anime',
#    'Coming-of-Age',
#    'Fairy Tale',
#    'Hand-Drawn Animation',
#    'Quest',
#    'Supernatural Fantasy',
#    'Adventure',
#    'Animation',
#    'Family',
#    'Fantasy']},
#  {'title': 'There Will Be Blood',
#   'director': 'Paul Thomas Anderson',
#   'year': 2007,
#   'link': 'https://www.imdb.com/title/tt0469494/',
#   'rating': 8.2,
#   'wins': 114.0,
#   'nominations': 138.0,
#   'genres': ['Epic',
#    'Period Drama',
#    'Psychological Drama',
#    'Tragedy',
#    'Drama']},
#  {'title': 'In the Mood for Love',
#   'director': 'Wong Kar-wai',
#   'year': 2000,
#   'link': 'https://www.imdb.com/title/tt0118694/',
#   'rating': 8.1,
#   'wins': 45.0,
#   'nominations': 50.0,
#   'genres': ['Dark Romance', 'Tragic Romance', 'Drama', 'Romance']},
#  {'title': 'Mulholland Drive',
#   'director': 'David Lynch',
#   'year': 2001,
#   'link': 'https://www.imdb.com/title/tt0166924/',
#   'rating': 7.9,
#   'wins': 50.0,
#   'nominations': 61.0,
#   'genres': ['Psychological Drama',
#    'Psychological Thriller',
#    'Showbiz Drama',
#    'Suspense Mystery',
#    'Tragedy',
#    'Drama',
#    'Mystery',
#    'Thriller']}]

# %%
df_list_of_dicts = pd.DataFrame(list_of_dicts)

# %%
df_list_of_dicts.to_csv('list_all_bbc.csv', index=False)

# %% [markdown]
# # I DECIDED TO NOT USE THIS FOR MY STORY - Scraping Rotten Tomatos (for a detailed breakdown of which genre we see the most growth and pronominence of female directors)

# %% [markdown]
# ## 1. Set up a loop that PRINTS titles and directors

# %%
base_url = "https://editorial.rottentomatoes.com/guide/best-movies-directed-by-women-of-the-21st-century/{}/"
movies = []

for page_num in range(1, 4): 
    url = base_url.format(page_num)
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Loop through each movie container
    for movie in soup.find_all('div', class_='countdown-item'):
        # Extract title and year
        title_div = movie.find('div', class_='article_movie_title')
        title = title_div.h2.a.text.strip() if title_div else "N/A"
        year = title_div.find('span', class_='subtle start-year').text.strip('()') if title_div else "N/A"
        
        # Extract director (from separate div)
        details_div = movie.find('div', class_='countdown-item-details')
        director_div = details_div.find('div', class_='info director') if details_div else None
        director = director_div.a.text.strip() if director_div and director_div.a else "N/A"
        
        movies.append({
            "Title": title,
            "Year": year,
            "Director": director
        })

# %%
# checkpoint
movies
# Out:
# [{'Title': 'The Substance', 'Year': '2024', 'Director': 'Coralie Fargeat'},
#  {'Title': 'My Old Ass', 'Year': '2024', 'Director': 'Megan Park'},
#  {'Title': 'Love Lies Bleeding', 'Year': '2024', 'Director': 'Rose Glass'},
#  {'Title': 'The Fire Inside', 'Year': '2024', 'Director': 'Rachel Morrison'},
#  {'Title': "The Devil's Bath", 'Year': '2024', 'Director': 'Veronika Franz'},
#  {'Title': 'Vermiglio', 'Year': '2024', 'Director': 'Maura Delpero'},
#  {'Title': 'In the Summers',
#   'Year': '2024',
#   'Director': 'Alessandra Lacorazza Samudio'},
#  {'Title': 'Santosh', 'Year': '2024', 'Director': 'Sandhya Suri'},
#  {'Title': 'Black Box Diaries', 'Year': '2024', 'Director': 'Shiori Ito'},
#  {'Title': 'Good One', 'Year': '2024', 'Director': 'India Donaldson'},
#  {'Title': 'Girls Will Be Girls', 'Year': '2024', 'Director': 'Shuchi Talati'},
#  {'Title': 'Ghostlight', 'Year': '2024', 'Director': "Kelly O'Sullivan"},
#  {'Title': 'On Becoming a Guinea Fowl',
#   'Year': '2024',
#   'Director': 'Rungano Nyoni'},
#  {'Title': 'All We Imagine as Light',
#   'Year': '2024',
#   'Director': 'Payal Kapadia'},
#  {'Title': 'Hoard', 'Year': '2023', 'Director': 'Luna Carmoon'},
#  {'Title': 'Banel & Adama', 'Year': '2023', 'Director': 'Ramata-Toulaye Sy'},
#  {'Title': 'Fancy Dance', 'Year': '2023', 'Director': 'Erica Tremblay'},
#  {'Title': 'Tiger Stripes', 'Year': '2023', 'Director': 'Amanda Nell Eu'},
#  {'Title': 'Tótem', 'Year': '2023', 'Director': 'Lila Avilés'},
#  {'Title': 'Anatomy of a Fall', 'Year': '2023', 'Director': 'Justine Triet'},
#  {'Title': 'Past Lives', 'Year': '2023', 'Director': 'Celine Song'},
#  {'Title': "Are You There God? It's Me, Margaret.",
#   'Year': '2023',
#   'Director': 'Kelly Fremon Craig'},
#  {'Title': 'Bottoms', 'Year': '2023', 'Director': 'Emma Seligman'},
#  {'Title': 'Rye Lane', 'Year': '2023', 'Director': 'Raine Allen Miller'},
#  {'Title': 'You Are So Not Invited to My Bat Mitzvah',
#   'Year': '2023',
#   'Director': 'Sammi Cohen'},
#  {'Title': 'Joy Ride', 'Year': '2023', 'Director': 'Adele Lim'},
#  {'Title': 'Reality', 'Year': '2023', 'Director': 'Tina Satter'},
#  {'Title': 'The Starling Girl', 'Year': '2023', 'Director': 'Laurel Parmet'},
#  {'Title': 'Scrapper', 'Year': '2023', 'Director': 'Charlotte Regan'},
#  {'Title': 'You Hurt My Feelings',
#   'Year': '2023',
#   'Director': 'Nicole Holofcener'},
#  {'Title': 'How to Have Sex',
#   'Year': '2023',
#   'Director': 'Molly Manning Walker'},
#  {'Title': 'birth/rebirth', 'Year': '2023', 'Director': 'Laura Moss'},
#  {'Title': 'Four Daughters', 'Year': '2023', 'Director': 'Kaouther Ben Hania'},
#  {'Title': 'Earth Mama', 'Year': '2023', 'Director': 'Savanah Leaf'},
#  {'Title': 'Shayda', 'Year': '2023', 'Director': 'Noora Niasari'},
#  {'Title': 'A Thousand and One', 'Year': '2023', 'Director': 'A.V. Rockwell'},
#  {'Title': 'Girl Picture', 'Year': '2022', 'Director': 'Alli Haapasalo'},
#  {'Title': 'Till', 'Year': '2022', 'Director': 'Chinonye Chukwu'},
#  {'Title': 'Sissy', 'Year': '2022', 'Director': 'Hannah Barlow'},
#  {'Title': 'Turning Red', 'Year': '2022', 'Director': 'Domee Shi'},
#  {'Title': 'The Woman King',
#   'Year': '2022',
#   'Director': 'Gina Prince-Bythewood'},
#  {'Title': 'Good Luck to You, Leo Grande',
#   'Year': '2022',
#   'Director': 'Sophie Hyde'},
#  {'Title': 'Aftersun', 'Year': '2022', 'Director': 'Charlotte Wells'},
#  {'Title': 'Hatching', 'Year': '2022', 'Director': 'Hanna Bergholm'},
#  {'Title': 'Piggy', 'Year': '2022', 'Director': 'Carlota Pereda'},
#  {'Title': 'Deadstream', 'Year': '2022', 'Director': 'Joseph Winter'},
#  {'Title': 'Nanny', 'Year': '2022', 'Director': 'Nikyatu Jusu'},
#  {'Title': 'You Can Live Forever', 'Year': '2022', 'Director': 'Sarah Watts'},
#  {'Title': 'Leonor Will Never Die',
#   'Year': '2022',
#   'Director': 'Martika Ramirez Escobar'},
#  {'Title': 'The Unknown Country', 'Year': '2022', 'Director': 'Morrisa Maltz'},
#  {'Title': "Chile '76", 'Year': '2022', 'Director': 'Manuela Martelli'},
#  {'Title': "Other People's Children",
#   'Year': '2022',
#   'Director': 'Rebecca Zlotowski'},
#  {'Title': 'War Pony', 'Year': '2022', 'Director': 'Riley Keough'},
#  {'Title': 'Falcon Lake', 'Year': '2022', 'Director': 'Charlotte Le Bon'},
#  {'Title': 'Revoir Paris', 'Year': '2022', 'Director': 'Alice Winocour'},
#  {'Title': 'Saint Omer', 'Year': '2022', 'Director': 'Alice Diop'},
#  {'Title': 'Women Talking', 'Year': '2022', 'Director': 'Sarah Polley'},
#  {'Title': 'Blue Jean', 'Year': '2022', 'Director': 'Georgia Oakley'},
#  {'Title': 'Amanda', 'Year': '2022', 'Director': 'Carolina Cavalli'},
#  {'Title': 'Huesera: The Bone Woman',
#   'Year': '2022',
#   'Director': 'Michelle Garza Cervera'},
#  {'Title': 'Klondike', 'Year': '2022', 'Director': 'Maryna Er Gorbach'},
#  {'Title': 'Alcarràs', 'Year': '2022', 'Director': 'Carla Simón'},
#  {'Title': 'Vesper', 'Year': '2022', 'Director': 'Kristina Buozyte'},
#  {'Title': 'One Fine Morning', 'Year': '2022', 'Director': 'Mia Hansen-Løve'},
#  {'Title': 'Pray Away', 'Year': '2020', 'Director': 'Kristine Stolakis'},
#  {'Title': 'Shiva Baby', 'Year': '2020', 'Director': 'Emma Seligman'},
#  {'Title': 'Together Together', 'Year': '2021', 'Director': 'Nikole Beckwith'},
#  {'Title': 'V/H/S/94', 'Year': '2021', 'Director': 'Simon Barrett'},
#  {'Title': 'Ailey', 'Year': '2021', 'Director': 'Jamila Wignot'},
#  {'Title': 'Passing', 'Year': '2021', 'Director': 'Rebecca Hall'},
#  {'Title': 'The Souvenir Part II', 'Year': '2021', 'Director': 'Joanna Hogg'},
#  {'Title': 'El Planeta', 'Year': '2021', 'Director': 'Amalia Ulman'},
#  {'Title': 'Street Gang: How We Got to Sesame Street',
#   'Year': '2021',
#   'Director': 'Marilyn Agrelo'},
#  {'Title': 'Rita Moreno: Just a Girl Who Decided to Go For It',
#   'Year': '2021',
#   'Director': 'Mariem Pérez Riera'},
#  {'Title': 'Plan B', 'Year': '2021', 'Director': 'Natalie Morales'},
#  {'Title': 'In the Same Breath', 'Year': '2021', 'Director': 'Nanfu Wang'},
#  {'Title': 'The Novice', 'Year': '2021', 'Director': 'Lauren Hadaway'},
#  {'Title': "I'm Your Man", 'Year': '2021', 'Director': 'Maria Schrader'},
#  {'Title': 'Petite Maman', 'Year': '2021', 'Director': 'Céline Sciamma'},
#  {'Title': 'The Rescue',
#   'Year': '2021',
#   'Director': 'Elizabeth Chai Vasarhelyi'},
#  {'Title': 'Attica', 'Year': '2021', 'Director': 'Stanley Nelson'},
#  {'Title': 'Becoming Cousteau', 'Year': '2021', 'Director': 'Liz Garbus'},
#  {'Title': 'Julia', 'Year': '2021', 'Director': 'Julie Cohen'},
#  {'Title': 'Hive', 'Year': '2021', 'Director': 'Blerta Basholli'},
#  {'Title': 'Woodlands Dark and Days Bewitched: A History of Folk Horror',
#   'Year': '2021',
#   'Director': 'Kier-La Janisse'},
#  {'Title': 'CODA', 'Year': '2021', 'Director': 'Sian Heder'},
#  {'Title': 'The Power of the Dog', 'Year': '2021', 'Director': 'Jane Campion'},
#  {'Title': 'Happening', 'Year': '2021', 'Director': 'Audrey Diwan'},
#  {'Title': 'Hellbender', 'Year': '2021', 'Director': 'John Adams'},
#  {'Title': 'Neptune Frost', 'Year': '2021', 'Director': 'Saul Williams'},
#  {'Title': 'The Pink Cloud', 'Year': '2021', 'Director': 'Iuli Gerbase'},
#  {'Title': 'The Fallout', 'Year': '2021', 'Director': 'Megan Park'},
#  {'Title': "We're All Going to the World's Fair",
#   'Year': '2021',
#   'Director': 'Jane Schoenbrun'},
#  {'Title': 'Murina',
#   'Year': '2021',
#   'Director': 'Antoneta Alamat Kusijanovic'},
#  {'Title': 'Anaïs in Love',
#   'Year': '2021',
#   'Director': 'Charline Bourgeois-Tacquet'},
#  {'Title': 'Clara Sola', 'Year': '2021', 'Director': 'Nathalie Álvarez Mesén'},
#  {'Title': 'The Forty-Year-Old Version',
#   'Year': '2020',
#   'Director': 'Radha Blank'},
#  {'Title': 'Totally Under Control', 'Year': '2020', 'Director': 'Alex Gibney'},
#  {'Title': 'Miss Juneteenth',
#   'Year': '2020',
#   'Director': 'Channing Godfrey Peoples'},
#  {'Title': 'Kajillionaire', 'Year': '2020', 'Director': 'Miranda July'},
#  {'Title': 'Never Rarely Sometimes Always',
#   'Year': '2020',
#   'Director': 'Eliza Hittman'},
#  {'Title': 'Athlete A', 'Year': '2020', 'Director': 'Bonni Cohen'},
#  {'Title': 'Mucho Mucho Amor: The Legend of Walter Mercado',
#   'Year': '2020',
#   'Director': 'Cristina Constantini'},
#  {'Title': 'All In: The Fight for Democracy',
#   'Year': '2020',
#   'Director': 'Lisa Cortes'},
#  {'Title': 'Dick Johnson Is Dead',
#   'Year': '2020',
#   'Director': 'Kirsten Johnson'},
#  {'Title': 'Relic', 'Year': '2020', 'Director': 'Natalie Erika James'},
#  {'Title': 'One Night in Miami', 'Year': '2020', 'Director': 'Regina King'},
#  {'Title': 'Les Nôtres', 'Year': '2020', 'Director': 'Jeanne Leblanc'},
#  {'Title': 'Beginning', 'Year': '2020', 'Director': 'Dea Kulumbegashvili'},
#  {'Title': 'Beans', 'Year': '2020', 'Director': 'Tracey Deer'},
#  {'Title': 'Truman & Tennessee: An Intimate Conversation',
#   'Year': '2020',
#   'Director': 'Lisa Immordino Vreeland'},
#  {'Title': 'Holler', 'Year': '2020', 'Director': 'Nicole Riegel'},
#  {'Title': 'My Octopus Teacher', 'Year': '2020', 'Director': 'Pippa Ehrlich'},
#  {'Title': 'True Mothers', 'Year': '2020', 'Director': 'Naomi Kawase'},
#  {'Title': 'Wildfire', 'Year': '2020', 'Director': 'Cathy Brady'},
#  {'Title': 'Wildland', 'Year': '2020', 'Director': 'Jeanette Nordahl'},
#  {'Title': 'Lucky', 'Year': '2020', 'Director': 'Natasha Kermani'},
#  {'Title': 'Never Gonna Snow Again',
#   'Year': '2020',
#   'Director': 'Małgorzata Szumowska'},
#  {'Title': 'Jimmy Carter: Rock & Roll President',
#   'Year': '2020',
#   'Director': 'Mary Wharton'},
#  {'Title': 'Spring Blossom', 'Year': '2020', 'Director': 'Suzanne Lindon'},
#  {'Title': 'I Carry You With Me', 'Year': '2020', 'Director': 'Heidi Ewing'},
#  {'Title': 'Slaxx', 'Year': '2020', 'Director': 'Elza Kephart'},
#  {'Title': 'Identifying Features',
#   'Year': '2020',
#   'Director': 'Fernanda Valadez'},
#  {'Title': 'Quo Vadis, Aida?', 'Year': '2020', 'Director': 'Jasmila Zbanic'},
#  {'Title': 'The Stylist', 'Year': '2020', 'Director': 'Jill Gevargizian'},
#  {'Title': 'Slalom', 'Year': '2020', 'Director': 'Charlène Favier'},
#  {'Title': 'Nomadland', 'Year': '2020', 'Director': 'Chloé Zhao'},
#  {'Title': 'Promising Young Woman',
#   'Year': '2020',
#   'Director': 'Emerald Fennell'},
#  {'Title': 'Stray', 'Year': '2021', 'Director': 'Elizabeth Lo'},
#  {'Title': 'Gagarine', 'Year': '2020', 'Director': 'Fanny Liatard'},
#  {'Title': 'Tove', 'Year': '2020', 'Director': 'Zaida Bergroth'},
#  {'Title': 'Sword of Trust', 'Year': '2019', 'Director': 'Lynn Shelton'},
#  {'Title': 'Sword of Trust', 'Year': '2019', 'Director': 'Lynn Shelton'},
#  {'Title': 'Honey Boy', 'Year': '2019', 'Director': "Alma Har'el"},
#  {'Title': 'Raise Hell: The Life & Times of Molly Ivins',
#   'Year': '2019',
#   'Director': 'Janice Engel'},
#  {'Title': 'The Mustang',
#   'Year': '2019',
#   'Director': 'Laure de Clermont-Tonnerre'},
#  {'Title': 'A Beautiful Day in the Neighborhood',
#   'Year': '2019',
#   'Director': 'Marielle Heller'},
#  {'Title': 'Little Women', 'Year': '2019', 'Director': 'Greta Gerwig'},
#  {'Title': 'Hail Satan?', 'Year': '2019', 'Director': 'Penny Lane'},
#  {'Title': 'American Factory', 'Year': '2019', 'Director': 'Steven Bognar'},
#  {'Title': 'Booksmart', 'Year': '2019', 'Director': 'Olivia Wilde'},
#  {'Title': 'Making Waves: The Art of Cinematic Sound',
#   'Year': '2019',
#   'Director': 'Midge Costin'},
#  {'Title': 'The Kingmaker', 'Year': '2019', 'Director': 'Lauren Greenfield'},
#  {'Title': 'The Farewell', 'Year': '2019', 'Director': 'Lulu Wang'},
#  {'Title': 'One Child Nation', 'Year': '2019', 'Director': 'Nanfu Wang'},
#  {'Title': 'For Sama', 'Year': '2019', 'Director': 'Edward Watts'},
#  {'Title': 'Atlantics', 'Year': '2019', 'Director': 'Mati Diop'},
#  {'Title': 'Varda by Agnès', 'Year': '2019', 'Director': 'Agnès Varda'},
#  {'Title': 'Mickey and the Bear',
#   'Year': '2019',
#   'Director': 'Annabelle Attanasio'},
#  {'Title': 'Honeyland', 'Year': '2019', 'Director': 'Ljubo Stefanov'},
#  {'Title': 'Portrait of a Lady on Fire',
#   'Year': '2019',
#   'Director': 'Céline Sciamma'},
#  {'Title': 'The Assistant', 'Year': '2019', 'Director': 'Kitty Green'},
#  {'Title': 'Hope', 'Year': '2019', 'Director': 'Maria Sødahl'},
#  {'Title': 'Saint Maud', 'Year': '2019', 'Director': 'Rose Glass'},
#  {'Title': 'First Cow', 'Year': '2019', 'Director': 'Kelly Reichardt'},
#  {'Title': 'Blow the Man Down',
#   'Year': '2019',
#   'Director': 'Bridget Savage Cole'},
#  {'Title': 'The Long Walk', 'Year': '2019', 'Director': 'Mattie Do'},
#  {'Title': 'Science Fair', 'Year': '2018', 'Director': 'Cristina Costantini'},
#  {'Title': 'Free Solo',
#   'Year': '2018',
#   'Director': 'Elizabeth Chai Vasarhelyi'},
#  {'Title': 'On Her Shoulders',
#   'Year': '2018',
#   'Director': 'Alexandria Bombach'},
#  {'Title': 'Rafiki', 'Year': '2018', 'Director': 'Wanuri Kahiu'},
#  {'Title': "To All the Boys I've Loved Before",
#   'Year': '2018',
#   'Director': 'Susan Johnson'},
#  {'Title': 'Dark Money', 'Year': '2018', 'Director': 'Kimberly Reed'},
#  {'Title': 'Kusama: Infinity', 'Year': '2018', 'Director': 'Heather Lenz'},
#  {'Title': 'Little Woods', 'Year': '2018', 'Director': 'Nia DaCosta'},
#  {'Title': 'Private Life', 'Year': '2018', 'Director': 'Tamara Jenkins'},
#  {'Title': 'Be Natural: The Untold Story of Alice Guy-Blaché',
#   'Year': '2018',
#   'Director': 'Pamela B. Green'},
#  {'Title': 'Birds of Passage', 'Year': '2018', 'Director': 'Cristina Gallego'},
#  {'Title': 'RBG', 'Year': '2018', 'Director': 'Betsy West'},
#  {'Title': 'Pick of the Litter', 'Year': '2018', 'Director': 'Dana Nachman'},
#  {'Title': 'The Chambermaid', 'Year': '2018', 'Director': 'Lila Avilés'},
#  {'Title': 'Can You Ever Forgive Me?',
#   'Year': '2018',
#   'Director': 'Marielle Heller'},
#  {'Title': 'Too Late to Die Young',
#   'Year': '2018',
#   'Director': 'Dominga Sotomayor'},
#  {'Title': 'Leave No Trace', 'Year': '2018', 'Director': 'Debra Granik'},
#  {'Title': 'Night Comes On', 'Year': '2018', 'Director': 'Jordana Spiro'},
#  {'Title': 'Wonder Woman', 'Year': '2017', 'Director': 'Patty Jenkins'},
#  {'Title': 'Most Beautiful Island', 'Year': '2017', 'Director': 'Ana Asensio'},
#  {'Title': 'School Life', 'Year': '2017', 'Director': 'David Rane'},
#  {'Title': 'The Breadwinner', 'Year': '2017', 'Director': 'Nora Twomey'},
#  {'Title': 'Bombshell: The Hedy Lamarr Story',
#   'Year': '2017',
#   'Director': 'Alexandra Dean'},
#  {'Title': 'Step', 'Year': '2017', 'Director': 'Amanda Lipitz'},
#  {'Title': 'Mudbound', 'Year': '2017', 'Director': 'Dee Rees'},
#  {'Title': 'Whose Streets?', 'Year': '2017', 'Director': 'Sabaah Folayan'},
#  {'Title': 'Good Manners', 'Year': '2017', 'Director': 'Juliana Rojas'},
#  {'Title': 'Trophy', 'Year': '2017', 'Director': 'Shaul Schwarz'},
#  {'Title': 'Lady Bird', 'Year': '2017', 'Director': 'Greta Gerwig'},
#  {'Title': 'Faces Places', 'Year': '2017', 'Director': 'Agnès Varda'},
#  {'Title': 'Outside In', 'Year': '2017', 'Director': 'Lynn Shelton'},
#  {'Title': 'Western', 'Year': '2017', 'Director': 'Valeska Grisebach'},
#  {'Title': 'The Rider', 'Year': '2017', 'Director': 'Chloé Zhao'},
#  {'Title': 'Summer 1993', 'Year': '2017', 'Director': 'Carla Simón'},
#  {'Title': 'Marlina the Murderer in Four Acts',
#   'Year': '2017',
#   'Director': 'Mouly Surya'},
#  {'Title': 'Tigers Are Not Afraid', 'Year': '2017', 'Director': 'Issa López'},
#  {'Title': 'Oh Lucy!', 'Year': '2017', 'Director': 'Atsuko Hirayanagi'},
#  {'Title': 'Zama', 'Year': '2017', 'Director': 'Lucrecia Martel'},
#  {'Title': 'I Am Not a Witch', 'Year': '2017', 'Director': 'Rungano Nyoni'},
#  {'Title': 'Sand Storm', 'Year': '2016', 'Director': 'Elite Zexer'},
#  {'Title': 'Toni Erdmann', 'Year': '2016', 'Director': 'Maren Ade'},
#  {'Title': 'Queen of Katwe', 'Year': '2016', 'Director': 'Mira Nair'},
#  {'Title': 'Nuts!', 'Year': '2016', 'Director': 'Penny Lane'},
#  {'Title': 'All This Panic', 'Year': '2016', 'Director': 'Jenny Gage'},
#  {'Title': 'The Edge of Seventeen',
#   'Year': '2016',
#   'Director': 'Kelly Fremon Craig'},
#  {'Title': 'The Love Witch', 'Year': '2016', 'Director': 'Anna Biller'},
#  {'Title': 'The Innocents', 'Year': '2016', 'Director': 'Anne Fontaine'},
#  {'Title': '13TH', 'Year': '2016', 'Director': 'Ava DuVernay'},
#  {'Title': 'Bar Bahar', 'Year': '2016', 'Director': 'Maysaloun Hamoud'},
#  {'Title': 'Kedi', 'Year': '2016', 'Director': 'Ceyda Torun'},
#  {'Title': 'Weiner', 'Year': '2016', 'Director': 'Josh Kriegman'},
#  {'Title': 'Cameraperson', 'Year': '2016', 'Director': 'Kirsten Johnson'},
#  {'Title': 'Things to Come', 'Year': '2016', 'Director': 'Mia Hansen-Løve'},
#  {'Title': 'The Hunting Ground', 'Year': '2015', 'Director': 'Kirby Dick'},
#  {'Title': 'Janis: Little Girl Blue', 'Year': '2015', 'Director': 'Amy Berg'},
#  {'Title': 'The Diary of a Teenage Girl',
#   'Year': '2015',
#   'Director': 'Marielle Heller'},
#  {'Title': 'Heart of a Dog', 'Year': '2015', 'Director': 'Laurie Anderson'},
#  {'Title': 'Mustang', 'Year': '2015', 'Director': 'Deniz Gamze Ergüven'},
#  {'Title': 'The Second Mother', 'Year': '2015', 'Director': 'Anna Muylaert'},
#  {'Title': 'Dark Horse', 'Year': '2015', 'Director': 'Louise Osmond'},
#  {'Title': 'Sherpa', 'Year': '2015', 'Director': 'Jennifer Peedom'},
#  {'Title': 'The Fits', 'Year': '2015', 'Director': 'Anna Rose Holmer'},
#  {'Title': "She's Beautiful When She's Angry",
#   'Year': '2014',
#   'Director': 'Mary Dore'},
#  {'Title': '20,000 Days on Earth', 'Year': '2014', 'Director': 'Iain Forsyth'},
#  {'Title': 'A Girl Walks Home Alone at Night',
#   'Year': '2014',
#   'Director': 'Ana Lily Amirpour'},
#  {'Title': 'Citizenfour', 'Year': '2014', 'Director': 'Laura Poitras'},
#  {'Title': 'The Babadook', 'Year': '2014', 'Director': 'Jennifer Kent'},
#  {'Title': 'Girlhood', 'Year': '2014', 'Director': 'Céline Sciamma'},
#  {'Title': 'The Wonders', 'Year': '2014', 'Director': 'Alice Rohrwacher'},
#  {'Title': 'Selma', 'Year': '2014', 'Director': 'Ava DuVernay'},
#  {'Title': 'Gett: The Trial of Viviane Amsalem',
#   'Year': '2014',
#   'Director': 'Ronit Elkabetz'},
#  {'Title': 'Appropriate Behavior',
#   'Year': '2014',
#   'Director': 'Desiree Akhavan'},
#  {'Title': 'Enough Said', 'Year': '2013', 'Director': 'Nicole Holofcener'},
#  {'Title': 'Elaine Stritch: Shoot Me',
#   'Year': '2013',
#   'Director': 'Chiemi Karasawa'},
#  {'Title': 'The Crash Reel', 'Year': '2013', 'Director': 'Lucy Walker'},
#  {'Title': 'The Selfish Giant', 'Year': '2013', 'Director': 'Clio Barnard'},
#  {'Title': 'Blackfish', 'Year': '2013', 'Director': 'Gabriela Cowperthwaite'},
#  {'Title': 'The Square', 'Year': '2013', 'Director': 'Jehane Noujaim'},
#  {'Title': 'The Queen of Versailles',
#   'Year': '2012',
#   'Director': 'Lauren Greenfield'},
#  {'Title': 'West of Memphis', 'Year': '2012', 'Director': 'Amy Berg'},
#  {'Title': 'Brooklyn Castle',
#   'Year': '2012',
#   'Director': 'Katie Dellamaggiore'},
#  {'Title': 'Sister', 'Year': '2012', 'Director': 'Ursula Meier'},
#  {'Title': 'Ai Weiwei: Never Sorry',
#   'Year': '2012',
#   'Director': 'Alison Klayman'},
#  {'Title': 'Lore', 'Year': '2012', 'Director': 'Cate Shortland'},
#  {'Title': 'Stories We Tell', 'Year': '2012', 'Director': 'Sarah Polley'},
#  {'Title': 'Wadjda', 'Year': '2012', 'Director': 'Haifaa Al-Mansour'},
#  {'Title': 'Call Me Kuchu',
#   'Year': '2012',
#   'Director': 'Katherine Fairfax Wright'},
#  {'Title': 'Pariah', 'Year': '2011', 'Director': 'Dee Rees'},
#  {'Title': "Being Elmo: A Puppeteer's Journey",
#   'Year': '2011',
#   'Director': 'Constance Marks'},
#  {'Title': 'Tomboy', 'Year': '2011', 'Director': 'Céline Sciamma'},
#  {'Title': 'First Position', 'Year': '2011', 'Director': 'Bess Kargman'},
#  {'Title': 'Turn Me On, Dammit!',
#   'Year': '2011',
#   'Director': 'Jannicke Systad Jacobsen'},
#  {'Title': 'Sing Your Song', 'Year': '2011', 'Director': 'Susanne Rostock'},
#  {'Title': 'Diana Vreeland: The Eye Has to Travel',
#   'Year': '2011',
#   'Director': 'Lisa Immordino Vreeland'},
#  {'Title': 'The Kids Are All Right',
#   'Year': '2010',
#   'Director': 'Lisa Cholodenko'},
#  {'Title': "Winter's Bone", 'Year': '2010', 'Director': 'Debra Granik'},
#  {'Title': 'Waste Land', 'Year': '2010', 'Director': 'Lucy Walker'},
#  {'Title': 'The Arbor', 'Year': '2010', 'Director': 'Clio Barnard'},
#  {'Title': 'Yoo-Hoo, Mrs. Goldberg',
#   'Year': '2009',
#   'Director': 'Aviva Kempner'},
#  {'Title': 'An Education', 'Year': '2009', 'Director': 'Lone Scherfig'},
#  {'Title': 'The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon Papers',
#   'Year': '2009',
#   'Director': 'Judith Ehrlich'},
#  {'Title': 'Sweetgrass', 'Year': '2009', 'Director': 'Lucien Castaing-Taylor'},
#  {'Title': 'Afghan Star', 'Year': '2009', 'Director': 'Havana Marking'},
#  {'Title': 'A Film Unfinished', 'Year': '2009', 'Director': 'Yael Hersonski'},
#  {'Title': 'Trouble the Water', 'Year': '2008', 'Director': 'Carl Deal'},
#  {'Title': 'The Beaches of Agnès', 'Year': '2008', 'Director': 'Agnès Varda'},
#  {'Title': '35 Shots of Rum', 'Year': '2008', 'Director': 'Claire Denis'},
#  {'Title': 'The Hurt Locker', 'Year': '2008', 'Director': 'Kathryn Bigelow'},
#  {'Title': 'Persepolis', 'Year': '2007', 'Director': 'Marjane Satrapi'},
#  {'Title': 'The Devil Came on Horseback',
#   'Year': '2007',
#   'Director': 'Ricki Stern'},
#  {'Title': 'Blame It on Fidel', 'Year': '2006', 'Director': 'Julie Gavras'},
#  {'Title': 'Deep Water', 'Year': '2006', 'Director': 'Louise Osmond'},
#  {'Title': 'Blindsight', 'Year': '2006', 'Director': 'Lucy Walker'},
#  {'Title': 'The War Tapes', 'Year': '2006', 'Director': 'Deborah Scranton'},
#  {'Title': 'Away From Her', 'Year': '2006', 'Director': 'Sarah Polley'},
#  {'Title': 'Grbavica: The Land of My Dreams',
#   'Year': '2006',
#   'Director': 'Jasmila Zbanic'},
#  {'Title': 'Control Room', 'Year': '2004', 'Director': 'Jehane Noujaim'},
#  {'Title': 'Born Into Brothels', 'Year': '2004', 'Director': 'Zana Briski'},
#  {'Title': 'American Splendor',
#   'Year': '2003',
#   'Director': 'Shari Springer Berman'},
#  {'Title': 'Lost in Translation', 'Year': '2003', 'Director': 'Sofia Coppola'},
#  {'Title': 'The Revolution Will Not Be Televised',
#   'Year': '2003',
#   'Director': 'Kim Bartley'},
#  {'Title': 'The Story of the Weeping Camel',
#   'Year': '2003',
#   'Director': 'Byambasuren Davaa'},
#  {'Title': 'Lost Boys of Sudan', 'Year': '2003', 'Director': 'Megan Mylan'},
#  {'Title': 'Since Otar Left', 'Year': '2003', 'Director': 'Julie Bertuccelli'},
#  {'Title': 'The Wild Parrots of Telegraph Hill',
#   'Year': '2003',
#   'Director': 'Judy Irving'},
#  {'Title': 'Open Hearts', 'Year': '2002', 'Director': 'Susanne Bier'},
#  {'Title': 'Monsoon Wedding', 'Year': '2001', 'Director': 'Mira Nair'},
#  {'Title': 'Promises', 'Year': '2001', 'Director': 'Justine Shapiro'},
#  {'Title': 'The Taste of Others', 'Year': '2000', 'Director': 'Agnès Jaoui'},
#  {'Title': 'The Gleaners and I', 'Year': '2000', 'Director': 'Agnès Varda'},
#  {'Title': 'The Life and Times of Hank Greenberg',
#   'Year': '1999',
#   'Director': 'Aviva Kempner'}]

# %% [markdown]
# ## 2. Merge information from IMDB - adding links to their individual pages

# %% [markdown]
# ### bring the same function earlier

# %%
def get_imdb_link(title, year):
    base_url = "https://www.imdb.com"
    search_url = f"{base_url}/find/?q={title.replace(' ', '+')}+{year}"
    
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(search_url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        result = soup.find('a', class_='ipc-metadata-list-summary-item__t')
        
        if result:
            return base_url + result['href'].split('?')[0] 
        return None
    except Exception as e:
        print(f"Error searching for {title}: {e}")
        return None

# %% [markdown]
# ### extract each individual film's IMDb page

# %%
for movie in movies:
    link = get_imdb_link(movie['Title'], movie['Year'])
    movie['Link'] = link
# Out:
# [{'Title': 'The Substance', 'Year': '2024', 'Director': 'Coralie Fargeat', 'Link': 'https://www.imdb.com/title/tt17526714/'}, {'Title': 'My Old Ass', 'Year': '2024', 'Director': 'Megan Park', 'Link': 'https://www.imdb.com/title/tt18559464/'}, {'Title': 'Love Lies Bleeding', 'Year': '2024', 'Director': 'Rose Glass', 'Link': 'https://www.imdb.com/title/tt19637052/'}, {'Title': 'The Fire Inside', 'Year': '2024', 'Director': 'Rachel Morrison', 'Link': 'https://www.imdb.com/title/tt6133444/'}, {'Title': "The Devil's Bath", 'Year': '2024', 'Director': 'Veronika Franz', 'Link': 'https://www.imdb.com/title/tt29141112/'}, {'Title': 'Vermiglio', 'Year': '2024', 'Director': 'Maura Delpero', 'Link': 'https://www.imdb.com/title/tt28618488/'}, {'Title': 'In the Summers', 'Year': '2024', 'Director': 'Alessandra Lacorazza Samudio', 'Link': 'https://www.imdb.com/title/tt24805832/'}, {'Title': 'Santosh', 'Year': '2024', 'Director': 'Sandhya Suri', 'Link': 'https://www.imdb.com/title/tt30444418/'}, {'Title': 'Black Box Diaries', 'Year': '2024', 'Director': 'Shiori Ito', 'Link': 'https://www.imdb.com/title/tt30227076/'}, {'Title': 'Good One', 'Year': '2024', 'Director': 'India Donaldson', 'Link': 'https://www.imdb.com/title/tt30319516/'}, {'Title': 'Girls Will Be Girls', 'Year': '2024', 'Director': 'Shuchi Talati', 'Link': 'https://www.imdb.com/title/tt18277182/'}, {'Title': 'Ghostlight', 'Year': '2024', 'Director': "Kelly O'Sullivan", 'Link': 'https://www.imdb.com/title/tt30321095/'}, {'Title': 'On Becoming a Guinea Fowl', 'Year': '2024', 'Director': 'Rungano Nyoni', 'Link': 'https://www.imdb.com/title/tt32083311/'}, {'Title': 'All We Imagine as Light', 'Year': '2024', 'Director': 'Payal Kapadia', 'Link': 'https://www.imdb.com/title/tt32086077/'}, {'Title': 'Hoard', 'Year': '2023', 'Director': 'Luna Carmoon', 'Link': 'https://www.imdb.com/title/tt20729172/'}, {'Title': 'Banel & Adama', 'Year': '2023', 'Director': 'Ramata-Toulaye Sy', 'Link': 'https://www.imdb.com/name/nm0051826/'}, {'Title': 'Fancy Dance', 'Year': '2023', 'Director': 'Erica Tremblay', 'Link': 'https://www.imdb.com/title/tt21813994/'}, {'Title': 'Tiger Stripes', 'Year': '2023', 'Director': 'Amanda Nell Eu', 'Link': 'https://www.imdb.com/title/tt10803634/'}, {'Title': 'Tótem', 'Year': '2023', 'Director': 'Lila Avilés', 'Link': 'https://www.imdb.com/title/tt26315142/'}, {'Title': 'Anatomy of a Fall', 'Year': '2023', 'Director': 'Justine Triet', 'Link': 'https://www.imdb.com/title/tt17009710/'}, {'Title': 'Past Lives', 'Year': '2023', 'Director': 'Celine Song', 'Link': 'https://www.imdb.com/title/tt13238346/'}, {'Title': "Are You There God? It's Me, Margaret.", 'Year': '2023', 'Director': 'Kelly Fremon Craig', 'Link': 'https://www.imdb.com/title/tt9185206/'}, {'Title': 'Bottoms', 'Year': '2023', 'Director': 'Emma Seligman', 'Link': 'https://www.imdb.com/title/tt17527468/'}, {'Title': 'Rye Lane', 'Year': '2023', 'Director': 'Raine Allen Miller', 'Link': 'https://www.imdb.com/title/tt15893750/'}, {'Title': 'You Are So Not Invited to My Bat Mitzvah', 'Year': '2023', 'Director': 'Sammi Cohen', 'Link': 'https://www.imdb.com/title/tt21276878/'}, {'Title': 'Joy Ride', 'Year': '2023', 'Director': 'Adele Lim', 'Link': 'https://www.imdb.com/title/tt15268244/'}, {'Title': 'Reality', 'Year': '2023', 'Director': 'Tina Satter', 'Link': 'https://www.imdb.com/title/tt24068064/'}, {'Title': 'The Starling Girl', 'Year': '2023', 'Director': 'Laurel Parmet', 'Link': 'https://www.imdb.com/title/tt21156390/'}, {'Title': 'Scrapper', 'Year': '2023', 'Director': 'Charlotte Regan', 'Link': 'https://www.imdb.com/title/tt8649252/'}, {'Title': 'You Hurt My Feelings', 'Year': '2023', 'Director': 'Nicole Holofcener', 'Link': 'https://www.imdb.com/title/tt15771916/'}, {'Title': 'How to Have Sex', 'Year': '2023', 'Director': 'Molly Manning Walker', 'Link': 'https://www.imdb.com/title/tt22890246/'}, {'Title': 'birth/rebirth', 'Year': '2023', 'Director': 'Laura Moss', 'Link': 'https://www.imdb.com/title/tt9048804/'}, ...

# %%
# checkpoint
movies
# Out:
# [{'Title': 'The Substance',
#   'Year': '2024',
#   'Director': 'Coralie Fargeat',
#   'Link': 'https://www.imdb.com/title/tt17526714/',
#   'Rating': '7.3'},
#  {'Title': 'My Old Ass',
#   'Year': '2024',
#   'Director': 'Megan Park',
#   'Link': 'https://www.imdb.com/title/tt18559464/',
#   'Rating': '6.9'},
#  {'Title': 'Love Lies Bleeding',
#   'Year': '2024',
#   'Director': 'Rose Glass',
#   'Link': 'https://www.imdb.com/title/tt19637052/',
#   'Rating': '6.6'},
#  {'Title': 'The Fire Inside',
#   'Year': '2024',
#   'Director': 'Rachel Morrison',
#   'Link': 'https://www.imdb.com/title/tt6133444/',
#   'Rating': '6.7'},
#  {'Title': "The Devil's Bath",
#   'Year': '2024',
#   'Director': 'Veronika Franz',
#   'Link': 'https://www.imdb.com/title/tt29141112/',
#   'Rating': '6.6'},
#  {'Title': 'Vermiglio',
#   'Year': '2024',
#   'Director': 'Maura Delpero',
#   'Link': 'https://www.imdb.com/title/tt28618488/',
#   'Rating': '6.9'},
#  {'Title': 'In the Summers',
#   'Year': '2024',
#   'Director': 'Alessandra Lacorazza Samudio',
#   'Link': 'https://www.imdb.com/title/tt24805832/',
#   'Rating': '6.5'},
#  {'Title': 'Santosh',
#   'Year': '2024',
#   'Director': 'Sandhya Suri',
#   'Link': 'https://www.imdb.com/title/tt30444418/',
#   'Rating': '7.1'},
#  {'Title': 'Black Box Diaries',
#   'Year': '2024',
#   'Director': 'Shiori Ito',
#   'Link': 'https://www.imdb.com/title/tt30227076/',
#   'Rating': '7.5'},
#  {'Title': 'Good One',
#   'Year': '2024',
#   'Director': 'India Donaldson',
#   'Link': 'https://www.imdb.com/title/tt30319516/',
#   'Rating': '6.6'},
#  {'Title': 'Girls Will Be Girls',
#   'Year': '2024',
#   'Director': 'Shuchi Talati',
#   'Link': 'https://www.imdb.com/title/tt18277182/',
#   'Rating': '7.1'},
#  {'Title': 'Ghostlight',
#   'Year': '2024',
#   'Director': "Kelly O'Sullivan",
#   'Link': 'https://www.imdb.com/title/tt30321095/',
#   'Rating': '7.6'},
#  {'Title': 'On Becoming a Guinea Fowl',
#   'Year': '2024',
#   'Director': 'Rungano Nyoni',
#   'Link': 'https://www.imdb.com/title/tt32083311/',
#   'Rating': '7.1'},
#  {'Title': 'All We Imagine as Light',
#   'Year': '2024',
#   'Director': 'Payal Kapadia',
#   'Link': 'https://www.imdb.com/title/tt32086077/',
#   'Rating': '7.1'},
#  {'Title': 'Hoard',
#   'Year': '2023',
#   'Director': 'Luna Carmoon',
#   'Link': 'https://www.imdb.com/title/tt20729172/',
#   'Rating': '6.5'},
#  {'Title': 'Banel & Adama',
#   'Year': '2023',
#   'Director': 'Ramata-Toulaye Sy',
#   'Link': 'https://www.imdb.com/name/nm0051826/',
#   'Rating': 'N/A'},
#  {'Title': 'Fancy Dance',
#   'Year': '2023',
#   'Director': 'Erica Tremblay',
#   'Link': 'https://www.imdb.com/title/tt21813994/',
#   'Rating': '6.6'},
#  {'Title': 'Tiger Stripes',
#   'Year': '2023',
#   'Director': 'Amanda Nell Eu',
#   'Link': 'https://www.imdb.com/title/tt10803634/',
#   'Rating': '6.0'},
#  {'Title': 'Tótem',
#   'Year': '2023',
#   'Director': 'Lila Avilés',
#   'Link': 'https://www.imdb.com/title/tt26315142/',
#   'Rating': '7.0'},
#  {'Title': 'Anatomy of a Fall',
#   'Year': '2023',
#   'Director': 'Justine Triet',
#   'Link': 'https://www.imdb.com/title/tt17009710/',
#   'Rating': '7.6'},
#  {'Title': 'Past Lives',
#   'Year': '2023',
#   'Director': 'Celine Song',
#   'Link': 'https://www.imdb.com/title/tt13238346/',
#   'Rating': '7.8'},
#  {'Title': "Are You There God? It's Me, Margaret.",
#   'Year': '2023',
#   'Director': 'Kelly Fremon Craig',
#   'Link': 'https://www.imdb.com/title/tt9185206/',
#   'Rating': '7.3'},
#  {'Title': 'Bottoms',
#   'Year': '2023',
#   'Director': 'Emma Seligman',
#   'Link': 'https://www.imdb.com/title/tt17527468/',
#   'Rating': '6.7'},
#  {'Title': 'Rye Lane',
#   'Year': '2023',
#   'Director': 'Raine Allen Miller',
#   'Link': 'https://www.imdb.com/title/tt15893750/',
#   'Rating': '7.2'},
#  {'Title': 'You Are So Not Invited to My Bat Mitzvah',
#   'Year': '2023',
#   'Director': 'Sammi Cohen',
#   'Link': 'https://www.imdb.com/title/tt21276878/',
#   'Rating': '5.9'},
#  {'Title': 'Joy Ride',
#   'Year': '2023',
#   'Director': 'Adele Lim',
#   'Link': 'https://www.imdb.com/title/tt15268244/',
#   'Rating': '6.4'},
#  {'Title': 'Reality',
#   'Year': '2023',
#   'Director': 'Tina Satter',
#   'Link': 'https://www.imdb.com/title/tt24068064/',
#   'Rating': '6.7'},
#  {'Title': 'The Starling Girl',
#   'Year': '2023',
#   'Director': 'Laurel Parmet',
#   'Link': 'https://www.imdb.com/title/tt21156390/',
#   'Rating': '6.7'},
#  {'Title': 'Scrapper',
#   'Year': '2023',
#   'Director': 'Charlotte Regan',
#   'Link': 'https://www.imdb.com/title/tt8649252/',
#   'Rating': '6.9'},
#  {'Title': 'You Hurt My Feelings',
#   'Year': '2023',
#   'Director': 'Nicole Holofcener',
#   'Link': 'https://www.imdb.com/title/tt15771916/',
#   'Rating': '6.5'},
#  {'Title': 'How to Have Sex',
#   'Year': '2023',
#   'Director': 'Molly Manning Walker',
#   'Link': 'https://www.imdb.com/title/tt22890246/',
#   'Rating': '6.5'},
#  {'Title': 'birth/rebirth',
#   'Year': '2023',
#   'Director': 'Laura Moss',
#   'Link': 'https://www.imdb.com/title/tt9048804/',
#   'Rating': '6.2'},
#  {'Title': 'Four Daughters',
#   'Year': '2023',
#   'Director': 'Kaouther Ben Hania',
#   'Link': 'https://www.imdb.com/title/tt27502426/',
#   'Rating': '7.4'},
#  {'Title': 'Earth Mama',
#   'Year': '2023',
#   'Director': 'Savanah Leaf',
#   'Link': 'https://www.imdb.com/title/tt18382328/',
#   'Rating': '6.6'},
#  {'Title': 'Shayda',
#   'Year': '2023',
#   'Director': 'Noora Niasari',
#   'Link': 'https://www.imdb.com/title/tt13200006/',
#   'Rating': '6.7'},
#  {'Title': 'A Thousand and One',
#   'Year': '2023',
#   'Director': 'A.V. Rockwell',
#   'Link': 'https://www.imdb.com/title/tt12427158/',
#   'Rating': '7.0'},
#  {'Title': 'Girl Picture',
#   'Year': '2022',
#   'Director': 'Alli Haapasalo',
#   'Link': 'https://www.imdb.com/title/tt13328800/',
#   'Rating': '6.9'},
#  {'Title': 'Till',
#   'Year': '2022',
#   'Director': 'Chinonye Chukwu',
#   'Link': 'https://www.imdb.com/title/tt4960748/',
#   'Rating': '7.2'},
#  {'Title': 'Sissy',
#   'Year': '2022',
#   'Director': 'Hannah Barlow',
#   'Link': 'https://www.imdb.com/title/tt9602472/',
#   'Rating': '6.1'},
#  {'Title': 'Turning Red',
#   'Year': '2022',
#   'Director': 'Domee Shi',
#   'Link': 'https://www.imdb.com/title/tt8097030/',
#   'Rating': '6.9'},
#  {'Title': 'The Woman King',
#   'Year': '2022',
#   'Director': 'Gina Prince-Bythewood',
#   'Link': 'https://www.imdb.com/title/tt8093700/',
#   'Rating': '6.9'},
#  {'Title': 'Good Luck to You, Leo Grande',
#   'Year': '2022',
#   'Director': 'Sophie Hyde',
#   'Link': 'https://www.imdb.com/title/tt13352968/',
#   'Rating': '7.2'},
#  {'Title': 'Aftersun',
#   'Year': '2022',
#   'Director': 'Charlotte Wells',
#   'Link': 'https://www.imdb.com/title/tt19770238/',
#   'Rating': '7.6'},
#  {'Title': 'Hatching',
#   'Year': '2022',
#   'Director': 'Hanna Bergholm',
#   'Link': 'https://www.imdb.com/title/tt12519030/',
#   'Rating': '6.2'},
#  {'Title': 'Piggy',
#   'Year': '2022',
#   'Director': 'Carlota Pereda',
#   'Link': 'https://www.imdb.com/title/tt10399608/',
#   'Rating': '6.2'},
#  {'Title': 'Deadstream',
#   'Year': '2022',
#   'Director': 'Joseph Winter',
#   'Link': 'https://www.imdb.com/title/tt12788488/',
#   'Rating': '6.4'},
#  {'Title': 'Nanny',
#   'Year': '2022',
#   'Director': 'Nikyatu Jusu',
#   'Link': 'https://www.imdb.com/title/tt10931784/',
#   'Rating': '5.3'},
#  {'Title': 'You Can Live Forever',
#   'Year': '2022',
#   'Director': 'Sarah Watts',
#   'Link': 'https://www.imdb.com/title/tt15782570/',
#   'Rating': '6.8'},
#  {'Title': 'Leonor Will Never Die',
#   'Year': '2022',
#   'Director': 'Martika Ramirez Escobar',
#   'Link': 'https://www.imdb.com/title/tt16377714/',
#   'Rating': '6.6'},
#  {'Title': 'The Unknown Country',
#   'Year': '2022',
#   'Director': 'Morrisa Maltz',
#   'Link': 'https://www.imdb.com/title/tt12783826/',
#   'Rating': '6.3'},
#  {'Title': "Chile '76",
#   'Year': '2022',
#   'Director': 'Manuela Martelli',
#   'Link': 'https://www.imdb.com/title/tt19758012/',
#   'Rating': '6.7'},
#  {'Title': "Other People's Children",
#   'Year': '2022',
#   'Director': 'Rebecca Zlotowski',
#   'Link': 'https://www.imdb.com/title/tt15403712/',
#   'Rating': '6.8'},
#  {'Title': 'War Pony',
#   'Year': '2022',
#   'Director': 'Riley Keough',
#   'Link': 'https://www.imdb.com/title/tt16227002/',
#   'Rating': '6.8'},
#  {'Title': 'Falcon Lake',
#   'Year': '2022',
#   'Director': 'Charlotte Le Bon',
#   'Link': 'https://www.imdb.com/title/tt11448830/',
#   'Rating': '7.0'},
#  {'Title': 'Revoir Paris',
#   'Year': '2022',
#   'Director': 'Alice Winocour',
#   'Link': 'https://www.imdb.com/title/tt15329224/',
#   'Rating': '6.9'},
#  {'Title': 'Saint Omer',
#   'Year': '2022',
#   'Director': 'Alice Diop',
#   'Link': 'https://www.imdb.com/title/tt15376894/',
#   'Rating': '6.8'},
#  {'Title': 'Women Talking',
#   'Year': '2022',
#   'Director': 'Sarah Polley',
#   'Link': 'https://www.imdb.com/title/tt13669038/',
#   'Rating': '6.9'},
#  {'Title': 'Blue Jean',
#   'Year': '2022',
#   'Director': 'Georgia Oakley',
#   'Link': 'https://www.imdb.com/title/tt8649344/',
#   'Rating': '7.0'},
#  {'Title': 'Amanda',
#   'Year': '2022',
#   'Director': 'Carolina Cavalli',
#   'Link': 'https://www.imdb.com/title/tt18469872/',
#   'Rating': '6.5'},
#  {'Title': 'Huesera: The Bone Woman',
#   'Year': '2022',
#   'Director': 'Michelle Garza Cervera',
#   'Link': 'https://www.imdb.com/title/tt11718516/',
#   'Rating': '6.0'},
#  {'Title': 'Klondike',
#   'Year': '2022',
#   'Director': 'Maryna Er Gorbach',
#   'Link': 'https://www.imdb.com/title/tt16315948/',
#   'Rating': '6.8'},
#  {'Title': 'Alcarràs',
#   'Year': '2022',
#   'Director': 'Carla Simón',
#   'Link': 'https://www.imdb.com/title/tt11930126/',
#   'Rating': '7.0'},
#  {'Title': 'Vesper',
#   'Year': '2022',
#   'Director': 'Kristina Buozyte',
#   'Link': 'https://www.imdb.com/title/tt20225374/',
#   'Rating': '6.0'},
#  {'Title': 'One Fine Morning',
#   'Year': '2022',
#   'Director': 'Mia Hansen-Løve',
#   'Link': 'https://www.imdb.com/title/tt13482828/',
#   'Rating': '6.9'},
#  {'Title': 'Pray Away',
#   'Year': '2020',
#   'Director': 'Kristine Stolakis',
#   'Link': 'https://www.imdb.com/title/tt12119040/',
#   'Rating': 'N/A'},
#  {'Title': 'Shiva Baby',
#   'Year': '2020',
#   'Director': 'Emma Seligman',
#   'Link': 'https://www.imdb.com/title/tt11317142/',
#   'Rating': '7.1'},
#  {'Title': 'Together Together',
#   'Year': '2021',
#   'Director': 'Nikole Beckwith',
#   'Link': 'https://www.imdb.com/title/tt11285280/',
#   'Rating': '6.4'},
#  {'Title': 'V/H/S/94',
#   'Year': '2021',
#   'Director': 'Simon Barrett',
#   'Link': 'https://www.imdb.com/title/tt14867006/',
#   'Rating': '5.5'},
#  {'Title': 'Ailey',
#   'Year': '2021',
#   'Director': 'Jamila Wignot',
#   'Link': 'https://www.imdb.com/title/tt13622084/',
#   'Rating': '6.8'},
#  {'Title': 'Passing',
#   'Year': '2021',
#   'Director': 'Rebecca Hall',
#   'Link': 'https://www.imdb.com/title/tt8893974/',
#   'Rating': '6.6'},
#  {'Title': 'The Souvenir Part II',
#   'Year': '2021',
#   'Director': 'Joanna Hogg',
#   'Link': 'https://www.imdb.com/title/tt6992978/',
#   'Rating': '7.1'},
#  {'Title': 'El Planeta',
#   'Year': '2021',
#   'Director': 'Amalia Ulman',
#   'Link': 'https://www.imdb.com/title/tt12788368/',
#   'Rating': '6.4'},
#  {'Title': 'Street Gang: How We Got to Sesame Street',
#   'Year': '2021',
#   'Director': 'Marilyn Agrelo',
#   'Link': 'https://www.imdb.com/title/tt5618690/',
#   'Rating': '8.0'},
#  {'Title': 'Rita Moreno: Just a Girl Who Decided to Go For It',
#   'Year': '2021',
#   'Director': 'Mariem Pérez Riera',
#   'Link': 'https://www.imdb.com/title/tt10741846/',
#   'Rating': '7.6'},
#  {'Title': 'Plan B',
#   'Year': '2021',
#   'Director': 'Natalie Morales',
#   'Link': 'https://www.imdb.com/title/tt13172796/',
#   'Rating': '6.7'},
#  {'Title': 'In the Same Breath',
#   'Year': '2021',
#   'Director': 'Nanfu Wang',
#   'Link': 'https://www.imdb.com/title/tt13648230/',
#   'Rating': '7.5'},
#  {'Title': 'The Novice',
#   'Year': '2021',
#   'Director': 'Lauren Hadaway',
#   'Link': 'https://www.imdb.com/title/tt11131464/',
#   'Rating': '6.5'},
#  {'Title': "I'm Your Man",
#   'Year': '2021',
#   'Director': 'Maria Schrader',
#   'Link': 'https://www.imdb.com/title/tt13087796/',
#   'Rating': '7.1'},
#  {'Title': 'Petite Maman',
#   'Year': '2021',
#   'Director': 'Céline Sciamma',
#   'Link': 'https://www.imdb.com/title/tt13204490/',
#   'Rating': '7.4'},
#  {'Title': 'The Rescue',
#   'Year': '2021',
#   'Director': 'Elizabeth Chai Vasarhelyi',
#   'Link': 'https://www.imdb.com/title/tt9098872/',
#   'Rating': '8.3'},
#  {'Title': 'Attica',
#   'Year': '2021',
#   'Director': 'Stanley Nelson',
#   'Link': 'https://www.imdb.com/title/tt12482898/',
#   'Rating': '7.5'},
#  {'Title': 'Becoming Cousteau',
#   'Year': '2021',
#   'Director': 'Liz Garbus',
#   'Link': 'https://www.imdb.com/title/tt10334438/',
#   'Rating': '7.1'},
#  {'Title': 'Julia',
#   'Year': '2021',
#   'Director': 'Julie Cohen',
#   'Link': 'https://www.imdb.com/title/tt13782428/',
#   'Rating': '7.6'},
#  {'Title': 'Hive',
#   'Year': '2021',
#   'Director': 'Blerta Basholli',
#   'Link': 'https://www.imdb.com/title/tt13648212/',
#   'Rating': '7.1'},
#  {'Title': 'Woodlands Dark and Days Bewitched: A History of Folk Horror',
#   'Year': '2021',
#   'Director': 'Kier-La Janisse',
#   'Link': 'https://www.imdb.com/title/tt13938338/',
#   'Rating': '7.6'},
#  {'Title': 'CODA',
#   'Year': '2021',
#   'Director': 'Sian Heder',
#   'Link': 'https://www.imdb.com/title/tt10366460/',
#   'Rating': '8.0'},
#  {'Title': 'The Power of the Dog',
#   'Year': '2021',
#   'Director': 'Jane Campion',
#   'Link': 'https://www.imdb.com/title/tt10293406/',
#   'Rating': '6.8'},
#  {'Title': 'Happening',
#   'Year': '2021',
#   'Director': 'Audrey Diwan',
#   'Link': 'https://www.imdb.com/title/tt13880104/',
#   'Rating': '7.4'},
#  {'Title': 'Hellbender',
#   'Year': '2021',
#   'Director': 'John Adams',
#   'Link': 'https://www.imdb.com/title/tt14905650/',
#   'Rating': '5.8'},
#  {'Title': 'Neptune Frost',
#   'Year': '2021',
#   'Director': 'Saul Williams',
#   'Link': 'https://www.imdb.com/title/tt11873472/',
#   'Rating': '6.5'},
#  {'Title': 'The Pink Cloud',
#   'Year': '2021',
#   'Director': 'Iuli Gerbase',
#   'Link': 'https://www.imdb.com/title/tt3548874/',
#   'Rating': '6.0'},
#  {'Title': 'The Fallout',
#   'Year': '2021',
#   'Director': 'Megan Park',
#   'Link': 'https://www.imdb.com/title/tt11847410/',
#   'Rating': '7.0'},
#  {'Title': "We're All Going to the World's Fair",
#   'Year': '2021',
#   'Director': 'Jane Schoenbrun',
#   'Link': 'https://www.imdb.com/title/tt13648224/',
#   'Rating': '5.4'},
#  {'Title': 'Murina',
#   'Year': '2021',
#   'Director': 'Antoneta Alamat Kusijanovic',
#   'Link': 'https://www.imdb.com/title/tt8434110/',
#   'Rating': '6.8'},
#  {'Title': 'Anaïs in Love',
#   'Year': '2021',
#   'Director': 'Charline Bourgeois-Tacquet',
#   'Link': 'https://www.imdb.com/title/tt13142240/',
#   'Rating': '6.4'},
#  {'Title': 'Clara Sola',
#   'Year': '2021',
#   'Director': 'Nathalie Álvarez Mesén',
#   'Link': 'https://www.imdb.com/title/tt12637442/',
#   'Rating': '6.7'},
#  {'Title': 'The Forty-Year-Old Version',
#   'Year': '2020',
#   'Director': 'Radha Blank',
#   'Link': 'https://www.imdb.com/title/tt34062583/',
#   'Rating': 'N/A'},
#  {'Title': 'Totally Under Control',
#   'Year': '2020',
#   'Director': 'Alex Gibney',
#   'Link': 'https://www.imdb.com/title/tt13065386/',
#   'Rating': '7.6'},
#  {'Title': 'Miss Juneteenth',
#   'Year': '2020',
#   'Director': 'Channing Godfrey Peoples',
#   'Link': 'https://www.imdb.com/title/tt11394158/',
#   'Rating': '6.5'},
#  {'Title': 'Kajillionaire',
#   'Year': '2020',
#   'Director': 'Miranda July',
#   'Link': 'https://www.imdb.com/title/tt8143990/',
#   'Rating': '6.4'},
#  {'Title': 'Never Rarely Sometimes Always',
#   'Year': '2020',
#   'Director': 'Eliza Hittman',
#   'Link': 'https://www.imdb.com/title/tt7772582/',
#   'Rating': '7.4'},
#  {'Title': 'Athlete A',
#   'Year': '2020',
#   'Director': 'Bonni Cohen',
#   'Link': 'https://www.imdb.com/title/tt11905462/',
#   'Rating': '7.6'},
#  {'Title': 'Mucho Mucho Amor: The Legend of Walter Mercado',
#   'Year': '2020',
#   'Director': 'Cristina Constantini',
#   'Link': 'https://www.imdb.com/title/tt11378264/',
#   'Rating': '7.3'},
#  {'Title': 'All In: The Fight for Democracy',
#   'Year': '2020',
#   'Director': 'Lisa Cortes',
#   'Link': 'https://www.imdb.com/title/tt12538822/',
#   'Rating': '6.9'},
#  {'Title': 'Dick Johnson Is Dead',
#   'Year': '2020',
#   'Director': 'Kirsten Johnson',
#   'Link': 'https://www.imdb.com/title/tt11394180/',
#   'Rating': '7.4'},
#  {'Title': 'Relic',
#   'Year': '2020',
#   'Director': 'Natalie Erika James',
#   'Link': 'https://www.imdb.com/title/tt9072352/',
#   'Rating': '6.0'},
#  {'Title': 'One Night in Miami',
#   'Year': '2020',
#   'Director': 'Regina King',
#   'Link': 'https://www.imdb.com/title/tt10612922/',
#   'Rating': '7.1'},
#  {'Title': 'Les Nôtres',
#   'Year': '2020',
#   'Director': 'Jeanne Leblanc',
#   'Link': 'https://www.imdb.com/title/tt8724130/',
#   'Rating': '6.4'},
#  {'Title': 'Beginning',
#   'Year': '2020',
#   'Director': 'Dea Kulumbegashvili',
#   'Link': 'https://www.imdb.com/title/tt12444572/',
#   'Rating': '6.6'},
#  {'Title': 'Beans',
#   'Year': '2020',
#   'Director': 'Tracey Deer',
#   'Link': 'https://www.imdb.com/title/tt11735544/',
#   'Rating': '7.0'},
#  {'Title': 'Truman & Tennessee: An Intimate Conversation',
#   'Year': '2020',
#   'Director': 'Lisa Immordino Vreeland',
#   'Link': 'https://www.imdb.com/name/nm9669780/',
#   'Rating': 'N/A'},
#  {'Title': 'Holler',
#   'Year': '2020',
#   'Director': 'Nicole Riegel',
#   'Link': 'https://www.imdb.com/title/tt6763778/',
#   'Rating': '6.2'},
#  {'Title': 'My Octopus Teacher',
#   'Year': '2020',
#   'Director': 'Pippa Ehrlich',
#   'Link': 'https://www.imdb.com/title/tt12888462/',
#   'Rating': '8.1'},
#  {'Title': 'True Mothers',
#   'Year': '2020',
#   'Director': 'Naomi Kawase',
#   'Link': 'https://www.imdb.com/title/tt10418630/',
#   'Rating': '7.0'},
#  {'Title': 'Wildfire',
#   'Year': '2020',
#   'Director': 'Cathy Brady',
#   'Link': 'https://www.imdb.com/title/tt9180460/',
#   'Rating': '6.2'},
#  {'Title': 'Wildland',
#   'Year': '2020',
#   'Director': 'Jeanette Nordahl',
#   'Link': 'https://www.imdb.com/title/tt8386958/',
#   'Rating': '5.8'},
#  {'Title': 'Lucky',
#   'Year': '2020',
#   'Director': 'Natasha Kermani',
#   'Link': 'https://www.imdb.com/title/tt11701774/',
#   'Rating': '4.9'},
#  {'Title': 'Never Gonna Snow Again',
#   'Year': '2020',
#   'Director': 'Małgorzata Szumowska',
#   'Link': 'https://www.imdb.com/title/tt9526784/',
#   'Rating': '6.4'},
#  {'Title': 'Jimmy Carter: Rock & Roll President',
#   'Year': '2020',
#   'Director': 'Mary Wharton',
#   'Link': 'https://www.imdb.com/title/tt11804758/',
#   'Rating': '7.6'},
#  {'Title': 'Spring Blossom',
#   'Year': '2020',
#   'Director': 'Suzanne Lindon',
#   'Link': 'https://www.imdb.com/title/tt12444426/',
#   'Rating': '5.8'},
#  {'Title': 'I Carry You With Me',
#   'Year': '2020',
#   'Director': 'Heidi Ewing',
#   'Link': 'https://www.imdb.com/title/tt11388990/',
#   'Rating': '6.7'},
#  {'Title': 'Slaxx',
#   'Year': '2020',
#   'Director': 'Elza Kephart',
#   'Link': 'https://www.imdb.com/title/tt9741310/',
#   'Rating': '5.4'},
#  {'Title': 'Identifying Features',
#   'Year': '2020',
#   'Director': 'Fernanda Valadez',
#   'Link': 'https://www.imdb.com/title/tt11394282/',
#   'Rating': '7.3'},
#  {'Title': 'Quo Vadis, Aida?',
#   'Year': '2020',
#   'Director': 'Jasmila Zbanic',
#   'Link': 'https://www.imdb.com/title/tt8633462/',
#   'Rating': '8.0'},
#  {'Title': 'The Stylist',
#   'Year': '2020',
#   'Director': 'Jill Gevargizian',
#   'Link': 'https://www.imdb.com/title/tt11056910/',
#   'Rating': '5.6'},
#  {'Title': 'Slalom',
#   'Year': '2020',
#   'Director': 'Charlène Favier',
#   'Link': 'https://www.imdb.com/title/tt9697780/',
#   'Rating': '6.6'},
#  {'Title': 'Nomadland',
#   'Year': '2020',
#   'Director': 'Chloé Zhao',
#   'Link': 'https://www.imdb.com/title/tt9770150/',
#   'Rating': '7.3'},
#  {'Title': 'Promising Young Woman',
#   'Year': '2020',
#   'Director': 'Emerald Fennell',
#   'Link': 'https://www.imdb.com/title/tt9620292/',
#   'Rating': '7.5'},
#  {'Title': 'Stray',
#   'Year': '2021',
#   'Director': 'Elizabeth Lo',
#   'Link': 'https://www.imdb.com/title/tt13192574/',
#   'Rating': '7.6'},
#  {'Title': 'Gagarine',
#   'Year': '2020',
#   'Director': 'Fanny Liatard',
#   'Link': 'https://www.imdb.com/title/tt12444424/',
#   'Rating': '6.7'},
#  {'Title': 'Tove',
#   'Year': '2020',
#   'Director': 'Zaida Bergroth',
#   'Link': 'https://www.imdb.com/title/tt11007444/',
#   'Rating': '6.8'},
#  {'Title': 'Sword of Trust',
#   'Year': '2019',
#   'Director': 'Lynn Shelton',
#   'Link': 'https://www.imdb.com/title/tt36170772/',
#   'Rating': 'N/A'},
#  {'Title': 'Sword of Trust',
#   'Year': '2019',
#   'Director': 'Lynn Shelton',
#   'Link': 'https://www.imdb.com/title/tt36170772/',
#   'Rating': 'N/A'},
#  {'Title': 'Honey Boy',
#   'Year': '2019',
#   'Director': "Alma Har'el",
#   'Link': 'https://www.imdb.com/title/tt8151874/',
#   'Rating': '7.2'},
#  {'Title': 'Raise Hell: The Life & Times of Molly Ivins',
#   'Year': '2019',
#   'Director': 'Janice Engel',
#   'Link': 'https://www.imdb.com/title/tt9129296/',
#   'Rating': '8.0'},
#  {'Title': 'The Mustang',
#   'Year': '2019',
#   'Director': 'Laure de Clermont-Tonnerre',
#   'Link': 'https://www.imdb.com/title/tt5952594/',
#   'Rating': '6.8'},
#  {'Title': 'A Beautiful Day in the Neighborhood',
#   'Year': '2019',
#   'Director': 'Marielle Heller',
#   'Link': 'https://www.imdb.com/title/tt3224458/',
#   'Rating': '7.2'},
#  {'Title': 'Little Women',
#   'Year': '2019',
#   'Director': 'Greta Gerwig',
#   'Link': 'https://www.imdb.com/title/tt3281548/',
#   'Rating': '7.8'},
#  {'Title': 'Hail Satan?',
#   'Year': '2019',
#   'Director': 'Penny Lane',
#   'Link': 'https://www.imdb.com/title/tt9358044/',
#   'Rating': '7.3'},
#  {'Title': 'American Factory',
#   'Year': '2019',
#   'Director': 'Steven Bognar',
#   'Link': 'https://www.imdb.com/title/tt9351980/',
#   'Rating': '7.4'},
#  {'Title': 'Booksmart',
#   'Year': '2019',
#   'Director': 'Olivia Wilde',
#   'Link': 'https://www.imdb.com/title/tt1489887/',
#   'Rating': '7.1'},
#  {'Title': 'Making Waves: The Art of Cinematic Sound',
#   'Year': '2019',
#   'Director': 'Midge Costin',
#   'Link': 'https://www.imdb.com/title/tt3856408/',
#   'Rating': '7.6'},
#  {'Title': 'The Kingmaker',
#   'Year': '2019',
#   'Director': 'Lauren Greenfield',
#   'Link': 'https://www.imdb.com/title/tt5105734/',
#   'Rating': '7.6'},
#  {'Title': 'The Farewell',
#   'Year': '2019',
#   'Director': 'Lulu Wang',
#   'Link': 'https://www.imdb.com/title/tt8637428/',
#   'Rating': '7.5'},
#  {'Title': 'One Child Nation',
#   'Year': '2019',
#   'Director': 'Nanfu Wang',
#   'Link': 'https://www.imdb.com/title/tt8923482/',
#   'Rating': '7.5'},
#  {'Title': 'For Sama',
#   'Year': '2019',
#   'Director': 'Edward Watts',
#   'Link': 'https://www.imdb.com/title/tt9617456/',
#   'Rating': '8.5'},
#  {'Title': 'Atlantics',
#   'Year': '2019',
#   'Director': 'Mati Diop',
#   'Link': 'https://www.imdb.com/title/tt10199586/',
#   'Rating': '6.7'},
#  {'Title': 'Varda by Agnès',
#   'Year': '2019',
#   'Director': 'Agnès Varda',
#   'Link': 'https://www.imdb.com/title/tt9530198/',
#   'Rating': '7.8'},
#  {'Title': 'Mickey and the Bear',
#   'Year': '2019',
#   'Director': 'Annabelle Attanasio',
#   'Link': 'https://www.imdb.com/title/tt9614440/',
#   'Rating': '6.6'},
#  {'Title': 'Honeyland',
#   'Year': '2019',
#   'Director': 'Ljubo Stefanov',
#   'Link': 'https://www.imdb.com/title/tt8991268/',
#   'Rating': '8.0'},
#  {'Title': 'Portrait of a Lady on Fire',
#   'Year': '2019',
#   'Director': 'Céline Sciamma',
#   'Link': 'https://www.imdb.com/title/tt8613070/',
#   'Rating': '8.1'},
#  {'Title': 'The Assistant',
#   'Year': '2019',
#   'Director': 'Kitty Green',
#   'Link': 'https://www.imdb.com/title/tt9000224/',
#   'Rating': '6.3'},
#  {'Title': 'Hope',
#   'Year': '2019',
#   'Director': 'Maria Sødahl',
#   'Link': 'https://www.imdb.com/title/tt9145334/',
#   'Rating': '7.7'},
#  {'Title': 'Saint Maud',
#   'Year': '2019',
#   'Director': 'Rose Glass',
#   'Link': 'https://www.imdb.com/title/tt7557108/',
#   'Rating': '6.7'},
#  {'Title': 'First Cow',
#   'Year': '2019',
#   'Director': 'Kelly Reichardt',
#   'Link': 'https://www.imdb.com/title/tt9231040/',
#   'Rating': '7.1'},
#  {'Title': 'Blow the Man Down',
#   'Year': '2019',
#   'Director': 'Bridget Savage Cole',
#   'Link': 'https://www.imdb.com/title/tt8299768/',
#   'Rating': '6.4'},
#  {'Title': 'The Long Walk',
#   'Year': '2019',
#   'Director': 'Mattie Do',
#   'Link': 'https://www.imdb.com/title/tt10374610/',
#   'Rating': 'N/A'},
#  {'Title': 'Science Fair',
#   'Year': '2018',
#   'Director': 'Cristina Costantini',
#   'Link': 'https://www.imdb.com/title/tt7153434/',
#   'Rating': '7.5'},
#  {'Title': 'Free Solo',
#   'Year': '2018',
#   'Director': 'Elizabeth Chai Vasarhelyi',
#   'Link': 'https://www.imdb.com/title/tt7775622/',
#   'Rating': '8.1'},
#  {'Title': 'On Her Shoulders',
#   'Year': '2018',
#   'Director': 'Alexandria Bombach',
#   'Link': 'https://www.imdb.com/title/tt7689484/',
#   'Rating': '7.3'},
#  {'Title': 'Rafiki',
#   'Year': '2018',
#   'Director': 'Wanuri Kahiu',
#   'Link': 'https://www.imdb.com/title/tt8286894/',
#   'Rating': '6.8'},
#  {'Title': "To All the Boys I've Loved Before",
#   'Year': '2018',
#   'Director': 'Susan Johnson',
#   'Link': 'https://www.imdb.com/title/tt3846674/',
#   'Rating': '7.0'},
#  {'Title': 'Dark Money',
#   'Year': '2018',
#   'Director': 'Kimberly Reed',
#   'Link': 'https://www.imdb.com/title/tt6633182/',
#   'Rating': '7.1'},
#  {'Title': 'Kusama: Infinity',
#   'Year': '2018',
#   'Director': 'Heather Lenz',
#   'Link': 'https://www.imdb.com/title/tt1893269/',
#   'Rating': '7.3'},
#  {'Title': 'Little Woods',
#   'Year': '2018',
#   'Director': 'Nia DaCosta',
#   'Link': 'https://www.imdb.com/title/tt6418918/',
#   'Rating': '6.2'},
#  {'Title': 'Private Life',
#   'Year': '2018',
#   'Director': 'Tamara Jenkins',
#   'Link': 'https://www.imdb.com/title/tt5536610/',
#   'Rating': '7.2'},
#  {'Title': 'Be Natural: The Untold Story of Alice Guy-Blaché',
#   'Year': '2018',
#   'Director': 'Pamela B. Green',
#   'Link': 'https://www.imdb.com/title/tt3146022/',
#   'Rating': '7.7'},
#  {'Title': 'Birds of Passage',
#   'Year': '2018',
#   'Director': 'Cristina Gallego',
#   'Link': 'https://www.imdb.com/title/tt6386748/',
#   'Rating': '7.5'},
#  {'Title': 'RBG',
#   'Year': '2018',
#   'Director': 'Betsy West',
#   'Link': 'https://www.imdb.com/title/tt7689964/',
#   'Rating': '7.6'},
#  {'Title': 'Pick of the Litter',
#   'Year': '2018',
#   'Director': 'Dana Nachman',
#   'Link': 'https://www.imdb.com/title/tt5644050/',
#   'Rating': '7.6'},
#  {'Title': 'The Chambermaid',
#   'Year': '2018',
#   'Director': 'Lila Avilés',
#   'Link': 'https://www.imdb.com/title/tt8331988/',
#   'Rating': '7.0'},
#  {'Title': 'Can You Ever Forgive Me?',
#   'Year': '2018',
#   'Director': 'Marielle Heller',
#   'Link': 'https://www.imdb.com/title/tt4595882/',
#   'Rating': '7.1'},
#  {'Title': 'Too Late to Die Young',
#   'Year': '2018',
#   'Director': 'Dominga Sotomayor',
#   'Link': 'https://www.imdb.com/title/tt8726098/',
#   'Rating': '6.4'},
#  {'Title': 'Leave No Trace',
#   'Year': '2018',
#   'Director': 'Debra Granik',
#   'Link': 'https://www.imdb.com/title/tt3892172/',
#   'Rating': '7.1'},
#  {'Title': 'Night Comes On',
#   'Year': '2018',
#   'Director': 'Jordana Spiro',
#   'Link': 'https://www.imdb.com/title/tt7184124/',
#   'Rating': '6.7'},
#  {'Title': 'Wonder Woman',
#   'Year': '2017',
#   'Director': 'Patty Jenkins',
#   'Link': 'https://www.imdb.com/title/tt0451279/',
#   'Rating': '7.3'},
#  {'Title': 'Most Beautiful Island',
#   'Year': '2017',
#   'Director': 'Ana Asensio',
#   'Link': 'https://www.imdb.com/title/tt4866448/',
#   'Rating': '5.7'},
#  {'Title': 'School Life',
#   'Year': '2017',
#   'Director': 'David Rane',
#   'Link': 'https://www.imdb.com/title/tt6330246/',
#   'Rating': '6.9'},
#  {'Title': 'The Breadwinner',
#   'Year': '2017',
#   'Director': 'Nora Twomey',
#   'Link': 'https://www.imdb.com/title/tt3901826/',
#   'Rating': '7.7'},
#  {'Title': 'Bombshell: The Hedy Lamarr Story',
#   'Year': '2017',
#   'Director': 'Alexandra Dean',
#   'Link': 'https://www.imdb.com/title/tt6752848/',
#   'Rating': '7.4'},
#  {'Title': 'Step',
#   'Year': '2017',
#   'Director': 'Amanda Lipitz',
#   'Link': 'https://www.imdb.com/title/tt5758404/',
#   'Rating': '7.0'},
#  {'Title': 'Mudbound',
#   'Year': '2017',
#   'Director': 'Dee Rees',
#   'Link': 'https://www.imdb.com/title/tt2396589/',
#   'Rating': '7.4'},
#  {'Title': 'Whose Streets?',
#   'Year': '2017',
#   'Director': 'Sabaah Folayan',
#   'Link': 'https://www.imdb.com/title/tt6176928/',
#   'Rating': '6.0'},
#  {'Title': 'Good Manners',
#   'Year': '2017',
#   'Director': 'Juliana Rojas',
#   'Link': 'https://www.imdb.com/title/tt5480782/',
#   'Rating': '6.7'},
#  {'Title': 'Trophy',
#   'Year': '2017',
#   'Director': 'Shaul Schwarz',
#   'Link': 'https://www.imdb.com/title/tt6333066/',
#   'Rating': '7.3'},
#  {'Title': 'Lady Bird',
#   'Year': '2017',
#   'Director': 'Greta Gerwig',
#   'Link': 'https://www.imdb.com/title/tt4925292/',
#   'Rating': '7.4'},
#  {'Title': 'Faces Places',
#   'Year': '2017',
#   'Director': 'Agnès Varda',
#   'Link': 'https://www.imdb.com/title/tt5598102/',
#   'Rating': '7.8'},
#  {'Title': 'Outside In',
#   'Year': '2017',
#   'Director': 'Lynn Shelton',
#   'Link': 'https://www.imdb.com/title/tt7260048/',
#   'Rating': '6.7'},
#  {'Title': 'Western',
#   'Year': '2017',
#   'Director': 'Valeska Grisebach',
#   'Link': 'https://www.imdb.com/title/tt5157326/',
#   'Rating': '7.0'},
#  {'Title': 'The Rider',
#   'Year': '2017',
#   'Director': 'Chloé Zhao',
#   'Link': 'https://www.imdb.com/title/tt6217608/',
#   'Rating': '7.4'},
#  {'Title': 'Summer 1993',
#   'Year': '2017',
#   'Director': 'Carla Simón',
#   'Link': None,
#   'Rating': 'N/A'},
#  {'Title': 'Marlina the Murderer in Four Acts',
#   'Year': '2017',
#   'Director': 'Mouly Surya',
#   'Link': 'https://www.imdb.com/title/tt5923026/',
#   'Rating': '6.9'},
#  {'Title': 'Tigers Are Not Afraid',
#   'Year': '2017',
#   'Director': 'Issa López',
#   'Link': 'https://www.imdb.com/title/tt4823434/',
#   'Rating': '6.9'},
#  {'Title': 'Oh Lucy!',
#   'Year': '2017',
#   'Director': 'Atsuko Hirayanagi',
#   'Link': 'https://www.imdb.com/title/tt6343058/',
#   'Rating': '6.8'},
#  {'Title': 'Zama',
#   'Year': '2017',
#   'Director': 'Lucrecia Martel',
#   'Link': 'https://www.imdb.com/title/tt3409848/',
#   'Rating': '6.7'},
#  {'Title': 'I Am Not a Witch',
#   'Year': '2017',
#   'Director': 'Rungano Nyoni',
#   'Link': 'https://www.imdb.com/title/tt6213284/',
#   'Rating': '6.9'},
#  {'Title': 'Sand Storm',
#   'Year': '2016',
#   'Director': 'Elite Zexer',
#   'Link': 'https://www.imdb.com/title/tt4365518/',
#   'Rating': '6.8'},
#  {'Title': 'Toni Erdmann',
#   'Year': '2016',
#   'Director': 'Maren Ade',
#   'Link': 'https://www.imdb.com/title/tt4048272/',
#   'Rating': '7.3'},
#  {'Title': 'Queen of Katwe',
#   'Year': '2016',
#   'Director': 'Mira Nair',
#   'Link': 'https://www.imdb.com/title/tt31379972/',
#   'Rating': 'N/A'},
#  {'Title': 'Nuts!',
#   'Year': '2016',
#   'Director': 'Penny Lane',
#   'Link': 'https://www.imdb.com/title/tt5236900/',
#   'Rating': '7.1'},
#  {'Title': 'All This Panic',
#   'Year': '2016',
#   'Director': 'Jenny Gage',
#   'Link': 'https://www.imdb.com/title/tt5590718/',
#   'Rating': '6.7'},
#  {'Title': 'The Edge of Seventeen',
#   'Year': '2016',
#   'Director': 'Kelly Fremon Craig',
#   'Link': 'https://www.imdb.com/title/tt1878870/',
#   'Rating': '7.3'},
#  {'Title': 'The Love Witch',
#   'Year': '2016',
#   'Director': 'Anna Biller',
#   'Link': 'https://www.imdb.com/title/tt3908142/',
#   'Rating': '6.2'},
#  {'Title': 'The Innocents',
#   'Year': '2016',
#   'Director': 'Anne Fontaine',
#   'Link': 'https://www.imdb.com/title/tt4370784/',
#   'Rating': '7.3'},
#  {'Title': '13TH',
#   'Year': '2016',
#   'Director': 'Ava DuVernay',
#   'Link': 'https://www.imdb.com/title/tt5895028/',
#   'Rating': '8.2'},
#  {'Title': 'Bar Bahar',
#   'Year': '2016',
#   'Director': 'Maysaloun Hamoud',
#   'Link': 'https://www.imdb.com/title/tt5974388/',
#   'Rating': '7.3'},
#  {'Title': 'Kedi',
#   'Year': '2016',
#   'Director': 'Ceyda Torun',
#   'Link': 'https://www.imdb.com/title/tt4420704/',
#   'Rating': '7.6'},
#  {'Title': 'Weiner',
#   'Year': '2016',
#   'Director': 'Josh Kriegman',
#   'Link': 'https://www.imdb.com/title/tt5278596/',
#   'Rating': '7.6'},
#  {'Title': 'Cameraperson',
#   'Year': '2016',
#   'Director': 'Kirsten Johnson',
#   'Link': 'https://www.imdb.com/title/tt5375040/'},
#  {'Title': 'Things to Come',
#   'Year': '2016',
#   'Director': 'Mia Hansen-Løve',
#   'Link': 'https://www.imdb.com/title/tt4120176/'},
#  {'Title': 'The Hunting Ground',
#   'Year': '2015',
#   'Director': 'Kirby Dick',
#   'Link': 'https://www.imdb.com/title/tt4185572/'},
#  {'Title': 'Janis: Little Girl Blue',
#   'Year': '2015',
#   'Director': 'Amy Berg',
#   'Link': 'https://www.imdb.com/title/tt3707114/'},
#  {'Title': 'The Diary of a Teenage Girl',
#   'Year': '2015',
#   'Director': 'Marielle Heller',
#   'Link': 'https://www.imdb.com/title/tt3172532/'},
#  {'Title': 'Heart of a Dog',
#   'Year': '2015',
#   'Director': 'Laurie Anderson',
#   'Link': 'https://www.imdb.com/title/tt4935446/'},
#  {'Title': 'Mustang',
#   'Year': '2015',
#   'Director': 'Deniz Gamze Ergüven',
#   'Link': 'https://www.imdb.com/title/tt3966404/'},
#  {'Title': 'The Second Mother',
#   'Year': '2015',
#   'Director': 'Anna Muylaert',
#   'Link': 'https://www.imdb.com/title/tt3742378/'},
#  {'Title': 'Dark Horse',
#   'Year': '2015',
#   'Director': 'Louise Osmond',
#   'Link': 'https://www.imdb.com/title/tt4137902/'},
#  {'Title': 'Sherpa',
#   'Year': '2015',
#   'Director': 'Jennifer Peedom',
#   'Link': 'https://www.imdb.com/title/tt3746250/'},
#  {'Title': 'The Fits',
#   'Year': '2015',
#   'Director': 'Anna Rose Holmer',
#   'Link': 'https://www.imdb.com/title/tt4238858/'},
#  {'Title': "She's Beautiful When She's Angry",
#   'Year': '2014',
#   'Director': 'Mary Dore',
#   'Link': 'https://www.imdb.com/title/tt3319508/'},
#  {'Title': '20,000 Days on Earth',
#   'Year': '2014',
#   'Director': 'Iain Forsyth',
#   'Link': 'https://www.imdb.com/title/tt2920540/'},
#  {'Title': 'A Girl Walks Home Alone at Night',
#   'Year': '2014',
#   'Director': 'Ana Lily Amirpour',
#   'Link': 'https://www.imdb.com/title/tt2326554/'},
#  {'Title': 'Citizenfour',
#   'Year': '2014',
#   'Director': 'Laura Poitras',
#   'Link': 'https://www.imdb.com/title/tt4044364/'},
#  {'Title': 'The Babadook',
#   'Year': '2014',
#   'Director': 'Jennifer Kent',
#   'Link': 'https://www.imdb.com/title/tt2321549/'},
#  {'Title': 'Girlhood',
#   'Year': '2014',
#   'Director': 'Céline Sciamma',
#   'Link': 'https://www.imdb.com/title/tt3655522/'},
#  {'Title': 'The Wonders',
#   'Year': '2014',
#   'Director': 'Alice Rohrwacher',
#   'Link': 'https://www.imdb.com/title/tt3044244/'},
#  {'Title': 'Selma',
#   'Year': '2014',
#   'Director': 'Ava DuVernay',
#   'Link': 'https://www.imdb.com/title/tt1020072/'},
#  {'Title': 'Gett: The Trial of Viviane Amsalem',
#   'Year': '2014',
#   'Director': 'Ronit Elkabetz',
#   'Link': 'https://www.imdb.com/title/tt3062880/'},
#  {'Title': 'Appropriate Behavior',
#   'Year': '2014',
#   'Director': 'Desiree Akhavan',
#   'Link': 'https://www.imdb.com/title/tt3077108/'},
#  {'Title': 'Enough Said',
#   'Year': '2013',
#   'Director': 'Nicole Holofcener',
#   'Link': 'https://www.imdb.com/title/tt2390361/'},
#  {'Title': 'Elaine Stritch: Shoot Me',
#   'Year': '2013',
#   'Director': 'Chiemi Karasawa',
#   'Link': 'https://www.imdb.com/title/tt2405792/'},
#  {'Title': 'The Crash Reel',
#   'Year': '2013',
#   'Director': 'Lucy Walker',
#   'Link': 'https://www.imdb.com/title/tt2499076/'},
#  {'Title': 'The Selfish Giant',
#   'Year': '2013',
#   'Director': 'Clio Barnard',
#   'Link': 'https://www.imdb.com/title/tt2304426/'},
#  {'Title': 'Blackfish',
#   'Year': '2013',
#   'Director': 'Gabriela Cowperthwaite',
#   'Link': 'https://www.imdb.com/title/tt2545118/'},
#  {'Title': 'The Square',
#   'Year': '2013',
#   'Director': 'Jehane Noujaim',
#   'Link': 'https://www.imdb.com/title/tt2486682/'},
#  {'Title': 'The Queen of Versailles',
#   'Year': '2012',
#   'Director': 'Lauren Greenfield',
#   'Link': 'https://www.imdb.com/title/tt2125666/'},
#  {'Title': 'West of Memphis',
#   'Year': '2012',
#   'Director': 'Amy Berg',
#   'Link': 'https://www.imdb.com/title/tt2130321/'},
#  {'Title': 'Brooklyn Castle',
#   'Year': '2012',
#   'Director': 'Katie Dellamaggiore',
#   'Link': 'https://www.imdb.com/title/tt1800266/'},
#  {'Title': 'Sister',
#   'Year': '2012',
#   'Director': 'Ursula Meier',
#   'Link': 'https://www.imdb.com/title/tt2062969/'},
#  {'Title': 'Ai Weiwei: Never Sorry',
#   'Year': '2012',
#   'Director': 'Alison Klayman',
#   'Link': 'https://www.imdb.com/title/tt1845773/'},
#  {'Title': 'Lore',
#   'Year': '2012',
#   'Director': 'Cate Shortland',
#   'Link': 'https://www.imdb.com/title/tt1996310/'},
#  {'Title': 'Stories We Tell',
#   'Year': '2012',
#   'Director': 'Sarah Polley',
#   'Link': 'https://www.imdb.com/title/tt2366450/'},
#  {'Title': 'Wadjda',
#   'Year': '2012',
#   'Director': 'Haifaa Al-Mansour',
#   'Link': 'https://www.imdb.com/title/tt2258858/'},
#  {'Title': 'Call Me Kuchu',
#   'Year': '2012',
#   'Director': 'Katherine Fairfax Wright',
#   'Link': 'https://www.imdb.com/title/tt2088714/'},
#  {'Title': 'Pariah',
#   'Year': '2011',
#   'Director': 'Dee Rees',
#   'Link': 'https://www.imdb.com/title/tt1233334/'},
#  {'Title': "Being Elmo: A Puppeteer's Journey",
#   'Year': '2011',
#   'Director': 'Constance Marks',
#   'Link': 'https://www.imdb.com/title/tt1787660/'},
#  {'Title': 'Tomboy',
#   'Year': '2011',
#   'Director': 'Céline Sciamma',
#   'Link': 'https://www.imdb.com/title/tt1847731/'},
#  {'Title': 'First Position',
#   'Year': '2011',
#   'Director': 'Bess Kargman',
#   'Link': 'https://www.imdb.com/title/tt2008513/'},
#  {'Title': 'Turn Me On, Dammit!',
#   'Year': '2011',
#   'Director': 'Jannicke Systad Jacobsen',
#   'Link': 'https://www.imdb.com/title/tt1650407/'},
#  {'Title': 'Sing Your Song',
#   'Year': '2011',
#   'Director': 'Susanne Rostock',
#   'Link': 'https://www.imdb.com/title/tt1787797/'},
#  {'Title': 'Diana Vreeland: The Eye Has to Travel',
#   'Year': '2011',
#   'Director': 'Lisa Immordino Vreeland',
#   'Link': 'https://www.imdb.com/title/tt2053352/'},
#  {'Title': 'The Kids Are All Right',
#   'Year': '2010',
#   'Director': 'Lisa Cholodenko',
#   'Link': 'https://www.imdb.com/title/tt0842926/'},
#  {'Title': "Winter's Bone",
#   'Year': '2010',
#   'Director': 'Debra Granik',
#   'Link': 'https://www.imdb.com/title/tt1399683/'},
#  {'Title': 'Waste Land',
#   'Year': '2010',
#   'Director': 'Lucy Walker',
#   'Link': 'https://www.imdb.com/title/tt1268204/'},
#  {'Title': 'The Arbor',
#   'Year': '2010',
#   'Director': 'Clio Barnard',
#   'Link': 'https://www.imdb.com/title/tt1623008/'},
#  {'Title': 'Yoo-Hoo, Mrs. Goldberg',
#   'Year': '2009',
#   'Director': 'Aviva Kempner',
#   'Link': 'https://www.imdb.com/title/tt1334479/'},
#  {'Title': 'An Education',
#   'Year': '2009',
#   'Director': 'Lone Scherfig',
#   'Link': 'https://www.imdb.com/title/tt1174732/'},
#  {'Title': 'The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon Papers',
#   'Year': '2009',
#   'Director': 'Judith Ehrlich',
#   'Link': 'https://www.imdb.com/title/tt1319726/'},
#  {'Title': 'Sweetgrass',
#   'Year': '2009',
#   'Director': 'Lucien Castaing-Taylor',
#   'Link': 'https://www.imdb.com/title/tt1517252/'},
#  {'Title': 'Afghan Star',
#   'Year': '2009',
#   'Director': 'Havana Marking',
#   'Link': 'https://www.imdb.com/title/tt1334510/'},
#  {'Title': 'A Film Unfinished',
#   'Year': '2009',
#   'Director': 'Yael Hersonski',
#   'Link': 'https://www.imdb.com/title/tt1568923/'},
#  {'Title': 'Trouble the Water',
#   'Year': '2008',
#   'Director': 'Carl Deal',
#   'Link': 'https://www.imdb.com/title/tt1149405/'},
#  {'Title': 'The Beaches of Agnès',
#   'Year': '2008',
#   'Director': 'Agnès Varda',
#   'Link': 'https://www.imdb.com/title/tt1129435/'},
#  {'Title': '35 Shots of Rum',
#   'Year': '2008',
#   'Director': 'Claire Denis',
#   'Link': 'https://www.imdb.com/title/tt1100048/'},
#  {'Title': 'The Hurt Locker',
#   'Year': '2008',
#   'Director': 'Kathryn Bigelow',
#   'Link': 'https://www.imdb.com/title/tt0887912/'},
#  {'Title': 'Persepolis',
#   'Year': '2007',
#   'Director': 'Marjane Satrapi',
#   'Link': 'https://www.imdb.com/title/tt0808417/'},
#  {'Title': 'The Devil Came on Horseback',
#   'Year': '2007',
#   'Director': 'Ricki Stern',
#   'Link': 'https://www.imdb.com/title/tt0912580/'},
#  {'Title': 'Blame It on Fidel',
#   'Year': '2006',
#   'Director': 'Julie Gavras',
#   'Link': 'https://www.imdb.com/title/tt0792966/'},
#  {'Title': 'Deep Water',
#   'Year': '2006',
#   'Director': 'Louise Osmond',
#   'Link': 'https://www.imdb.com/title/tt0460766/'},
#  {'Title': 'Blindsight',
#   'Year': '2006',
#   'Director': 'Lucy Walker',
#   'Link': 'https://www.imdb.com/title/tt0841084/'},
#  {'Title': 'The War Tapes',
#   'Year': '2006',
#   'Director': 'Deborah Scranton',
#   'Link': 'https://www.imdb.com/title/tt0775566/'},
#  {'Title': 'Away From Her',
#   'Year': '2006',
#   'Director': 'Sarah Polley',
#   'Link': 'https://www.imdb.com/title/tt0491747/'},
#  {'Title': 'Grbavica: The Land of My Dreams',
#   'Year': '2006',
#   'Director': 'Jasmila Zbanic',
#   'Link': 'https://www.imdb.com/title/tt0464029/'},
#  {'Title': 'Control Room',
#   'Year': '2004',
#   'Director': 'Jehane Noujaim',
#   'Link': 'https://www.imdb.com/title/tt0391024/'},
#  {'Title': 'Born Into Brothels',
#   'Year': '2004',
#   'Director': 'Zana Briski',
#   'Link': 'https://www.imdb.com/title/tt0388789/'},
#  {'Title': 'American Splendor',
#   'Year': '2003',
#   'Director': 'Shari Springer Berman',
#   'Link': 'https://www.imdb.com/title/tt0305206/'},
#  {'Title': 'Lost in Translation',
#   'Year': '2003',
#   'Director': 'Sofia Coppola',
#   'Link': 'https://www.imdb.com/title/tt0335266/'},
#  {'Title': 'The Revolution Will Not Be Televised',
#   'Year': '2003',
#   'Director': 'Kim Bartley',
#   'Link': 'https://www.imdb.com/title/tt9063104/'},
#  {'Title': 'The Story of the Weeping Camel',
#   'Year': '2003',
#   'Director': 'Byambasuren Davaa',
#   'Link': 'https://www.imdb.com/title/tt0373861/'},
#  {'Title': 'Lost Boys of Sudan',
#   'Year': '2003',
#   'Director': 'Megan Mylan',
#   'Link': 'https://www.imdb.com/title/tt0383475/'},
#  {'Title': 'Since Otar Left',
#   'Year': '2003',
#   'Director': 'Julie Bertuccelli',
#   'Link': 'https://www.imdb.com/title/tt0336264/'},
#  {'Title': 'The Wild Parrots of Telegraph Hill',
#   'Year': '2003',
#   'Director': 'Judy Irving',
#   'Link': 'https://www.imdb.com/title/tt0424565/'},
#  {'Title': 'Open Hearts',
#   'Year': '2002',
#   'Director': 'Susanne Bier',
#   'Link': 'https://www.imdb.com/title/tt0315543/'},
#  {'Title': 'Monsoon Wedding',
#   'Year': '2001',
#   'Director': 'Mira Nair',
#   'Link': 'https://www.imdb.com/title/tt0265343/'},
#  {'Title': 'Promises',
#   'Year': '2001',
#   'Director': 'Justine Shapiro',
#   'Link': 'https://www.imdb.com/title/tt0282864/'},
#  {'Title': 'The Taste of Others',
#   'Year': '2000',
#   'Director': 'Agnès Jaoui',
#   'Link': 'https://www.imdb.com/title/tt0216787/'},
#  {'Title': 'The Gleaners and I',
#   'Year': '2000',
#   'Director': 'Agnès Varda',
#   'Link': 'https://www.imdb.com/title/tt0247380/'},
#  {'Title': 'The Life and Times of Hank Greenberg',
#   'Year': '1999',
#   'Director': 'Aviva Kempner',
#   'Link': 'https://www.imdb.com/title/tt0208261/'}]

# %% [markdown]
# ### fix wrong links

# %%
corrected_links = {
    'Pray Away': 'https://www.imdb.com/title/tt11224358/',
    'The Forty-Year-Old Version': 'https://www.imdb.com/title/tt10642834/',
    'Truman & Tennessee: An Intimate Conversation': 'https://www.imdb.com/title/tt13016030/',
    'Stray': 'https://www.imdb.com/title/tt11905922/',
    'The Long Walk': 'https://www.imdb.com/title/tt6800268/',
    'Summer 1993': 'https://www.imdb.com/title/tt5897636/',
    'Queen of Katwe': 'https://www.imdb.com/title/tt4341582/'
}

# %%
for movie in movies:
    title = movie['Title']
    if title in corrected_links:
        movie['Link'] = corrected_links[title]

# %% [markdown]
# ## 3. Merge more information from IMDb: rating, the number of nominations/wins, genre tags

# %% [markdown]
# ### a. scraping the ratings

# %%
for movie in movies:
    try:
        response = requests.get(movie['Link'], headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Try both possible rating locations
        rating = soup.find(class_='sc-d541859f-1 imUuxf').get_text(strip=True)
        
        movie['Rating'] = rating if rating else "N/A"
        
    except Exception as e:
        print(f"Error getting rating for {movie['Title']}: {str(e)}")
        movie['Rating'] = "N/A"
# Out:
# Error getting rating for Banel & Adama: 'NoneType' object has no attribute 'get_text'
# Error getting rating for Sword of Trust: 'NoneType' object has no attribute 'get_text'
# Error getting rating for Sword of Trust: 'NoneType' object has no attribute 'get_text'

# %% [markdown]
# ### b. scraping the number of nominations & wins

# %%
for movie in movies:
    if not movie.get('Link'):
        movie['wins'] = None
        movie['nominations'] = None
        continue
    
    try:       
        response = requests.get(movie['Link'], headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        awards_span = soup.find('span', class_='ipc-metadata-list-item__list-content-item')
        
        if awards_span:
            awards_text = awards_span.get_text(strip=True)
            wins, nominations = extract_wins_nominations(awards_text)
            
            movie['Wins'] = wins
            movie['Nominations'] = nominations

        else:
            movie['Wins'] = None
            movie['Nominations'] = None
            
    except Exception as e:
        print(f"Error processing {movie.get('title', 'Unknown')}: {str(e)}")
        movie['Wins'] = None
        movie['Nominations'] = None

# %% [markdown]
# ### c. scraping genres

# %%
for movie in movies:
    try:
        response = requests.get(movie['Link'], headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        genre_tags = soup.find_all('a', class_='ipc-chip ipc-chip--on-baseAlt')
        movie['Genres'] = [tag.span.get_text(strip=True) for tag in genre_tags if tag.span]
    except Exception as e:
        print(f"🚨 Error processing {movie['Title']}: {str(e)}")
        movie.setdefault('Genres', [])

# %%
# checkpoint 
movies
# Out:
# [{'Title': 'The Substance',
#   'Year': '2024',
#   'Director': 'Coralie Fargeat',
#   'Link': 'https://www.imdb.com/title/tt17526714/',
#   'Rating': '7.3',
#   'Wins': 143,
#   'Nominations': 280,
#   'Genres': ['Body Horror',
#    'Dark Comedy',
#    'Monster Horror',
#    'Psychological Horror',
#    'Showbiz Drama',
#    'Drama',
#    'Horror',
#    'Sci-Fi']},
#  {'Title': 'My Old Ass',
#   'Year': '2024',
#   'Director': 'Megan Park',
#   'Link': 'https://www.imdb.com/title/tt18559464/',
#   'Rating': '6.9',
#   'Wins': 9,
#   'Nominations': 35,
#   'Genres': ['Coming-of-Age', 'Comedy', 'Drama', 'Romance']},
#  {'Title': 'Love Lies Bleeding',
#   'Year': '2024',
#   'Director': 'Rose Glass',
#   'Link': 'https://www.imdb.com/title/tt19637052/',
#   'Rating': '6.6',
#   'Wins': 6,
#   'Nominations': 53,
#   'Genres': ['Dark Romance',
#    'Drug Crime',
#    'Erotic Thriller',
#    'Action',
#    'Adventure',
#    'Crime',
#    'Drama',
#    'Mystery',
#    'Romance',
#    'Thriller']},
#  {'Title': 'The Fire Inside',
#   'Year': '2024',
#   'Director': 'Rachel Morrison',
#   'Link': 'https://www.imdb.com/title/tt6133444/',
#   'Rating': '6.7',
#   'Wins': 5,
#   'Nominations': 17,
#   'Genres': ['Boxing', 'Docudrama', 'Biography', 'Drama', 'Sport']},
#  {'Title': "The Devil's Bath",
#   'Year': '2024',
#   'Director': 'Veronika Franz',
#   'Link': 'https://www.imdb.com/title/tt29141112/',
#   'Rating': '6.6',
#   'Wins': 15,
#   'Nominations': 10,
#   'Genres': ['Folk Horror',
#    'Period Drama',
#    'Drama',
#    'History',
#    'Horror',
#    'Thriller']},
#  {'Title': 'Vermiglio',
#   'Year': '2024',
#   'Director': 'Maura Delpero',
#   'Link': 'https://www.imdb.com/title/tt28618488/',
#   'Rating': '6.9',
#   'Wins': 10,
#   'Nominations': 32,
#   'Genres': ['Period Drama', 'Drama', 'History']},
#  {'Title': 'In the Summers',
#   'Year': '2024',
#   'Director': 'Alessandra Lacorazza Samudio',
#   'Link': 'https://www.imdb.com/title/tt24805832/',
#   'Rating': '6.5',
#   'Wins': 8,
#   'Nominations': 6,
#   'Genres': ['Coming-of-Age', 'Drama']},
#  {'Title': 'Santosh',
#   'Year': '2024',
#   'Director': 'Sandhya Suri',
#   'Link': 'https://www.imdb.com/title/tt30444418/',
#   'Rating': '7.1',
#   'Wins': 9,
#   'Nominations': 10,
#   'Genres': ['Crime', 'Drama', 'Thriller']},
#  {'Title': 'Black Box Diaries',
#   'Year': '2024',
#   'Director': 'Shiori Ito',
#   'Link': 'https://www.imdb.com/title/tt30227076/',
#   'Rating': '7.5',
#   'Wins': 21,
#   'Nominations': 34,
#   'Genres': ['Crime Documentary', 'Documentary']},
#  {'Title': 'Good One',
#   'Year': '2024',
#   'Director': 'India Donaldson',
#   'Link': 'https://www.imdb.com/title/tt30319516/',
#   'Rating': '6.6',
#   'Wins': 6,
#   'Nominations': 22,
#   'Genres': ['Drama']},
#  {'Title': 'Girls Will Be Girls',
#   'Year': '2024',
#   'Director': 'Shuchi Talati',
#   'Link': 'https://www.imdb.com/title/tt18277182/',
#   'Rating': '7.1',
#   'Wins': 21,
#   'Nominations': 30,
#   'Genres': ['Coming-of-Age', 'Drama', 'Romance']},
#  {'Title': 'Ghostlight',
#   'Year': '2024',
#   'Director': "Kelly O'Sullivan",
#   'Link': 'https://www.imdb.com/title/tt30321095/',
#   'Rating': '7.6',
#   'Wins': 6,
#   'Nominations': 21,
#   'Genres': ['Comedy', 'Drama']},
#  {'Title': 'On Becoming a Guinea Fowl',
#   'Year': '2024',
#   'Director': 'Rungano Nyoni',
#   'Link': 'https://www.imdb.com/title/tt32083311/',
#   'Rating': '7.1',
#   'Wins': 7,
#   'Nominations': 13,
#   'Genres': ['Dark Comedy', 'Comedy', 'Drama']},
#  {'Title': 'All We Imagine as Light',
#   'Year': '2024',
#   'Director': 'Payal Kapadia',
#   'Link': 'https://www.imdb.com/title/tt32086077/',
#   'Rating': '7.1',
#   'Wins': 47,
#   'Nominations': 92,
#   'Genres': ['Psychological Drama', 'Drama', 'Romance']},
#  {'Title': 'Hoard',
#   'Year': '2023',
#   'Director': 'Luna Carmoon',
#   'Link': 'https://www.imdb.com/title/tt20729172/',
#   'Rating': '6.5',
#   'Wins': 9,
#   'Nominations': 22,
#   'Genres': ['Coming-of-Age', 'Psychological Drama', 'Drama']},
#  {'Title': 'Banel & Adama',
#   'Year': '2023',
#   'Director': 'Ramata-Toulaye Sy',
#   'Link': 'https://www.imdb.com/name/nm0051826/',
#   'Rating': 'N/A',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': []},
#  {'Title': 'Fancy Dance',
#   'Year': '2023',
#   'Director': 'Erica Tremblay',
#   'Link': 'https://www.imdb.com/title/tt21813994/',
#   'Rating': '6.6',
#   'Wins': 13,
#   'Nominations': 9,
#   'Genres': ['Drama']},
#  {'Title': 'Tiger Stripes',
#   'Year': '2023',
#   'Director': 'Amanda Nell Eu',
#   'Link': 'https://www.imdb.com/title/tt10803634/',
#   'Rating': '6.0',
#   'Wins': 7,
#   'Nominations': 15,
#   'Genres': ['Body Horror', 'Drama', 'Horror']},
#  {'Title': 'Tótem',
#   'Year': '2023',
#   'Director': 'Lila Avilés',
#   'Link': 'https://www.imdb.com/title/tt26315142/',
#   'Rating': '7.0',
#   'Wins': 24,
#   'Nominations': 40,
#   'Genres': ['Drama']},
#  {'Title': 'Anatomy of a Fall',
#   'Year': '2023',
#   'Director': 'Justine Triet',
#   'Link': 'https://www.imdb.com/title/tt17009710/',
#   'Rating': '7.6',
#   'Wins': 130,
#   'Nominations': 192,
#   'Genres': ['Legal Drama',
#    'Legal Thriller',
#    'Psychological Drama',
#    'Psychological Thriller',
#    'Crime',
#    'Drama',
#    'Thriller']},
#  {'Title': 'Past Lives',
#   'Year': '2023',
#   'Director': 'Celine Song',
#   'Link': 'https://www.imdb.com/title/tt13238346/',
#   'Rating': '7.8',
#   'Wins': 87,
#   'Nominations': 239,
#   'Genres': ['Korean Drama', 'Drama', 'Romance']},
#  {'Title': "Are You There God? It's Me, Margaret.",
#   'Year': '2023',
#   'Director': 'Kelly Fremon Craig',
#   'Link': 'https://www.imdb.com/title/tt9185206/',
#   'Rating': '7.3',
#   'Wins': 27,
#   'Nominations': 83,
#   'Genres': ['Coming-of-Age', 'Comedy', 'Drama', 'Family']},
#  {'Title': 'Bottoms',
#   'Year': '2023',
#   'Director': 'Emma Seligman',
#   'Link': 'https://www.imdb.com/title/tt17527468/',
#   'Rating': '6.7',
#   'Wins': 5,
#   'Nominations': 24,
#   'Genres': ['Dark Comedy',
#    'High-Concept Comedy',
#    'Raunchy Comedy',
#    'Satire',
#    'Teen Comedy',
#    'Comedy']},
#  {'Title': 'Rye Lane',
#   'Year': '2023',
#   'Director': 'Raine Allen Miller',
#   'Link': 'https://www.imdb.com/title/tt15893750/',
#   'Rating': '7.2',
#   'Wins': 6,
#   'Nominations': 36,
#   'Genres': ['Coming-of-Age',
#    'Romantic Comedy',
#    'Comedy',
#    'Drama',
#    'Romance']},
#  {'Title': 'You Are So Not Invited to My Bat Mitzvah',
#   'Year': '2023',
#   'Director': 'Sammi Cohen',
#   'Link': 'https://www.imdb.com/title/tt21276878/',
#   'Rating': '5.9',
#   'Wins': 2,
#   'Nominations': 2,
#   'Genres': ['Coming-of-Age', 'Teen Comedy', 'Comedy']},
#  {'Title': 'Joy Ride',
#   'Year': '2023',
#   'Director': 'Adele Lim',
#   'Link': 'https://www.imdb.com/title/tt15268244/',
#   'Rating': '6.4',
#   'Wins': 2,
#   'Nominations': 17,
#   'Genres': ['Raunchy Comedy', 'Comedy']},
#  {'Title': 'Reality',
#   'Year': '2023',
#   'Director': 'Tina Satter',
#   'Link': 'https://www.imdb.com/title/tt24068064/',
#   'Rating': '6.7',
#   'Wins': 5,
#   'Nominations': 12,
#   'Genres': ['Docudrama', 'Legal Drama', 'Drama']},
#  {'Title': 'The Starling Girl',
#   'Year': '2023',
#   'Director': 'Laurel Parmet',
#   'Link': 'https://www.imdb.com/title/tt21156390/',
#   'Rating': '6.7',
#   'Wins': 1,
#   'Nominations': 4,
#   'Genres': ['Drama']},
#  {'Title': 'Scrapper',
#   'Year': '2023',
#   'Director': 'Charlotte Regan',
#   'Link': 'https://www.imdb.com/title/tt8649252/',
#   'Rating': '6.9',
#   'Wins': 11,
#   'Nominations': 23,
#   'Genres': ['Coming-of-Age', 'Comedy', 'Drama']},
#  {'Title': 'You Hurt My Feelings',
#   'Year': '2023',
#   'Director': 'Nicole Holofcener',
#   'Link': 'https://www.imdb.com/title/tt15771916/',
#   'Rating': '6.5',
#   'Wins': 1,
#   'Nominations': 8,
#   'Genres': ['Dark Comedy',
#    'Romantic Comedy',
#    'Satire',
#    'Comedy',
#    'Drama',
#    'Romance']},
#  {'Title': 'How to Have Sex',
#   'Year': '2023',
#   'Director': 'Molly Manning Walker',
#   'Link': 'https://www.imdb.com/title/tt22890246/',
#   'Rating': '6.5',
#   'Wins': 14,
#   'Nominations': 34,
#   'Genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'Title': 'birth/rebirth',
#   'Year': '2023',
#   'Director': 'Laura Moss',
#   'Link': 'https://www.imdb.com/title/tt9048804/',
#   'Rating': '6.2',
#   'Wins': 3,
#   'Nominations': 6,
#   'Genres': ['Body Horror', 'Medical Drama', 'Drama', 'Horror', 'Thriller']},
#  {'Title': 'Four Daughters',
#   'Year': '2023',
#   'Director': 'Kaouther Ben Hania',
#   'Link': 'https://www.imdb.com/title/tt27502426/',
#   'Rating': '7.4',
#   'Wins': 21,
#   'Nominations': 33,
#   'Genres': ['Political Documentary', 'Documentary']},
#  {'Title': 'Earth Mama',
#   'Year': '2023',
#   'Director': 'Savanah Leaf',
#   'Link': 'https://www.imdb.com/title/tt18382328/',
#   'Rating': '6.6',
#   'Wins': 7,
#   'Nominations': 13,
#   'Genres': ['Coming-of-Age', 'Legal Drama', 'Psychological Drama', 'Drama']},
#  {'Title': 'Shayda',
#   'Year': '2023',
#   'Director': 'Noora Niasari',
#   'Link': 'https://www.imdb.com/title/tt13200006/',
#   'Rating': '6.7',
#   'Wins': 7,
#   'Nominations': 28,
#   'Genres': ['Drama']},
#  {'Title': 'A Thousand and One',
#   'Year': '2023',
#   'Director': 'A.V. Rockwell',
#   'Link': 'https://www.imdb.com/title/tt12427158/',
#   'Rating': '7.0',
#   'Wins': 11,
#   'Nominations': 54,
#   'Genres': ['Crime', 'Drama']},
#  {'Title': 'Girl Picture',
#   'Year': '2022',
#   'Director': 'Alli Haapasalo',
#   'Link': 'https://www.imdb.com/title/tt13328800/',
#   'Rating': '6.9',
#   'Wins': 11,
#   'Nominations': 15,
#   'Genres': ['Teen Romance', 'Drama', 'Romance']},
#  {'Title': 'Till',
#   'Year': '2022',
#   'Director': 'Chinonye Chukwu',
#   'Link': 'https://www.imdb.com/title/tt4960748/',
#   'Rating': '7.2',
#   'Wins': 25,
#   'Nominations': 90,
#   'Genres': ['Docudrama',
#    'Period Drama',
#    'Biography',
#    'Crime',
#    'Drama',
#    'History']},
#  {'Title': 'Sissy',
#   'Year': '2022',
#   'Director': 'Hannah Barlow',
#   'Link': 'https://www.imdb.com/title/tt9602472/',
#   'Rating': '6.1',
#   'Wins': 4,
#   'Nominations': 12,
#   'Genres': ['Dark Comedy',
#    'Psychological Horror',
#    'Slasher Horror',
#    'Comedy',
#    'Drama',
#    'Horror',
#    'Romance',
#    'Thriller']},
#  {'Title': 'Turning Red',
#   'Year': '2022',
#   'Director': 'Domee Shi',
#   'Link': 'https://www.imdb.com/title/tt8097030/',
#   'Rating': '6.9',
#   'Wins': 11,
#   'Nominations': 93,
#   'Genres': ['Coming-of-Age',
#    'Computer Animation',
#    'Teen Comedy',
#    'Teen Drama',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Drama',
#    'Family',
#    'Fantasy']},
#  {'Title': 'The Woman King',
#   'Year': '2022',
#   'Director': 'Gina Prince-Bythewood',
#   'Link': 'https://www.imdb.com/title/tt8093700/',
#   'Rating': '6.9',
#   'Wins': 28,
#   'Nominations': 126,
#   'Genres': ['Action Epic', 'Historical Epic', 'Action', 'Drama', 'History']},
#  {'Title': 'Good Luck to You, Leo Grande',
#   'Year': '2022',
#   'Director': 'Sophie Hyde',
#   'Link': 'https://www.imdb.com/title/tt13352968/',
#   'Rating': '7.2',
#   'Wins': 9,
#   'Nominations': 36,
#   'Genres': ['Quirky Comedy', 'Comedy', 'Drama']},
#  {'Title': 'Aftersun',
#   'Year': '2022',
#   'Director': 'Charlotte Wells',
#   'Link': 'https://www.imdb.com/title/tt19770238/',
#   'Rating': '7.6',
#   'Wins': 96,
#   'Nominations': 186,
#   'Genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'Title': 'Hatching',
#   'Year': '2022',
#   'Director': 'Hanna Bergholm',
#   'Link': 'https://www.imdb.com/title/tt12519030/',
#   'Rating': '6.2',
#   'Wins': 6,
#   'Nominations': 11,
#   'Genres': ['Body Horror', 'Monster Horror', 'Drama', 'Fantasy', 'Horror']},
#  {'Title': 'Piggy',
#   'Year': '2022',
#   'Director': 'Carlota Pereda',
#   'Link': 'https://www.imdb.com/title/tt10399608/',
#   'Rating': '6.2',
#   'Wins': 10,
#   'Nominations': 29,
#   'Genres': ['Slasher Horror', 'Drama', 'Horror', 'Thriller']},
#  {'Title': 'Deadstream',
#   'Year': '2022',
#   'Director': 'Joseph Winter',
#   'Link': 'https://www.imdb.com/title/tt12788488/',
#   'Rating': '6.4',
#   'Wins': 2,
#   'Nominations': 6,
#   'Genres': ['Found Footage Horror',
#    'Supernatural Horror',
#    'Comedy',
#    'Horror']},
#  {'Title': 'Nanny',
#   'Year': '2022',
#   'Director': 'Nikyatu Jusu',
#   'Link': 'https://www.imdb.com/title/tt10931784/',
#   'Rating': '5.3',
#   'Wins': 11,
#   'Nominations': 18,
#   'Genres': ['Supernatural Horror', 'Drama', 'Horror']},
#  {'Title': 'You Can Live Forever',
#   'Year': '2022',
#   'Director': 'Sarah Watts',
#   'Link': 'https://www.imdb.com/title/tt15782570/',
#   'Rating': '6.8',
#   'Wins': 1,
#   'Nominations': 2,
#   'Genres': ['Coming-of-Age', 'Tragic Romance', 'Drama', 'Romance']},
#  {'Title': 'Leonor Will Never Die',
#   'Year': '2022',
#   'Director': 'Martika Ramirez Escobar',
#   'Link': 'https://www.imdb.com/title/tt16377714/',
#   'Rating': '6.6',
#   'Wins': 20,
#   'Nominations': 45,
#   'Genres': ['Action', 'Comedy', 'Drama']},
#  {'Title': 'The Unknown Country',
#   'Year': '2022',
#   'Director': 'Morrisa Maltz',
#   'Link': 'https://www.imdb.com/title/tt12783826/',
#   'Rating': '6.3',
#   'Wins': 6,
#   'Nominations': 14,
#   'Genres': ['Adventure', 'Drama', 'Mystery', 'Romance']},
#  {'Title': "Chile '76",
#   'Year': '2022',
#   'Director': 'Manuela Martelli',
#   'Link': 'https://www.imdb.com/title/tt19758012/',
#   'Rating': '6.7',
#   'Wins': 19,
#   'Nominations': 20,
#   'Genres': ['Drama']},
#  {'Title': "Other People's Children",
#   'Year': '2022',
#   'Director': 'Rebecca Zlotowski',
#   'Link': 'https://www.imdb.com/title/tt15403712/',
#   'Rating': '6.8',
#   'Wins': 3,
#   'Nominations': 9,
#   'Genres': ['Comedy', 'Drama', 'Romance']},
#  {'Title': 'War Pony',
#   'Year': '2022',
#   'Director': 'Riley Keough',
#   'Link': 'https://www.imdb.com/title/tt16227002/',
#   'Rating': '6.8',
#   'Wins': 10,
#   'Nominations': 11,
#   'Genres': ['Crime', 'Drama']},
#  {'Title': 'Falcon Lake',
#   'Year': '2022',
#   'Director': 'Charlotte Le Bon',
#   'Link': 'https://www.imdb.com/title/tt11448830/',
#   'Rating': '7.0',
#   'Wins': 10,
#   'Nominations': 24,
#   'Genres': ['Coming-of-Age', 'Drama', 'Fantasy', 'Romance']},
#  {'Title': 'Revoir Paris',
#   'Year': '2022',
#   'Director': 'Alice Winocour',
#   'Link': 'https://www.imdb.com/title/tt15329224/',
#   'Rating': '6.9',
#   'Wins': 4,
#   'Nominations': 2,
#   'Genres': ['Crime', 'Drama', 'Thriller']},
#  {'Title': 'Saint Omer',
#   'Year': '2022',
#   'Director': 'Alice Diop',
#   'Link': 'https://www.imdb.com/title/tt15376894/',
#   'Rating': '6.8',
#   'Wins': 21,
#   'Nominations': 50,
#   'Genres': ['Drama']},
#  {'Title': 'Women Talking',
#   'Year': '2022',
#   'Director': 'Sarah Polley',
#   'Link': 'https://www.imdb.com/title/tt13669038/',
#   'Rating': '6.9',
#   'Wins': 65,
#   'Nominations': 166,
#   'Genres': ['Period Drama', 'Psychological Drama', 'Drama']},
#  {'Title': 'Blue Jean',
#   'Year': '2022',
#   'Director': 'Georgia Oakley',
#   'Link': 'https://www.imdb.com/title/tt8649344/',
#   'Rating': '7.0',
#   'Wins': 14,
#   'Nominations': 27,
#   'Genres': ['Psychological Drama', 'Drama', 'History']},
#  {'Title': 'Amanda',
#   'Year': '2022',
#   'Director': 'Carolina Cavalli',
#   'Link': 'https://www.imdb.com/title/tt18469872/',
#   'Rating': '6.5',
#   'Wins': 3,
#   'Nominations': 10,
#   'Genres': ['Comedy', 'Drama']},
#  {'Title': 'Huesera: The Bone Woman',
#   'Year': '2022',
#   'Director': 'Michelle Garza Cervera',
#   'Link': 'https://www.imdb.com/title/tt11718516/',
#   'Rating': '6.0',
#   'Wins': 13,
#   'Nominations': 31,
#   'Genres': ['Body Horror', 'Folk Horror', 'Drama', 'Horror']},
#  {'Title': 'Klondike',
#   'Year': '2022',
#   'Director': 'Maryna Er Gorbach',
#   'Link': 'https://www.imdb.com/title/tt16315948/',
#   'Rating': '6.8',
#   'Wins': 51,
#   'Nominations': 29,
#   'Genres': ['Political Drama', 'Drama', 'War']},
#  {'Title': 'Alcarràs',
#   'Year': '2022',
#   'Director': 'Carla Simón',
#   'Link': 'https://www.imdb.com/title/tt11930126/',
#   'Rating': '7.0',
#   'Wins': 21,
#   'Nominations': 57,
#   'Genres': ['Drama']},
#  {'Title': 'Vesper',
#   'Year': '2022',
#   'Director': 'Kristina Buozyte',
#   'Link': 'https://www.imdb.com/title/tt20225374/',
#   'Rating': '6.0',
#   'Wins': 7,
#   'Nominations': 10,
#   'Genres': ['Adventure Epic', 'Cyberpunk', 'Adventure', 'Drama', 'Sci-Fi']},
#  {'Title': 'One Fine Morning',
#   'Year': '2022',
#   'Director': 'Mia Hansen-Løve',
#   'Link': 'https://www.imdb.com/title/tt13482828/',
#   'Rating': '6.9',
#   'Wins': 3,
#   'Nominations': 9,
#   'Genres': ['Drama', 'Romance']},
#  {'Title': 'Pray Away',
#   'Year': '2020',
#   'Director': 'Kristine Stolakis',
#   'Link': 'https://www.imdb.com/title/tt11224358/',
#   'Rating': '6.5',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': ['Faith & Spirituality Documentary', 'Documentary']},
#  {'Title': 'Shiva Baby',
#   'Year': '2020',
#   'Director': 'Emma Seligman',
#   'Link': 'https://www.imdb.com/title/tt11317142/',
#   'Rating': '7.1',
#   'Wins': 12,
#   'Nominations': 43,
#   'Genres': ['Dark Comedy',
#    'Psychological Drama',
#    'Raunchy Comedy',
#    'Comedy',
#    'Drama']},
#  {'Title': 'Together Together',
#   'Year': '2021',
#   'Director': 'Nikole Beckwith',
#   'Link': 'https://www.imdb.com/title/tt11285280/',
#   'Rating': '6.4',
#   'Wins': 2,
#   'Nominations': 8,
#   'Genres': ['Comedy', 'Drama']},
#  {'Title': 'V/H/S/94',
#   'Year': '2021',
#   'Director': 'Simon Barrett',
#   'Link': 'https://www.imdb.com/title/tt14867006/',
#   'Rating': '5.5',
#   'Wins': 1,
#   'Nominations': 1,
#   'Genres': ['Body Horror',
#    'Found Footage Horror',
#    'Monster Horror',
#    'Splatter Horror',
#    'Supernatural Horror',
#    'Vampire Horror',
#    'Zombie Horror',
#    'Horror',
#    'Mystery',
#    'Thriller']},
#  {'Title': 'Ailey',
#   'Year': '2021',
#   'Director': 'Jamila Wignot',
#   'Link': 'https://www.imdb.com/title/tt13622084/',
#   'Rating': '6.8',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': ['Biography', 'Documentary', 'History', 'Music']},
#  {'Title': 'Passing',
#   'Year': '2021',
#   'Director': 'Rebecca Hall',
#   'Link': 'https://www.imdb.com/title/tt8893974/',
#   'Rating': '6.6',
#   'Wins': 37,
#   'Nominations': 130,
#   'Genres': ['Period Drama', 'Drama', 'Mystery', 'Thriller']},
#  {'Title': 'The Souvenir Part II',
#   'Year': '2021',
#   'Director': 'Joanna Hogg',
#   'Link': 'https://www.imdb.com/title/tt6992978/',
#   'Rating': '7.1',
#   'Wins': 9,
#   'Nominations': 17,
#   'Genres': ['Coming-of-Age',
#    'Tragic Romance',
#    'Workplace Drama',
#    'Drama',
#    'Romance']},
#  {'Title': 'El Planeta',
#   'Year': '2021',
#   'Director': 'Amalia Ulman',
#   'Link': 'https://www.imdb.com/title/tt12788368/',
#   'Rating': '6.4',
#   'Wins': 11,
#   'Nominations': 14,
#   'Genres': ['Comedy', 'Drama']},
#  {'Title': 'Street Gang: How We Got to Sesame Street',
#   'Year': '2021',
#   'Director': 'Marilyn Agrelo',
#   'Link': 'https://www.imdb.com/title/tt5618690/',
#   'Rating': '8.0',
#   'Wins': 3,
#   'Nominations': 3,
#   'Genres': ['History Documentary', 'Documentary', 'Family', 'History']},
#  {'Title': 'Rita Moreno: Just a Girl Who Decided to Go For It',
#   'Year': '2021',
#   'Director': 'Mariem Pérez Riera',
#   'Link': 'https://www.imdb.com/title/tt10741846/',
#   'Rating': '7.6',
#   'Wins': 3,
#   'Nominations': 7,
#   'Genres': ['Biography', 'Documentary']},
#  {'Title': 'Plan B',
#   'Year': '2021',
#   'Director': 'Natalie Morales',
#   'Link': 'https://www.imdb.com/title/tt13172796/',
#   'Rating': '6.7',
#   'Wins': 2,
#   'Nominations': 3,
#   'Genres': ['Comedy']},
#  {'Title': 'In the Same Breath',
#   'Year': '2021',
#   'Director': 'Nanfu Wang',
#   'Link': 'https://www.imdb.com/title/tt13648230/',
#   'Rating': '7.5',
#   'Wins': 5,
#   'Nominations': 10,
#   'Genres': ['Documentary']},
#  {'Title': 'The Novice',
#   'Year': '2021',
#   'Director': 'Lauren Hadaway',
#   'Link': 'https://www.imdb.com/title/tt11131464/',
#   'Rating': '6.5',
#   'Wins': 4,
#   'Nominations': 11,
#   'Genres': ['Psychological Drama', 'Water Sport', 'Drama', 'Sport']},
#  {'Title': "I'm Your Man",
#   'Year': '2021',
#   'Director': 'Maria Schrader',
#   'Link': 'https://www.imdb.com/title/tt13087796/',
#   'Rating': '7.1',
#   'Wins': 10,
#   'Nominations': 15,
#   'Genres': ['Artificial Intelligence',
#    'Romantic Comedy',
#    'Comedy',
#    'Drama',
#    'Romance',
#    'Sci-Fi']},
#  {'Title': 'Petite Maman',
#   'Year': '2021',
#   'Director': 'Céline Sciamma',
#   'Link': 'https://www.imdb.com/title/tt13204490/',
#   'Rating': '7.4',
#   'Wins': 9,
#   'Nominations': 37,
#   'Genres': ['Coming-of-Age', 'Drama', 'Fantasy']},
#  {'Title': 'The Rescue',
#   'Year': '2021',
#   'Director': 'Elizabeth Chai Vasarhelyi',
#   'Link': 'https://www.imdb.com/title/tt9098872/',
#   'Rating': '8.3',
#   'Wins': 16,
#   'Nominations': 40,
#   'Genres': ['Nature Documentary',
#    'Suspense Mystery',
#    'Action',
#    'Documentary',
#    'Mystery',
#    'Thriller']},
#  {'Title': 'Attica',
#   'Year': '2021',
#   'Director': 'Stanley Nelson',
#   'Link': 'https://www.imdb.com/title/tt12482898/',
#   'Rating': '7.5',
#   'Wins': 2,
#   'Nominations': 14,
#   'Genres': ['Documentary', 'History']},
#  {'Title': 'Becoming Cousteau',
#   'Year': '2021',
#   'Director': 'Liz Garbus',
#   'Link': 'https://www.imdb.com/title/tt10334438/',
#   'Rating': '7.1',
#   'Wins': 2,
#   'Nominations': 13,
#   'Genres': ['Adventure', 'Biography', 'Documentary']},
#  {'Title': 'Julia',
#   'Year': '2021',
#   'Director': 'Julie Cohen',
#   'Link': 'https://www.imdb.com/title/tt13782428/',
#   'Rating': '7.6',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': ['Food Documentary', 'Biography', 'Documentary']},
#  {'Title': 'Hive',
#   'Year': '2021',
#   'Director': 'Blerta Basholli',
#   'Link': 'https://www.imdb.com/title/tt13648212/',
#   'Rating': '7.1',
#   'Wins': 21,
#   'Nominations': 15,
#   'Genres': ['Drama']},
#  {'Title': 'Woodlands Dark and Days Bewitched: A History of Folk Horror',
#   'Year': '2021',
#   'Director': 'Kier-La Janisse',
#   'Link': 'https://www.imdb.com/title/tt13938338/',
#   'Rating': '7.6',
#   'Wins': 4,
#   'Nominations': 2,
#   'Genres': ['Faith & Spirituality Documentary',
#    'Folk Horror',
#    'Supernatural Horror',
#    'Documentary',
#    'Horror']},
#  {'Title': 'CODA',
#   'Year': '2021',
#   'Director': 'Sian Heder',
#   'Link': 'https://www.imdb.com/title/tt10366460/',
#   'Rating': '8.0',
#   'Wins': 69,
#   'Nominations': 150,
#   'Genres': ['Coming-of-Age', 'Comedy', 'Drama', 'Music']},
#  {'Title': 'The Power of the Dog',
#   'Year': '2021',
#   'Director': 'Jane Campion',
#   'Link': 'https://www.imdb.com/title/tt10293406/',
#   'Rating': '6.8',
#   'Wins': 287,
#   'Nominations': 324,
#   'Genres': ['Period Drama', 'Psychological Drama', 'Drama', 'Western']},
#  {'Title': 'Happening',
#   'Year': '2021',
#   'Director': 'Audrey Diwan',
#   'Link': 'https://www.imdb.com/title/tt13880104/',
#   'Rating': '7.4',
#   'Wins': 27,
#   'Nominations': 49,
#   'Genres': ['Coming-of-Age', 'Period Drama', 'Drama']},
#  {'Title': 'Hellbender',
#   'Year': '2021',
#   'Director': 'John Adams',
#   'Link': 'https://www.imdb.com/title/tt14905650/',
#   'Rating': '5.8',
#   'Wins': 3,
#   'Nominations': 3,
#   'Genres': ['Folk Horror', 'Horror']},
#  {'Title': 'Neptune Frost',
#   'Year': '2021',
#   'Director': 'Saul Williams',
#   'Link': 'https://www.imdb.com/title/tt11873472/',
#   'Rating': '6.5',
#   'Wins': 3,
#   'Nominations': 17,
#   'Genres': ['Musical', 'Sci-Fi']},
#  {'Title': 'The Pink Cloud',
#   'Year': '2021',
#   'Director': 'Iuli Gerbase',
#   'Link': 'https://www.imdb.com/title/tt3548874/',
#   'Rating': '6.0',
#   'Wins': 5,
#   'Nominations': 19,
#   'Genres': ['Drama', 'Sci-Fi']},
#  {'Title': 'The Fallout',
#   'Year': '2021',
#   'Director': 'Megan Park',
#   'Link': 'https://www.imdb.com/title/tt11847410/',
#   'Rating': '7.0',
#   'Wins': 6,
#   'Nominations': 8,
#   'Genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'Title': "We're All Going to the World's Fair",
#   'Year': '2021',
#   'Director': 'Jane Schoenbrun',
#   'Link': 'https://www.imdb.com/title/tt13648224/',
#   'Rating': '5.4',
#   'Wins': 4,
#   'Nominations': 23,
#   'Genres': ['Coming-of-Age', 'Supernatural Horror', 'Drama', 'Horror']},
#  {'Title': 'Murina',
#   'Year': '2021',
#   'Director': 'Antoneta Alamat Kusijanovic',
#   'Link': 'https://www.imdb.com/title/tt8434110/',
#   'Rating': '6.8',
#   'Wins': 9,
#   'Nominations': 18,
#   'Genres': ['Coming-of-Age', 'Drama']},
#  {'Title': 'Anaïs in Love',
#   'Year': '2021',
#   'Director': 'Charline Bourgeois-Tacquet',
#   'Link': 'https://www.imdb.com/title/tt13142240/',
#   'Rating': '6.4',
#   'Wins': 3,
#   'Nominations': 5,
#   'Genres': ['Comedy', 'Drama', 'Romance']},
#  {'Title': 'Clara Sola',
#   'Year': '2021',
#   'Director': 'Nathalie Álvarez Mesén',
#   'Link': 'https://www.imdb.com/title/tt12637442/',
#   'Rating': '6.7',
#   'Wins': 20,
#   'Nominations': 23,
#   'Genres': ['Drama', 'Fantasy']},
#  {'Title': 'The Forty-Year-Old Version',
#   'Year': '2020',
#   'Director': 'Radha Blank',
#   'Link': 'https://www.imdb.com/title/tt10642834/',
#   'Rating': '7.2',
#   'Wins': 23,
#   'Nominations': 43,
#   'Genres': ['Comedy', 'Drama']},
#  {'Title': 'Totally Under Control',
#   'Year': '2020',
#   'Director': 'Alex Gibney',
#   'Link': 'https://www.imdb.com/title/tt13065386/',
#   'Rating': '7.6',
#   'Wins': 2,
#   'Nominations': 8,
#   'Genres': ['Documentary']},
#  {'Title': 'Miss Juneteenth',
#   'Year': '2020',
#   'Director': 'Channing Godfrey Peoples',
#   'Link': 'https://www.imdb.com/title/tt11394158/',
#   'Rating': '6.5',
#   'Wins': 9,
#   'Nominations': 34,
#   'Genres': ['Drama']},
#  {'Title': 'Kajillionaire',
#   'Year': '2020',
#   'Director': 'Miranda July',
#   'Link': 'https://www.imdb.com/title/tt8143990/',
#   'Rating': '6.4',
#   'Wins': 4,
#   'Nominations': 9,
#   'Genres': ['Coming-of-Age', 'Quirky Comedy', 'Comedy', 'Crime', 'Drama']},
#  {'Title': 'Never Rarely Sometimes Always',
#   'Year': '2020',
#   'Director': 'Eliza Hittman',
#   'Link': 'https://www.imdb.com/title/tt7772582/',
#   'Rating': '7.4',
#   'Wins': 30,
#   'Nominations': 119,
#   'Genres': ['Coming-of-Age', 'Drama']},
#  {'Title': 'Athlete A',
#   'Year': '2020',
#   'Director': 'Bonni Cohen',
#   'Link': 'https://www.imdb.com/title/tt11905462/',
#   'Rating': '7.6',
#   'Wins': 4,
#   'Nominations': 10,
#   'Genres': ['Crime Documentary',
#    'Sports Documentary',
#    'Crime',
#    'Documentary',
#    'Sport']},
#  {'Title': 'Mucho Mucho Amor: The Legend of Walter Mercado',
#   'Year': '2020',
#   'Director': 'Cristina Constantini',
#   'Link': 'https://www.imdb.com/title/tt11378264/',
#   'Rating': '7.3',
#   'Wins': 4,
#   'Nominations': 9,
#   'Genres': ['Biography', 'Documentary']},
#  {'Title': 'All In: The Fight for Democracy',
#   'Year': '2020',
#   'Director': 'Lisa Cortes',
#   'Link': 'https://www.imdb.com/title/tt12538822/',
#   'Rating': '6.9',
#   'Wins': 6,
#   'Nominations': 16,
#   'Genres': ['Political Documentary', 'Documentary']},
#  {'Title': 'Dick Johnson Is Dead',
#   'Year': '2020',
#   'Director': 'Kirsten Johnson',
#   'Link': 'https://www.imdb.com/title/tt11394180/',
#   'Rating': '7.4',
#   'Wins': 19,
#   'Nominations': 42,
#   'Genres': ['Biography', 'Documentary', 'Drama']},
#  {'Title': 'Relic',
#   'Year': '2020',
#   'Director': 'Natalie Erika James',
#   'Link': 'https://www.imdb.com/title/tt9072352/',
#   'Rating': '6.0',
#   'Wins': 5,
#   'Nominations': 29,
#   'Genres': ['Psychological Drama',
#    'Supernatural Horror',
#    'Drama',
#    'Horror',
#    'Mystery',
#    'Thriller']},
#  {'Title': 'One Night in Miami',
#   'Year': '2020',
#   'Director': 'Regina King',
#   'Link': 'https://www.imdb.com/title/tt10612922/',
#   'Rating': '7.1',
#   'Wins': 70,
#   'Nominations': 185,
#   'Genres': ['Drama']},
#  {'Title': 'Les Nôtres',
#   'Year': '2020',
#   'Director': 'Jeanne Leblanc',
#   'Link': 'https://www.imdb.com/title/tt8724130/',
#   'Rating': '6.4',
#   'Wins': 3,
#   'Nominations': 7,
#   'Genres': ['Drama']},
#  {'Title': 'Beginning',
#   'Year': '2020',
#   'Director': 'Dea Kulumbegashvili',
#   'Link': 'https://www.imdb.com/title/tt12444572/',
#   'Rating': '6.6',
#   'Wins': 12,
#   'Nominations': 16,
#   'Genres': ['Drama']},
#  {'Title': 'Beans',
#   'Year': '2020',
#   'Director': 'Tracey Deer',
#   'Link': 'https://www.imdb.com/title/tt11735544/',
#   'Rating': '7.0',
#   'Wins': 16,
#   'Nominations': 21,
#   'Genres': ['Drama']},
#  {'Title': 'Truman & Tennessee: An Intimate Conversation',
#   'Year': '2020',
#   'Director': 'Lisa Immordino Vreeland',
#   'Link': 'https://www.imdb.com/title/tt13016030/',
#   'Rating': '7.2',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': ['Documentary']},
#  {'Title': 'Holler',
#   'Year': '2020',
#   'Director': 'Nicole Riegel',
#   'Link': 'https://www.imdb.com/title/tt6763778/',
#   'Rating': '6.2',
#   'Wins': 4,
#   'Nominations': 5,
#   'Genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'Title': 'My Octopus Teacher',
#   'Year': '2020',
#   'Director': 'Pippa Ehrlich',
#   'Link': 'https://www.imdb.com/title/tt12888462/',
#   'Rating': '8.1',
#   'Wins': 11,
#   'Nominations': 16,
#   'Genres': ['Nature Documentary', 'Documentary', 'Drama']},
#  {'Title': 'True Mothers',
#   'Year': '2020',
#   'Director': 'Naomi Kawase',
#   'Link': 'https://www.imdb.com/title/tt10418630/',
#   'Rating': '7.0',
#   'Wins': 5,
#   'Nominations': 14,
#   'Genres': ['Drama']},
#  {'Title': 'Wildfire',
#   'Year': '2020',
#   'Director': 'Cathy Brady',
#   'Link': 'https://www.imdb.com/title/tt9180460/',
#   'Rating': '6.2',
#   'Wins': 3,
#   'Nominations': 7,
#   'Genres': ['Drama']},
#  {'Title': 'Wildland',
#   'Year': '2020',
#   'Director': 'Jeanette Nordahl',
#   'Link': 'https://www.imdb.com/title/tt8386958/',
#   'Rating': '5.8',
#   'Wins': 2,
#   'Nominations': 19,
#   'Genres': ['Crime', 'Drama', 'Thriller']},
#  {'Title': 'Lucky',
#   'Year': '2020',
#   'Director': 'Natasha Kermani',
#   'Link': 'https://www.imdb.com/title/tt11701774/',
#   'Rating': '4.9',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': ['Drama', 'Fantasy', 'Horror', 'Thriller']},
#  {'Title': 'Never Gonna Snow Again',
#   'Year': '2020',
#   'Director': 'Małgorzata Szumowska',
#   'Link': 'https://www.imdb.com/title/tt9526784/',
#   'Rating': '6.4',
#   'Wins': 3,
#   'Nominations': 23,
#   'Genres': ['Dark Comedy', 'Satire', 'Comedy', 'Drama', 'Mystery']},
#  {'Title': 'Jimmy Carter: Rock & Roll President',
#   'Year': '2020',
#   'Director': 'Mary Wharton',
#   'Link': 'https://www.imdb.com/title/tt11804758/',
#   'Rating': '7.6',
#   'Wins': 3,
#   'Nominations': 4,
#   'Genres': ['Documentary', 'History', 'Music']},
#  {'Title': 'Spring Blossom',
#   'Year': '2020',
#   'Director': 'Suzanne Lindon',
#   'Link': 'https://www.imdb.com/title/tt12444426/',
#   'Rating': '5.8',
#   'Wins': 1,
#   'Nominations': 11,
#   'Genres': ['Drama', 'Romance']},
#  {'Title': 'I Carry You With Me',
#   'Year': '2020',
#   'Director': 'Heidi Ewing',
#   'Link': 'https://www.imdb.com/title/tt11388990/',
#   'Rating': '6.7',
#   'Wins': 5,
#   'Nominations': 25,
#   'Genres': ['Drama']},
#  {'Title': 'Slaxx',
#   'Year': '2020',
#   'Director': 'Elza Kephart',
#   'Link': 'https://www.imdb.com/title/tt9741310/',
#   'Rating': '5.4',
#   'Wins': 1,
#   'Nominations': 1,
#   'Genres': ['Comedy', 'Horror']},
#  {'Title': 'Identifying Features',
#   'Year': '2020',
#   'Director': 'Fernanda Valadez',
#   'Link': 'https://www.imdb.com/title/tt11394282/',
#   'Rating': '7.3',
#   'Wins': 45,
#   'Nominations': 27,
#   'Genres': ['Drama']},
#  {'Title': 'Quo Vadis, Aida?',
#   'Year': '2020',
#   'Director': 'Jasmila Zbanic',
#   'Link': 'https://www.imdb.com/title/tt8633462/',
#   'Rating': '8.0',
#   'Wins': 40,
#   'Nominations': 43,
#   'Genres': ['Tragedy', 'Drama', 'History', 'War']},
#  {'Title': 'The Stylist',
#   'Year': '2020',
#   'Director': 'Jill Gevargizian',
#   'Link': 'https://www.imdb.com/title/tt11056910/',
#   'Rating': '5.6',
#   'Wins': 4,
#   'Nominations': 5,
#   'Genres': ['Body Horror', 'Drama', 'Horror']},
#  {'Title': 'Slalom',
#   'Year': '2020',
#   'Director': 'Charlène Favier',
#   'Link': 'https://www.imdb.com/title/tt9697780/',
#   'Rating': '6.6',
#   'Wins': 6,
#   'Nominations': 16,
#   'Genres': ['Coming-of-Age',
#    'Psychological Drama',
#    'Teen Drama',
#    'Drama',
#    'Sport']},
#  {'Title': 'Nomadland',
#   'Year': '2020',
#   'Director': 'Chloé Zhao',
#   'Link': 'https://www.imdb.com/title/tt9770150/',
#   'Rating': '7.3',
#   'Wins': 258,
#   'Nominations': 159,
#   'Genres': ['Road Trip', 'Tragedy', 'Drama']},
#  {'Title': 'Promising Young Woman',
#   'Year': '2020',
#   'Director': 'Emerald Fennell',
#   'Link': 'https://www.imdb.com/title/tt9620292/',
#   'Rating': '7.5',
#   'Wins': 118,
#   'Nominations': 201,
#   'Genres': ['Psychological Thriller',
#    'Suspense Mystery',
#    'Tragedy',
#    'Crime',
#    'Drama',
#    'Mystery',
#    'Thriller']},
#  {'Title': 'Stray',
#   'Year': '2021',
#   'Director': 'Elizabeth Lo',
#   'Link': 'https://www.imdb.com/title/tt11905922/',
#   'Rating': '6.9',
#   'Wins': 2,
#   'Nominations': 10,
#   'Genres': ['Documentary']},
#  {'Title': 'Gagarine',
#   'Year': '2020',
#   'Director': 'Fanny Liatard',
#   'Link': 'https://www.imdb.com/title/tt12444424/',
#   'Rating': '6.7',
#   'Wins': 7,
#   'Nominations': 15,
#   'Genres': ['Drama', 'Fantasy']},
#  {'Title': 'Tove',
#   'Year': '2020',
#   'Director': 'Zaida Bergroth',
#   'Link': 'https://www.imdb.com/title/tt11007444/',
#   'Rating': '6.8',
#   'Wins': 11,
#   'Nominations': 6,
#   'Genres': ['Period Drama', 'Biography', 'Drama']},
#  {'Title': 'Sword of Trust',
#   'Year': '2019',
#   'Director': 'Lynn Shelton',
#   'Link': 'https://www.imdb.com/title/tt36170772/',
#   'Rating': 'N/A',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': []},
#  {'Title': 'Sword of Trust',
#   'Year': '2019',
#   'Director': 'Lynn Shelton',
#   'Link': 'https://www.imdb.com/title/tt36170772/',
#   'Rating': 'N/A',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': []},
#  {'Title': 'Honey Boy',
#   'Year': '2019',
#   'Director': "Alma Har'el",
#   'Link': 'https://www.imdb.com/title/tt8151874/',
#   'Rating': '7.2',
#   'Wins': 10,
#   'Nominations': 41,
#   'Genres': ['Coming-of-Age', 'Drama']},
#  {'Title': 'Raise Hell: The Life & Times of Molly Ivins',
#   'Year': '2019',
#   'Director': 'Janice Engel',
#   'Link': 'https://www.imdb.com/title/tt9129296/',
#   'Rating': '8.0',
#   'Wins': 4,
#   'Nominations': 2,
#   'Genres': ['Documentary']},
#  {'Title': 'The Mustang',
#   'Year': '2019',
#   'Director': 'Laure de Clermont-Tonnerre',
#   'Link': 'https://www.imdb.com/title/tt5952594/',
#   'Rating': '6.8',
#   'Wins': 6,
#   'Nominations': 10,
#   'Genres': ['Prison Drama', 'Psychological Drama', 'Drama']},
#  {'Title': 'A Beautiful Day in the Neighborhood',
#   'Year': '2019',
#   'Director': 'Marielle Heller',
#   'Link': 'https://www.imdb.com/title/tt3224458/',
#   'Rating': '7.2',
#   'Wins': 10,
#   'Nominations': 64,
#   'Genres': ['Docudrama', 'Biography', 'Drama', 'Family']},
#  {'Title': 'Little Women',
#   'Year': '2019',
#   'Director': 'Greta Gerwig',
#   'Link': 'https://www.imdb.com/title/tt3281548/',
#   'Rating': '7.8',
#   'Wins': 78,
#   'Nominations': 239,
#   'Genres': ['Coming-of-Age',
#    'Costume Drama',
#    'Holiday Romance',
#    'Period Drama',
#    'Teen Drama',
#    'Teen Romance',
#    'Drama',
#    'Romance']},
#  {'Title': 'Hail Satan?',
#   'Year': '2019',
#   'Director': 'Penny Lane',
#   'Link': 'https://www.imdb.com/title/tt9358044/',
#   'Rating': '7.3',
#   'Wins': 5,
#   'Nominations': 20,
#   'Genres': ['Faith & Spirituality Documentary', 'Documentary']},
#  {'Title': 'American Factory',
#   'Year': '2019',
#   'Director': 'Steven Bognar',
#   'Link': 'https://www.imdb.com/title/tt9351980/',
#   'Rating': '7.4',
#   'Wins': 19,
#   'Nominations': 50,
#   'Genres': ['Science & Technology Documentary', 'Documentary']},
#  {'Title': 'Booksmart',
#   'Year': '2019',
#   'Director': 'Olivia Wilde',
#   'Link': 'https://www.imdb.com/title/tt1489887/',
#   'Rating': '7.1',
#   'Wins': 29,
#   'Nominations': 61,
#   'Genres': ['Buddy Comedy', 'Coming-of-Age', 'Teen Comedy', 'Comedy']},
#  {'Title': 'Making Waves: The Art of Cinematic Sound',
#   'Year': '2019',
#   'Director': 'Midge Costin',
#   'Link': 'https://www.imdb.com/title/tt3856408/',
#   'Rating': '7.6',
#   'Wins': 1,
#   'Nominations': 10,
#   'Genres': ['Documentary', 'History']},
#  {'Title': 'The Kingmaker',
#   'Year': '2019',
#   'Director': 'Lauren Greenfield',
#   'Link': 'https://www.imdb.com/title/tt5105734/',
#   'Rating': '7.6',
#   'Wins': 2,
#   'Nominations': 14,
#   'Genres': ['History Documentary', 'Biography', 'Documentary', 'History']},
#  {'Title': 'The Farewell',
#   'Year': '2019',
#   'Director': 'Lulu Wang',
#   'Link': 'https://www.imdb.com/title/tt8637428/',
#   'Rating': '7.5',
#   'Wins': 37,
#   'Nominations': 194,
#   'Genres': ['Coming-of-Age', 'Quirky Comedy', 'Comedy', 'Drama']},
#  {'Title': 'One Child Nation',
#   'Year': '2019',
#   'Director': 'Nanfu Wang',
#   'Link': 'https://www.imdb.com/title/tt8923482/',
#   'Rating': '7.5',
#   'Wins': 10,
#   'Nominations': 50,
#   'Genres': ['Documentary', 'History']},
#  {'Title': 'For Sama',
#   'Year': '2019',
#   'Director': 'Edward Watts',
#   'Link': 'https://www.imdb.com/title/tt9617456/',
#   'Rating': '8.5',
#   'Wins': 71,
#   'Nominations': 52,
#   'Genres': ['Military Documentary', 'Biography', 'Documentary', 'War']},
#  {'Title': 'Atlantics',
#   'Year': '2019',
#   'Director': 'Mati Diop',
#   'Link': 'https://www.imdb.com/title/tt10199586/',
#   'Rating': '6.7',
#   'Wins': 13,
#   'Nominations': 64,
#   'Genres': ['Drama', 'Fantasy', 'Mystery', 'Romance']},
#  {'Title': 'Varda by Agnès',
#   'Year': '2019',
#   'Director': 'Agnès Varda',
#   'Link': 'https://www.imdb.com/title/tt9530198/',
#   'Rating': '7.8',
#   'Wins': 2,
#   'Nominations': 3,
#   'Genres': ['Biography', 'Documentary']},
#  {'Title': 'Mickey and the Bear',
#   'Year': '2019',
#   'Director': 'Annabelle Attanasio',
#   'Link': 'https://www.imdb.com/title/tt9614440/',
#   'Rating': '6.6',
#   'Wins': 5,
#   'Nominations': 15,
#   'Genres': ['Drama']},
#  {'Title': 'Honeyland',
#   'Year': '2019',
#   'Director': 'Ljubo Stefanov',
#   'Link': 'https://www.imdb.com/title/tt8991268/',
#   'Rating': '8.0',
#   'Wins': 37,
#   'Nominations': 55,
#   'Genres': ['Documentary', 'Drama']},
#  {'Title': 'Portrait of a Lady on Fire',
#   'Year': '2019',
#   'Director': 'Céline Sciamma',
#   'Link': 'https://www.imdb.com/title/tt8613070/',
#   'Rating': '8.1',
#   'Wins': 60,
#   'Nominations': 164,
#   'Genres': ['Steamy Romance', 'Drama', 'Romance']},
#  {'Title': 'The Assistant',
#   'Year': '2019',
#   'Director': 'Kitty Green',
#   'Link': 'https://www.imdb.com/title/tt9000224/',
#   'Rating': '6.3',
#   'Wins': 5,
#   'Nominations': 25,
#   'Genres': ['Workplace Drama', 'Drama']},
#  {'Title': 'Hope',
#   'Year': '2019',
#   'Director': 'Maria Sødahl',
#   'Link': 'https://www.imdb.com/title/tt9145334/',
#   'Rating': '7.7',
#   'Wins': 1,
#   'Nominations': 7,
#   'Genres': ['Feel-Good Romance',
#    'Period Drama',
#    'Drama',
#    'Romance',
#    'Western']},
#  {'Title': 'Saint Maud',
#   'Year': '2019',
#   'Director': 'Rose Glass',
#   'Link': 'https://www.imdb.com/title/tt7557108/',
#   'Rating': '6.7',
#   'Wins': 11,
#   'Nominations': 33,
#   'Genres': ['Psychological Horror',
#    'Psychological Thriller',
#    'Suspense Mystery',
#    'Tragedy',
#    'Drama',
#    'Horror',
#    'Mystery',
#    'Thriller']},
#  {'Title': 'First Cow',
#   'Year': '2019',
#   'Director': 'Kelly Reichardt',
#   'Link': 'https://www.imdb.com/title/tt9231040/',
#   'Rating': '7.1',
#   'Wins': 28,
#   'Nominations': 158,
#   'Genres': ['Classical Western', 'Period Drama', 'Drama', 'Western']},
#  {'Title': 'Blow the Man Down',
#   'Year': '2019',
#   'Director': 'Bridget Savage Cole',
#   'Link': 'https://www.imdb.com/title/tt8299768/',
#   'Rating': '6.4',
#   'Wins': 1,
#   'Nominations': 13,
#   'Genres': ['Dark Comedy',
#    'Comedy',
#    'Crime',
#    'Drama',
#    'Mystery',
#    'Thriller']},
#  {'Title': 'The Long Walk',
#   'Year': '2019',
#   'Director': 'Mattie Do',
#   'Link': 'https://www.imdb.com/title/tt6800268/',
#   'Rating': '6.9',
#   'Wins': 5,
#   'Nominations': 4,
#   'Genres': ['Drama', 'Horror', 'Mystery', 'Sci-Fi']},
#  {'Title': 'Science Fair',
#   'Year': '2018',
#   'Director': 'Cristina Costantini',
#   'Link': 'https://www.imdb.com/title/tt7153434/',
#   'Rating': '7.5',
#   'Wins': 15,
#   'Nominations': 9,
#   'Genres': ['Science & Technology Documentary', 'Documentary']},
#  {'Title': 'Free Solo',
#   'Year': '2018',
#   'Director': 'Elizabeth Chai Vasarhelyi',
#   'Link': 'https://www.imdb.com/title/tt7775622/',
#   'Rating': '8.1',
#   'Wins': 31,
#   'Nominations': 54,
#   'Genres': ['Extreme Sport',
#    'Mountain Adventure',
#    'Sports Documentary',
#    'Adventure',
#    'Documentary',
#    'Sport']},
#  {'Title': 'On Her Shoulders',
#   'Year': '2018',
#   'Director': 'Alexandria Bombach',
#   'Link': 'https://www.imdb.com/title/tt7689484/',
#   'Rating': '7.3',
#   'Wins': 13,
#   'Nominations': 17,
#   'Genres': ['Biography', 'Documentary']},
#  {'Title': 'Rafiki',
#   'Year': '2018',
#   'Director': 'Wanuri Kahiu',
#   'Link': 'https://www.imdb.com/title/tt8286894/',
#   'Rating': '6.8',
#   'Wins': 19,
#   'Nominations': 26,
#   'Genres': ['Drama', 'Romance']},
#  {'Title': "To All the Boys I've Loved Before",
#   'Year': '2018',
#   'Director': 'Susan Johnson',
#   'Link': 'https://www.imdb.com/title/tt3846674/',
#   'Rating': '7.0',
#   'Wins': 5,
#   'Nominations': 11,
#   'Genres': ['Romantic Comedy',
#    'Teen Comedy',
#    'Teen Drama',
#    'Teen Romance',
#    'Comedy',
#    'Drama',
#    'Romance']},
#  {'Title': 'Dark Money',
#   'Year': '2018',
#   'Director': 'Kimberly Reed',
#   'Link': 'https://www.imdb.com/title/tt6633182/',
#   'Rating': '7.1',
#   'Wins': 4,
#   'Nominations': 14,
#   'Genres': ['Political Documentary', 'Documentary']},
#  {'Title': 'Kusama: Infinity',
#   'Year': '2018',
#   'Director': 'Heather Lenz',
#   'Link': 'https://www.imdb.com/title/tt1893269/',
#   'Rating': '7.3',
#   'Wins': 1,
#   'Nominations': 7,
#   'Genres': ['Documentary']},
#  {'Title': 'Little Woods',
#   'Year': '2018',
#   'Director': 'Nia DaCosta',
#   'Link': 'https://www.imdb.com/title/tt6418918/',
#   'Rating': '6.2',
#   'Wins': 6,
#   'Nominations': 6,
#   'Genres': ['Crime', 'Drama', 'Western']},
#  {'Title': 'Private Life',
#   'Year': '2018',
#   'Director': 'Tamara Jenkins',
#   'Link': 'https://www.imdb.com/title/tt5536610/',
#   'Rating': '7.2',
#   'Wins': 1,
#   'Nominations': 19,
#   'Genres': ['Quirky Comedy', 'Comedy', 'Drama']},
#  {'Title': 'Be Natural: The Untold Story of Alice Guy-Blaché',
#   'Year': '2018',
#   'Director': 'Pamela B. Green',
#   'Link': 'https://www.imdb.com/title/tt3146022/',
#   'Rating': '7.7',
#   'Wins': 11,
#   'Nominations': 11,
#   'Genres': ['Biography', 'Documentary', 'History']},
#  {'Title': 'Birds of Passage',
#   'Year': '2018',
#   'Director': 'Cristina Gallego',
#   'Link': 'https://www.imdb.com/title/tt6386748/',
#   'Rating': '7.5',
#   'Wins': 30,
#   'Nominations': 42,
#   'Genres': ['Crime', 'Drama']},
#  {'Title': 'RBG',
#   'Year': '2018',
#   'Director': 'Betsy West',
#   'Link': 'https://www.imdb.com/title/tt7689964/',
#   'Rating': '7.6',
#   'Wins': 13,
#   'Nominations': 51,
#   'Genres': ['Political Documentary', 'Biography', 'Documentary']},
#  {'Title': 'Pick of the Litter',
#   'Year': '2018',
#   'Director': 'Dana Nachman',
#   'Link': 'https://www.imdb.com/title/tt5644050/',
#   'Rating': '7.6',
#   'Wins': 8,
#   'Nominations': 4,
#   'Genres': ['Documentary']},
#  {'Title': 'The Chambermaid',
#   'Year': '2018',
#   'Director': 'Lila Avilés',
#   'Link': 'https://www.imdb.com/title/tt8331988/',
#   'Rating': '7.0',
#   'Wins': 13,
#   'Nominations': 36,
#   'Genres': ['Drama']},
#  {'Title': 'Can You Ever Forgive Me?',
#   'Year': '2018',
#   'Director': 'Marielle Heller',
#   'Link': 'https://www.imdb.com/title/tt4595882/',
#   'Rating': '7.1',
#   'Wins': 54,
#   'Nominations': 102,
#   'Genres': ['Docudrama',
#    'Period Drama',
#    'True Crime',
#    'Biography',
#    'Comedy',
#    'Crime',
#    'Drama']},
#  {'Title': 'Too Late to Die Young',
#   'Year': '2018',
#   'Director': 'Dominga Sotomayor',
#   'Link': 'https://www.imdb.com/title/tt8726098/',
#   'Rating': '6.4',
#   'Wins': 6,
#   'Nominations': 17,
#   'Genres': ['Drama']},
#  {'Title': 'Leave No Trace',
#   'Year': '2018',
#   'Director': 'Debra Granik',
#   'Link': 'https://www.imdb.com/title/tt3892172/',
#   'Rating': '7.1',
#   'Wins': 18,
#   'Nominations': 92,
#   'Genres': ['Adventure', 'Drama']},
#  {'Title': 'Night Comes On',
#   'Year': '2018',
#   'Director': 'Jordana Spiro',
#   'Link': 'https://www.imdb.com/title/tt7184124/',
#   'Rating': '6.7',
#   'Wins': 9,
#   'Nominations': 6,
#   'Genres': ['Drama']},
#  {'Title': 'Wonder Woman',
#   'Year': '2017',
#   'Director': 'Patty Jenkins',
#   'Link': 'https://www.imdb.com/title/tt0451279/',
#   'Rating': '7.3',
#   'Wins': 38,
#   'Nominations': 75,
#   'Genres': ['Superhero', 'Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'War']},
#  {'Title': 'Most Beautiful Island',
#   'Year': '2017',
#   'Director': 'Ana Asensio',
#   'Link': 'https://www.imdb.com/title/tt4866448/',
#   'Rating': '5.7',
#   'Wins': 3,
#   'Nominations': 6,
#   'Genres': ['Drama', 'Horror', 'Thriller']},
#  {'Title': 'School Life',
#   'Year': '2017',
#   'Director': 'David Rane',
#   'Link': 'https://www.imdb.com/title/tt6330246/',
#   'Rating': '6.9',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': ['Comedy', 'Drama', 'Family']},
#  {'Title': 'The Breadwinner',
#   'Year': '2017',
#   'Director': 'Nora Twomey',
#   'Link': 'https://www.imdb.com/title/tt3901826/',
#   'Rating': '7.7',
#   'Wins': 24,
#   'Nominations': 55,
#   'Genres': ['Coming-of-Age',
#    'Tragedy',
#    'Animation',
#    'Drama',
#    'Family',
#    'War']},
#  {'Title': 'Bombshell: The Hedy Lamarr Story',
#   'Year': '2017',
#   'Director': 'Alexandra Dean',
#   'Link': 'https://www.imdb.com/title/tt6752848/',
#   'Rating': '7.4',
#   'Wins': 8,
#   'Nominations': 5,
#   'Genres': ['Biography', 'Documentary', 'History', 'War']},
#  {'Title': 'Step',
#   'Year': '2017',
#   'Director': 'Amanda Lipitz',
#   'Link': 'https://www.imdb.com/title/tt5758404/',
#   'Rating': '7.0',
#   'Wins': 9,
#   'Nominations': 20,
#   'Genres': ['Documentary']},
#  {'Title': 'Mudbound',
#   'Year': '2017',
#   'Director': 'Dee Rees',
#   'Link': 'https://www.imdb.com/title/tt2396589/',
#   'Rating': '7.4',
#   'Wins': 36,
#   'Nominations': 117,
#   'Genres': ['Drama', 'War']},
#  {'Title': 'Whose Streets?',
#   'Year': '2017',
#   'Director': 'Sabaah Folayan',
#   'Link': 'https://www.imdb.com/title/tt6176928/',
#   'Rating': '6.0',
#   'Wins': 2,
#   'Nominations': 18,
#   'Genres': ['Documentary']},
#  {'Title': 'Good Manners',
#   'Year': '2017',
#   'Director': 'Juliana Rojas',
#   'Link': 'https://www.imdb.com/title/tt5480782/',
#   'Rating': '6.7',
#   'Wins': 32,
#   'Nominations': 34,
#   'Genres': ['Dark Fantasy', 'Werewolf Horror', 'Fantasy', 'Horror']},
#  {'Title': 'Trophy',
#   'Year': '2017',
#   'Director': 'Shaul Schwarz',
#   'Link': 'https://www.imdb.com/title/tt6333066/',
#   'Rating': '7.3',
#   'Wins': 2,
#   'Nominations': 6,
#   'Genres': ['Documentary']},
#  {'Title': 'Lady Bird',
#   'Year': '2017',
#   'Director': 'Greta Gerwig',
#   'Link': 'https://www.imdb.com/title/tt4925292/',
#   'Rating': '7.4',
#   'Wins': 124,
#   'Nominations': 228,
#   'Genres': ['Coming-of-Age',
#    'Quirky Comedy',
#    'Teen Comedy',
#    'Comedy',
#    'Drama']},
#  {'Title': 'Faces Places',
#   'Year': '2017',
#   'Director': 'Agnès Varda',
#   'Link': 'https://www.imdb.com/title/tt5598102/',
#   'Rating': '7.8',
#   'Wins': 36,
#   'Nominations': 41,
#   'Genres': ['Adventure', 'Documentary']},
#  {'Title': 'Outside In',
#   'Year': '2017',
#   'Director': 'Lynn Shelton',
#   'Link': 'https://www.imdb.com/title/tt7260048/',
#   'Rating': '6.7',
#   'Wins': 2,
#   'Nominations': 2,
#   'Genres': ['Drama']},
#  {'Title': 'Western',
#   'Year': '2017',
#   'Director': 'Valeska Grisebach',
#   'Link': 'https://www.imdb.com/title/tt5157326/',
#   'Rating': '7.0',
#   'Wins': 18,
#   'Nominations': 24,
#   'Genres': ['Drama']},
#  {'Title': 'The Rider',
#   'Year': '2017',
#   'Director': 'Chloé Zhao',
#   'Link': 'https://www.imdb.com/title/tt6217608/',
#   'Rating': '7.4',
#   'Wins': 25,
#   'Nominations': 59,
#   'Genres': ['Drama', 'Western']},
#  {'Title': 'Summer 1993',
#   'Year': '2017',
#   'Director': 'Carla Simón',
#   'Link': 'https://www.imdb.com/title/tt5897636/',
#   'Rating': '7.1',
#   'Wins': 38,
#   'Nominations': 58,
#   'Genres': ['Drama', 'Family']},
#  {'Title': 'Marlina the Murderer in Four Acts',
#   'Year': '2017',
#   'Director': 'Mouly Surya',
#   'Link': 'https://www.imdb.com/title/tt5923026/',
#   'Rating': '6.9',
#   'Wins': 27,
#   'Nominations': 41,
#   'Genres': ['Drama', 'Thriller', 'Western']},
#  {'Title': 'Tigers Are Not Afraid',
#   'Year': '2017',
#   'Director': 'Issa López',
#   'Link': 'https://www.imdb.com/title/tt4823434/',
#   'Rating': '6.9',
#   'Wins': 29,
#   'Nominations': 26,
#   'Genres': ['Supernatural Horror', 'Fantasy', 'Horror', 'Mystery']},
#  {'Title': 'Oh Lucy!',
#   'Year': '2017',
#   'Director': 'Atsuko Hirayanagi',
#   'Link': 'https://www.imdb.com/title/tt6343058/',
#   'Rating': '6.8',
#   'Wins': 3,
#   'Nominations': 8,
#   'Genres': ['Comedy', 'Drama', 'Romance']},
#  {'Title': 'Zama',
#   'Year': '2017',
#   'Director': 'Lucrecia Martel',
#   'Link': 'https://www.imdb.com/title/tt3409848/',
#   'Rating': '6.7',
#   'Wins': 42,
#   'Nominations': 48,
#   'Genres': ['Drama', 'History']},
#  {'Title': 'I Am Not a Witch',
#   'Year': '2017',
#   'Director': 'Rungano Nyoni',
#   'Link': 'https://www.imdb.com/title/tt6213284/',
#   'Rating': '6.9',
#   'Wins': 17,
#   'Nominations': 38,
#   'Genres': ['Comedy', 'Drama']},
#  {'Title': 'Sand Storm',
#   'Year': '2016',
#   'Director': 'Elite Zexer',
#   'Link': 'https://www.imdb.com/title/tt4365518/',
#   'Rating': '6.8',
#   'Wins': 15,
#   'Nominations': 19,
#   'Genres': ['Drama']},
#  {'Title': 'Toni Erdmann',
#   'Year': '2016',
#   'Director': 'Maren Ade',
#   'Link': 'https://www.imdb.com/title/tt4048272/',
#   'Rating': '7.3',
#   'Wins': 59,
#   'Nominations': 85,
# ...
#   'Director': 'Ana Lily Amirpour',
#   'Link': 'https://www.imdb.com/title/tt2326554/',
#   'Rating': '6.9',
#   'Wins': 9,
#   'Nominations': 23,
#   'Genres': ['Dark Romance',
#    'Vampire Horror',
#    'Drama',
#    'Horror',
#    'Romance',
#    'Thriller']},
#  {'Title': 'Citizenfour',
#   'Year': '2014',
#   'Director': 'Laura Poitras',
#   'Link': 'https://www.imdb.com/title/tt4044364/',
#   'Rating': '8.0',
#   'Wins': 44,
#   'Nominations': 40,
#   'Genres': ['History Documentary',
#    'Political Documentary',
#    'Biography',
#    'Documentary']},
#  {'Title': 'The Babadook',
#   'Year': '2014',
#   'Director': 'Jennifer Kent',
#   'Link': 'https://www.imdb.com/title/tt2321549/',
#   'Rating': '6.8',
#   'Wins': 56,
#   'Nominations': 64,
#   'Genres': ['Monster Horror',
#    'Psychological Horror',
#    'Supernatural Horror',
#    'Drama',
#    'Horror',
#    'Mystery']},
#  {'Title': 'Girlhood',
#   'Year': '2014',
#   'Director': 'Céline Sciamma',
#   'Link': 'https://www.imdb.com/title/tt3655522/',
#   'Rating': '6.9',
#   'Wins': 12,
#   'Nominations': 22,
#   'Genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'Title': 'The Wonders',
#   'Year': '2014',
#   'Director': 'Alice Rohrwacher',
#   'Link': 'https://www.imdb.com/title/tt3044244/',
#   'Rating': '6.7',
#   'Wins': 12,
#   'Nominations': 18,
#   'Genres': ['Drama']},
#  {'Title': 'Selma',
#   'Year': '2014',
#   'Director': 'Ava DuVernay',
#   'Link': 'https://www.imdb.com/title/tt1020072/',
#   'Rating': '7.5',
#   'Wins': 58,
#   'Nominations': 91,
#   'Genres': ['Docudrama', 'Period Drama', 'Biography', 'Drama', 'History']},
#  {'Title': 'Gett: The Trial of Viviane Amsalem',
#   'Year': '2014',
#   'Director': 'Ronit Elkabetz',
#   'Link': 'https://www.imdb.com/title/tt3062880/',
#   'Rating': '7.7',
#   'Wins': 15,
#   'Nominations': 19,
#   'Genres': ['Drama']},
#  {'Title': 'Appropriate Behavior',
#   'Year': '2014',
#   'Director': 'Desiree Akhavan',
#   'Link': 'https://www.imdb.com/title/tt3077108/',
#   'Rating': '6.5',
#   'Wins': 2,
#   'Nominations': 11,
#   'Genres': ['Comedy', 'Drama', 'Romance']},
#  {'Title': 'Enough Said',
#   'Year': '2013',
#   'Director': 'Nicole Holofcener',
#   'Link': 'https://www.imdb.com/title/tt2390361/',
#   'Rating': '7.0',
#   'Wins': 8,
#   'Nominations': 38,
#   'Genres': ['Romantic Comedy', 'Comedy', 'Drama', 'Romance']},
#  {'Title': 'Elaine Stritch: Shoot Me',
#   'Year': '2013',
#   'Director': 'Chiemi Karasawa',
#   'Link': 'https://www.imdb.com/title/tt2405792/',
#   'Rating': '7.5',
#   'Wins': 1,
#   'Nominations': 6,
#   'Genres': ['Documentary']},
#  {'Title': 'The Crash Reel',
#   'Year': '2013',
#   'Director': 'Lucy Walker',
#   'Link': 'https://www.imdb.com/title/tt2499076/',
#   'Rating': '8.2',
#   'Wins': 13,
#   'Nominations': 8,
#   'Genres': ['Sports Documentary', 'Biography', 'Documentary', 'Sport']},
#  {'Title': 'The Selfish Giant',
#   'Year': '2013',
#   'Director': 'Clio Barnard',
#   'Link': 'https://www.imdb.com/title/tt2304426/',
#   'Rating': '7.3',
#   'Wins': 12,
#   'Nominations': 21,
#   'Genres': ['Drama']},
#  {'Title': 'Blackfish',
#   'Year': '2013',
#   'Director': 'Gabriela Cowperthwaite',
#   'Link': 'https://www.imdb.com/title/tt2545118/',
#   'Rating': '8.1',
#   'Wins': 6,
#   'Nominations': 41,
#   'Genres': ['Crime Documentary',
#    'Nature Documentary',
#    'Documentary',
#    'Drama',
#    'Horror',
#    'Thriller']},
#  {'Title': 'The Square',
#   'Year': '2013',
#   'Director': 'Jehane Noujaim',
#   'Link': 'https://www.imdb.com/title/tt2486682/',
#   'Rating': '8.0',
#   'Wins': 16,
#   'Nominations': 16,
#   'Genres': ['News', 'Documentary', 'Drama', 'History']},
#  {'Title': 'The Queen of Versailles',
#   'Year': '2012',
#   'Director': 'Lauren Greenfield',
#   'Link': 'https://www.imdb.com/title/tt2125666/',
#   'Rating': '7.1',
#   'Wins': 8,
#   'Nominations': 27,
#   'Genres': ['Documentary']},
#  {'Title': 'West of Memphis',
#   'Year': '2012',
#   'Director': 'Amy Berg',
#   'Link': 'https://www.imdb.com/title/tt2130321/',
#   'Rating': '7.9',
#   'Wins': 1,
#   'Nominations': 10,
#   'Genres': ['Crime Documentary', 'Crime', 'Documentary']},
#  {'Title': 'Brooklyn Castle',
#   'Year': '2012',
#   'Director': 'Katie Dellamaggiore',
#   'Link': 'https://www.imdb.com/title/tt1800266/',
#   'Rating': '7.2',
#   'Wins': 3,
#   'Nominations': 3,
#   'Genres': ['Documentary']},
#  {'Title': 'Sister',
#   'Year': '2012',
#   'Director': 'Ursula Meier',
#   'Link': 'https://www.imdb.com/title/tt2062969/',
#   'Rating': '7.0',
#   'Wins': 12,
#   'Nominations': 10,
#   'Genres': ['Crime', 'Drama']},
#  {'Title': 'Ai Weiwei: Never Sorry',
#   'Year': '2012',
#   'Director': 'Alison Klayman',
#   'Link': 'https://www.imdb.com/title/tt1845773/',
#   'Rating': '7.5',
#   'Wins': 9,
#   'Nominations': 15,
#   'Genres': ['Documentary']},
#  {'Title': 'Lore',
#   'Year': '2012',
#   'Director': 'Cate Shortland',
#   'Link': 'https://www.imdb.com/title/tt1996310/',
#   'Rating': '7.1',
#   'Wins': 34,
#   'Nominations': 34,
#   'Genres': ['Drama', 'Romance', 'War']},
#  {'Title': 'Stories We Tell',
#   'Year': '2012',
#   'Director': 'Sarah Polley',
#   'Link': 'https://www.imdb.com/title/tt2366450/',
#   'Rating': '7.5',
#   'Wins': 25,
#   'Nominations': 44,
#   'Genres': ['Documentary']},
#  {'Title': 'Wadjda',
#   'Year': '2012',
#   'Director': 'Haifaa Al-Mansour',
#   'Link': 'https://www.imdb.com/title/tt2258858/',
#   'Rating': '7.5',
#   'Wins': 22,
#   'Nominations': 36,
#   'Genres': ['Coming-of-Age', 'Comedy', 'Drama']},
#  {'Title': 'Call Me Kuchu',
#   'Year': '2012',
#   'Director': 'Katherine Fairfax Wright',
#   'Link': 'https://www.imdb.com/title/tt2088714/',
#   'Rating': '7.6',
#   'Wins': 16,
#   'Nominations': 13,
#   'Genres': ['Documentary']},
#  {'Title': 'Pariah',
#   'Year': '2011',
#   'Director': 'Dee Rees',
#   'Link': 'https://www.imdb.com/title/tt1233334/',
#   'Rating': '7.2',
#   'Wins': 14,
#   'Nominations': 30,
#   'Genres': ['Coming-of-Age', 'Teen Drama', 'Drama']},
#  {'Title': "Being Elmo: A Puppeteer's Journey",
#   'Year': '2011',
#   'Director': 'Constance Marks',
#   'Link': 'https://www.imdb.com/title/tt1787660/',
#   'Rating': '7.6',
#   'Wins': 8,
#   'Nominations': 8,
#   'Genres': ['Biography', 'Documentary']},
#  {'Title': 'Tomboy',
#   'Year': '2011',
#   'Director': 'Céline Sciamma',
#   'Link': 'https://www.imdb.com/title/tt1847731/',
#   'Rating': '7.4',
#   'Wins': 10,
#   'Nominations': 6,
#   'Genres': ['Coming-of-Age', 'Drama']},
#  {'Title': 'First Position',
#   'Year': '2011',
#   'Director': 'Bess Kargman',
#   'Link': 'https://www.imdb.com/title/tt2008513/',
#   'Rating': '7.5',
#   'Wins': 5,
#   'Nominations': 9,
#   'Genres': ['Documentary']},
#  {'Title': 'Turn Me On, Dammit!',
#   'Year': '2011',
#   'Director': 'Jannicke Systad Jacobsen',
#   'Link': 'https://www.imdb.com/title/tt1650407/',
#   'Rating': '6.3',
#   'Wins': 5,
#   'Nominations': 7,
#   'Genres': ['Comedy', 'Romance']},
#  {'Title': 'Sing Your Song',
#   'Year': '2011',
#   'Director': 'Susanne Rostock',
#   'Link': 'https://www.imdb.com/title/tt1787797/',
#   'Rating': '7.5',
#   'Wins': 5,
#   'Nominations': 2,
#   'Genres': ['Biography', 'Documentary', 'Music']},
#  {'Title': 'Diana Vreeland: The Eye Has to Travel',
#   'Year': '2011',
#   'Director': 'Lisa Immordino Vreeland',
#   'Link': 'https://www.imdb.com/title/tt2053352/',
#   'Rating': '7.5',
#   'Wins': 1,
#   'Nominations': 3,
#   'Genres': ['Biography', 'Documentary']},
#  {'Title': 'The Kids Are All Right',
#   'Year': '2010',
#   'Director': 'Lisa Cholodenko',
#   'Link': 'https://www.imdb.com/title/tt0842926/',
#   'Rating': '7.0',
#   'Wins': 29,
#   'Nominations': 133,
#   'Genres': ['Comedy', 'Drama', 'Romance']},
#  {'Title': "Winter's Bone",
#   'Year': '2010',
#   'Director': 'Debra Granik',
#   'Link': 'https://www.imdb.com/title/tt1399683/',
#   'Rating': '7.1',
#   'Wins': 63,
#   'Nominations': 131,
#   'Genres': ['Mountain Adventure',
#    'Quest',
#    'Survival',
#    'Suspense Mystery',
#    'Teen Drama',
#    'Crime',
#    'Drama',
#    'Mystery',
#    'Thriller']},
#  {'Title': 'Waste Land',
#   'Year': '2010',
#   'Director': 'Lucy Walker',
#   'Link': 'https://www.imdb.com/title/tt1268204/',
#   'Rating': '7.8',
#   'Wins': 29,
#   'Nominations': 13,
#   'Genres': ['Documentary']},
#  {'Title': 'The Arbor',
#   'Year': '2010',
#   'Director': 'Clio Barnard',
#   'Link': 'https://www.imdb.com/title/tt1623008/',
#   'Rating': '7.3',
#   'Wins': 8,
#   'Nominations': 26,
#   'Genres': ['Biography', 'Documentary', 'Drama']},
#  {'Title': 'Yoo-Hoo, Mrs. Goldberg',
#   'Year': '2009',
#   'Director': 'Aviva Kempner',
#   'Link': 'https://www.imdb.com/title/tt1334479/',
#   'Rating': '7.4',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': ['Biography', 'Documentary']},
#  {'Title': 'An Education',
#   'Year': '2009',
#   'Director': 'Lone Scherfig',
#   'Link': 'https://www.imdb.com/title/tt1174732/',
#   'Rating': '7.2',
#   'Wins': 36,
#   'Nominations': 96,
#   'Genres': ['Coming-of-Age', 'Drama']},
#  {'Title': 'The Most Dangerous Man in America: Daniel Ellsberg and the Pentagon Papers',
#   'Year': '2009',
#   'Director': 'Judith Ehrlich',
#   'Link': 'https://www.imdb.com/title/tt1319726/',
#   'Rating': '7.7',
#   'Wins': 5,
#   'Nominations': 3,
#   'Genres': ['Documentary']},
#  {'Title': 'Sweetgrass',
#   'Year': '2009',
#   'Director': 'Lucien Castaing-Taylor',
#   'Link': 'https://www.imdb.com/title/tt1517252/',
#   'Rating': '6.8',
#   'Wins': 1,
#   'Nominations': 10,
#   'Genres': ['Adventure', 'Documentary', 'Western']},
#  {'Title': 'Afghan Star',
#   'Year': '2009',
#   'Director': 'Havana Marking',
#   'Link': 'https://www.imdb.com/title/tt1334510/',
#   'Rating': '7.2',
#   'Wins': 3,
#   'Nominations': 3,
#   'Genres': ['Documentary', 'Music']},
#  {'Title': 'A Film Unfinished',
#   'Year': '2009',
#   'Director': 'Yael Hersonski',
#   'Link': 'https://www.imdb.com/title/tt1568923/',
#   'Rating': '7.4',
#   'Wins': 6,
#   'Nominations': 11,
#   'Genres': ['Documentary', 'Drama', 'History']},
#  {'Title': 'Trouble the Water',
#   'Year': '2008',
#   'Director': 'Carl Deal',
#   'Link': 'https://www.imdb.com/title/tt1149405/',
#   'Rating': '7.3',
#   'Wins': 7,
#   'Nominations': 14,
#   'Genres': ['Documentary']},
#  {'Title': 'The Beaches of Agnès',
#   'Year': '2008',
#   'Director': 'Agnès Varda',
#   'Link': 'https://www.imdb.com/title/tt1129435/',
#   'Rating': '8.0',
#   'Wins': 12,
#   'Nominations': 13,
#   'Genres': ['Biography', 'Documentary']},
#  {'Title': '35 Shots of Rum',
#   'Year': '2008',
#   'Director': 'Claire Denis',
#   'Link': 'https://www.imdb.com/title/tt1100048/',
#   'Rating': '7.1',
#   'Wins': 2,
#   'Nominations': 17,
#   'Genres': ['Coming-of-Age', 'Drama']},
#  {'Title': 'The Hurt Locker',
#   'Year': '2008',
#   'Director': 'Kathryn Bigelow',
#   'Link': 'https://www.imdb.com/title/tt0887912/',
#   'Rating': '7.5',
#   'Wins': 125,
#   'Nominations': 130,
#   'Genres': ['Psychological Drama', 'Drama', 'Thriller', 'War']},
#  {'Title': 'Persepolis',
#   'Year': '2007',
#   'Director': 'Marjane Satrapi',
#   'Link': 'https://www.imdb.com/title/tt0808417/',
#   'Rating': '8.0',
#   'Wins': 29,
#   'Nominations': 58,
#   'Genres': ['Adult Animation',
#    'Coming-of-Age',
#    'Docudrama',
#    'Period Drama',
#    'Teen Drama',
#    'Animation',
#    'Biography',
#    'Drama',
#    'History',
#    'War']},
#  {'Title': 'The Devil Came on Horseback',
#   'Year': '2007',
#   'Director': 'Ricki Stern',
#   'Link': 'https://www.imdb.com/title/tt0912580/',
#   'Rating': '7.6',
#   'Wins': 5,
#   'Nominations': 5,
#   'Genres': ['Documentary']},
#  {'Title': 'Blame It on Fidel',
#   'Year': '2006',
#   'Director': 'Julie Gavras',
#   'Link': 'https://www.imdb.com/title/tt0792966/',
#   'Rating': '7.5',
#   'Wins': 1,
#   'Nominations': 5,
#   'Genres': ['Drama']},
#  {'Title': 'Deep Water',
#   'Year': '2006',
#   'Director': 'Louise Osmond',
#   'Link': 'https://www.imdb.com/title/tt0460766/',
#   'Rating': '7.8',
#   'Wins': 4,
#   'Nominations': 2,
#   'Genres': ['Sports Documentary',
#    'Water Sport',
#    'Documentary',
#    'History',
#    'Sport']},
#  {'Title': 'Blindsight',
#   'Year': '2006',
#   'Director': 'Lucy Walker',
#   'Link': 'https://www.imdb.com/title/tt0841084/',
#   'Rating': '7.2',
#   'Wins': 4,
#   'Nominations': 2,
#   'Genres': ['Mountain Adventure',
#    'Nature Documentary',
#    'Travel Documentary',
#    'Adventure',
#    'Documentary']},
#  {'Title': 'The War Tapes',
#   'Year': '2006',
#   'Director': 'Deborah Scranton',
#   'Link': 'https://www.imdb.com/title/tt0775566/',
#   'Rating': '7.2',
#   'Wins': 2,
#   'Nominations': 1,
#   'Genres': ['Military Documentary', 'Documentary', 'War']},
#  {'Title': 'Away From Her',
#   'Year': '2006',
#   'Director': 'Sarah Polley',
#   'Link': 'https://www.imdb.com/title/tt0491747/',
#   'Rating': '7.5',
#   'Wins': 62,
#   'Nominations': 43,
#   'Genres': ['Drama']},
#  {'Title': 'Grbavica: The Land of My Dreams',
#   'Year': '2006',
#   'Director': 'Jasmila Zbanic',
#   'Link': 'https://www.imdb.com/title/tt0464029/',
#   'Rating': '7.2',
#   'Wins': 12,
#   'Nominations': 7,
#   'Genres': ['Drama']},
#  {'Title': 'Control Room',
#   'Year': '2004',
#   'Director': 'Jehane Noujaim',
#   'Link': 'https://www.imdb.com/title/tt0391024/',
#   'Rating': '7.6',
#   'Wins': 9,
#   'Nominations': 10,
#   'Genres': ['Military Documentary', 'Documentary']},
#  {'Title': 'Born Into Brothels',
#   'Year': '2004',
#   'Director': 'Zana Briski',
#   'Link': 'https://www.imdb.com/title/tt0388789/',
#   'Rating': '7.2',
#   'Wins': 21,
#   'Nominations': 5,
#   'Genres': ['News', 'Biography', 'Documentary']},
#  {'Title': 'American Splendor',
#   'Year': '2003',
#   'Director': 'Shari Springer Berman',
#   'Link': 'https://www.imdb.com/title/tt0305206/',
#   'Rating': '7.4',
#   'Wins': 31,
#   'Nominations': 50,
#   'Genres': ['Biography', 'Comedy', 'Drama']},
#  {'Title': 'Lost in Translation',
#   'Year': '2003',
#   'Director': 'Sofia Coppola',
#   'Link': 'https://www.imdb.com/title/tt0335266/',
#   'Rating': '7.7',
#   'Wins': 97,
#   'Nominations': 133,
#   'Genres': ['Coming-of-Age', 'Comedy', 'Drama']},
#  {'Title': 'The Revolution Will Not Be Televised',
#   'Year': '2003',
#   'Director': 'Kim Bartley',
#   'Link': 'https://www.imdb.com/title/tt9063104/',
#   'Rating': '7.1',
#   'Wins': None,
#   'Nominations': None,
#   'Genres': ['Biography']},
#  {'Title': 'The Story of the Weeping Camel',
#   'Year': '2003',
#   'Director': 'Byambasuren Davaa',
#   'Link': 'https://www.imdb.com/title/tt0373861/',
#   'Rating': '7.4',
#   'Wins': 10,
#   'Nominations': 9,
#   'Genres': ['Documentary', 'Drama', 'Family']},
#  {'Title': 'Lost Boys of Sudan',
#   'Year': '2003',
#   'Director': 'Megan Mylan',
#   'Link': 'https://www.imdb.com/title/tt0383475/',
#   'Rating': '7.5',
#   'Wins': 3,
#   'Nominations': 3,
#   'Genres': ['Documentary']},
#  {'Title': 'Since Otar Left',
#   'Year': '2003',
#   'Director': 'Julie Bertuccelli',
#   'Link': 'https://www.imdb.com/title/tt0336264/',
#   'Rating': '7.5',
#   'Wins': 12,
#   'Nominations': 6,
#   'Genres': ['Drama']},
#  {'Title': 'The Wild Parrots of Telegraph Hill',
#   'Year': '2003',
#   'Director': 'Judy Irving',
#   'Link': 'https://www.imdb.com/title/tt0424565/',
#   'Rating': '7.8',
#   'Wins': 4,
#   'Nominations': 2,
#   'Genres': ['Documentary']},
#  {'Title': 'Open Hearts',
#   'Year': '2002',
#   'Director': 'Susanne Bier',
#   'Link': 'https://www.imdb.com/title/tt0315543/',
#   'Rating': '7.5',
#   'Wins': 12,
#   'Nominations': 12,
#   'Genres': ['Drama', 'Romance']},
#  {'Title': 'Monsoon Wedding',
#   'Year': '2001',
#   'Director': 'Mira Nair',
#   'Link': 'https://www.imdb.com/title/tt0265343/',
#   'Rating': '7.3',
#   'Wins': 7,
#   'Nominations': 12,
#   'Genres': ['Feel-Good Romance',
#    'Romantic Comedy',
#    'Comedy',
#    'Drama',
#    'Romance']},
#  {'Title': 'Promises',
#   'Year': '2001',
#   'Director': 'Justine Shapiro',
#   'Link': 'https://www.imdb.com/title/tt0282864/',
#   'Rating': '8.3',
#   'Wins': 15,
#   'Nominations': 5,
#   'Genres': ['Documentary']},
#  {'Title': 'The Taste of Others',
#   'Year': '2000',
#   'Director': 'Agnès Jaoui',
#   'Link': 'https://www.imdb.com/title/tt0216787/',
#   'Rating': '7.2',
#   'Wins': 16,
#   'Nominations': 12,
#   'Genres': ['Comedy', 'Drama', 'Romance']},
#  {'Title': 'The Gleaners and I',
#   'Year': '2000',
#   'Director': 'Agnès Varda',
#   'Link': 'https://www.imdb.com/title/tt0247380/',
#   'Rating': '7.7',
#   'Wins': 16,
#   'Nominations': 3,
#   'Genres': ['Documentary']},
#  {'Title': 'The Life and Times of Hank Greenberg',
#   'Year': '1999',
#   'Director': 'Aviva Kempner',
#   'Link': 'https://www.imdb.com/title/tt0208261/',
#   'Rating': '7.6',
#   'Wins': 12,
#   'Nominations': 8,
#   'Genres': ['Baseball',
#    'Sports Documentary',
#    'Biography',
#    'Documentary',
#    'Sport']}]
